# %%
include("shared.jl");

# %% [markdown]
# ## Problem 501: Eight Divisors
# <p>The eight divisors of 24 are 1, 2, 3, 4, 6, 8, 12 and 24.
# The ten numbers not exceeding 100 having exactly eight divisors are 24, 30, 40, 42, 54, 56, 66, 70, 78 and 88.
# Let <var>f</var>(<var>n</var>) be the count of numbers not exceeding <var>n</var> with exactly eight divisors.<br>
# You are given <var>f</var>(100)&nbsp;=&nbsp;10, <var>f</var>(1000)&nbsp;=&nbsp;180 and <var>f</var>(10<sup>6</sup>)&nbsp;=&nbsp;224427.<br>
# Find <var>f</var>(10<sup>12</sup>).</p>

# %%
submit_answer(answer; prob_num=501);

# %% [markdown]
# ## Problem 502: Counting Castles
# <p>We define a <i>block</i> to be a rectangle with a height of 1 and an integer-valued length. Let a <i>castle</i> be a configuration of stacked blocks.</p>
#
# <p>Given a game grid that is <var>w</var> units wide and <var>h</var> units tall, a castle is generated according to the following rules:</p>
#
#
# <ol><li>Blocks can be placed on top of other blocks as long as nothing sticks out past the edges or hangs out over open space.</li>
# <li>All blocks are aligned/snapped to the grid.</li>
# <li>Any two neighboring blocks on the same row have at least one unit of space between them.</li>
# <li>The bottom row is occupied by a block of length <var>w</var>.</li>
# <li>The maximum achieved height of the entire castle is exactly <var>h</var>.</li>
# <li>The castle is made from an even number of blocks.</li>
# </ol><p>The following is a sample castle for <var>w</var>=8 and <var>h</var>=5:</p>
#
# <p align="center"><img src="webfiles/p502_castles.png" alt="p502_castles.png"></p>
#
# <p>Let F(<var>w</var>,<var>h</var>) represent the number of valid castles, given grid parameters <var>w</var> and <var>h</var>.</p>
#
# <p>For example, F(4,2) = 10, F(13,10) = 3729050610636, F(10,13) = 37959702514, and F(100,100) mod 1 000 000 007 = 841913936.</p>
#
# <p>Find (F(10<sup>12</sup>,100) + F(10000,10000) + F(100,10<sup>12</sup>)) mod 1 000 000 007.</p>

# %%
submit_answer(answer; prob_num=502);

# %% [markdown]
# ## Problem 503: Compromise or persist
# <p>Alice is playing a game with <var>n</var> cards numbered 1 to <var>n</var>.</p>
#
# <p>A game consists of iterations of the following steps.<br>
# (1) Alice picks one of the cards at random.<br>
# (2) Alice cannot see the number on it. Instead, Bob, one of her friends,
#  sees the number and tells Alice how many previously-seen numbers are
# bigger than the number which he is seeing.<br>
# (3) Alice can end or continue the game. If she decides to end, the
# number becomes her score. If she decides to continue, the card is
# removed from the game and she returns to (1). If there is no card left,
# she is forced to end the game.<br></p>
#
# "<p>Let F(<var>n</var>) be the Alice's expected score if she takes the optimized strategy to <b>minimize</b> her score.</p>"
#
# <p>For example, F(3) = 5/3. At the first iteration, she should continue
# the game. At the second iteration, she should end the game if Bob says
# that one previously-seen number is bigger than the number which he is
# seeing, otherwise she should continue the game.</p>
#
# <p>We can also verify that F(4) = 15/8 and F(10) ≈ 2.5579365079.</p>
#
# <p>Find F(10<sup>6</sup>). Give your answer rounded to 10 decimal places behind the decimal point.</p>

# %%
submit_answer(answer; prob_num=503);

# %% [markdown]
# ## Problem 504: Square on the Inside
# <p>Let <var>ABCD</var> be a quadrilateral whose vertices are lattice points lying on the coordinate axes as follows:</p>
#
# <p><var>A</var>(<var>a</var>, 0), <var>B</var>(0, <var>b</var>), <var>C</var>(<var>−c</var>, 0), <var>D</var>(0, <var>−d</var>), where 1 ≤ <var>a</var>, <var>b</var>, <var>c</var>, <var>d</var> ≤ <var>m</var> and <var>a</var>, <var>b</var>, <var>c</var>, <var>d</var>, <var>m</var> are integers.</p>
#
# <p>It can be shown that for <var>m</var> = 4 there are exactly 256 valid ways to construct <var>ABCD</var>. Of these 256 quadrilaterals, 42 of them <u>strictly</u> contain a square number of lattice points.</p>
#
# <p>How many quadrilaterals <var>ABCD</var> strictly contain a square number of lattice points for <var>m</var> = 100?</p>

# %%
submit_answer(answer; prob_num=504);

# %% [markdown]
# ## Problem 505: Bidirectional Recurrence
# <p>Let:</p>
# <p style="margin-left:32px;"><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-113-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mtable columnalign="left left" rowspacing="4pt" columnspacing="1em"&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230A;&lt;/mo&gt;&lt;mfrac&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230B;&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;mod&amp;#xA0;&lt;/mtext&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mtext&gt;&amp;#xA0;for&amp;#xA0;&lt;/mtext&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mtext&gt;, where&amp;#xA0;&lt;/mtext&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230A;&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;&lt;/mtext&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230B;&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;is the floor function&lt;/mtext&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230A;&lt;/mo&gt;&lt;mfrac&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230B;&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;mod&amp;#xA0;&lt;/mtext&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mtext&gt;&amp;#xA0;for&amp;#xA0;&lt;/mtext&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mrow&gt;&lt;mo&gt;{&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mtable columnalign="left center" rowspacing="4pt" columnspacing="1em"&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd /&gt;&lt;mtd&gt;&lt;mtext&gt;if&amp;#xA0;&lt;/mtext&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd /&gt;&lt;mtd&gt;&lt;mtext&gt;if&amp;#xA0;&lt;/mtext&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;/mtable&gt;&lt;/mrow&gt;&lt;mo fence="true" stretchy="true" symmetric="true"&gt;&lt;/mo&gt;&lt;/mrow&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;/mtable&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-1923" style="width: 46.366em; display: inline-block;"><span style="display: inline-block; position: relative; width: 35.12em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(-3.318em, 1034.94em, 7.22em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-1924"><span class="mtable" id="MathJax-Span-1925" style="padding-right: 0.167em; padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 34.807em; height: 0px;"><span style="position: absolute; clip: rect(5.727em, 1004em, 16.216em, -1000em); top: -11.196em; left: 0em;"><span style="display: inline-block; position: relative; width: 4.093em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001.76em, 4.413em, -1000em); top: -8.595em; left: 0em;"><span class="mtd" id="MathJax-Span-1926"><span class="mrow" id="MathJax-Span-1927"><span class="mi" id="MathJax-Span-1928" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-1929" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-1930" style="font-family: MathJax_Main;">0</span><span class="mo" id="MathJax-Span-1931" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1001.76em, 4.413em, -1000em); top: -7.145em; left: 0em;"><span class="mtd" id="MathJax-Span-1936"><span class="mrow" id="MathJax-Span-1937"><span class="mi" id="MathJax-Span-1938" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-1939" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-1940" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-1941" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.28em, 4.413em, -1000em); top: -5.597em; left: 0em;"><span class="mtd" id="MathJax-Span-1946"><span class="mrow" id="MathJax-Span-1947"><span class="mi" id="MathJax-Span-1948" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-1949" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-1950" style="font-family: MathJax_Main;">2</span><span class="mi" id="MathJax-Span-1951" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-1952" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1004em, 4.413em, -1000em); top: -3.928em; left: 0em;"><span class="mtd" id="MathJax-Span-1988"><span class="mrow" id="MathJax-Span-1989"><span class="mi" id="MathJax-Span-1990" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-1991" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-1992" style="font-family: MathJax_Main;">2</span><span class="mi" id="MathJax-Span-1993" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-1994" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-1995" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-1996" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.19em, 4.413em, -1000em); top: -1.625em; left: 0em;"><span class="mtd" id="MathJax-Span-2027"><span class="mrow" id="MathJax-Span-2028"><span class="msubsup" id="MathJax-Span-2029"><span style="display: inline-block; position: relative; width: 0.989em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2030" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mi" id="MathJax-Span-2031" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2032" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2033" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2034" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.03em, 4.413em, -1000em); top: 0.607em; left: 0em;"><span class="mtd" id="MathJax-Span-2098"><span class="mrow" id="MathJax-Span-2099"><span class="mi" id="MathJax-Span-2100" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-2101" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2102" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2103" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 11.196em;"></span></span><span style="position: absolute; clip: rect(5.715em, 1029.7em, 16.12em, -1000em); top: -11.1em; left: 5.093em;"><span style="display: inline-block; position: relative; width: 29.714em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1001.52em, 4.185em, -1000em); top: -8.595em; left: 0em;"><span class="mtd" id="MathJax-Span-1932"><span class="mrow" id="MathJax-Span-1933"><span class="mo" id="MathJax-Span-1934" style="font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-1935" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.21em, 1001.48em, 4.163em, -1000em); top: -7.145em; left: 0em;"><span class="mtd" id="MathJax-Span-1942"><span class="mrow" id="MathJax-Span-1943"><span class="mo" id="MathJax-Span-1944" style="font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-1945" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.977em, 1029.7em, 4.533em, -1000em); top: -5.597em; left: 0em;"><span class="mtd" id="MathJax-Span-1953"><span class="mrow" id="MathJax-Span-1954"><span class="mo" id="MathJax-Span-1955" style="font-family: MathJax_Main;">=</span><span class="mo" id="MathJax-Span-1956" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="mn" id="MathJax-Span-1957" style="font-family: MathJax_Main;">3</span><span class="mi" id="MathJax-Span-1958" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-1959" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-1960" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-1961" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-1962" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-1963" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mi" id="MathJax-Span-1964" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-1965" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-1966" style="font-family: MathJax_Main;">⌊</span><span class="mfrac" id="MathJax-Span-1967"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -4.427em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-1968" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-1969" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-1970" style="font-family: MathJax_Main;">⌋</span><span class="mo" id="MathJax-Span-1971" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-1972" style="font-family: MathJax_Main;">)</span><span class="mtext" id="MathJax-Span-1973" style="font-family: MathJax_Main;">&nbsp;mod&nbsp;</span><span class="msubsup" id="MathJax-Span-1974"><span style="display: inline-block; position: relative; width: 1.282em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-1975" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="texatom" id="MathJax-Span-1976"><span class="mrow" id="MathJax-Span-1977"><span class="mn" id="MathJax-Span-1978" style="font-size: 70.7%; font-family: MathJax_Main;">60</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mtext" id="MathJax-Span-1979" style="font-family: MathJax_Main;">&nbsp;for&nbsp;</span><span class="mi" id="MathJax-Span-1980" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-1981" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-1982" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span><span class="mtext" id="MathJax-Span-1983" style="font-family: MathJax_Main;">, where&nbsp;</span><span class="mo" id="MathJax-Span-1984" style="font-family: MathJax_Main;">⌊</span><span class="mtext" id="MathJax-Span-1985" style="font-family: MathJax_Main;">&nbsp;</span><span class="mo" id="MathJax-Span-1986" style="font-family: MathJax_Main;">⌋</span><span class="mtext" id="MathJax-Span-1987" style="font-family: MathJax_Main;">&nbsp;is the floor function</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.977em, 1016.54em, 4.533em, -1000em); top: -3.928em; left: 0em;"><span class="mtd" id="MathJax-Span-1997"><span class="mrow" id="MathJax-Span-1998"><span class="mo" id="MathJax-Span-1999" style="font-family: MathJax_Main;">=</span><span class="mo" id="MathJax-Span-2000" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="mn" id="MathJax-Span-2001" style="font-family: MathJax_Main;">2</span><span class="mi" id="MathJax-Span-2002" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2003" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2004" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2005" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2006" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-2007" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mi" id="MathJax-Span-2008" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2009" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-2010" style="font-family: MathJax_Main;">⌊</span><span class="mfrac" id="MathJax-Span-2011"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -4.427em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-2012" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-2013" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-2014" style="font-family: MathJax_Main;">⌋</span><span class="mo" id="MathJax-Span-2015" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2016" style="font-family: MathJax_Main;">)</span><span class="mtext" id="MathJax-Span-2017" style="font-family: MathJax_Main;">&nbsp;mod&nbsp;</span><span class="msubsup" id="MathJax-Span-2018"><span style="display: inline-block; position: relative; width: 1.282em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2019" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="texatom" id="MathJax-Span-2020"><span class="mrow" id="MathJax-Span-2021"><span class="mn" id="MathJax-Span-2022" style="font-size: 70.7%; font-family: MathJax_Main;">60</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mtext" id="MathJax-Span-2023" style="font-family: MathJax_Main;">&nbsp;for&nbsp;</span><span class="mi" id="MathJax-Span-2024" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2025" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-2026" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.344em, 1022.16em, 5.195em, -1000em); top: -1.625em; left: 0em;"><span class="mtd" id="MathJax-Span-2035"><span class="mrow" id="MathJax-Span-2036"><span class="mo" id="MathJax-Span-2037" style="font-family: MathJax_Main;">=</span><span class="mrow" id="MathJax-Span-2038" style="padding-left: 0.278em;"><span class="mo" id="MathJax-Span-2039" style="vertical-align: 0em;"><span style="font-family: MathJax_Size3;">{</span></span><span class="texatom" id="MathJax-Span-2040"><span class="mrow" id="MathJax-Span-2041"><span class="mtable" id="MathJax-Span-2042" style="padding-right: 0.167em; padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 20.016em; height: 0px;"><span style="position: absolute; clip: rect(2.394em, 1014.63em, 5.195em, -1000em); top: -4.019em; left: 0em;"><span style="display: inline-block; position: relative; width: 14.727em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001.78em, 4.413em, -1000em); top: -4.751em; left: 0em;"><span class="mtd" id="MathJax-Span-2043"><span class="mrow" id="MathJax-Span-2044"><span class="mi" id="MathJax-Span-2045" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2046" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2047" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2048" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.012em, 1014.63em, 4.413em, -1000em); top: -3.237em; left: 0em;"><span class="mtd" id="MathJax-Span-2057"><span class="mrow" id="MathJax-Span-2058"><span class="msubsup" id="MathJax-Span-2059"><span style="display: inline-block; position: relative; width: 1.282em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2060" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="texatom" id="MathJax-Span-2061"><span class="mrow" id="MathJax-Span-2062"><span class="mn" id="MathJax-Span-2063" style="font-size: 70.7%; font-family: MathJax_Main;">60</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2064" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-2065" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-2066" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mi" id="MathJax-Span-2067" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">m</span><span class="mi" id="MathJax-Span-2068" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-2069" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2070" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-2071"><span style="display: inline-block; position: relative; width: 0.989em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2072" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mi" id="MathJax-Span-2073" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2074" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2075" style="font-family: MathJax_Main;">2</span><span class="mi" id="MathJax-Span-2076" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2077" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2078" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2079" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.989em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2080" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mi" id="MathJax-Span-2081" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2082" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2083" style="font-family: MathJax_Main;">2</span><span class="mi" id="MathJax-Span-2084" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2085" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-2086" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-2087" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2088" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.144em, 1000em, 4.945em, -1000em); top: -4.019em; left: 15.727em;"><span style="display: inline-block; position: relative; width: 0em; height: 0px;"><span style="position: absolute; clip: rect(3.876em, 1000em, 4.163em, -1000em); top: -4.751em; left: 50%; margin-left: 0em;"><span class="mtd" id="MathJax-Span-2049"><span class="mrow" id="MathJax-Span-2050"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.876em, 1000em, 4.163em, -1000em); top: -3.237em; left: 50%; margin-left: 0em;"><span class="mtd" id="MathJax-Span-2089"><span class="mrow" id="MathJax-Span-2090"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.439em, 1003.27em, 4.985em, -1000em); top: -4.019em; left: 16.727em;"><span style="display: inline-block; position: relative; width: 3.289em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1003.27em, 4.301em, -1000em); top: -4.751em; left: 50%; margin-left: -1.645em;"><span class="mtd" id="MathJax-Span-2051"><span class="mrow" id="MathJax-Span-2052"><span class="mtext" id="MathJax-Span-2053" style="font-family: MathJax_Main;">if&nbsp;</span><span class="mi" id="MathJax-Span-2054" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2055" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mi" id="MathJax-Span-2056" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.171em, 1003.27em, 4.203em, -1000em); top: -3.237em; left: 50%; margin-left: -1.645em;"><span class="mtd" id="MathJax-Span-2091"><span class="mrow" id="MathJax-Span-2092"><span class="mtext" id="MathJax-Span-2093" style="font-family: MathJax_Main;">if&nbsp;</span><span class="mi" id="MathJax-Span-2094" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2095" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-2096" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span><span class="mo" id="MathJax-Span-2097"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1003.23em, 4.413em, -1000em); top: 0.607em; left: 0em;"><span class="mtd" id="MathJax-Span-2104"><span class="mrow" id="MathJax-Span-2105"><span class="mo" id="MathJax-Span-2106" style="font-family: MathJax_Main;">=</span><span class="msubsup" id="MathJax-Span-2107" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.989em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2108" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mi" id="MathJax-Span-2109" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2110" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2111" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-2112" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 11.1em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -6.499em; border-left: 0px solid; width: 0px; height: 13.658em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mtable columnalign="left left" rowspacing="4pt" columnspacing="1em"><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mn>0</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mn>0</mn></mtd></mtr><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mn>1</mn></mtd></mtr><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mn>2</mn><mi>k</mi><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mo stretchy="false">(</mo><mn>3</mn><mi>x</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>+</mo><mn>2</mn><mi>x</mi><mo stretchy="false">(</mo><mo fence="false" stretchy="false">⌊</mo><mfrac><mi>k</mi><mn>2</mn></mfrac><mo fence="false" stretchy="false">⌋</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mtext>&nbsp;mod&nbsp;</mtext><msup><mn>2</mn><mrow class="MJX-TeXAtom-ORD"><mn>60</mn></mrow></msup><mtext>&nbsp;for&nbsp;</mtext><mi>k</mi><mo>≥</mo><mn>1</mn><mtext>, where&nbsp;</mtext><mo fence="false" stretchy="false">⌊</mo><mtext>&nbsp;</mtext><mo fence="false" stretchy="false">⌋</mo><mtext>&nbsp;is the floor function</mtext></mtd></mtr><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mn>2</mn><mi>k</mi><mo>+</mo><mn>1</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mo stretchy="false">(</mo><mn>2</mn><mi>x</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>+</mo><mn>3</mn><mi>x</mi><mo stretchy="false">(</mo><mo fence="false" stretchy="false">⌊</mo><mfrac><mi>k</mi><mn>2</mn></mfrac><mo fence="false" stretchy="false">⌋</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mtext>&nbsp;mod&nbsp;</mtext><msup><mn>2</mn><mrow class="MJX-TeXAtom-ORD"><mn>60</mn></mrow></msup><mtext>&nbsp;for&nbsp;</mtext><mi>k</mi><mo>≥</mo><mn>1</mn></mtd></mtr><mtr><mtd><msub><mi>y</mi><mi>n</mi></msub><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mrow><mo>{</mo><mrow class="MJX-TeXAtom-ORD"><mtable columnalign="left center" rowspacing="4pt" columnspacing="1em"><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></mtd><mtd></mtd><mtd><mtext>if&nbsp;</mtext><mi>k</mi><mo>≥</mo><mi>n</mi></mtd></mtr><mtr><mtd><msup><mn>2</mn><mrow class="MJX-TeXAtom-ORD"><mn>60</mn></mrow></msup><mo>−</mo><mn>1</mn><mo>−</mo><mi>m</mi><mi>a</mi><mi>x</mi><mo stretchy="false">(</mo><msub><mi>y</mi><mi>n</mi></msub><mo stretchy="false">(</mo><mn>2</mn><mi>k</mi><mo stretchy="false">)</mo><mo>,</mo><msub><mi>y</mi><mi>n</mi></msub><mo stretchy="false">(</mo><mn>2</mn><mi>k</mi><mo>+</mo><mn>1</mn><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd></mtd><mtd><mtext>if&nbsp;</mtext><mi>k</mi><mo>&lt;</mo><mi>n</mi></mtd></mtr></mtable></mrow><mo fence="true" stretchy="true" symmetric="true"></mo></mrow></mtd></mtr><mtr><mtd><mi>A</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><msub><mi>y</mi><mi>n</mi></msub><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo></mtd></mtr></mtable></math></span></span><script type="math/tex" id="MathJax-Element-113">\\begin{array}{ll} x(0)&=0 \\\\ x(1)&=1 \\\\ x(2k)&=(3x(k)+2x(\\lfloor \\frac k 2 \\rfloor)) \\text{ mod } 2^{60} \\text{ for } k \\ge 1 \\text {, where } \\lfloor \\text { } \\rfloor \\text { is the floor function} \\\\ x(2k+1)&=(2x(k)+3x(\\lfloor \\frac k 2 \\rfloor)) \\text{ mod } 2^{60} \\text{ for } k \\ge 1 \\\\ y_n(k)&=\\left\\{{\\begin{array}{lc} x(k) && \\text{if } k \\ge n \\\\ 2^{60} - 1 - max(y_n(2k),y_n(2k+1)) && \\text{if } k < n \\end{array}} \\right. \\\\ A(n)&=y_n(1) \\end{array}</script></p>
# <p>You are given:</p>
# <p style="margin-left:32px;"><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-114-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mtable columnalign="left left" rowspacing="4pt" columnspacing="1em"&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msub&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;34&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;101881&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;/mtable&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2113" style="width: 12.156em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.187em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(-4.645em, 1008.98em, 8.547em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-2114"><span class="mtable" id="MathJax-Span-2115" style="padding-right: 0.167em; padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 8.875em; height: 0px;"><span style="position: absolute; clip: rect(7.08em, 1002.86em, 20.222em, -1000em); top: -13.876em; left: 0em;"><span style="display: inline-block; position: relative; width: 2.957em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001.76em, 4.413em, -1000em); top: -9.922em; left: 0em;"><span class="mtd" id="MathJax-Span-2116"><span class="mrow" id="MathJax-Span-2117"><span class="mi" id="MathJax-Span-2118" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2119" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2120" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-2121" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1001.76em, 4.413em, -1000em); top: -8.472em; left: 0em;"><span class="mtd" id="MathJax-Span-2126"><span class="mrow" id="MathJax-Span-2127"><span class="mi" id="MathJax-Span-2128" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2129" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2130" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-2131" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1001.76em, 4.413em, -1000em); top: -7.022em; left: 0em;"><span class="mtd" id="MathJax-Span-2136"><span class="mrow" id="MathJax-Span-2137"><span class="mi" id="MathJax-Span-2138" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2139" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2140" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-2141" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.1em, 4.413em, -1000em); top: -5.572em; left: 0em;"><span class="mtd" id="MathJax-Span-2146"><span class="mrow" id="MathJax-Span-2147"><span class="msubsup" id="MathJax-Span-2148"><span style="display: inline-block; position: relative; width: 0.919em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2149" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mn" id="MathJax-Span-2150" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2151" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2152" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-2153" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.1em, 4.413em, -1000em); top: -4.058em; left: 0em;"><span class="mtd" id="MathJax-Span-2158"><span class="mrow" id="MathJax-Span-2159"><span class="msubsup" id="MathJax-Span-2160"><span style="display: inline-block; position: relative; width: 0.919em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2161" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mn" id="MathJax-Span-2162" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2163" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2164" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-2165" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.1em, 4.413em, -1000em); top: -2.544em; left: 0em;"><span class="mtd" id="MathJax-Span-2176"><span class="mrow" id="MathJax-Span-2177"><span class="msubsup" id="MathJax-Span-2178"><span style="display: inline-block; position: relative; width: 0.919em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2179" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mn" id="MathJax-Span-2180" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2181" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2182" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-2183" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.1em, 4.413em, -1000em); top: -1.094em; left: 0em;"><span class="mtd" id="MathJax-Span-2194"><span class="mrow" id="MathJax-Span-2195"><span class="msubsup" id="MathJax-Span-2196"><span style="display: inline-block; position: relative; width: 0.919em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2197" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.49em;"><span class="mn" id="MathJax-Span-2198" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2199" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2200" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-2201" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1002.43em, 4.413em, -1000em); top: 0.42em; left: 0em;"><span class="mtd" id="MathJax-Span-2211"><span class="mrow" id="MathJax-Span-2212"><span class="mi" id="MathJax-Span-2213" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-2214" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2215" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-2216" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.012em, 1002.86em, 4.413em, -1000em); top: 1.933em; left: 0em;"><span class="mtd" id="MathJax-Span-2227"><span class="mrow" id="MathJax-Span-2228"><span class="mi" id="MathJax-Span-2229" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-2230" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-2231"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2232" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-2233" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2234" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 13.876em;"></span></span><span style="position: absolute; clip: rect(6.83em, 1004.88em, 19.659em, -1000em); top: -13.541em; left: 3.957em;"><span style="display: inline-block; position: relative; width: 4.918em; height: 0px;"><span style="position: absolute; clip: rect(3.211em, 1001.51em, 4.185em, -1000em); top: -9.922em; left: 0em;"><span class="mtd" id="MathJax-Span-2122"><span class="mrow" id="MathJax-Span-2123"><span class="mo" id="MathJax-Span-2124" style="font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2125" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.21em, 1001.51em, 4.163em, -1000em); top: -8.472em; left: 0em;"><span class="mtd" id="MathJax-Span-2132"><span class="mrow" id="MathJax-Span-2133"><span class="mo" id="MathJax-Span-2134" style="font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2135" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.21em, 1001.98em, 4.163em, -1000em); top: -7.022em; left: 0em;"><span class="mtd" id="MathJax-Span-2142"><span class="mrow" id="MathJax-Span-2143"><span class="mo" id="MathJax-Span-2144" style="font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2145" style="font-family: MathJax_Main; padding-left: 0.278em;">11</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.21em, 1001.98em, 4.163em, -1000em); top: -5.572em; left: 0em;"><span class="mtd" id="MathJax-Span-2154"><span class="mrow" id="MathJax-Span-2155"><span class="mo" id="MathJax-Span-2156" style="font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2157" style="font-family: MathJax_Main; padding-left: 0.278em;">11</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.012em, 1004.02em, 4.245em, -1000em); top: -4.058em; left: 0em;"><span class="mtd" id="MathJax-Span-2166"><span class="mrow" id="MathJax-Span-2167"><span class="mo" id="MathJax-Span-2168" style="font-family: MathJax_Main;">=</span><span class="msubsup" id="MathJax-Span-2169" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.282em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2170" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="texatom" id="MathJax-Span-2171"><span class="mrow" id="MathJax-Span-2172"><span class="mn" id="MathJax-Span-2173" style="font-size: 70.7%; font-family: MathJax_Main;">60</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2174" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-2175" style="font-family: MathJax_Main; padding-left: 0.222em;">9</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.012em, 1004.51em, 4.245em, -1000em); top: -2.544em; left: 0em;"><span class="mtd" id="MathJax-Span-2184"><span class="mrow" id="MathJax-Span-2185"><span class="mo" id="MathJax-Span-2186" style="font-family: MathJax_Main;">=</span><span class="msubsup" id="MathJax-Span-2187" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.282em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2188" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="texatom" id="MathJax-Span-2189"><span class="mrow" id="MathJax-Span-2190"><span class="mn" id="MathJax-Span-2191" style="font-size: 70.7%; font-family: MathJax_Main;">60</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2192" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-2193" style="font-family: MathJax_Main; padding-left: 0.222em;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1004.88em, 4.413em, -1000em); top: -1.094em; left: 0em;"><span class="mtd" id="MathJax-Span-2202"><span class="mrow" id="MathJax-Span-2203"><span class="mo" id="MathJax-Span-2204" style="font-family: MathJax_Main;">=</span><span class="mi" id="MathJax-Span-2205" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">A</span><span class="mo" id="MathJax-Span-2206" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2207" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-2208" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2209" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2210" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.012em, 1004.53em, 4.245em, -1000em); top: 0.42em; left: 0em;"><span class="mtd" id="MathJax-Span-2217"><span class="mrow" id="MathJax-Span-2218"><span class="mo" id="MathJax-Span-2219" style="font-family: MathJax_Main;">=</span><span class="msubsup" id="MathJax-Span-2220" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.282em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2221" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="texatom" id="MathJax-Span-2222"><span class="mrow" id="MathJax-Span-2223"><span class="mn" id="MathJax-Span-2224" style="font-size: 70.7%; font-family: MathJax_Main;">60</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2225" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-2226" style="font-family: MathJax_Main; padding-left: 0.222em;">34</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.21em, 1003.98em, 4.185em, -1000em); top: 1.933em; left: 0em;"><span class="mtd" id="MathJax-Span-2235"><span class="mrow" id="MathJax-Span-2236"><span class="mo" id="MathJax-Span-2237" style="font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2238" style="font-family: MathJax_Main; padding-left: 0.278em;">101881</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 13.541em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -8.25em; border-left: 0px solid; width: 0px; height: 17.161em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mtable columnalign="left left" rowspacing="4pt" columnspacing="1em"><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mn>3</mn></mtd></mtr><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mn>2</mn></mtd></mtr><mtr><mtd><mi>x</mi><mo stretchy="false">(</mo><mn>4</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mn>11</mn></mtd></mtr><mtr><mtd><msub><mi>y</mi><mn>4</mn></msub><mo stretchy="false">(</mo><mn>4</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mn>11</mn></mtd></mtr><mtr><mtd><msub><mi>y</mi><mn>4</mn></msub><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><msup><mn>2</mn><mrow class="MJX-TeXAtom-ORD"><mn>60</mn></mrow></msup><mo>−</mo><mn>9</mn></mtd></mtr><mtr><mtd><msub><mi>y</mi><mn>4</mn></msub><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><msup><mn>2</mn><mrow class="MJX-TeXAtom-ORD"><mn>60</mn></mrow></msup><mo>−</mo><mn>12</mn></mtd></mtr><mtr><mtd><msub><mi>y</mi><mn>4</mn></msub><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mi>A</mi><mo stretchy="false">(</mo><mn>4</mn><mo stretchy="false">)</mo><mo>=</mo><mn>8</mn></mtd></mtr><mtr><mtd><mi>A</mi><mo stretchy="false">(</mo><mn>10</mn><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><msup><mn>2</mn><mrow class="MJX-TeXAtom-ORD"><mn>60</mn></mrow></msup><mo>−</mo><mn>34</mn></mtd></mtr><mtr><mtd><mi>A</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>3</mn></msup><mo stretchy="false">)</mo></mtd><mtd><mo>=</mo><mn>101881</mn></mtd></mtr></mtable></math></span></span><script type="math/tex" id="MathJax-Element-114">\\begin{array}{ll} x(2)&=3 \\\\ x(3)&=2 \\\\ x(4)&=11 \\\\ y_4(4)&=11 \\\\ y_4(3)&=2^{60}-9\\\\ y_4(2)&=2^{60}-12 \\\\ y_4(1)&=A(4)=8 \\\\ A(10)&=2^{60}-34\\\\ A(10^3)&=101881 \\end{array}</script></p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-115-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2239" style="width: 4.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.301em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.21em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2240"><span class="mi" id="MathJax-Span-2241" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-2242" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-2243"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2244" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-2245"><span class="mrow" id="MathJax-Span-2246"><span class="mn" id="MathJax-Span-2247" style="font-size: 70.7%; font-family: MathJax_Main;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2248" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>12</mn></mrow></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-115">A(10^{12})</script>.

# %%
submit_answer(answer; prob_num=505);

# %% [markdown]
# ## Problem 506: Clock sequence
# <p>Consider the infinite repeating sequence of digits:<br>
# 1234321234321234321...</p>
# "<p>Amazingly, you can break this sequence of digits into a sequence of integers such that the sum of the digits in the <var>n</var>'th value is <var>n</var>.</p>"
# <p>The sequence goes as follows:<br>
# 1, 2, 3, 4, 32, 123, 43, 2123, 432, 1234, 32123, ...</p>
# "<p>Let <var>v<sub>n</sub></var> be the <var>n</var>'th value in this sequence. For example, <var>v</var><sub>2</sub>&nbsp;=&nbsp;2, <var>v</var><sub>5</sub>&nbsp;=&nbsp;32 and <var>v</var><sub>11</sub>&nbsp;=&nbsp;32123.</p>"
# <p>Let <var>S</var>(<var>n</var>) be <var>v</var><sub>1</sub>&nbsp;+&nbsp;<var>v</var><sub>2</sub>&nbsp;+&nbsp;...&nbsp;+&nbsp;<var>v<sub>n</sub></var>. For example, <var>S</var>(11)&nbsp;=&nbsp;36120, and <var>S</var>(1000)&nbsp;mod&nbsp;123454321&nbsp;=&nbsp;18232686.</p>
# <p>Find <var>S</var>(10<sup>14</sup>)&nbsp;mod&nbsp;123454321.</p>

# %%
submit_answer(answer; prob_num=506);

# %% [markdown]
# ## Problem 507: Shortest Lattice Vector
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-116-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2249" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.431em, 1000.86em, 2.502em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-2250"><span class="msubsup" id="MathJax-Span-2251"><span style="display: inline-block; position: relative; width: 0.86em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2252" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="mi" id="MathJax-Span-2253" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.271em; border-left: 0px solid; width: 0px; height: 1.161em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>t</mi><mi>n</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-116">t_n</script> be the <b>tribonacci numbers</b> defined as:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-117-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2254" style="width: 6.222em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.689em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1004.65em, 2.989em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2255"><span class="msubsup" id="MathJax-Span-2256"><span style="display: inline-block; position: relative; width: 0.79em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2257" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="mn" id="MathJax-Span-2258" style="font-size: 70.7%; font-family: MathJax_Main;">0</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2259" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2260" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.79em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2261" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="mn" id="MathJax-Span-2262" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2263" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2264" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.224em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>t</mi><mn>0</mn></msub><mo>=</mo><msub><mi>t</mi><mn>1</mn></msub><mo>=</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-117">t_0 = t_1 = 0</script>;<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-118-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2265" style="width: 3.447em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.584em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.51em, 2.973em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2266"><span class="msubsup" id="MathJax-Span-2267"><span style="display: inline-block; position: relative; width: 0.79em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2268" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="mn" id="MathJax-Span-2269" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2270" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2271" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.261em; border-left: 0px solid; width: 0px; height: 1.203em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>t</mi><mn>2</mn></msub><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-118">t_2 = 1</script>;<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-119-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2272" style="width: 13.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.904em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.91em, 1009.9em, 3.031em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2273"><span class="msubsup" id="MathJax-Span-2274"><span style="display: inline-block; position: relative; width: 0.86em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2275" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="mi" id="MathJax-Span-2276" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2277" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2278" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.764em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2279" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="texatom" id="MathJax-Span-2280"><span class="mrow" id="MathJax-Span-2281"><span class="mi" id="MathJax-Span-2282" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2283" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2284" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2285" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-2286" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.764em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2287" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="texatom" id="MathJax-Span-2288"><span class="mrow" id="MathJax-Span-2289"><span class="mi" id="MathJax-Span-2290" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2291" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2292" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2293" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-2294" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.764em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2295" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="texatom" id="MathJax-Span-2296"><span class="mrow" id="MathJax-Span-2297"><span class="mi" id="MathJax-Span-2298" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2299" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2300" style="font-size: 70.7%; font-family: MathJax_Main;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.338em; border-left: 0px solid; width: 0px; height: 1.227em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>t</mi><mi>n</mi></msub><mo>=</mo><msub><mi>t</mi><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>−</mo><mn>1</mn></mrow></msub><mo>+</mo><msub><mi>t</mi><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>−</mo><mn>2</mn></mrow></msub><mo>+</mo><msub><mi>t</mi><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>−</mo><mn>3</mn></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-119">t_n = t_{n-1} + t_{n-2} + t_{n-3}</script> for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-120-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2301" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1002.4em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2302"><span class="mi" id="MathJax-Span-2303" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2304" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-2305" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.186em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>≥</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-120">n \\ge 3</script><br>
# and let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-121-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mtext&gt;&amp;#xA0;mod&amp;#xA0;&lt;/mtext&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2306" style="width: 9.093em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.89em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.665em, 1006.89em, 2.981em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2307"><span class="msubsup" id="MathJax-Span-2308"><span style="display: inline-block; position: relative; width: 0.95em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2309" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="mi" id="MathJax-Span-2310" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2311" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2312" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.86em; height: 0px;"><span style="position: absolute; clip: rect(3.25em, 1000.33em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2313" style="font-family: MathJax_Math; font-style: italic;">t</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.361em;"><span class="mi" id="MathJax-Span-2314" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mtext" id="MathJax-Span-2315" style="font-family: MathJax_Main;">&nbsp;mod&nbsp;</span><span class="msubsup" id="MathJax-Span-2316"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2317" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-2318" style="font-size: 70.7%; font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.271em; border-left: 0px solid; width: 0px; height: 1.484em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>r</mi><mi>n</mi></msub><mo>=</mo><msub><mi>t</mi><mi>n</mi></msub><mtext>&nbsp;mod&nbsp;</mtext><msup><mn>10</mn><mn>7</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-121">r_n = t_n \\text{ mod } 10^7</script>.
# </p>
# <p>
# For each pair of Vectors <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-122-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2319" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.75em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2320"><span class="msubsup" id="MathJax-Span-2321"><span style="display: inline-block; position: relative; width: 1.082em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.77em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2322" style="font-family: MathJax_Math; font-style: italic; text-rendering: optimizelegibility;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.186em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.583em;"><span class="mi" id="MathJax-Span-2323" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2324" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-2325" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="msubsup" id="MathJax-Span-2326"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2327" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2328" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2329" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2330" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2331" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2332" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2333" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2334" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2335" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2336" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2337" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>V</mi><mi>n</mi></msub><mo>=</mo><mo stretchy="false">(</mo><msub><mi>v</mi><mn>1</mn></msub><mo>,</mo><msub><mi>v</mi><mn>2</mn></msub><mo>,</mo><msub><mi>v</mi><mn>3</mn></msub><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-122">V_n=(v_1,v_2,v_3)</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-123-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;W&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2338" style="width: 10.433em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.895em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.8em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2339"><span class="msubsup" id="MathJax-Span-2340"><span style="display: inline-block; position: relative; width: 1.443em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2341" style="font-family: MathJax_Math; font-style: italic;">W<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.104em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.944em;"><span class="mi" id="MathJax-Span-2342" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2343" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-2344" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="msubsup" id="MathJax-Span-2345"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2346" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2347" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2348" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2349" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2350" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2351" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2352" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2353" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2354" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2355" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2356" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>W</mi><mi>n</mi></msub><mo>=</mo><mo stretchy="false">(</mo><msub><mi>w</mi><mn>1</mn></msub><mo>,</mo><msub><mi>w</mi><mn>2</mn></msub><mo>,</mo><msub><mi>w</mi><mn>3</mn></msub><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-123">W_n=(w_1,w_2,w_3)</script> with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-124-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2357" style="width: 35.457em; display: inline-block;"><span style="display: inline-block; position: relative; width: 26.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.953em, 1026.84em, 3.031em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2358"><span class="msubsup" id="MathJax-Span-2359"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2360" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2361" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2362" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2363" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.915em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2364" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2365"><span class="mrow" id="MathJax-Span-2366"><span class="mn" id="MathJax-Span-2367" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2368" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2369" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2370" style="font-size: 70.7%; font-family: MathJax_Main;">11</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2371" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="msubsup" id="MathJax-Span-2372" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 2.915em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2373" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2374"><span class="mrow" id="MathJax-Span-2375"><span class="mn" id="MathJax-Span-2376" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2377" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2378" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2379" style="font-size: 70.7%; font-family: MathJax_Main;">10</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2380" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2381" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2382" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2383" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2384" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2385" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2386" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2387"><span class="mrow" id="MathJax-Span-2388"><span class="mn" id="MathJax-Span-2389" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2390" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2391" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2392" style="font-size: 70.7%; font-family: MathJax_Main;">9</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2393" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-2394" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2395" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2396"><span class="mrow" id="MathJax-Span-2397"><span class="mn" id="MathJax-Span-2398" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2399" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2400" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2401" style="font-size: 70.7%; font-family: MathJax_Main;">8</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2402" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2403" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2404" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2405" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2406" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2407" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2408" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2409"><span class="mrow" id="MathJax-Span-2410"><span class="mn" id="MathJax-Span-2411" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2412" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2413" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2414" style="font-size: 70.7%; font-family: MathJax_Main;">7</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2415" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2416" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2417" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2418"><span class="mrow" id="MathJax-Span-2419"><span class="mn" id="MathJax-Span-2420" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2421" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2422" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2423" style="font-size: 70.7%; font-family: MathJax_Main;">6</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.338em; border-left: 0px solid; width: 0px; height: 1.17em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>v</mi><mn>1</mn></msub><mo>=</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>11</mn></mrow></msub><mo>−</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>10</mn></mrow></msub><mo>,</mo><msub><mi>v</mi><mn>2</mn></msub><mo>=</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>9</mn></mrow></msub><mo>+</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>8</mn></mrow></msub><mo>,</mo><msub><mi>v</mi><mn>3</mn></msub><mo>=</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>7</mn></mrow></msub><mo>⋅</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>6</mn></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-124">v_1=r_{12n-11}-r_{12n-10}, v_2=r_{12n-9}+r_{12n-8}, v_3=r_{12n-7} \\cdot r_{12n-6}</script>  and <br> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-125-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2424" style="width: 34.261em; display: inline-block;"><span style="display: inline-block; position: relative; width: 25.933em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.953em, 1025.93em, 3.031em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2425"><span class="msubsup" id="MathJax-Span-2426"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2427" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2428" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2429" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2430" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2431" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2432"><span class="mrow" id="MathJax-Span-2433"><span class="mn" id="MathJax-Span-2434" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2435" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2436" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2437" style="font-size: 70.7%; font-family: MathJax_Main;">5</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2438" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="msubsup" id="MathJax-Span-2439" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2440" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2441"><span class="mrow" id="MathJax-Span-2442"><span class="mn" id="MathJax-Span-2443" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2444" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2445" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2446" style="font-size: 70.7%; font-family: MathJax_Main;">4</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2447" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2448" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2449" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2450" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2451" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2452" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2453" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2454"><span class="mrow" id="MathJax-Span-2455"><span class="mn" id="MathJax-Span-2456" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2457" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2458" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2459" style="font-size: 70.7%; font-family: MathJax_Main;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2460" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-2461" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2462" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2463"><span class="mrow" id="MathJax-Span-2464"><span class="mn" id="MathJax-Span-2465" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2466" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2467" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2468" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2469" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-2470" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2471" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2472" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2473" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2474" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.561em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2475" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2476"><span class="mrow" id="MathJax-Span-2477"><span class="mn" id="MathJax-Span-2478" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2479" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2480" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-2481" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2482" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2483" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.657em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2484" style="font-family: MathJax_Math; font-style: italic;">r</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.451em;"><span class="texatom" id="MathJax-Span-2485"><span class="mrow" id="MathJax-Span-2486"><span class="mn" id="MathJax-Span-2487" style="font-size: 70.7%; font-family: MathJax_Main;">12</span><span class="mi" id="MathJax-Span-2488" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.338em; border-left: 0px solid; width: 0px; height: 1.17em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>w</mi><mn>1</mn></msub><mo>=</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>5</mn></mrow></msub><mo>−</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>4</mn></mrow></msub><mo>,</mo><msub><mi>w</mi><mn>2</mn></msub><mo>=</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>3</mn></mrow></msub><mo>+</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>2</mn></mrow></msub><mo>,</mo><msub><mi>w</mi><mn>3</mn></msub><mo>=</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi><mo>−</mo><mn>1</mn></mrow></msub><mo>⋅</mo><msub><mi>r</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn><mi>n</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-125">w_1=r_{12n-5}-r_{12n-4}, w_2=r_{12n-3}+r_{12n-2}, w_3=r_{12n-1} \\cdot r_{12n}</script>
# <br>
#
# we define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-126-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2489" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2490"><span class="mi" id="MathJax-Span-2491" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-2492" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2493" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2494" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-126">S(n)</script> as the minimal value of the manhattan length of the vector <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-127-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;W&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2495" style="width: 10.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.134em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1008.13em, 2.981em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2496"><span class="mi" id="MathJax-Span-2497" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-2498" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-2499" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">k</span><span class="mo" id="MathJax-Span-2500" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2501" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.082em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.77em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2502" style="font-family: MathJax_Math; font-style: italic; text-rendering: optimizelegibility;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.186em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.583em;"><span class="mi" id="MathJax-Span-2503" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2504" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-2505" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">l</span><span class="mo" id="MathJax-Span-2506" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2507" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.443em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2508" style="font-family: MathJax_Math; font-style: italic;">W<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.104em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.944em;"><span class="mi" id="MathJax-Span-2509" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.271em; border-left: 0px solid; width: 0px; height: 1.251em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo>=</mo><mi>k</mi><mo>⋅</mo><msub><mi>V</mi><mi>n</mi></msub><mo>+</mo><mi>l</mi><mo>⋅</mo><msub><mi>W</mi><mi>n</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-127">D=k \\cdot V_n+l \\cdot W_n</script> measured as <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-128-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;w&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2510" style="width: 27.419em; display: inline-block;"><span style="display: inline-block; position: relative; width: 20.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1020.65em, 3.072em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2511"><span class="texatom" id="MathJax-Span-2512"><span class="mrow" id="MathJax-Span-2513"><span class="mo" id="MathJax-Span-2514" style="font-family: MathJax_Main;">|</span></span></span><span class="mi" id="MathJax-Span-2515" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2516" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2517" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2518" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2519" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2520" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-2521" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">l</span><span class="mo" id="MathJax-Span-2522" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2523" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2524" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2525" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="texatom" id="MathJax-Span-2526"><span class="mrow" id="MathJax-Span-2527"><span class="mo" id="MathJax-Span-2528" style="font-family: MathJax_Main;">|</span></span></span><span class="mo" id="MathJax-Span-2529" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="texatom" id="MathJax-Span-2530" style="padding-left: 0.222em;"><span class="mrow" id="MathJax-Span-2531"><span class="mo" id="MathJax-Span-2532" style="font-family: MathJax_Main;">|</span></span></span><span class="mi" id="MathJax-Span-2533" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2534" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2535" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2536" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2537" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2538" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-2539" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">l</span><span class="mo" id="MathJax-Span-2540" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2541" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2542" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2543" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="texatom" id="MathJax-Span-2544"><span class="mrow" id="MathJax-Span-2545"><span class="mo" id="MathJax-Span-2546" style="font-family: MathJax_Main;">|</span></span></span><span class="mo" id="MathJax-Span-2547" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="texatom" id="MathJax-Span-2548" style="padding-left: 0.222em;"><span class="mrow" id="MathJax-Span-2549"><span class="mo" id="MathJax-Span-2550" style="font-family: MathJax_Main;">|</span></span></span><span class="mi" id="MathJax-Span-2551" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2552" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2553" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.914em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2554" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mn" id="MathJax-Span-2555" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2556" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-2557" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">l</span><span class="mo" id="MathJax-Span-2558" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="msubsup" id="MathJax-Span-2559" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.145em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.69em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2560" style="font-family: MathJax_Math; font-style: italic;">w</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.716em;"><span class="mn" id="MathJax-Span-2561" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="texatom" id="MathJax-Span-2562"><span class="mrow" id="MathJax-Span-2563"><span class="mo" id="MathJax-Span-2564" style="font-family: MathJax_Main;">|</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.392em; border-left: 0px solid; width: 0px; height: 1.445em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><mi>k</mi><mo>⋅</mo><msub><mi>v</mi><mn>1</mn></msub><mo>+</mo><mi>l</mi><mo>⋅</mo><msub><mi>w</mi><mn>1</mn></msub><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><mo>+</mo><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><mi>k</mi><mo>⋅</mo><msub><mi>v</mi><mn>2</mn></msub><mo>+</mo><mi>l</mi><mo>⋅</mo><msub><mi>w</mi><mn>2</mn></msub><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><mo>+</mo><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><mi>k</mi><mo>⋅</mo><msub><mi>v</mi><mn>3</mn></msub><mo>+</mo><mi>l</mi><mo>⋅</mo><msub><mi>w</mi><mn>3</mn></msub><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow></math></span></span><script type="math/tex" id="MathJax-Element-128">|k \\cdot v_1+l \\cdot w_1|+|k \\cdot v_2+l \\cdot w_2|+|k \\cdot v_3+l \\cdot w_3|</script>
#  for any integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-129-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2565" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-2566"><span class="mi" id="MathJax-Span-2567" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-129">k</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-130-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2568" style="width: 0.385em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.287em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.26em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-2569"><span class="mi" id="MathJax-Span-2570" style="font-family: MathJax_Math; font-style: italic;">l</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>l</mi></math></span></span><script type="math/tex" id="MathJax-Element-130">l</script> with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-131-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;&amp;#x2260;&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2571" style="width: 7.323em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.55em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.46em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2572"><span class="mo" id="MathJax-Span-2573" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2574" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-2575" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-2576" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">l</span><span class="mo" id="MathJax-Span-2577" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2578" style="font-family: MathJax_Main; padding-left: 0.278em;">≠</span><span class="mo" id="MathJax-Span-2579" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="mn" id="MathJax-Span-2580" style="font-family: MathJax_Main;">0</span><span class="mo" id="MathJax-Span-2581" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-2582" style="font-family: MathJax_Main; padding-left: 0.167em;">0</span><span class="mo" id="MathJax-Span-2583" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>k</mi><mo>,</mo><mi>l</mi><mo stretchy="false">)</mo><mo>≠</mo><mo stretchy="false">(</mo><mn>0</mn><mo>,</mo><mn>0</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-131">(k,l)\\neq (0,0)</script>.
# </p><p>
# The first vector pair  is (-1, 3, 28), (-11, 125, 40826).<br>
# You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-132-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;32&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2584" style="width: 5.505em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.163em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.11em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2585"><span class="mi" id="MathJax-Span-2586" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-2587" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2588" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-2589" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2590" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2591" style="font-family: MathJax_Main; padding-left: 0.278em;">32</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>32</mn></math></span></span><script type="math/tex" id="MathJax-Element-132">S(1)=32</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-133-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;130762273722&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2592" style="width: 15.505em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.722em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.588em, 1011.67em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2593"><span class="munderover" id="MathJax-Span-2594"><span style="display: inline-block; position: relative; width: 2.459em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-2595" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.78em, 4.178em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2596"><span class="mrow" id="MathJax-Span-2597"><span class="mn" id="MathJax-Span-2598" style="font-size: 70.7%; font-family: MathJax_Main;">10</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.4em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2599"><span class="mrow" id="MathJax-Span-2600"><span class="mi" id="MathJax-Span-2601" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2602" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2603" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-2604" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-2605" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2606" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2607" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2608" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2609" style="font-family: MathJax_Main; padding-left: 0.278em;">130762273722</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.764em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>10</mn></mrow></munderover><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mn>130762273722</mn></math></span></span><script type="math/tex" id="MathJax-Element-133">\\sum_{n=1}^{10} S(n)=130762273722</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-134-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;20000000&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2610" style="width: 8.184em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.172em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.588em, 1006.08em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2611"><span class="munderover" id="MathJax-Span-2612"><span style="display: inline-block; position: relative; width: 3.959em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-2613" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1002.9em, 4.178em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2614"><span class="mrow" id="MathJax-Span-2615"><span class="mn" id="MathJax-Span-2616" style="font-size: 70.7%; font-family: MathJax_Main;">20000000</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.4em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2617"><span class="mrow" id="MathJax-Span-2618"><span class="mi" id="MathJax-Span-2619" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2620" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2621" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-2622" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-2623" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2624" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2625" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.764em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>20000000</mn></mrow></munderover><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-134">\\sum_{n=1}^{20000000} S(n)</script>.
# </p>

# %%
submit_answer(answer; prob_num=507);

# %% [markdown]
# ## Problem 508: Integers in base i-1
# <p>Consider the Gaussian integer i-1. A <b>base i-1 representation</b> of a Gaussian integer <var>a</var>+<var>b</var>i is a finite sequence of digits <var>d</var><sub><var>n</var>-1</sub><var>d</var><sub><var>n</var>-2</sub>...<var>d</var><sub>1</sub><var>d</var><sub>0</sub> such that:</p>
#
# <ul><li><var>a</var>+<var>b</var>i = <var>d</var><sub><var>n</var>-1</sub>(i-1)<sup><var>n</var>-1</sup> + <var>d</var><sub><var>n</var>-2</sub>(i-1)<sup><var>n</var>-2</sup> + ... + <var>d</var><sub>1</sub>(i-1) + <var>d</var><sub>0</sub></li>
# <li>Each <var>d</var><sub><var>k</var></sub> is in {0,1}</li>
# <li>There are no leading zeroes, i.e. <var>d</var><sub>n-1</sub> ≠ 0, unless <var>a</var>+<var>b</var>i is itself 0</li>
# </ul><p>Here are base i-1 representations of a few Gaussian integers:<br><br>
# 11+24i → 111010110001101<br>
# 24-11i → 110010110011<br>
# 8+0i → 111000000<br>
# -5+0i → 11001101<br>
# 0+0i → 0</p>
#
# Remarkably, every Gaussian integer has a unique base i-1 representation!<br><br>
#
# Define <var>f</var>(<var>a</var>+<var>b</var>i) as the number of 1s in the unique base i-1 representation of <var>a</var>+<var>b</var>i. For example, <var>f</var>(11+24i) = 9 and <var>f</var>(24-11i) = 7.<br><br>
#
# Define <var>B</var>(<var>L</var>) as the sum of <var>f</var>(<var>a</var>+<var>b</var>i) for all integers <var>a</var>, <var>b</var> such that |<var>a</var>| ≤ <var>L</var> and |<var>b</var>| ≤ <var>L</var>. For example, <var>B</var>(500) = 10795060.<br><br>
#
# Find <var>B</var>(10<sup>15</sup>) mod 1 000 000 007.

# %%
submit_answer(answer; prob_num=508);

# %% [markdown]
# ## Problem 509: Divisor Nim
# <p>
# Anton and Bertrand love to play three pile Nim.<br>
# However, after a lot of games of Nim they got bored and changed the rules somewhat.<br>
# They may only take a number of stones from a pile that is a <dfn title="a proper divisor of n is a divisor of n smaller than n">proper divisor</dfn> of the number of stones present in the pile.<br> E.g. if a pile at a certain moment contains 24 stones they may take only 1,2,3,4,6,8 or 12 stones from that pile.<br>
# "So if a pile contains one stone they can't take the last stone from it as 1 isn't a proper divisor of 1.<br>"
# "The first player that can't make a valid move loses the game.<br>"
# Of course both Anton and Bertrand play optimally.</p>
# <p>
# The triple (<var>a</var>,<var>b</var>,<var>c</var>) indicates the number of stones in the three piles.<br>
# Let <var>S</var>(<var>n</var>) be the number of winning positions for the next player for 1 ≤ <var>a</var>, <var>b</var>, <var>c</var> ≤ <var>n</var>.<br><var>S</var>(10) = 692 and <var>S</var>(100) = 735494.</p>
# <p>
# Find <var>S</var>(123456787654321) modulo 1234567890.
# </p>

# %%
submit_answer(answer; prob_num=509);

# %% [markdown]
# ## Problem 510: Tangent Circles
# <p>Circles A and B are tangent to each other and to line L at three distinct points.<br>
# Circle C is inside the space between A, B and L, and tangent to all three.<br>
# Let <var>r</var><sub>A</sub>, <var>r</var><sub>B</sub> and <var>r</var><sub>C</sub> be the radii of A, B and C respectively.<br></p><div align="center"><img src="webfiles/p510_tangent_circles.png" alt="p510_tangent_circles.png"></div>
# <p>Let <var>S</var>(<var>n</var>)&nbsp;=&nbsp;Σ&nbsp;<var>r</var><sub>A</sub>&nbsp;+&nbsp;<var>r</var><sub>B</sub>&nbsp;+&nbsp;<var>r</var><sub>C</sub>, for 0&nbsp;&lt;&nbsp;<var>r</var><sub>A</sub>&nbsp;≤&nbsp;<var>r</var><sub>B</sub>&nbsp;≤&nbsp;<var>n</var> where <var>r</var><sub>A</sub>, <var>r</var><sub>B</sub> and <var>r</var><sub>C</sub> are integers.
# The only solution for 0&nbsp;&lt;&nbsp;<var>r</var><sub>A</sub>&nbsp;≤&nbsp;<var>r</var><sub>B</sub>&nbsp;≤&nbsp;5 is <var>r</var><sub>A</sub>&nbsp;=&nbsp;4, <var>r</var><sub>B</sub>&nbsp;=&nbsp;4 and <var>r</var><sub>C</sub>&nbsp;=&nbsp;1, so <var>S</var>(5)&nbsp;=&nbsp;4&nbsp;+&nbsp;4&nbsp;+&nbsp;1&nbsp;=&nbsp;9.
# You are also given <var>S</var>(100)&nbsp;=&nbsp;3072.</p>
# <p>Find <var>S</var>(10<sup>9</sup>).</p>

# %%
submit_answer(answer; prob_num=510);

# %% [markdown]
# ## Problem 511: Sequences with nice divisibility properties
# <p>Let <var>Seq</var>(<var>n</var>,<var>k</var>) be the number of positive-integer sequences {<var>a<sub>i</sub></var>}<sub>1≤i≤<var>n</var></sub> of length <var>n</var> such that:</p>
# <ul style="list-style-type:disc;"><li><var>n</var> is divisible by <var>a<sub>i</sub></var> for 1&nbsp;≤&nbsp;<var>i</var>&nbsp;≤&nbsp;<var>n</var>, and</li>
#   <li><var>n</var> + <var>a</var><sub>1</sub> + <var>a</var><sub>2</sub> + ... + <var>a<sub>n</sub></var> is divisible by <var>k</var>.</li>
# </ul><p>Examples:</p>
# <p><var>Seq</var>(3,4) = 4, and the 4 sequences are:<br>
# {1, 1, 3}<br>
# {1, 3, 1}<br>
# {3, 1, 1}<br>
# {3, 3, 3}</p>
# <p><var>Seq</var>(4,11) = 8, and the 8 sequences are:<br>
# {1, 1, 1, 4}<br>
# {1, 1, 4, 1}<br>
# {1, 4, 1, 1}<br>
# {4, 1, 1, 1}<br>
# {2, 2, 2, 1}<br>
# {2, 2, 1, 2}<br>
# {2, 1, 2, 2}<br>
# {1, 2, 2, 2}</p>
# <p>The last nine digits of <var>Seq</var>(1111,24) are 840643584.</p>
# <p>Find the last nine digits of <var>Seq</var>(1234567898765,4321).</p>

# %%
submit_answer(answer; prob_num=511);

# %% [markdown]
# ## Problem 512: Sums of totients of powers
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-135-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C6;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2626" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2627"><span class="mi" id="MathJax-Span-2628" style="font-family: MathJax_Math; font-style: italic;">φ</span><span class="mo" id="MathJax-Span-2629" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2630" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2631" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>φ</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-135">\\varphi(n)</script> be Euler's totient function.</p><p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-136-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;&amp;#x03C6;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;mod&amp;#xA0;&lt;/mtext&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2632" style="width: 18.758em; display: inline-block;"><span style="display: inline-block; position: relative; width: 14.211em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.706em, 1014.12em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2633"><span class="mi" id="MathJax-Span-2634" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-2635" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2636" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2637" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2638" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-2639" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="munderover" id="MathJax-Span-2640"><span style="display: inline-block; position: relative; width: 2.279em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-2641" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.5em, 4.17em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2642"><span class="mrow" id="MathJax-Span-2643"><span class="mi" id="MathJax-Span-2644" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.22em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2645"><span class="mrow" id="MathJax-Span-2646"><span class="mi" id="MathJax-Span-2647" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-2648" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2649" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-2650" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">φ</span><span class="mo" id="MathJax-Span-2651" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-2652"><span style="display: inline-block; position: relative; width: 0.919em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.58em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2653" style="font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.6em;"><span class="mi" id="MathJax-Span-2654" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2655" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2656" style="font-family: MathJax_Main;">)</span><span class="mtext" id="MathJax-Span-2657" style="font-family: MathJax_Main;">&nbsp;mod&nbsp;</span><span class="mo" id="MathJax-Span-2658" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2659" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2660" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-2661" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-2662" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.609em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mo stretchy="false">(</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mi>n</mi></mrow></munderover><mi>φ</mi><mo stretchy="false">(</mo><msup><mi>n</mi><mi>i</mi></msup><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mtext>&nbsp;mod&nbsp;</mtext><mo stretchy="false">(</mo><mi>n</mi><mo>+</mo><mn>1</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-136">f(n)=(\\sum_{i=1}^{n}\\varphi(n^i)) \\text{ mod } (n+1)</script>.</p><p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-137-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2663" style="width: 9.62em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.273em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.746em, 1007.18em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2664"><span class="mi" id="MathJax-Span-2665" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-2666" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2667" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2668" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2669" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-2670" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.279em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-2671" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.5em, 4.17em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2672"><span class="mrow" id="MathJax-Span-2673"><span class="mi" id="MathJax-Span-2674" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.22em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2675"><span class="mrow" id="MathJax-Span-2676"><span class="mi" id="MathJax-Span-2677" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-2678" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2679" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-2680" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-2681" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2682" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-2683" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.555em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mi>n</mi></mrow></munderover><mi>f</mi><mo stretchy="false">(</mo><mi>i</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-137">g(n)=\\sum_{i=1}^{n} f(i)</script>.</p><p>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-138-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2007&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2684" style="width: 7.849em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.933em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.92em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2685"><span class="mi" id="MathJax-Span-2686" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-2687" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2688" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-2689" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2690" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2691" style="font-family: MathJax_Main; padding-left: 0.278em;">2007</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2007</mn></math></span></span><script type="math/tex" id="MathJax-Element-138">g(100)=2007</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-139-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2692" style="width: 5.744em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.354em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1004.26em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2693"><span class="mi" id="MathJax-Span-2694" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-2695" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2696" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-2697" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="msubsup" id="MathJax-Span-2698" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-2699" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-2700" style="font-size: 70.7%; font-family: MathJax_Main;">8</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2701" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo stretchy="false">(</mo><mn>5</mn><mo>×</mo><msup><mn>10</mn><mn>8</mn></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-139">g(5 \\times 10^8)</script>.
# </p>

# %%
submit_answer(answer; prob_num=512);

# %% [markdown]
# ## Problem 513: Integral median
# <p>
# ABC is an integral sided triangle with sides a≤b≤c.<br>
# m<sub>c</sub> is the median connecting C and the midpoint of AB. <br>
# F(n) is the number of such triangles with  c≤n for which m<sub>c</sub> has integral length as well.<br>
# F(10)=3 and F(50)=165.</p>
# <p>
# Find F(100000).
# </p>

# %%
submit_answer(answer; prob_num=513);

# %% [markdown]
# ## Problem 514: Geoboard Shapes
# <p>A <b>geoboard</b> (of order <var>N</var>)
#  is a square board with equally-spaced pins protruding from the surface,
#  representing an integer point lattice for coordinates 0 ≤ <var>x</var>,<var>y</var> ≤ <var>N</var>.</p>
#
# <p>John begins with a pinless geoboard. Each position on the board is a
# hole that can be filled with a pin. John decides to generate a random
# integer between 1 and <var>N</var>+1 (inclusive) for each hole in the
# geoboard. If the random integer is equal to 1 for a given hole, then a
# pin is placed in that hole.</p>
#
# <p>After John is finished generating numbers for all (<var>N</var>+1)<sup>2</sup>
#  holes and placing any/all corresponding pins, he wraps a tight
# rubberband around the entire group of pins protruding from the board.
# Let <var>S</var> represent the shape that is formed. <var>S</var> can also be defined as the smallest convex shape that contains all the pins.</p>
#
# <div align="center"><img src="webfiles/p514_geoboard.png" alt="p514_geoboard.png"></div>
#
# <p>The above image depicts a sample layout for <var>N</var> = 4. The
# green markers indicate positions where pins have been placed, and the
# blue lines collectively represent the rubberband. For this particular
# arrangement, <var>S</var> has an area of 6. If there are fewer than three pins on the board (or if all pins are collinear), <var>S</var> can be assumed to have zero area.</p>
#
# <p>Let E(<var>N</var>) be the expected area of <var>S</var> given a geoboard of order <var>N</var>. For example, E(1) = 0.18750, E(2) = 0.94335, and E(10) = 55.03013 when rounded to five decimal places each.</p>
#
# <p>Calculate E(100) rounded to five decimal places.</p>

# %%
submit_answer(answer; prob_num=514);

# %% [markdown]
# ## Problem 515: Dissonant Numbers
# <p>Let <var>d</var>(<var>p</var>,<var>n</var>,0) be the multiplicative inverse of <var>n</var> modulo prime <var>p</var>, defined as <var>n</var>&nbsp;×&nbsp;<var>d</var>(<var>p</var>,<var>n</var>,0)&nbsp;=&nbsp;1&nbsp;mod&nbsp;<var>p</var>.<br>
# Let <var>d</var>(<var>p</var>,<var>n</var>,<var>k</var>) = <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-140-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/munderover&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2702" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.268em, 1002.3em, 2.638em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-2703"><span class="munderover" id="MathJax-Span-2704"><span style="display: inline-block; position: relative; width: 2.279em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-2705" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.5em, 4.17em, -1000em); top: -4.496em; left: 1.056em;"><span class="mi" id="MathJax-Span-2706" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.22em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-2707"><span class="mrow" id="MathJax-Span-2708"><span class="mi" id="MathJax-Span-2709" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-2710" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-2711" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.555em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover></math></span></span><script type="math/tex" id="MathJax-Element-140">\\sum_{i=1}^n</script><var>d</var>(<var>p</var>,<var>i</var>,<var>k</var>−1) for <var>k</var>&nbsp;≥&nbsp;1.<br>
# Let <var>D</var>(<var>a</var>,<var>b</var>,<var>k</var>) = <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-141-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2712" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.834em, 1001em, 3.121em, -1000em); top: -2.727em; left: 0em;"><span class="mrow" id="MathJax-Span-2713"><span class="mo" id="MathJax-Span-2714" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span></span><span style="display: inline-block; width: 0px; height: 2.727em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo>∑</mo></math></span></span><script type="math/tex" id="MathJax-Element-141">\\sum</script>(<var>d</var>(<var>p</var>,<var>p</var>-1,<var>k</var>) mod <var>p</var>) for all primes <var>a</var>&nbsp;≤&nbsp;<var>p</var>&nbsp;&lt;&nbsp;<var>a</var>&nbsp;+&nbsp;<var>b</var>.</p>
# <p>You are given:</p>
# <ul><li><var>D</var>(101,1,10) = 45</li>
# <li><var>D</var>(10<sup>3</sup>,10<sup>2</sup>,10<sup>2</sup>) = 8334</li>
# <li><var>D</var>(10<sup>6</sup>,10<sup>3</sup>,10<sup>3</sup>) = 38162302</li></ul><p>Find <var>D</var>(10<sup>9</sup>,10<sup>5</sup>,10<sup>5</sup>).</p>

# %%
submit_answer(answer; prob_num=515);

# %% [markdown]
# ## Problem 516: 5-smooth totients
# <p>
# "5-smooth numbers are numbers whose largest prime factor doesn't exceed 5.<br>"
# 5-smooth numbers are also called Hamming numbers.<br>
# "Let S(L) be the sum of the numbers n not exceeding L such that Euler's totient function φ(n) is a Hamming number.<br>"
# S(100)=3728.
# </p>
# <p>
# Find S(10<sup>12</sup>). Give your answer modulo 2<sup>32</sup>.
# </p>

# %%
submit_answer(answer; prob_num=516);

# %% [markdown]
# ## Problem 517: A real recursion
# <p>
# For every real number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-142-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;#x003E;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2715" style="width: 3.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.27em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2716"><span class="mi" id="MathJax-Span-2717" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-2718" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-2719" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 1.058em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>&gt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-142">a \\gt 1</script> is given the sequence <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-143-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2720" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.615em, 1000.91em, 2.549em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-2721"><span class="msubsup" id="MathJax-Span-2722"><span style="display: inline-block; position: relative; width: 0.926em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.48em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2723" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.477em;"><span class="mi" id="MathJax-Span-2724" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>g</mi><mi>a</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-143">g_a</script> by:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-144-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2725" style="width: 5.409em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.067em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.99em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2726"><span class="msubsup" id="MathJax-Span-2727"><span style="display: inline-block; position: relative; width: 0.926em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.48em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2728" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.477em;"><span class="texatom" id="MathJax-Span-2729"><span class="mrow" id="MathJax-Span-2730"><span class="mi" id="MathJax-Span-2731" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2732" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2733" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2734" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2735" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2736" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>g</mi><mrow class="MJX-TeXAtom-ORD"><mi>a</mi></mrow></msub><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-144">g_{a}(x)=1</script> for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-145-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x003C;&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2737" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.996em, 1002.42em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2738"><span class="mi" id="MathJax-Span-2739" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2740" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-2741" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">a</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 0.892em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi><mo>&lt;</mo><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-145">x \\lt a</script><br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-146-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2742" style="width: 16.797em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.727em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1012.63em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2743"><span class="msubsup" id="MathJax-Span-2744"><span style="display: inline-block; position: relative; width: 0.926em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.48em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2745" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.477em;"><span class="texatom" id="MathJax-Span-2746"><span class="mrow" id="MathJax-Span-2747"><span class="mi" id="MathJax-Span-2748" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2749" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2750" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2751" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2752" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2753" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.926em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.48em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2754" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.477em;"><span class="texatom" id="MathJax-Span-2755"><span class="mrow" id="MathJax-Span-2756"><span class="mi" id="MathJax-Span-2757" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2758" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2759" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2760" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-2761" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-2762" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2763" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-2764" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.926em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.48em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2765" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.477em;"><span class="mi" id="MathJax-Span-2766" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2767" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2768" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2769" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mi" id="MathJax-Span-2770" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">a</span><span class="mo" id="MathJax-Span-2771" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>g</mi><mrow class="MJX-TeXAtom-ORD"><mi>a</mi></mrow></msub><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">)</mo><mo>=</mo><msub><mi>g</mi><mrow class="MJX-TeXAtom-ORD"><mi>a</mi></mrow></msub><mo stretchy="false">(</mo><mi>x</mi><mo>−</mo><mn>1</mn><mo stretchy="false">)</mo><mo>+</mo><msub><mi>g</mi><mi>a</mi></msub><mo stretchy="false">(</mo><mi>x</mi><mo>−</mo><mi>a</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-146">g_{a}(x)=g_{a}(x-1)+g_a(x-a)</script> for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-147-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2772" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.9em, 1002.42em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2773"><span class="mi" id="MathJax-Span-2774" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2775" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mi" id="MathJax-Span-2776" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">a</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.148em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi><mo>≥</mo><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-147">x \\ge a</script><br>
#
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-148-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;msqrt&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msqrt&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2777" style="width: 8.471em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.411em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.32em, 3.186em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2778"><span class="mi" id="MathJax-Span-2779" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-2780" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2781" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2782" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2783" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-2784" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.565em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.48em, 4.368em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2785" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.86em; left: 0.477em;"><span class="texatom" id="MathJax-Span-2786"><span class="mrow" id="MathJax-Span-2787"><span class="msqrt" id="MathJax-Span-2788"><span style="display: inline-block; position: relative; width: 1.013em; height: 0px;"><span style="position: absolute; clip: rect(3.563em, 1000.41em, 4.17em, -1000em); top: -4.019em; left: 0.589em;"><span class="mrow" id="MathJax-Span-2789"><span class="mi" id="MathJax-Span-2790" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.952em, 1000.42em, 1.256em, -1000em); top: -1.599em; left: 0.589em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.424em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.31em, 1000.6em, 4.304em, -1000em); top: -3.957em; left: 0em;"><span><span style="font-size: 70.7%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-2791" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2792" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-2793" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.542em; border-left: 0px solid; width: 0px; height: 1.595em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><msub><mi>g</mi><mrow class="MJX-TeXAtom-ORD"><msqrt><mi>n</mi></msqrt></mrow></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-148">G(n)=g_{\\sqrt {n}}(n)</script><br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-149-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;90&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7564511&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2794" style="width: 9.476em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.177em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.1em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2795"><span class="mi" id="MathJax-Span-2796" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-2797" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-2798" style="font-family: MathJax_Main;">90</span><span class="mo" id="MathJax-Span-2799" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2800" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2801" style="font-family: MathJax_Main; padding-left: 0.278em;">7564511</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>90</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7564511</mn></math></span></span><script type="math/tex" id="MathJax-Element-149">G(90)=7564511</script>.</p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-150-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2802" style="width: 4.309em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.254em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.882em, 1003.16em, 3.169em, -1000em); top: -2.775em; left: 0em;"><span class="mrow" id="MathJax-Span-2803"><span class="mo" id="MathJax-Span-2804" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span class="mi" id="MathJax-Span-2805" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">G</span><span class="mo" id="MathJax-Span-2806" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2807" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-2808" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.775em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo>∑</mo><mi>G</mi><mo stretchy="false">(</mo><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-150">\\sum G(p)</script> for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-151-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2809" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-2810"><span class="mi" id="MathJax-Span-2811" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-151">p</script> prime and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-152-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;10000000&lt;/mn&gt;&lt;mo&gt;&amp;#x003C;&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;&amp;#x003C;&lt;/mo&gt;&lt;mn&gt;10010000&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2812" style="width: 14.309em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.813em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1010.77em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2813"><span class="mn" id="MathJax-Span-2814" style="font-family: MathJax_Main;">10000000</span><span class="mo" id="MathJax-Span-2815" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-2816" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">p</span><span class="mo" id="MathJax-Span-2817" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mn" id="MathJax-Span-2818" style="font-family: MathJax_Main; padding-left: 0.278em;">10010000</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.262em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>10000000</mn><mo>&lt;</mo><mi>p</mi><mo>&lt;</mo><mn>10010000</mn></math></span></span><script type="math/tex" id="MathJax-Element-152">10000000 \\lt p \\lt 10010000</script><br>
# Give your answer modulo 1000000007.
# </p>

# %%
submit_answer(answer; prob_num=517);

# %% [markdown]
# ## Problem 518: Prime triples and geometric sequences
# <p>Let S(<var>n</var>) = Σ <var>a</var>+<var>b</var>+<var>c</var> over all triples (<var>a</var>,<var>b</var>,<var>c</var>) such that:</p>
#
# <ul style="list-style-type:disc;"><li><var>a</var>, <var>b</var>, and <var>c</var> are prime numbers.</li>
# <li><var>a</var> &lt; <var>b</var> &lt; <var>c</var> &lt; <var>n</var>.</li>
# <li><var>a</var>+1, <var>b</var>+1, and <var>c</var>+1 form a <b>geometric sequence</b>.</li>
# </ul><p>For example, S(100) = 1035 with the following triples: </p>
#
# <p>(2, 5, 11), (2, 11, 47), (5, 11, 23), (5, 17, 53), (7, 11, 17), (7,
# 23, 71), (11, 23, 47), (17, 23, 31), (17, 41, 97), (31, 47, 71), (71,
# 83, 97)</p>
#
# <p>Find S(10<sup>8</sup>).</p>

# %%
submit_answer(answer; prob_num=518);

# %% [markdown]
# ## Problem 519: Tricolored Coin Fountains
# <p>An
#  arrangement of coins in one or more rows with the bottom row being a
# block without gaps and every coin in a higher row touching exactly two
# coins in the row below is called a <b>fountain</b> of coins. Let <var>f</var>(<var>n</var>) be the number of possible fountains with <var>n</var> coins. For 4 coins there are three possible arrangements:</p>
# <div align="center"><img src="webfiles/p519_coin_fountain.png" alt="p519_coin_fountain.png"></div>
# <p>Therefore <var>f</var>(4)&nbsp;=&nbsp;3 while <var>f</var>(10)&nbsp;=&nbsp;78.</p>
# <p>Let <var>T</var>(<var>n</var>) be the number of all possible colorings with three colors for all <var>f</var>(<var>n</var>) different fountains with <var>n</var>
#  coins, given the condition that no two touching coins have the same
# color. Below you see the possible colorings for one of the three valid
# fountains for 4 coins:</p>
# <div align="center"><img src="webfiles/p519_tricolored_coin_fountain.png" alt="p519_tricolored_coin_fountain.png"></div>
# <p>You are given that <var>T</var>(4)&nbsp;=&nbsp;48 and <var>T</var>(10)&nbsp;=&nbsp;17760.</p>
# <p>Find the last 9 digits of <var>T</var>(20000).</p>

# %%
submit_answer(answer; prob_num=519);

# %% [markdown]
# ## Problem 520: Simbers
# <p>We define a <i>simber</i>
#  to be a positive integer in which any odd digit, if present, occurs an
# odd number of times, and any even digit, if present, occurs an even
# number of times.</p>
#
# "<p>For example, 141221242 is a 9-digit simber because it has three 1's, four 2's and two 4's. </p>"
#
# <p>Let Q(<var>n</var>) be the count of all simbers with at most <var>n</var> digits.</p>
#
# <p>You are given Q(7) = 287975 and Q(100) mod 1 000 000 123 = 123864868.</p>
#
# <p>Find (∑<sub>1≤<var>u</var>≤39</sub> Q(2<sup><var>u</var></sup>)) mod 1 000 000 123.</p>

# %%
submit_answer(answer; prob_num=520);

# %% [markdown]
# ## Problem 521: Smallest prime factor
# <p>
# Let smpf(<var>n</var>) be the smallest prime factor of <var>n</var>.<br>
# smpf(91)=7 because 91=7×13 and smpf(45)=3 because 45=3×3×5.<br>
# Let S(<var>n</var>) be the sum of smpf(<var>i</var>) for 2 ≤ <var>i</var> ≤ <var>n</var>.<br>
# E.g. S(100)=1257.
# </p>
#
# <p>
# Find S(10<sup>12</sup>) mod 10<sup>9</sup>.
# </p>

# %%
submit_answer(answer; prob_num=521);

# %% [markdown]
# ## Problem 522: Hilbert's Blackout
# "<p>Despite the popularity of Hilbert's infinite hotel, Hilbert decided to try managing extremely large finite hotels, instead.</p> "
#
# <p>To cut costs, Hilbert wished to power the new hotel with his own
# special generator. Each floor would send power to the floor above it,
# with the top floor sending power back down to the bottom floor. That
# way, Hilbert could have the generator placed on any given floor (as he
# likes having the option) and have electricity flow freely throughout the
#  entire hotel.</p>
#
# <p>Unfortunately, the contractors misinterpreted the schematics when
# they built the hotel. They informed Hilbert that each floor sends power
# "to another floor at random, instead. This may compromise Hilbert's "
# freedom to have the generator placed anywhere, since blackouts could
# occur on certain floors.</p>
#
# <p>For example, consider a sample flow diagram for a three-story hotel:</p>
#
# <p align="center"><img src="webfiles/p522_hilberts_blackout.png" alt="p522_hilberts_blackout.png"></p>
#
# <p>If the generator were placed on the first floor, then every floor
# would receive power. But if it were placed on the second or third floors
#  instead, then there would be a blackout on the first floor. Note that
# while a given floor can <i>receive</i> power from many other floors at once, it can only <i>send</i> power to one other floor.</p>
#
# <p>To resolve the blackout concerns, Hilbert decided to have a minimal
# number of floors rewired. To rewire a floor is to change the floor it
# sends power to. In the sample diagram above, all possible blackouts can
# be avoided by rewiring the second floor to send power to the first floor
#  instead of the third floor.</p>
#
# <p>Let F(<var>n</var>) be the sum of the minimum number of floor rewirings needed over all possible power-flow arrangements in a hotel of <var>n</var> floors. For example, F(3) = 6, F(8) = 16276736, and F(100) mod 135707531 = 84326147.</p>
#
# <p>Find F(12344321) mod 135707531.</p>

# %%
submit_answer(answer; prob_num=522);

# %% [markdown]
# ## Problem 523: First Sort I
# <p>Consider the following algorithm for sorting a list:</p>
# <ul style="list-style-type:none;"><li>1. Starting from the beginning of the list, check each pair of adjacent elements in turn.</li>
# <li>2. If the elements are out of order:
# <ul style="list-style-type:none;"><li>a. Move the smallest element of the pair at the beginning of the list.</li>
# <li>b. Restart the process from step 1.</li></ul></li>
# <li>3. If all pairs are in order, stop.</li></ul><p>For example, the list { 4 1 3 2 } is sorted as follows:</p>
# <ul style="list-style-type:none;"><li><u>4 1</u> 3 2  (4 and 1 are out of order so move 1 to the front of the list)</li>
# <li>1 <u>4 3</u> 2  (4 and 3 are out of order so move 3 to the front of the list)</li>
# <li><u>3 1</u> 4 2  (3 and 1 are out of order so move 1 to the front of the list)</li>
# <li>1 3 <u>4 2</u>  (4 and 2 are out of order so move 2 to the front of the list)</li>
# <li><u>2 1</u> 3 4  (2 and 1 are out of order so move 1 to the front of the list)</li>
# <li>1 2 3 4  (The list is now sorted)</li></ul><p>Let <var>F</var>(<var>L</var>) be the number of times step 2a is executed to sort list <var>L</var>. For example, <var>F</var>({ 4 1 3 2 }) = 5.</p>
#
# <p>Let <var>E</var>(<var>n</var>) be the <b>expected value</b> of <var>F</var>(<var>P</var>) over all permutations <var>P</var> of the integers {1, 2, ..., <var>n</var>}.<br>
# You are given <var>E</var>(4) = 3.25 and <var>E</var>(10) = 115.725.</p>
#
# <p>Find <var>E</var>(30). Give your answer rounded to two digits after the decimal point.</p>

# %%
submit_answer(answer; prob_num=523);

# %% [markdown]
# ## Problem 524: First Sort II
# <p>Consider the following algorithm for sorting a list:</p>
# <ul style="list-style-type:none;"><li>1. Starting from the beginning of the list, check each pair of adjacent elements in turn.</li>
# <li>2. If the elements are out of order:
# <ul style="list-style-type:none;"><li>a. Move the smallest element of the pair at the beginning of the list.</li>
# <li>b. Restart the process from step 1.</li></ul></li>
# <li>3. If all pairs are in order, stop.</li></ul><p>For example, the list { 4 1 3 2 } is sorted as follows:</p>
# <ul style="list-style-type:none;"><li><u>4 1</u> 3 2  (4 and 1 are out of order so move 1 to the front of the list)</li>
# <li>1 <u>4 3</u> 2  (4 and 3 are out of order so move 3 to the front of the list)</li>
# <li><u>3 1</u> 4 2  (3 and 1 are out of order so move 1 to the front of the list)</li>
# <li>1 3 <u>4 2</u>  (4 and 2 are out of order so move 2 to the front of the list)</li>
# <li><u>2 1</u> 3 4  (2 and 1 are out of order so move 1 to the front of the list)</li>
# <li>1 2 3 4  (The list is now sorted)</li></ul><p>Let <var>F</var>(<var>L</var>) be the number of times step 2a is executed to sort list <var>L</var>. For example, <var>F</var>({ 4 1 3 2 }) = 5.</p>
#
# <p>We can list all permutations <var>P</var> of the integers {1, 2, ..., <var>n</var>} in <b>lexicographical order</b>, and assign to each permutation an index <var>I</var><sub><var>n</var></sub>(<var>P</var>) from 1 to <var>n</var>! corresponding to its position in the list.
#
# </p><p>Let <var>Q</var>(<var>n</var>, <var>k</var>) = min(<var>I</var><sub><var>n</var></sub>(<var>P</var>)) for <var>F</var>(<var>P</var>) = <var>k</var>, the index of the first permutation requiring exactly <var>k</var> steps to sort with First Sort. If there is no permutation for which <var>F</var>(<var>P</var>) = <var>k</var>, then <var>Q</var>(<var>n</var>, <var>k</var>) is undefined.</p>
#
# <p>For <var>n</var> = 4 we have:</p>
#
# <p></p><table style="text-align:left;" border="1"><tbody><tr><th><var>P</var></th><th><var>I</var><sub>4</sub>(<var>P</var>)</th><th><var>F</var>(<var>P</var>)</th><th></th></tr><tr><td>{1, 2, 3, 4}</td><td>1</td><td>0</td><td>Q(4, 0) = 1</td></tr><tr><td>{1, 2, 4, 3}</td><td>2</td><td>4</td><td>Q(4, 4) = 2</td></tr><tr><td>{1, 3, 2, 4}</td><td>3</td><td>2</td><td>Q(4, 2) = 3</td></tr><tr><td>{1, 3, 4, 2}</td><td>4</td><td>2</td><td></td></tr><tr><td>{1, 4, 2, 3}</td><td>5</td><td>6</td><td>Q(4, 6) = 5</td></tr><tr><td>{1, 4, 3, 2}</td><td>6</td><td>4</td><td></td></tr><tr><td>{2, 1, 3, 4}</td><td>7</td><td>1</td><td>Q(4, 1) = 7</td></tr><tr><td>{2, 1, 4, 3}</td><td>8</td><td>5</td><td>Q(4, 5) = 8</td></tr><tr><td>{2, 3, 1, 4}</td><td>9</td><td>1</td><td></td></tr><tr><td>{2, 3, 4, 1}</td><td>10</td><td>1</td><td></td></tr><tr><td>{2, 4, 1, 3}</td><td>11</td><td>5</td><td></td></tr><tr><td>{2, 4, 3, 1}</td><td>12</td><td>3</td><td>Q(4, 3) = 12</td></tr><tr><td>{3, 1, 2, 4}</td><td>13</td><td>3</td><td></td></tr><tr><td>{3, 1, 4, 2}</td><td>14</td><td>3</td><td></td></tr><tr><td>{3, 2, 1, 4}</td><td>15</td><td>2</td><td></td></tr><tr><td>{3, 2, 4, 1}</td><td>16</td><td>2</td><td></td></tr><tr><td>{3, 4, 1, 2}</td><td>17</td><td>3</td><td></td></tr><tr><td>{3, 4, 2, 1}</td><td>18</td><td>2</td><td></td></tr><tr><td>{4, 1, 2, 3}</td><td>19</td><td>7</td><td>Q(4, 7) = 19</td></tr><tr><td>{4, 1, 3, 2}</td><td>20</td><td>5</td><td></td></tr><tr><td>{4, 2, 1, 3}</td><td>21</td><td>6</td><td></td></tr><tr><td>{4, 2, 3, 1}</td><td>22</td><td>4</td><td></td></tr><tr><td>{4, 3, 1, 2}</td><td>23</td><td>4</td><td></td></tr><tr><td>{4, 3, 2, 1}</td><td>24</td><td>3</td><td></td></tr></tbody></table><p>Let <var>R</var>(<var>k</var>) = min(<var>Q</var>(<var>n</var>, <var>k</var>)) over all <var>n</var> for which <var>Q</var>(<var>n</var>, <var>k</var>) is defined.</p>
#
# <p>Find <var>R</var>(12<sup>12</sup>).</p>

# %%
submit_answer(answer; prob_num=524);

# %% [markdown]
# ## Problem 525: Rolling Ellipse
# <p>An ellipse <var>E</var>(<var>a</var>, <var>b</var>) is given at its initial position by equation:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-153-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;msup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/mfrac&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/mrow&gt;&lt;msup&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/mfrac&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2819" style="width: 8.615em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.507em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.289em, 1006.43em, 3.361em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2820"><span class="mfrac" id="MathJax-Span-2821"><span style="display: inline-block; position: relative; width: 0.827em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.286em, 1000.71em, 4.17em, -1000em); top: -4.427em; left: 50%; margin-left: -0.354em;"><span class="msubsup" id="MathJax-Span-2822"><span style="display: inline-block; position: relative; width: 0.707em; height: 0px;"><span style="position: absolute; clip: rect(3.563em, 1000.37em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2823" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.276em; left: 0.404em;"><span class="mn" id="MathJax-Span-2824" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.338em, 1000.68em, 4.17em, -1000em); top: -3.582em; left: 50%; margin-left: -0.339em;"><span class="msubsup" id="MathJax-Span-2825"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2826" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.223em; left: 0.374em;"><span class="mn" id="MathJax-Span-2827" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.83em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.827em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-2828" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mfrac" id="MathJax-Span-2829" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 2.177em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.205em, 1002.06em, 4.339em, -1000em); top: -4.596em; left: 50%; margin-left: -1.029em;"><span class="mrow" id="MathJax-Span-2830"><span class="mo" id="MathJax-Span-2831" style="font-size: 70.7%; font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2832" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.004em;"></span></span><span class="mo" id="MathJax-Span-2833" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mi" id="MathJax-Span-2834" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span class="msubsup" id="MathJax-Span-2835"><span style="display: inline-block; position: relative; width: 0.578em; height: 0px;"><span style="position: absolute; clip: rect(3.345em, 1000.21em, 4.339em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-2836" style="font-size: 70.7%; font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.356em; left: 0.275em;"><span class="mn" id="MathJax-Span-2837" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.245em, 1000.61em, 4.17em, -1000em); top: -3.489em; left: 50%; margin-left: -0.303em;"><span class="msubsup" id="MathJax-Span-2838"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-2839" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.317em; left: 0.303em;"><span class="mn" id="MathJax-Span-2840" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1002.18em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 2.177em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-2841" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2842" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.774em; border-left: 0px solid; width: 0px; height: 2.482em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><msup><mi>x</mi><mn>2</mn></msup><msup><mi>a</mi><mn>2</mn></msup></mfrac><mo>+</mo><mfrac><mrow><mo stretchy="false">(</mo><mi>y</mi><mo>−</mo><mi>b</mi><msup><mo stretchy="false">)</mo><mn>2</mn></msup></mrow><msup><mi>b</mi><mn>2</mn></msup></mfrac><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-153">\\frac {x^2} {a^2} + \\frac {(y - b)^2} {b^2} = 1</script></p>
#
# <p>The ellipse rolls without slipping along the <var>x</var> axis for
# one complete turn. Interestingly, the length of the curve generated by a
#  focus is independent from the size of the minor axis:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-154-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mtext&gt;&amp;#xA0;&lt;/mtext&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-2843" style="width: 12.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.665em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1009.57em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-2844"><span class="mi" id="MathJax-Span-2845" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-2846" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2847" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-2848" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-2849" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-2850" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-2851" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-2852" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span><span class="mi" id="MathJax-Span-2853" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mtext" id="MathJax-Span-2854" style="font-family: MathJax_Main;">&nbsp;</span><span class="mi" id="MathJax-Span-2855" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mi" id="MathJax-Span-2856" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-2857" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-2858" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-2859" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-2860" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-2861" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-2862" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mi>a</mi><mo>,</mo><mi>b</mi><mo stretchy="false">)</mo><mo>=</mo><mn>2</mn><mi>π</mi><mtext>&nbsp;</mtext><mi>m</mi><mi>a</mi><mi>x</mi><mo stretchy="false">(</mo><mi>a</mi><mo>,</mo><mi>b</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-154">F(a,b) =  2 \\pi \\text{ } max(a,b)</script></p>
#
# <div align="center"><img src="webfiles/p525-rolling-ellipse-1.gif" alt="p525-rolling-ellipse-1.gif"></div>
#
# <p>This is not true for the curve generated by the ellipse center. Let <var>C</var>(<var>a</var>,<var>b</var>) be the length of the curve generated by the center of the ellipse as it rolls without slipping for one turn.</p>
#
# <div align="center"><img src="webfiles/p525-rolling-ellipse-2.gif" alt="p525-rolling-ellipse-2.gif"></div>
#
# <p>You are given <var>C</var>(2, 4) ~ 21.38816906.</p>
#
# <p>Find <var>C</var>(1, 4) + <var>C</var>(3, 4). Give your answer rounded to 8 digits behind the decimal point in the form <i>ab.cdefghij</i>.</p>

# %%
submit_answer(answer; prob_num=525);
