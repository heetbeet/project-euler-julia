# %%
include("shared.jl");

# %% [markdown]
# ## Problem 576: Irrational jumps
# <p>
# A bouncing point moves counterclockwise along a circle with circumference <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-390-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5275" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5276"><span class="mn" id="MathJax-Span-5277" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-390">1</script> with  jumps of constant length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-391-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5278" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.03em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5279"><span class="mi" id="MathJax-Span-5280" style="font-family: MathJax_Math; font-style: italic;">l</span><span class="mo" id="MathJax-Span-5281" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mn" id="MathJax-Span-5282" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 1.095em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>l</mi><mo>&lt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-391">l<1</script>, until it hits a gap of length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-392-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5283" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.22em, 3.028em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5284"><span class="mi" id="MathJax-Span-5285" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5286" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mn" id="MathJax-Span-5287" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 1.276em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo>&lt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-392">g<1</script>, that is placed in a distance <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-393-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5288" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.53em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5289"><span class="mi" id="MathJax-Span-5290" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.056em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>d</mi></math></span></span><script type="math/tex" id="MathJax-Element-393">d</script> counterclockwise from the starting point. The gap does not include the starting point, that is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-394-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5291" style="width: 5.313em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.019em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1003.95em, 3.028em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5292"><span class="mi" id="MathJax-Span-5293" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5294" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-5295" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5296" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mn" id="MathJax-Span-5297" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 1.313em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo>+</mo><mi>d</mi><mo>&lt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-394">g+d<1</script>.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-395-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5298" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.54em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5299"><span class="mi" id="MathJax-Span-5300" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5301" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5302" style="font-family: MathJax_Math; font-style: italic;">l</span><span class="mo" id="MathJax-Span-5303" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5304" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5305" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5306" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5307" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>l</mi><mo>,</mo><mi>g</mi><mo>,</mo><mi>d</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-395">S(l,g,d)</script> be the sum of the length of all jumps, until the point falls into the gap. It can be shown that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-396-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5308" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.54em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5309"><span class="mi" id="MathJax-Span-5310" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5311" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5312" style="font-family: MathJax_Math; font-style: italic;">l</span><span class="mo" id="MathJax-Span-5313" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5314" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5315" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5316" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5317" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>l</mi><mo>,</mo><mi>g</mi><mo>,</mo><mi>d</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-396">S(l,g,d)</script> is finite for any irrational jump size <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-397-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;l&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5318" style="width: 0.385em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.287em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.26em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5319"><span class="mi" id="MathJax-Span-5320" style="font-family: MathJax_Math; font-style: italic;">l</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>l</mi></math></span></span><script type="math/tex" id="MathJax-Element-397">l</script>, regardless of the values of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-398-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5321" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.789em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5322"><span class="mi" id="MathJax-Span-5323" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi></math></span></span><script type="math/tex" id="MathJax-Element-398">g</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-399-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5324" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.53em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5325"><span class="mi" id="MathJax-Span-5326" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.056em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>d</mi></math></span></span><script type="math/tex" id="MathJax-Element-399">d</script>.<br>
# Examples: <br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-400-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.06&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.7071&lt;/mn&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5327" style="width: 16.366em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.392em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.371em, 1012.31em, 3.458em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5328"><span class="mi" id="MathJax-Span-5329" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5330" style="font-family: MathJax_Main;">(</span><span class="msqrt" id="MathJax-Span-5331"><span style="display: inline-block; position: relative; width: 1.739em; height: 0px;"><span style="position: absolute; clip: rect(3.005em, 1000.71em, 4.533em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-5332"><span class="mfrac" id="MathJax-Span-5333"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5334" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5335" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.74em, 3.935em, -1000em); top: -4.911em; left: 1em;"><span style="display: inline-block; position: relative; width: 0.739em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.045em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -4.034em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5336" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5337" style="font-family: MathJax_Main; padding-left: 0.167em;">0.06</span><span class="mo" id="MathJax-Span-5338" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5339" style="font-family: MathJax_Main; padding-left: 0.167em;">0.7</span><span class="mo" id="MathJax-Span-5340" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5341" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5342" style="font-family: MathJax_Main; padding-left: 0.278em;">0.7071</span><span class="mo" id="MathJax-Span-5343" style="font-family: MathJax_Main; padding-left: 0.167em;">…</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.901em; border-left: 0px solid; width: 0px; height: 2.502em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msqrt><mfrac><mn>1</mn><mn>2</mn></mfrac></msqrt><mo>,</mo><mn>0.06</mn><mo>,</mo><mn>0.7</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.7071</mn><mo>…</mo></math></span></span><script type="math/tex" id="MathJax-Element-400">S(\\sqrt{\\frac 1 2}, 0.06, 0.7)=0.7071 \\dots</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-401-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.06&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.3543&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1.4142&lt;/mn&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5344" style="width: 18.28em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.828em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.371em, 1013.75em, 3.458em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5345"><span class="mi" id="MathJax-Span-5346" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5347" style="font-family: MathJax_Main;">(</span><span class="msqrt" id="MathJax-Span-5348"><span style="display: inline-block; position: relative; width: 1.739em; height: 0px;"><span style="position: absolute; clip: rect(3.005em, 1000.71em, 4.533em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-5349"><span class="mfrac" id="MathJax-Span-5350"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5351" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5352" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.74em, 3.935em, -1000em); top: -4.911em; left: 1em;"><span style="display: inline-block; position: relative; width: 0.739em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.045em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -4.034em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5353" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5354" style="font-family: MathJax_Main; padding-left: 0.167em;">0.06</span><span class="mo" id="MathJax-Span-5355" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5356" style="font-family: MathJax_Main; padding-left: 0.167em;">0.3543</span><span class="mo" id="MathJax-Span-5357" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5358" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5359" style="font-family: MathJax_Main; padding-left: 0.278em;">1.4142</span><span class="mo" id="MathJax-Span-5360" style="font-family: MathJax_Main; padding-left: 0.167em;">…</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.901em; border-left: 0px solid; width: 0px; height: 2.502em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msqrt><mfrac><mn>1</mn><mn>2</mn></mfrac></msqrt><mo>,</mo><mn>0.06</mn><mo>,</mo><mn>0.3543</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1.4142</mn><mo>…</mo></math></span></span><script type="math/tex" id="MathJax-Element-401">S(\\sqrt{\\frac 1 2}, 0.06, 0.3543)=1.4142 \\dots</script> and <br> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-402-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.06&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.2427&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;16.2634&lt;/mn&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5361" style="width: 18.902em; display: inline-block;"><span style="display: inline-block; position: relative; width: 14.306em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.371em, 1014.23em, 3.458em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5362"><span class="mi" id="MathJax-Span-5363" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5364" style="font-family: MathJax_Main;">(</span><span class="msqrt" id="MathJax-Span-5365"><span style="display: inline-block; position: relative; width: 1.739em; height: 0px;"><span style="position: absolute; clip: rect(3.005em, 1000.71em, 4.533em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-5366"><span class="mfrac" id="MathJax-Span-5367"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5368" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5369" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.74em, 3.935em, -1000em); top: -4.911em; left: 1em;"><span style="display: inline-block; position: relative; width: 0.739em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.045em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -4.034em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5370" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5371" style="font-family: MathJax_Main; padding-left: 0.167em;">0.06</span><span class="mo" id="MathJax-Span-5372" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5373" style="font-family: MathJax_Main; padding-left: 0.167em;">0.2427</span><span class="mo" id="MathJax-Span-5374" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5375" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5376" style="font-family: MathJax_Main; padding-left: 0.278em;">16.2634</span><span class="mo" id="MathJax-Span-5377" style="font-family: MathJax_Main; padding-left: 0.167em;">…</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.901em; border-left: 0px solid; width: 0px; height: 2.502em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msqrt><mfrac><mn>1</mn><mn>2</mn></mfrac></msqrt><mo>,</mo><mn>0.06</mn><mo>,</mo><mn>0.2427</mn><mo stretchy="false">)</mo><mo>=</mo><mn>16.2634</mn><mo>…</mo></math></span></span><script type="math/tex" id="MathJax-Element-402">S(\\sqrt{\\frac 1 2}, 0.06, 0.2427)=16.2634 \\dots</script>.</p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-403-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5378" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.25em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5379"><span class="mi" id="MathJax-Span-5380" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-5381" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5382" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5383" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5384" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5385" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>g</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-403">M(n, g)</script> be the maximum of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-404-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5386" style="width: 8.376em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.316em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.522em, 1006.22em, 3.609em, -1000em); top: -2.775em; left: 0em;"><span class="mrow" id="MathJax-Span-5387"><span class="mo" id="MathJax-Span-5388" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span class="mi" id="MathJax-Span-5389" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5390" style="font-family: MathJax_Main;">(</span><span class="msqrt" id="MathJax-Span-5391"><span style="display: inline-block; position: relative; width: 1.741em; height: 0px;"><span style="position: absolute; clip: rect(3.005em, 1000.72em, 4.645em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-5392"><span class="mfrac" id="MathJax-Span-5393"><span style="display: inline-block; position: relative; width: 0.476em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5394" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.35em, 4.3em, -1000em); top: -3.674em; left: 50%; margin-left: -0.178em;"><span class="mi" id="MathJax-Span-5395" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.48em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.476em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.74em, 3.935em, -1000em); top: -4.856em; left: 1em;"><span style="display: inline-block; position: relative; width: 0.741em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.047em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -3.979em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5396" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5397" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5398" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5399" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5400" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.775em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.975em; border-left: 0px solid; width: 0px; height: 2.502em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo>∑</mo><mi>S</mi><mo stretchy="false">(</mo><msqrt><mfrac><mn>1</mn><mi>p</mi></mfrac></msqrt><mo>,</mo><mi>g</mi><mo>,</mo><mi>d</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-404"> \\sum S(\\sqrt{\\frac 1 p}, g, d)</script> for all primes <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-405-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5401" style="width: 3.304em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.488em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.9em, 1002.47em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5402"><span class="mi" id="MathJax-Span-5403" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5404" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-5405" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.222em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>≤</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-405">p \\le n</script> and any valid value of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-406-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5406" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.53em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5407"><span class="mi" id="MathJax-Span-5408" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.056em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>d</mi></math></span></span><script type="math/tex" id="MathJax-Element-406">d</script>.<br>
# Examples:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-407-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.06&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;29.5425&lt;/mn&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5409" style="width: 13.591em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.287em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1010.21em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5410"><span class="mi" id="MathJax-Span-5411" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-5412" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5413" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-5414" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5415" style="font-family: MathJax_Main; padding-left: 0.167em;">0.06</span><span class="mo" id="MathJax-Span-5416" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5417" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5418" style="font-family: MathJax_Main; padding-left: 0.278em;">29.5425</span><span class="mo" id="MathJax-Span-5419" style="font-family: MathJax_Main; padding-left: 0.167em;">…</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mn>0.06</mn><mo stretchy="false">)</mo><mo>=</mo><mn>29.5425</mn><mo>…</mo></math></span></span><script type="math/tex" id="MathJax-Element-407">M(3, 0.06) =29.5425 \\dots</script>, since <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-408-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.06&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.2427&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.06&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.2427&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;29.5425&lt;/mn&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5420" style="width: 31.677em; display: inline-block;"><span style="display: inline-block; position: relative; width: 23.971em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.371em, 1023.89em, 3.465em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5421"><span class="mi" id="MathJax-Span-5422" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5423" style="font-family: MathJax_Main;">(</span><span class="msqrt" id="MathJax-Span-5424"><span style="display: inline-block; position: relative; width: 1.739em; height: 0px;"><span style="position: absolute; clip: rect(3.005em, 1000.71em, 4.533em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-5425"><span class="mfrac" id="MathJax-Span-5426"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5427" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5428" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.74em, 3.935em, -1000em); top: -4.911em; left: 1em;"><span style="display: inline-block; position: relative; width: 0.739em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.045em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -4.034em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5429" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5430" style="font-family: MathJax_Main; padding-left: 0.167em;">0.06</span><span class="mo" id="MathJax-Span-5431" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5432" style="font-family: MathJax_Main; padding-left: 0.167em;">0.2427</span><span class="mo" id="MathJax-Span-5433" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5434" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-5435" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5436" style="font-family: MathJax_Main;">(</span><span class="msqrt" id="MathJax-Span-5437"><span style="display: inline-block; position: relative; width: 1.739em; height: 0px;"><span style="position: absolute; clip: rect(3.005em, 1000.71em, 4.548em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-5438"><span class="mfrac" id="MathJax-Span-5439"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5440" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.649em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5441" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.74em, 3.935em, -1000em); top: -4.904em; left: 1em;"><span style="display: inline-block; position: relative; width: 0.739em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.045em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -4.027em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5442" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5443" style="font-family: MathJax_Main; padding-left: 0.167em;">0.06</span><span class="mo" id="MathJax-Span-5444" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5445" style="font-family: MathJax_Main; padding-left: 0.167em;">0.2427</span><span class="mo" id="MathJax-Span-5446" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5447" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5448" style="font-family: MathJax_Main; padding-left: 0.278em;">29.5425</span><span class="mo" id="MathJax-Span-5449" style="font-family: MathJax_Main; padding-left: 0.167em;">…</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.911em; border-left: 0px solid; width: 0px; height: 2.512em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msqrt><mfrac><mn>1</mn><mn>2</mn></mfrac></msqrt><mo>,</mo><mn>0.06</mn><mo>,</mo><mn>0.2427</mn><mo stretchy="false">)</mo><mo>+</mo><mi>S</mi><mo stretchy="false">(</mo><msqrt><mfrac><mn>1</mn><mn>3</mn></mfrac></msqrt><mo>,</mo><mn>0.06</mn><mo>,</mo><mn>0.2427</mn><mo stretchy="false">)</mo><mo>=</mo><mn>29.5425</mn><mo>…</mo></math></span></span><script type="math/tex" id="MathJax-Element-408">S(\\sqrt{\\frac 1 2}, 0.06, 0.2427)+S(\\sqrt{\\frac 1 3}, 0.06, 0.2427)=29.5425 \\dots</script> is the maximal reachable sum for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-409-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.06&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5450" style="width: 4.691em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.541em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1003.5em, 3.028em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5451"><span class="mi" id="MathJax-Span-5452" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-5453" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5454" style="font-family: MathJax_Main; padding-left: 0.278em;">0.06</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 1.276em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo>=</mo><mn>0.06</mn></math></span></span><script type="math/tex" id="MathJax-Element-409">g=0.06</script>. <br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-410-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.01&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;266.9010&lt;/mn&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5455" style="width: 14.883em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.244em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1011.16em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5456"><span class="mi" id="MathJax-Span-5457" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-5458" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5459" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-5460" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5461" style="font-family: MathJax_Main; padding-left: 0.167em;">0.01</span><span class="mo" id="MathJax-Span-5462" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5463" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5464" style="font-family: MathJax_Main; padding-left: 0.278em;">266.9010</span><span class="mo" id="MathJax-Span-5465" style="font-family: MathJax_Main; padding-left: 0.167em;">…</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo stretchy="false">(</mo><mn>10</mn><mo>,</mo><mn>0.01</mn><mo stretchy="false">)</mo><mo>=</mo><mn>266.9010</mn><mo>…</mo></math></span></span><script type="math/tex" id="MathJax-Element-410">M(10, 0.01)=266.9010 \\dots</script> </p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-411-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;0.00002&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5466" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.75em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5467"><span class="mi" id="MathJax-Span-5468" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-5469" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5470" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-5471" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5472" style="font-family: MathJax_Main; padding-left: 0.167em;">0.00002</span><span class="mo" id="MathJax-Span-5473" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo stretchy="false">(</mo><mn>100</mn><mo>,</mo><mn>0.00002</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-411">M(100, 0.00002)</script>, rounded to 4 decimal places.</p>

# %%
submit_answer(answer; prob_num=576);

# %% [markdown]
# ## Problem 577: Counting hexagons
# <p>An equilateral triangle with integer side length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-412-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5474" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1002.4em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5475"><span class="mi" id="MathJax-Span-5476" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5477" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-5478" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.186em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>≥</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-412">n \\ge 3</script> is divided into <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-413-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5479" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.224em, 1001.05em, 2.355em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5480"><span class="msubsup" id="MathJax-Span-5481"><span style="display: inline-block; position: relative; width: 1.029em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.58em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5482" style="font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.6em;"><span class="mn" id="MathJax-Span-5483" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.241em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mi>n</mi><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-413">n^2</script> equilateral triangles with side length 1 as shown in the diagram below.<br>
# The vertices of these triangles constitute a triangular lattice with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-414-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5484" style="width: 5.457em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.115em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.951em, 1004.11em, 2.715em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5485"><span class="mfrac" id="MathJax-Span-5486"><span style="display: inline-block; position: relative; width: 3.876em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.345em, 1003.69em, 4.339em, -1000em); top: -4.596em; left: 50%; margin-left: -1.878em;"><span class="mrow" id="MathJax-Span-5487"><span class="mo" id="MathJax-Span-5488" style="font-size: 70.7%; font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5489" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5490" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mn" id="MathJax-Span-5491" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-5492" style="font-size: 70.7%; font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5493" style="font-size: 70.7%; font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5494" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5495" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mn" id="MathJax-Span-5496" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-5497" style="font-size: 70.7%; font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5498" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1003.88em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 3.876em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.552em; border-left: 0px solid; width: 0px; height: 2.077em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mrow><mo stretchy="false">(</mo><mi>n</mi><mo>+</mo><mn>1</mn><mo stretchy="false">)</mo><mo stretchy="false">(</mo><mi>n</mi><mo>+</mo><mn>2</mn><mo stretchy="false">)</mo></mrow><mn>2</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-414">\\frac{(n+1)(n+2)} 2</script> lattice points.</p>
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-415-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5499" style="width: 2.969em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.249em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.15em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5500"><span class="mi" id="MathJax-Span-5501" style="font-family: MathJax_Math; font-style: italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.057em;"></span></span><span class="mo" id="MathJax-Span-5502" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5503" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5504" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>H</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-415">H(n)</script> be the number of all regular hexagons that can be found by connecting 6 of these points.</p>
# <div style="text-align:center;">
# <img src="webfiles/p577_counting_hexagons.png" alt="p577_counting_hexagons.png"></div>
#
# <p>
# For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-416-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5505" style="width: 5.218em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.923em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.85em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5506"><span class="mi" id="MathJax-Span-5507" style="font-family: MathJax_Math; font-style: italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.057em;"></span></span><span class="mo" id="MathJax-Span-5508" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5509" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-5510" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5511" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5512" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>H</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-416">H(3)=1</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-417-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5513" style="width: 5.84em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.402em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.35em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5514"><span class="mi" id="MathJax-Span-5515" style="font-family: MathJax_Math; font-style: italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.057em;"></span></span><span class="mo" id="MathJax-Span-5516" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5517" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-5518" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5519" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5520" style="font-family: MathJax_Main; padding-left: 0.278em;">12</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>H</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>12</mn></math></span></span><script type="math/tex" id="MathJax-Element-417">H(6)=12</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-418-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;20&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;966&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5521" style="width: 7.084em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.359em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.32em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5522"><span class="mi" id="MathJax-Span-5523" style="font-family: MathJax_Math; font-style: italic;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.057em;"></span></span><span class="mo" id="MathJax-Span-5524" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5525" style="font-family: MathJax_Main;">20</span><span class="mo" id="MathJax-Span-5526" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5527" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5528" style="font-family: MathJax_Main; padding-left: 0.278em;">966</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>H</mi><mo stretchy="false">(</mo><mn>20</mn><mo stretchy="false">)</mo><mo>=</mo><mn>966</mn></math></span></span><script type="math/tex" id="MathJax-Element-418">H(20)=966</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-419-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12345&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5529" style="width: 5.553em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.211em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.807em, 1004.12em, 4.025em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5530"><span class="mstyle" id="MathJax-Span-5531"><span class="mrow" id="MathJax-Span-5532"><span class="munderover" id="MathJax-Span-5533"><span style="display: inline-block; position: relative; width: 1.768em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0.162em;"><span class="mo" id="MathJax-Span-5534" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.3em, 4.278em, -1000em); top: -2.932em; left: 0.22em;"><span class="texatom" id="MathJax-Span-5535"><span class="mrow" id="MathJax-Span-5536"><span class="mi" id="MathJax-Span-5537" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5538" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-5539" style="font-size: 70.7%; font-family: MathJax_Main;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.297em, 1001.73em, 4.178em, -1000em); top: -5.169em; left: 0em;"><span class="texatom" id="MathJax-Span-5540"><span class="mrow" id="MathJax-Span-5541"><span class="mn" id="MathJax-Span-5542" style="font-size: 70.7%; font-family: MathJax_Main;">12345</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-5543" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">H<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.057em;"></span></span><span class="mo" id="MathJax-Span-5544" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5545" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5546" style="font-family: MathJax_Main;">)</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.65em; border-left: 0px solid; width: 0px; height: 3.995em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>3</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>12345</mn></mrow></munderover><mi>H</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-419">\\displaystyle \\sum_{n=3}^{12345} H(n)</script>.</p>

# %%
submit_answer(answer; prob_num=577);

# %% [markdown]
# ## Problem 578: Integers with decreasing prime powers
# <p>Any positive integer can be written as a product of prime powers: <var>p</var><sub>1</sub><sup><var>a</var><sub>1</sub></sup>&nbsp;×&nbsp;<var>p</var><sub>2</sub><sup><var>a</var><sub>2</sub></sup>&nbsp;×&nbsp;...&nbsp;×&nbsp;<var>p<sub>k</sub><sup>a<sub>k</sub></sup></var>,<br>
# where <var>p<sub>i</sub></var> are distinct prime integers, <var>a<sub>i</sub></var>&nbsp;&gt;&nbsp;0 and <var>p<sub>i</sub></var>&nbsp;&lt;&nbsp;<var>p<sub>j</sub></var> if <var>i</var>&nbsp;&lt;&nbsp;<var>j</var>.</p>
#
# <p>A <i>decreasing prime power</i> positive integer is one for which <var>a<sub>i</sub></var>&nbsp;≥&nbsp;<var>a<sub>j</sub></var> if <var>i</var>&nbsp;&lt;&nbsp;<var>j</var>.<br>
# For example, 1, 2, 15=3×5, 360=2<sup>3</sup>×3<sup>2</sup>×5 and 1000=2<sup>3</sup>×5<sup>3</sup> are decreasing prime power integers.</p>
#
# <p>Let C(<var>n</var>) be the count of decreasing prime power positive integers not exceeding <var>n</var>.<br>
# C(100)&nbsp;=&nbsp;94 since all positive integers not exceeding 100 have
#  decreasing prime powers except 18, 50, 54, 75, 90 and 98.<br>
# You are given C(10<sup>6</sup>)&nbsp;=&nbsp;922052.</p>
#
# <p>Find C(10<sup>13</sup>).</p>

# %%
submit_answer(answer; prob_num=578);

# %% [markdown]
# ## Problem 579: Lattice points in lattice cubes
# <p>A <b>lattice cube</b> is a cube in which all vertices have integer coordinates. Let C(<var>n</var>) be the number of different lattice cubes in which the coordinates of all vertices range between (and including) 0 and <var>n</var>. Two cubes are hereby considered different if any of their vertices have different coordinates.<br>
# For example, C(1)=1, C(2)=9, C(4)=100, C(5)=229, C(10)=4469 and C(50)=8154671.
# </p>
# <p>Different cubes may contain different numbers of lattice points.</p>
# <p>
# For example, the cube with the vertices<br>
# (0, 0, 0), (3, 0, 0), (0, 3, 0), (0, 0, 3), (0, 3, 3), (3, 0, 3), (3, 3,
#  0), (3, 3, 3) contains 64 lattice points (56 lattice points on the
# surface including the 8 vertices and 8 points within the cube). </p>
# <p>In contrast, the cube with the vertices<br>
# (0, 2, 2), (1, 4, 4), (2, 0, 3), (2, 3, 0), (3, 2, 5), (3, 5, 2), (4, 1,
#  1), (5, 3, 3) contains only 40 lattice points (20 points on the surface
#  and 20 points within the cube), although both cubes have the same side
# length 3.
# </p>
# <p>
# Let S(<var>n</var>) be the sum of the lattice points contained in the
# different lattice cubes in which the coordinates of all vertices range
# between (and including) 0 and <var>n</var>.</p>
#
# <p>For example, S(1)=8, S(2)=91, S(4)=1878, S(5)=5832, S(10)=387003 and S(50)=29948928129.</p>
#
# <p>Find S(5000) mod 10<sup>9</sup>.</p>

# %%
submit_answer(answer; prob_num=579);

# %% [markdown]
# ## Problem 580: Squarefree Hilbert numbers
# <p>
# A <b>Hilbert number</b> is any positive integer of the form <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-420-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5547" style="width: 3.543em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.679em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.61em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5548"><span class="mn" id="MathJax-Span-5549" style="font-family: MathJax_Main;">4</span><span class="mi" id="MathJax-Span-5550" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-5551" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5552" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.151em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>4</mn><mi>k</mi><mo>+</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-420">4k+1</script> for integer <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-421-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5553" style="width: 3.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.3em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5554"><span class="mi" id="MathJax-Span-5555" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-5556" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-5557" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.225em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi><mo>≥</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-421">k\\geq 0</script>.  We shall define a <i>squarefree Hilbert number</i> as a Hilbert number which is not divisible by the square of any Hilbert number other than one.  For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-422-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;117&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5558" style="width: 1.916em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.435em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.86em, 1001.42em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5559"><span class="mn" id="MathJax-Span-5560" style="font-family: MathJax_Main;">117</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.048em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>117</mn></math></span></span><script type="math/tex" id="MathJax-Element-422">117</script> is a squarefree Hilbert number, equaling <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-423-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5561" style="width: 3.495em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.632em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.59em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5562"><span class="mn" id="MathJax-Span-5563" style="font-family: MathJax_Main;">9</span><span class="mo" id="MathJax-Span-5564" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-5565" style="font-family: MathJax_Main; padding-left: 0.222em;">13</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>9</mn><mo>×</mo><mn>13</mn></math></span></span><script type="math/tex" id="MathJax-Element-423">9\\times13</script>.  However <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-424-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;6237&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5566" style="width: 2.538em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.86em, 1001.9em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5567"><span class="mn" id="MathJax-Span-5568" style="font-family: MathJax_Main;">6237</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.048em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>6237</mn></math></span></span><script type="math/tex" id="MathJax-Element-424">6237</script> is a Hilbert number that is not squarefree in this sense, as it is divisible by <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-425-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5569" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.194em, 1000.91em, 2.366em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5570"><span class="msubsup" id="MathJax-Span-5571"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.46em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5572" style="font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mn" id="MathJax-Span-5573" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.296em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>9</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-425">9^2</script>.  The number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-426-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;3969&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5574" style="width: 2.538em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1001.87em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5575"><span class="mn" id="MathJax-Span-5576" style="font-family: MathJax_Main;">3969</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>3969</mn></math></span></span><script type="math/tex" id="MathJax-Element-426">3969</script> is also not squarefree, as it is divisible by both <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-427-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5577" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.194em, 1000.91em, 2.366em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5578"><span class="msubsup" id="MathJax-Span-5579"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.46em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5580" style="font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mn" id="MathJax-Span-5581" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.296em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>9</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-427">9^2</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-428-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;21&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5582" style="width: 1.916em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.435em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.194em, 1001.43em, 2.344em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5583"><span class="msubsup" id="MathJax-Span-5584"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.93em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5585" style="font-family: MathJax_Main;">21</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-5586" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.267em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>21</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-428">21^2</script>.
# </p>
# <p>
# There are <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-429-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2327192&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5587" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.86em, 1003.3em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5588"><span class="mn" id="MathJax-Span-5589" style="font-family: MathJax_Main;">2327192</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.048em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2327192</mn></math></span></span><script type="math/tex" id="MathJax-Element-429">2327192</script> squarefree Hilbert numbers below <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-430-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5590" style="width: 1.916em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.435em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.186em, 1001.43em, 2.366em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5591"><span class="msubsup" id="MathJax-Span-5592"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5593" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-5594" style="font-size: 70.7%; font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.305em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>10</mn><mn>7</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-430">10^7</script>. <br>
# How many squarefree Hilbert numbers are there below <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-431-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;16&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5595" style="width: 2.347em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.77em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.194em, 1001.77em, 2.366em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5596"><span class="msubsup" id="MathJax-Span-5597"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5598" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-5599"><span class="mrow" id="MathJax-Span-5600"><span class="mn" id="MathJax-Span-5601" style="font-size: 70.7%; font-family: MathJax_Main;">16</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.296em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>16</mn></mrow></msup></math></span></span><script type="math/tex" id="MathJax-Element-431">10^{16}</script>?
# </p>

# %%
submit_answer(answer; prob_num=580);

# %% [markdown]
# ## Problem 581: 47-smooth triangular numbers
# <p>
# A number is p-smooth if it has no prime factors larger than p.<br>
# Let T be the sequence of triangular numbers, ie T(<var>n</var>)=<var>n</var>(<var>n</var>+1)/2.<br>
# Find the sum of all indices <var>n</var> such that T(<var>n</var>) is 47-smooth.
# </p>

# %%
submit_answer(answer; prob_num=581);

# %% [markdown]
# ## Problem 582: Nearly isosceles 120 degree triangles
# <p>
# Let a, b and c be the sides of an integer sided triangle with one angle of 120 degrees, a≤b≤c and b-a≤100.<br>
# Let T(<var>n</var>) be the number of such triangles with c≤<var>n</var>.<br>
# T(1000)=235 and T(10<sup>8</sup>)=1245.<br>
# Find T(10<sup>100</sup>).
# </p>

# %%
submit_answer(answer; prob_num=582);

# %% [markdown]
# ## Problem 583: Heron Envelopes
# <p>
# A standard envelope shape is a convex figure consisting of an isosceles
# triangle (the flap) placed on top of a rectangle.  An example of an
# envelope with integral sides is shown below.  Note that to form a
# sensible envelope, the perpendicular height of the flap (BCD) must be
# smaller than the height of the rectangle (ABDE).
# </p>
#
# <div style="text-align:center;">
# <img src="webfiles/p583_heron_envelope.gif" alt="p583_heron_envelope.gif"></div>
#
# <p>
# In the envelope illustrated, not only are all the sides integral, but
# also all the diagonals (AC, AD, BD, BE and CE) are integral too. Let us
# call an envelope with these properties a <i>Heron envelope</i>.
# </p>
#
# <p>
# Let S(<var>p</var>) be the sum of the perimeters of all the Heron envelopes with a perimeter less than or equal to <var>p</var>.
# </p>
# <p>
# You are given that S(10<sup>4</sup>) = 884680.  Find S(10<sup>7</sup>).
# </p>

# %%
submit_answer(answer; prob_num=583);

# %% [markdown]
# ## Problem 584: Birthday Problem Revisited
# <p>A
#  long long time ago in a galaxy far far away, the Wimwians, inhabitants
# of planet WimWi, discovered an unmanned drone that had landed on their
# planet. On examining the drone, they uncovered a device that sought the
# answer for the so called "<b>Birthday Problem</b>". The description of the problem was as follows:</p>
#
# <p><i>If people on your planet were to enter a very large room one by
# one, what will be the expected number of people in the room when you
# first find <b>3 people with Birthdays within 1 day from each other</b>.</i></p>
#
# <p>The description further instructed them to enter the answer into the
# device and send the drone into space again. Startled by this turn of
# events, the Wimwians consulted their best mathematicians. Each year on
# Wimwi has 10 days and the mathematicians assumed equally likely
# birthdays and ignored leap years (leap years in Wimwi have 11 days), and
#  found 5.78688636 to be the required answer. As such, the Wimwians
# entered this answer and sent the drone back into space.</p>
#
#
# <p>After traveling light years away, the drone then landed on planet
# Joka. The same events ensued except this time, the numbers in the device
#  had changed due to some unknown technical issues. The description read:</p>
#
# <p><i>If people on your planet were to enter a very large room one by
# one, what will be the expected number of people in the room when you
# first find <b>3 people with Birthdays within 7 days from each other</b>.</i></p>
#
# <p>With a 100-day year on the planet, the Jokars (inhabitants of Joka)
# found the answer to be 8.48967364 (rounded to 8 decimal places because
# the device allowed only 8 places after the decimal point) assuming
# equally likely birthdays. They too entered the answer into the device
# and launched the drone into space again.</p>
#
#
# <p>This time the drone landed on planet Earth. As before the numbers in the problem description had changed. It read:</p>
#
# <p><i>If people on your planet were to enter a very large room one by
# one, what will be the expected number of people in the room when you
# first find <b>4 people with Birthdays within 7 days from each other</b>.</i></p>
#
# <p>What would be the answer (rounded to eight places after the decimal
# point) the people of Earth have to enter into the device for a year with
#  365 days? Ignore leap years. Also assume that all birthdays are equally
#  likely and independent of each other.</p>

# %%
submit_answer(answer; prob_num=584);

# %% [markdown]
# ## Problem 585: Nested square roots
# <p>Consider the term <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-432-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5602" style="width: 7.467em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.646em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.138em, 1005.65em, 2.955em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5603"><span class="mstyle" id="MathJax-Span-5604"><span class="mrow" id="MathJax-Span-5605"><span class="msqrt" id="MathJax-Span-5606"><span style="display: inline-block; position: relative; width: 5.65em; height: 0px;"><span style="position: absolute; clip: rect(3.261em, 1004.8em, 4.481em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5607"><span class="mi" id="MathJax-Span-5608" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-5609" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5610" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.13em; height: 0px;"><span style="position: absolute; clip: rect(3.5em, 1000.42em, 4.337em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5611"><span class="mi" id="MathJax-Span-5612" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.96em, 1000.42em, 1.256em, -1000em); top: -1.636em; left: 0.708em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.422em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -3.871em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5613" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5614" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.106em; height: 0px;"><span style="position: absolute; clip: rect(3.5em, 1000.4em, 4.172em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5615"><span class="mi" id="MathJax-Span-5616" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.96em, 1000.4em, 1.256em, -1000em); top: -1.718em; left: 0.708em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.398em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -3.953em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1004.75em, 3.922em, -1000em); top: -4.753em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 4.753em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.163em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.337em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.77em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.203em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.636em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.069em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.502em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.935em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.369em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.802em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.898em, 1000.87em, 4.715em, -1000em); top: -3.961em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size2;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.869em; border-left: 0px solid; width: 0px; height: 2.146em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mi>x</mi><mo>+</mo><msqrt><mi>y</mi></msqrt><mo>+</mo><msqrt><mi>z</mi></msqrt></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-432">\\small \\sqrt{x+\\sqrt{y}+\\sqrt{z}}</script> that is representing a <b>nested square root</b>. <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-433-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5617" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5618"><span class="mi" id="MathJax-Span-5619" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-433">x</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-434-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5620" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.789em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5621"><span class="mi" id="MathJax-Span-5622" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi></math></span></span><script type="math/tex" id="MathJax-Element-434">y</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-435-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5623" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5624"><span class="mi" id="MathJax-Span-5625" style="font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>z</mi></math></span></span><script type="math/tex" id="MathJax-Element-435">z</script> are positive integers and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-436-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5626" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.789em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5627"><span class="mi" id="MathJax-Span-5628" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi></math></span></span><script type="math/tex" id="MathJax-Element-436">y</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-437-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5629" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5630"><span class="mi" id="MathJax-Span-5631" style="font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>z</mi></math></span></span><script type="math/tex" id="MathJax-Element-437">z</script>
#  are not allowed to be perfect squares, so the number below the outer
# square root is irrational. Still it can be shown that for some
# combinations of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-438-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5632" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5633"><span class="mi" id="MathJax-Span-5634" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-438">x</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-439-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5635" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.789em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5636"><span class="mi" id="MathJax-Span-5637" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi></math></span></span><script type="math/tex" id="MathJax-Element-439">y</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-440-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5638" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5639"><span class="mi" id="MathJax-Span-5640" style="font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>z</mi></math></span></span><script type="math/tex" id="MathJax-Element-440">z</script> the given term can be simplified into a sum and/or difference of simple square roots of integers, actually <b>denesting</b> the square roots in the initial expression. </p>
#
# <p>Here are some examples of this denesting:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-441-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5641" style="width: 18.28em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.828em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.491em, 1013.77em, 2.798em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5642"><span class="mstyle" id="MathJax-Span-5643"><span class="mrow" id="MathJax-Span-5644"><span class="msqrt" id="MathJax-Span-5645"><span style="display: inline-block; position: relative; width: 5.619em; height: 0px;"><span style="position: absolute; clip: rect(3.161em, 1004.77em, 4.298em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5646"><span class="mn" id="MathJax-Span-5647" style="font-size: 85%; font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-5648" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5649" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5650"><span class="mn" id="MathJax-Span-5651" style="font-size: 85%; font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5652" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5653" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5654"><span class="mn" id="MathJax-Span-5655" style="font-size: 85%; font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1004.72em, 3.922em, -1000em); top: -4.639em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 4.723em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.133em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.334em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.764em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.194em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.624em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.054em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.484em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.914em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.344em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.774em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.153em, 1000.87em, 4.46em, -1000em); top: -4.102em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size1;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5656" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msqrt" id="MathJax-Span-5657" style="padding-left: 0.236em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5658"><span class="mn" id="MathJax-Span-5659" style="font-size: 85%; font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5660" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5661" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.36em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5662"><span class="mn" id="MathJax-Span-5663" style="font-size: 85%; font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5664" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msqrt" id="MathJax-Span-5665" style="padding-left: 0.236em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5666"><span class="mn" id="MathJax-Span-5667" style="font-size: 85%; font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5668" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5669" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">1</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.347em; border-left: 0px solid; width: 0px; height: 1.473em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mn>3</mn><mo>+</mo><msqrt><mn>2</mn></msqrt><mo>+</mo><msqrt><mn>2</mn></msqrt></msqrt><mo>=</mo><msqrt><mn>2</mn></msqrt><mo>+</mo><msqrt><mn>1</mn></msqrt><mo>=</mo><msqrt><mn>2</mn></msqrt><mo>+</mo><mn>1</mn></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-441">\\small \\sqrt{3+\\sqrt{2}+\\sqrt{2}}=\\sqrt{2}+\\sqrt{1}=\\sqrt{2}+1</script><br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-442-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5670" style="width: 14.5em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.501em, 1010.96em, 2.808em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5671"><span class="mstyle" id="MathJax-Span-5672"><span class="mrow" id="MathJax-Span-5673"><span class="msqrt" id="MathJax-Span-5674"><span style="display: inline-block; position: relative; width: 6.519em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1005.67em, 4.308em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5675"><span class="mn" id="MathJax-Span-5676" style="font-size: 85%; font-family: MathJax_Main;">8</span><span class="mo" id="MathJax-Span-5677" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5678" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.81em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5679"><span class="mn" id="MathJax-Span-5680" style="font-size: 85%; font-family: MathJax_Main;">15</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.538em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5681" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5682" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.81em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5683"><span class="mn" id="MathJax-Span-5684" style="font-size: 85%; font-family: MathJax_Main;">15</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.538em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1005.62em, 3.922em, -1000em); top: -4.63em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 5.623em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 5.033em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.376em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.849em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.322em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.795em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.268em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.74em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.213em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.686em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.159em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.631em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.153em, 1000.87em, 4.46em, -1000em); top: -4.093em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size1;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5685" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msqrt" id="MathJax-Span-5686" style="padding-left: 0.236em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5687"><span class="mn" id="MathJax-Span-5688" style="font-size: 85%; font-family: MathJax_Main;">5</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.482em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5689" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5690" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.31em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5691"><span class="mn" id="MathJax-Span-5692" style="font-size: 85%; font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.481em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.359em; border-left: 0px solid; width: 0px; height: 1.473em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mn>8</mn><mo>+</mo><msqrt><mn>15</mn></msqrt><mo>+</mo><msqrt><mn>15</mn></msqrt></msqrt><mo>=</mo><msqrt><mn>5</mn></msqrt><mo>+</mo><msqrt><mn>3</mn></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-442">\\small \\sqrt{8+\\sqrt{15}+\\sqrt{15}}=\\sqrt{5}+\\sqrt{3}</script><br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-443-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mn&gt;20&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;96&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5693" style="width: 31.533em; display: inline-block;"><span style="display: inline-block; position: relative; width: 23.876em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.496em, 1023.88em, 2.803em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5694"><span class="mstyle" id="MathJax-Span-5695"><span class="mrow" id="MathJax-Span-5696"><span class="msqrt" id="MathJax-Span-5697"><span style="display: inline-block; position: relative; width: 6.944em; height: 0px;"><span style="position: absolute; clip: rect(3.161em, 1006.09em, 4.308em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5698"><span class="mn" id="MathJax-Span-5699" style="font-size: 85%; font-family: MathJax_Main;">20</span><span class="mo" id="MathJax-Span-5700" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5701" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.81em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5702"><span class="mn" id="MathJax-Span-5703" style="font-size: 85%; font-family: MathJax_Main;">96</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.538em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5704" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5705" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.81em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5706"><span class="mn" id="MathJax-Span-5707" style="font-size: 85%; font-family: MathJax_Main;">12</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.548em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1006.05em, 3.922em, -1000em); top: -4.634em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 6.048em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 5.458em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.372em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.841em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.31em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.779em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.248em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.716em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.185em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.654em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.123em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.592em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 5.06em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.153em, 1000.87em, 4.46em, -1000em); top: -4.097em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size1;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5708" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msqrt" id="MathJax-Span-5709" style="padding-left: 0.236em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5710"><span class="mn" id="MathJax-Span-5711" style="font-size: 85%; font-family: MathJax_Main;">9</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.482em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5712" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5713" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5714"><span class="mn" id="MathJax-Span-5715" style="font-size: 85%; font-family: MathJax_Main;">6</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.482em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5716" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5717" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.31em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5718"><span class="mn" id="MathJax-Span-5719" style="font-size: 85%; font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.481em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5720" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="msqrt" id="MathJax-Span-5721" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5722"><span class="mn" id="MathJax-Span-5723" style="font-size: 85%; font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5724" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5725" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">3</span><span class="mo" id="MathJax-Span-5726" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5727" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5728"><span class="mn" id="MathJax-Span-5729" style="font-size: 85%; font-family: MathJax_Main;">6</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.482em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5730" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5731" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.31em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5732"><span class="mn" id="MathJax-Span-5733" style="font-size: 85%; font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.481em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5734" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="msqrt" id="MathJax-Span-5735" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5736"><span class="mn" id="MathJax-Span-5737" style="font-size: 85%; font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.353em; border-left: 0px solid; width: 0px; height: 1.473em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mn>20</mn><mo>+</mo><msqrt><mn>96</mn></msqrt><mo>+</mo><msqrt><mn>12</mn></msqrt></msqrt><mo>=</mo><msqrt><mn>9</mn></msqrt><mo>+</mo><msqrt><mn>6</mn></msqrt><mo>+</mo><msqrt><mn>3</mn></msqrt><mo>−</mo><msqrt><mn>2</mn></msqrt><mo>=</mo><mn>3</mn><mo>+</mo><msqrt><mn>6</mn></msqrt><mo>+</mo><msqrt><mn>3</mn></msqrt><mo>−</mo><msqrt><mn>2</mn></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-443">\\small \\sqrt{20+\\sqrt{96}+\\sqrt{12}}=\\sqrt{9}+\\sqrt{6}+\\sqrt{3}-\\sqrt{2}=3+\\sqrt{6}+\\sqrt{3}-\\sqrt{2}</script><br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-444-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mn&gt;28&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;160&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;108&lt;/mn&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5738" style="width: 22.49em; display: inline-block;"><span style="display: inline-block; position: relative; width: 17.033em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.501em, 1017.03em, 2.808em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5739"><span class="mstyle" id="MathJax-Span-5740"><span class="mrow" id="MathJax-Span-5741"><span class="msqrt" id="MathJax-Span-5742"><span style="display: inline-block; position: relative; width: 7.744em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1006.86em, 4.308em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5743"><span class="mn" id="MathJax-Span-5744" style="font-size: 85%; font-family: MathJax_Main;">28</span><span class="mo" id="MathJax-Span-5745" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5746" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.983em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1001.24em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5747"><span class="mn" id="MathJax-Span-5748" style="font-size: 85%; font-family: MathJax_Main;">160</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1001.23em, 3.922em, -1000em); top: -4.538em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 1.229em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.639em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.307em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5749" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5750" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.983em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1001.24em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5751"><span class="mn" id="MathJax-Span-5752" style="font-size: 85%; font-family: MathJax_Main;">108</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1001.23em, 3.922em, -1000em); top: -4.538em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 1.229em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.639em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.307em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1006.85em, 3.922em, -1000em); top: -4.63em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 6.848em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 6.258em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.363em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.822em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.281em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.739em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.198em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.657em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.116em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.575em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.034em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.493em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.952em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 5.411em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 5.87em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.153em, 1000.87em, 4.46em, -1000em); top: -4.093em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size1;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5753" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msqrt" id="MathJax-Span-5754" style="padding-left: 0.236em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.81em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5755"><span class="mn" id="MathJax-Span-5756" style="font-size: 85%; font-family: MathJax_Main;">15</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.538em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5757" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5758" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5759"><span class="mn" id="MathJax-Span-5760" style="font-size: 85%; font-family: MathJax_Main;">6</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.482em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5761" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5762" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5763"><span class="mn" id="MathJax-Span-5764" style="font-size: 85%; font-family: MathJax_Main;">5</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.482em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5765" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="msqrt" id="MathJax-Span-5766" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.38em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5767"><span class="mn" id="MathJax-Span-5768" style="font-size: 85%; font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.491em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.359em; border-left: 0px solid; width: 0px; height: 1.473em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mn>28</mn><mo>+</mo><msqrt><mn>160</mn></msqrt><mo>+</mo><msqrt><mn>108</mn></msqrt></msqrt><mo>=</mo><msqrt><mn>15</mn></msqrt><mo>+</mo><msqrt><mn>6</mn></msqrt><mo>+</mo><msqrt><mn>5</mn></msqrt><mo>−</mo><msqrt><mn>2</mn></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-444">\\small \\sqrt{28+\\sqrt{160}+\\sqrt{108}}=\\sqrt{15}+\\sqrt{6}+\\sqrt{5}-\\sqrt{2}</script></p>
# <p>As you can see the integers used in the denested expression may also be perfect squares resulting in further simplification.</p>
#
# <p>Let F(<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-445-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5769" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5770"><span class="mi" id="MathJax-Span-5771" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-445">n</script>) be the number of different terms <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-446-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5772" style="width: 7.467em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.646em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.138em, 1005.65em, 2.955em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5773"><span class="mstyle" id="MathJax-Span-5774"><span class="mrow" id="MathJax-Span-5775"><span class="msqrt" id="MathJax-Span-5776"><span style="display: inline-block; position: relative; width: 5.65em; height: 0px;"><span style="position: absolute; clip: rect(3.261em, 1004.8em, 4.481em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5777"><span class="mi" id="MathJax-Span-5778" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-5779" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5780" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.13em; height: 0px;"><span style="position: absolute; clip: rect(3.5em, 1000.42em, 4.337em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5781"><span class="mi" id="MathJax-Span-5782" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.96em, 1000.42em, 1.256em, -1000em); top: -1.636em; left: 0.708em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.422em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -3.871em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5783" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5784" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.106em; height: 0px;"><span style="position: absolute; clip: rect(3.5em, 1000.4em, 4.172em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5785"><span class="mi" id="MathJax-Span-5786" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.96em, 1000.4em, 1.256em, -1000em); top: -1.718em; left: 0.708em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.398em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -3.953em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1004.75em, 3.922em, -1000em); top: -4.753em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 4.753em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.163em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.337em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.77em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.203em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.636em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.069em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.502em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.935em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.369em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.802em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.898em, 1000.87em, 4.715em, -1000em); top: -3.961em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size2;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.869em; border-left: 0px solid; width: 0px; height: 2.146em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mi>x</mi><mo>+</mo><msqrt><mi>y</mi></msqrt><mo>+</mo><msqrt><mi>z</mi></msqrt></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-446">\\small \\sqrt{x+\\sqrt{y}+\\sqrt{z}}</script>, that can be denested into the sum and/or difference of a finite number of square roots, given the additional condition that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-447-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5787" style="width: 5.696em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.306em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1004.29em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5788"><span class="mn" id="MathJax-Span-5789" style="font-family: MathJax_Main;">0</span><span class="mo" id="MathJax-Span-5790" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-5791" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">x</span><span class="mo" id="MathJax-Span-5792" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-5793" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.188em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>0</mn><mo>&lt;</mo><mi>x</mi><mo>≤</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-447">0<x \\le n</script>. That is,<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-448-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;msqrt&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/munderover&gt;&lt;msub&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;msqrt&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5794" style="width: 13.591em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.287em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.817em, 1010.29em, 3.6em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5795"><span class="mstyle" id="MathJax-Span-5796"><span class="mrow" id="MathJax-Span-5797"><span class="mstyle" id="MathJax-Span-5798"><span class="mrow" id="MathJax-Span-5799"><span class="msqrt" id="MathJax-Span-5800"><span style="display: inline-block; position: relative; width: 5.65em; height: 0px;"><span style="position: absolute; clip: rect(3.288em, 1004.8em, 4.507em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5801"><span class="mi" id="MathJax-Span-5802" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-5803" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5804" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.13em; height: 0px;"><span style="position: absolute; clip: rect(3.5em, 1000.42em, 4.337em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5805"><span class="mi" id="MathJax-Span-5806" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.96em, 1000.42em, 1.256em, -1000em); top: -1.609em; left: 0.708em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.422em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -3.845em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5807" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5808" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.106em; height: 0px;"><span style="position: absolute; clip: rect(3.5em, 1000.4em, 4.172em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5809"><span class="mi" id="MathJax-Span-5810" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.96em, 1000.4em, 1.256em, -1000em); top: -1.692em; left: 0.708em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.398em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -3.927em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1004.75em, 3.922em, -1000em); top: -4.7em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 4.753em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.163em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.337em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.77em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.203em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.636em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.069em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.502em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.935em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.369em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.802em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.898em, 1000.87em, 4.715em, -1000em); top: -3.908em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size2;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5811" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-5812" style="padding-left: 0.236em;"><span style="display: inline-block; position: relative; width: 1.227em; height: 0px;"><span style="position: absolute; clip: rect(3.068em, 1001.18em, 4.545em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-5813" style="font-size: 85%; font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.475em, 1000.93em, 4.254em, -1000em); top: -3.095em; left: 0.126em;"><span class="texatom" id="MathJax-Span-5814"><span class="mrow" id="MathJax-Span-5815"><span class="mi" id="MathJax-Span-5816" style="font-size: 60.1%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-5817" style="font-size: 60.1%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-5818" style="font-size: 60.1%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.373em, 1000.3em, 4.169em, -1000em); top: -4.997em; left: 0.457em;"><span class="mi" id="MathJax-Span-5819" style="font-size: 60.1%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-5820" style="padding-left: 0.142em;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px;"><span style="position: absolute; clip: rect(3.5em, 1000.36em, 4.171em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5821" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">s</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.892em; left: 0.399em;"><span class="mi" id="MathJax-Span-5822" style="font-size: 60.1%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msqrt" id="MathJax-Span-5823"><span style="display: inline-block; position: relative; width: 1.454em; height: 0px;"><span style="position: absolute; clip: rect(3.501em, 1000.72em, 4.297em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5824"><span class="msubsup" id="MathJax-Span-5825"><span style="display: inline-block; position: relative; width: 0.721em; height: 0px;"><span style="position: absolute; clip: rect(3.501em, 1000.43em, 4.171em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5826" style="font-size: 85%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.892em; left: 0.45em;"><span class="mi" id="MathJax-Span-5827" style="font-size: 60.1%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.75em, 3.922em, -1000em); top: -4.359em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.746em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.156em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -3.864em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.404em; border-left: 0px solid; width: 0px; height: 3.421em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><mstyle displaystyle="true" scriptlevel="0"><msqrt><mi>x</mi><mo>+</mo><msqrt><mi>y</mi></msqrt><mo>+</mo><msqrt><mi>z</mi></msqrt></msqrt><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mi>k</mi></munderover><msub><mi>s</mi><mi>i</mi></msub><msqrt><msub><mi>a</mi><mi>i</mi></msub></msqrt></mstyle></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-448">\\small \\displaystyle \\sqrt{x+\\sqrt{y}+\\sqrt{z}}=\\sum_{i=1}^k s_i\\sqrt{a_i}</script><br>
# with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-449-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5828" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5829"><span class="mi" id="MathJax-Span-5830" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-449">k</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-450-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5831" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5832"><span class="mi" id="MathJax-Span-5833" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-450">x</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-451-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5834" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.789em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5835"><span class="mi" id="MathJax-Span-5836" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi></math></span></span><script type="math/tex" id="MathJax-Element-451">y</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-452-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5837" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5838"><span class="mi" id="MathJax-Span-5839" style="font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>z</mi></math></span></span><script type="math/tex" id="MathJax-Element-452">z</script> and all <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-453-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5840" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.616em, 1000.86em, 2.502em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5841"><span class="msubsup" id="MathJax-Span-5842"><span style="display: inline-block; position: relative; width: 0.848em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5843" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.529em;"><span class="mi" id="MathJax-Span-5844" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.271em; border-left: 0px solid; width: 0px; height: 0.917em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>a</mi><mi>i</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-453">a_i</script> being positive integers, all <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-454-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo&gt;&amp;#x00B1;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5845" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1003.28em, 2.981em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5846"><span class="msubsup" id="MathJax-Span-5847"><span style="display: inline-block; position: relative; width: 0.788em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.42em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5848" style="font-family: MathJax_Math; font-style: italic;">s</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.469em;"><span class="mi" id="MathJax-Span-5849" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5850" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-5851" style="font-family: MathJax_Main; padding-left: 0.278em;">±</span><span class="mn" id="MathJax-Span-5852" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.271em; border-left: 0px solid; width: 0px; height: 1.214em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>s</mi><mi>i</mi></msub><mo>=</mo><mo>±</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-454">s_i =\\pm 1</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-455-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5853" style="width: 3.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.536em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.9em, 1002.52em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5854"><span class="mi" id="MathJax-Span-5855" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-5856" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-5857" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.148em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi><mo>≤</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-455">x\\le n</script>.<br> Furthermore <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-456-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5858" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.789em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5859"><span class="mi" id="MathJax-Span-5860" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi></math></span></span><script type="math/tex" id="MathJax-Element-456">y</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-457-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5861" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5862"><span class="mi" id="MathJax-Span-5863" style="font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>z</mi></math></span></span><script type="math/tex" id="MathJax-Element-457">z</script>  are not allowed to be perfect squares.</p>
#
# <p>Nested roots with the same value are not considered different, for example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-458-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;27&lt;/mn&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5864" style="width: 8.041em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.077em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.26em, 1006.08em, 2.567em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5865"><span class="mstyle" id="MathJax-Span-5866"><span class="mrow" id="MathJax-Span-5867"><span class="msqrt" id="MathJax-Span-5868"><span style="display: inline-block; position: relative; width: 6.069em; height: 0px;"><span style="position: absolute; clip: rect(3.167em, 1005.22em, 4.308em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5869"><span class="mn" id="MathJax-Span-5870" style="font-size: 85%; font-family: MathJax_Main;">7</span><span class="mo" id="MathJax-Span-5871" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5872" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.31em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5873"><span class="mn" id="MathJax-Span-5874" style="font-size: 85%; font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.481em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5875" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5876" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.301em, 1000.84em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5877"><span class="mn" id="MathJax-Span-5878" style="font-size: 85%; font-family: MathJax_Main;">27</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.543em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.048em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1005.17em, 3.922em, -1000em); top: -4.631em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 5.173em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.583em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.335em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.767em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.199em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.631em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.063em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.495em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.927em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.359em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.79em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.222em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.153em, 1000.87em, 4.46em, -1000em); top: -4.095em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size1;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.356em; border-left: 0px solid; width: 0px; height: 1.473em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mn>7</mn><mo>+</mo><msqrt><mn>3</mn></msqrt><mo>+</mo><msqrt><mn>27</mn></msqrt></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-458">\\small \\sqrt{7+\\sqrt{3}+\\sqrt{27}}</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-459-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5879" style="width: 8.615em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.507em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.252em, 1006.51em, 2.559em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5880"><span class="mstyle" id="MathJax-Span-5881"><span class="mrow" id="MathJax-Span-5882"><span class="msqrt" id="MathJax-Span-5883"><span style="display: inline-block; position: relative; width: 6.519em; height: 0px;"><span style="position: absolute; clip: rect(3.161em, 1005.67em, 4.298em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5884"><span class="mn" id="MathJax-Span-5885" style="font-size: 85%; font-family: MathJax_Main;">7</span><span class="mo" id="MathJax-Span-5886" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5887" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.81em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5888"><span class="mn" id="MathJax-Span-5889" style="font-size: 85%; font-family: MathJax_Main;">12</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.548em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5890" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5891" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.309em, 1000.81em, 4.163em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5892"><span class="mn" id="MathJax-Span-5893" style="font-size: 85%; font-family: MathJax_Main;">12</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.548em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.053em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1005.62em, 3.922em, -1000em); top: -4.639em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 5.623em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 5.033em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.376em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.849em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.322em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.795em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.268em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.74em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.213em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.686em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.159em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.631em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.153em, 1000.87em, 4.46em, -1000em); top: -4.102em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size1;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.347em; border-left: 0px solid; width: 0px; height: 1.473em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mn>7</mn><mo>+</mo><msqrt><mn>12</mn></msqrt><mo>+</mo><msqrt><mn>12</mn></msqrt></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-459">\\small \\sqrt{7+\\sqrt{12}+\\sqrt{12}}</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-460-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;msqrt&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;27&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5894" style="width: 8.041em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.077em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.26em, 1006.08em, 2.567em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5895"><span class="mstyle" id="MathJax-Span-5896"><span class="mrow" id="MathJax-Span-5897"><span class="msqrt" id="MathJax-Span-5898"><span style="display: inline-block; position: relative; width: 6.069em; height: 0px;"><span style="position: absolute; clip: rect(3.167em, 1005.22em, 4.308em, -1000em); top: -4.019em; left: 0.85em;"><span class="mrow" id="MathJax-Span-5899"><span class="mn" id="MathJax-Span-5900" style="font-size: 85%; font-family: MathJax_Main;">7</span><span class="mo" id="MathJax-Span-5901" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5902" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.583em; height: 0px;"><span style="position: absolute; clip: rect(3.301em, 1000.84em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5903"><span class="mn" id="MathJax-Span-5904" style="font-size: 85%; font-family: MathJax_Main;">27</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1000.88em, 3.922em, -1000em); top: -4.543em; left: 0.708em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.285em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.048em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5905" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5906" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.31em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5907"><span class="mn" id="MathJax-Span-5908" style="font-size: 85%; font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.481em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.69em, 1005.17em, 3.922em, -1000em); top: -4.631em; left: 0.85em;"><span style="display: inline-block; position: relative; width: 5.173em; height: 0px;"><span style="position: absolute; top: -4.019em; left: -0.071em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.583em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.335em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 0.767em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.199em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 1.631em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.063em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.495em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 2.927em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.359em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 3.79em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.019em; left: 4.222em;"><span style="font-size: 85%; font-family: MathJax_Main;">−</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.153em, 1000.87em, 4.46em, -1000em); top: -4.095em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Size1;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.356em; border-left: 0px solid; width: 0px; height: 1.473em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><msqrt><mn>7</mn><mo>+</mo><msqrt><mn>27</mn></msqrt><mo>+</mo><msqrt><mn>3</mn></msqrt></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-460">\\small \\sqrt{7+\\sqrt{27}+\\sqrt{3}}</script>, that can all three be denested into <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-461-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5909" style="width: 3.495em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.632em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1002.63em, 2.729em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5910"><span class="mstyle" id="MathJax-Span-5911"><span class="mrow" id="MathJax-Span-5912"><span class="mn" id="MathJax-Span-5913" style="font-size: 85%; font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-5914" style="font-size: 85%; font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-5915" style="padding-left: 0.189em;"><span style="display: inline-block; position: relative; width: 1.133em; height: 0px;"><span style="position: absolute; clip: rect(3.31em, 1000.39em, 4.181em, -1000em); top: -4.019em; left: 0.708em;"><span class="mrow" id="MathJax-Span-5916"><span class="mn" id="MathJax-Span-5917" style="font-size: 85%; font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.633em, 1000.42em, 3.952em, -1000em); top: -4.481em; left: 0.708em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">–</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.196em, 1000.72em, 4.333em, -1000em); top: -4.044em; left: 0em;"><span><span style="font-size: 85%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.255em; border-left: 0px solid; width: 0px; height: 1.248em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle mathsize="0.85em"><mn>2</mn><mo>+</mo><msqrt><mn>3</mn></msqrt></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-461">\\small 2+\\sqrt{3}</script>, would only be counted once.</p>
#
# <p>You are given that F(10)=17, F(15)=46, F(20)=86, F(30)=213 and F(100)=2918 and F(5000)=11134074.<br>
# Find F(5000000).</p>

# %%
submit_answer(answer; prob_num=585);

# %% [markdown]
# ## Problem 586: Binary Quadratic Form
# <p>
# The number 209 can be expressed as <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-462-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5918" style="width: 7.467em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.646em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1005.65em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5919"><span class="msubsup" id="MathJax-Span-5920"><span style="display: inline-block; position: relative; width: 0.958em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5921" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.529em;"><span class="mn" id="MathJax-Span-5922" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5923" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5924" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mi" id="MathJax-Span-5925" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-5926" style="font-family: MathJax_Math; font-style: italic;">b</span><span class="mo" id="MathJax-Span-5927" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-5928" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.858em; height: 0px;"><span style="position: absolute; clip: rect(3.182em, 1000.42em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5929" style="font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.429em;"><span class="mn" id="MathJax-Span-5930" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.335em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mi>a</mi><mn>2</mn></msup><mo>+</mo><mn>3</mn><mi>a</mi><mi>b</mi><mo>+</mo><msup><mi>b</mi><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-462">a^2 + 3ab + b^2</script> in two distinct ways:
# </p>
# <p>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-463-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mspace width="2em" /&gt;&lt;mn&gt;209&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5931" style="width: 15.744em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1011.91em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5932"><span class="mspace" id="MathJax-Span-5933" style="height: 0em; vertical-align: 0em; width: 2em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-5934" style="font-family: MathJax_Main;">209</span><span class="mo" id="MathJax-Span-5935" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-5936" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.46em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5937" style="font-family: MathJax_Main;">8</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mn" id="MathJax-Span-5938" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5939" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5940" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mo" id="MathJax-Span-5941" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5942" style="font-family: MathJax_Main; padding-left: 0.222em;">8</span><span class="mo" id="MathJax-Span-5943" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5944" style="font-family: MathJax_Main; padding-left: 0.222em;">5</span><span class="mo" id="MathJax-Span-5945" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-5946" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5947" style="font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mn" id="MathJax-Span-5948" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.375em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mspace width="2em"></mspace><mn>209</mn><mo>=</mo><msup><mn>8</mn><mn>2</mn></msup><mo>+</mo><mn>3</mn><mo>⋅</mo><mn>8</mn><mo>⋅</mo><mn>5</mn><mo>+</mo><msup><mn>5</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-463"> \\qquad 209 = 8^2 + 3\\cdot 8\\cdot 5 + 5^2</script> <br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-464-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mspace width="2em" /&gt;&lt;mn&gt;209&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5949" style="width: 17.084em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1012.92em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5950"><span class="mspace" id="MathJax-Span-5951" style="height: 0em; vertical-align: 0em; width: 2em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-5952" style="font-family: MathJax_Main;">209</span><span class="mo" id="MathJax-Span-5953" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-5954" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5955" style="font-family: MathJax_Main;">13</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-5956" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5957" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5958" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mo" id="MathJax-Span-5959" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5960" style="font-family: MathJax_Main; padding-left: 0.222em;">13</span><span class="mo" id="MathJax-Span-5961" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5962" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-5963" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-5964" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.43em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5965" style="font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mn" id="MathJax-Span-5966" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.375em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mspace width="2em"></mspace><mn>209</mn><mo>=</mo><msup><mn>13</mn><mn>2</mn></msup><mo>+</mo><mn>3</mn><mo>⋅</mo><mn>13</mn><mo>⋅</mo><mn>1</mn><mo>+</mo><msup><mn>1</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-464"> \\qquad 209 = 13^2 + 3\\cdot13\\cdot 1 + 1^2</script>
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-465-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5967" style="width: 3.734em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.823em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5968"><span class="mi" id="MathJax-Span-5969" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-5970" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5971" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5972" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5973" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">r</span><span class="mo" id="MathJax-Span-5974" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>r</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-465">f(n,r)</script> be the number of integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-466-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5975" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5976"><span class="mi" id="MathJax-Span-5977" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-466">k</script> not exceeding <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-467-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5978" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5979"><span class="mi" id="MathJax-Span-5980" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-467">n</script> that can be expressed as <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-468-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5981" style="width: 9.955em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.512em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1007.51em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5982"><span class="mi" id="MathJax-Span-5983" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-5984" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-5985" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.958em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5986" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.529em;"><span class="mn" id="MathJax-Span-5987" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5988" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5989" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mi" id="MathJax-Span-5990" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-5991" style="font-family: MathJax_Math; font-style: italic;">b</span><span class="mo" id="MathJax-Span-5992" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-5993" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.858em; height: 0px;"><span style="position: absolute; clip: rect(3.182em, 1000.42em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5994" style="font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.429em;"><span class="mn" id="MathJax-Span-5995" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.335em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi><mo>=</mo><msup><mi>a</mi><mn>2</mn></msup><mo>+</mo><mn>3</mn><mi>a</mi><mi>b</mi><mo>+</mo><msup><mi>b</mi><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-468">k=a^2 + 3ab + b^2</script>, with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-469-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;#x003E;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5996" style="width: 5.409em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.067em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1004.03em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5997"><span class="mi" id="MathJax-Span-5998" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-5999" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mi" id="MathJax-Span-6000" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">b</span><span class="mo" id="MathJax-Span-6001" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-6002" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 1.095em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>&gt;</mo><mi>b</mi><mo>&gt;</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-469">a\\gt b>0</script> integers, in exactly <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-470-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6003" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.41em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6004"><span class="mi" id="MathJax-Span-6005" style="font-family: MathJax_Math; font-style: italic;">r</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>r</mi></math></span></span><script type="math/tex" id="MathJax-Element-470">r</script> different ways.
# </p>
# <p>
# You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-471-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;237&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6006" style="width: 8.471em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.411em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1006.4em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6007"><span class="mi" id="MathJax-Span-6008" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-6009" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6010"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6011" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6012" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6013" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6014" style="font-family: MathJax_Main; padding-left: 0.167em;">4</span><span class="mo" id="MathJax-Span-6015" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6016" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6017" style="font-family: MathJax_Main; padding-left: 0.278em;">237</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>5</mn></msup><mo>,</mo><mn>4</mn><mo stretchy="false">)</mo><mo>=</mo><mn>237</mn></math></span></span><script type="math/tex" id="MathJax-Element-471">f(10^5, 4) = 237</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-472-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;59517&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6018" style="width: 9.763em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.368em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1007.35em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6019"><span class="mi" id="MathJax-Span-6020" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-6021" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6022"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6023" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6024" style="font-size: 70.7%; font-family: MathJax_Main;">8</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6025" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6026" style="font-family: MathJax_Main; padding-left: 0.167em;">6</span><span class="mo" id="MathJax-Span-6027" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6028" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6029" style="font-family: MathJax_Main; padding-left: 0.278em;">59517</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>8</mn></msup><mo>,</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>59517</mn></math></span></span><script type="math/tex" id="MathJax-Element-472">f(10^8, 6) = 59517</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-473-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;40&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6030" style="width: 5.935em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.498em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1004.4em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6031"><span class="mi" id="MathJax-Span-6032" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-6033" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6034"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6035" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-6036"><span class="mrow" id="MathJax-Span-6037"><span class="mn" id="MathJax-Span-6038" style="font-size: 70.7%; font-family: MathJax_Main;">15</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6039" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6040" style="font-family: MathJax_Main; padding-left: 0.167em;">40</span><span class="mo" id="MathJax-Span-6041" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>15</mn></mrow></msup><mo>,</mo><mn>40</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-473">f(10^{15}, 40)</script>.
# </p>

# %%
submit_answer(answer; prob_num=586);

# %% [markdown]
# ## Problem 587: Concave triangle
# <p>
# A square is drawn around a circle as shown in the diagram below on the left.<br>
# We shall call the blue shaded region the L-section.<br>
# A line is drawn from the bottom left of the square to the top right as shown in the diagram on the right.<br>
# We shall call the orange shaded region a concave triangle.
# </p>
# <div style="text-align:center;">
# <img src="webfiles/p587_concave_triangle_1.png" alt="p587_concave_triangle_1.png"></div>
# <p>
# It should be clear that the concave triangle occupies exactly half of the L-section.
# </p>
# <p>
#
# Two circles are placed next to each other horizontally, a rectangle is
# drawn around both circles, and a line is drawn from the bottom left to
# the top right as shown in the diagram below.
# </p>
# <div style="text-align:center;">
# <img src="webfiles/p587_concave_triangle_2.png" alt="p587_concave_triangle_2.png"></div>
# <p>
# This time the concave triangle occupies approximately 36.46% of the L-section.
# </p>
# <p>
# If <var>n</var> circles are placed next to each other horizontally, a rectangle is drawn around the <var>n</var> circles, and a line is drawn from the bottom left to the top right, then it can be shown that the least value of <var>n</var> for which the concave triangle occupies less than 10% of the L-section is <var>n</var>&nbsp;=&nbsp;15.
# </p>
# <p>
# What is the least value of <var>n</var> for which the concave triangle occupies less than 0.1% of the L-section?
# </p>

# %%
submit_answer(answer; prob_num=587);

# %% [markdown]
# ## Problem 588: Quintinomial coefficients
# <p>
# The coefficients in the expansion of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-474-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6042" style="width: 4.644em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.493em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.682em, 1003.49em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6043"><span class="mo" id="MathJax-Span-6044" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6045" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-6046" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6047" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="msubsup" id="MathJax-Span-6048"><span style="display: inline-block; position: relative; width: 0.832em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1000.29em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6049" style="font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.389em;"><span class="mi" id="MathJax-Span-6050" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.583em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>x</mi><mo>+</mo><mn>1</mn><msup><mo stretchy="false">)</mo><mi>k</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-474">(x+1)^k</script> are called <b>binomial coefficients</b>.<br>
# Analoguously the coefficients in the expansion of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-475-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6051" style="width: 13.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.096em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.682em, 1010.1em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6052"><span class="mo" id="MathJax-Span-6053" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6054"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6055" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6056" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6057" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-6058" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6059" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6060" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6061" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-6062" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6063" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6064" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6065" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-6066" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">x</span><span class="mo" id="MathJax-Span-6067" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6068" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="msubsup" id="MathJax-Span-6069"><span style="display: inline-block; position: relative; width: 0.832em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1000.29em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6070" style="font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.389em;"><span class="mi" id="MathJax-Span-6071" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.583em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><msup><mi>x</mi><mn>4</mn></msup><mo>+</mo><msup><mi>x</mi><mn>3</mn></msup><mo>+</mo><msup><mi>x</mi><mn>2</mn></msup><mo>+</mo><mi>x</mi><mo>+</mo><mn>1</mn><msup><mo stretchy="false">)</mo><mi>k</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-475">(x^4+x^3+x^2+x+1)^k</script> are called <b>quintinomial coefficients</b>.<br> (quintus= Latin for fifth).
# </p>
# <p>
# Consider the expansion of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-476-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6072" style="width: 13.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.096em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.694em, 1010.1em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6073"><span class="mo" id="MathJax-Span-6074" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6075"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6076" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6077" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6078" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-6079" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6080" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6081" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6082" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-6083" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6084" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6085" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6086" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-6087" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">x</span><span class="mo" id="MathJax-Span-6088" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6089" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="msubsup" id="MathJax-Span-6090"><span style="display: inline-block; position: relative; width: 0.818em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1000.29em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6091" style="font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.389em;"><span class="mn" id="MathJax-Span-6092" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.567em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><msup><mi>x</mi><mn>4</mn></msup><mo>+</mo><msup><mi>x</mi><mn>3</mn></msup><mo>+</mo><msup><mi>x</mi><mn>2</mn></msup><mo>+</mo><mi>x</mi><mo>+</mo><mn>1</mn><msup><mo stretchy="false">)</mo><mn>3</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-476">(x^4+x^3+x^2+x+1)^3</script>:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-477-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;19&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6093" style="width: 47.849em; display: inline-block;"><span style="display: inline-block; position: relative; width: 36.22em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.694em, 1036.15em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6094"><span class="msubsup" id="MathJax-Span-6095"><span style="display: inline-block; position: relative; width: 1.354em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6096" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="texatom" id="MathJax-Span-6097"><span class="mrow" id="MathJax-Span-6098"><span class="mn" id="MathJax-Span-6099" style="font-size: 70.7%; font-family: MathJax_Main;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6100" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6101" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="msubsup" id="MathJax-Span-6102"><span style="display: inline-block; position: relative; width: 1.354em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6103" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="texatom" id="MathJax-Span-6104"><span class="mrow" id="MathJax-Span-6105"><span class="mn" id="MathJax-Span-6106" style="font-size: 70.7%; font-family: MathJax_Main;">11</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6107" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6108" style="font-family: MathJax_Main; padding-left: 0.222em;">6</span><span class="msubsup" id="MathJax-Span-6109"><span style="display: inline-block; position: relative; width: 1.354em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6110" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="texatom" id="MathJax-Span-6111"><span class="mrow" id="MathJax-Span-6112"><span class="mn" id="MathJax-Span-6113" style="font-size: 70.7%; font-family: MathJax_Main;">10</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6114" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6115" style="font-family: MathJax_Main; padding-left: 0.222em;">10</span><span class="msubsup" id="MathJax-Span-6116"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6117" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6118" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6119" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6120" style="font-family: MathJax_Main; padding-left: 0.222em;">15</span><span class="msubsup" id="MathJax-Span-6121"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6122" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6123" style="font-size: 70.7%; font-family: MathJax_Main;">8</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6124" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6125" style="font-family: MathJax_Main; padding-left: 0.222em;">18</span><span class="msubsup" id="MathJax-Span-6126"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6127" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6128" style="font-size: 70.7%; font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6129" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6130" style="font-family: MathJax_Main; padding-left: 0.222em;">19</span><span class="msubsup" id="MathJax-Span-6131"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6132" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6133" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6134" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6135" style="font-family: MathJax_Main; padding-left: 0.222em;">18</span><span class="msubsup" id="MathJax-Span-6136"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6137" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6138" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6139" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6140" style="font-family: MathJax_Main; padding-left: 0.222em;">15</span><span class="msubsup" id="MathJax-Span-6141"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6142" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6143" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6144" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6145" style="font-family: MathJax_Main; padding-left: 0.222em;">10</span><span class="msubsup" id="MathJax-Span-6146"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6147" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6148" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6149" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6150" style="font-family: MathJax_Main; padding-left: 0.222em;">6</span><span class="msubsup" id="MathJax-Span-6151"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6152" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6153" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6154" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6155" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mi" id="MathJax-Span-6156" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-6157" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6158" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.345em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mi>x</mi><mrow class="MJX-TeXAtom-ORD"><mn>12</mn></mrow></msup><mo>+</mo><mn>3</mn><msup><mi>x</mi><mrow class="MJX-TeXAtom-ORD"><mn>11</mn></mrow></msup><mo>+</mo><mn>6</mn><msup><mi>x</mi><mrow class="MJX-TeXAtom-ORD"><mn>10</mn></mrow></msup><mo>+</mo><mn>10</mn><msup><mi>x</mi><mn>9</mn></msup><mo>+</mo><mn>15</mn><msup><mi>x</mi><mn>8</mn></msup><mo>+</mo><mn>18</mn><msup><mi>x</mi><mn>7</mn></msup><mo>+</mo><mn>19</mn><msup><mi>x</mi><mn>6</mn></msup><mo>+</mo><mn>18</mn><msup><mi>x</mi><mn>5</mn></msup><mo>+</mo><mn>15</mn><msup><mi>x</mi><mn>4</mn></msup><mo>+</mo><mn>10</mn><msup><mi>x</mi><mn>3</mn></msup><mo>+</mo><mn>6</mn><msup><mi>x</mi><mn>2</mn></msup><mo>+</mo><mn>3</mn><mi>x</mi><mo>+</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-477">x^{12}+3x^{11}+6x^{10}+10x^9+15x^8+18x^7+19x^6+18x^5+15x^4+10x^3+6x^2+3x+1</script><br>
# As we can see 7 out of the 13 quintinomial coefficients for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-478-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6159" style="width: 3.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.3em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6160"><span class="mi" id="MathJax-Span-6161" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6162" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6163" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-478">k=3</script> are odd.
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-479-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6164" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6165"><span class="mi" id="MathJax-Span-6166" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-6167" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6168" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6169" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-479">Q(k)</script> be the number of odd coefficients in the expansion of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-480-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6170" style="width: 13.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.096em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.682em, 1010.1em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6171"><span class="mo" id="MathJax-Span-6172" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6173"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6174" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6175" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6176" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-6177" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6178" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6179" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6180" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-6181" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.52em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6182" style="font-family: MathJax_Math; font-style: italic;">x</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.572em;"><span class="mn" id="MathJax-Span-6183" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6184" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-6185" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">x</span><span class="mo" id="MathJax-Span-6186" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6187" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="msubsup" id="MathJax-Span-6188"><span style="display: inline-block; position: relative; width: 0.832em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1000.29em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6189" style="font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.389em;"><span class="mi" id="MathJax-Span-6190" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.583em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><msup><mi>x</mi><mn>4</mn></msup><mo>+</mo><msup><mi>x</mi><mn>3</mn></msup><mo>+</mo><msup><mi>x</mi><mn>2</mn></msup><mo>+</mo><mi>x</mi><mo>+</mo><mn>1</mn><msup><mo stretchy="false">)</mo><mi>k</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-480">(x^4+x^3+x^2+x+1)^k</script>.<br>
# So <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-481-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6191" style="width: 5.122em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.876em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.86em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6192"><span class="mi" id="MathJax-Span-6193" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-6194" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6195" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-6196" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6197" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6198" style="font-family: MathJax_Main; padding-left: 0.278em;">7</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7</mn></math></span></span><script type="math/tex" id="MathJax-Element-481">Q(3)=7</script>.
# </p>
# <p>
# You are given <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-482-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;17&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6199" style="width: 6.414em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.833em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6200"><span class="mi" id="MathJax-Span-6201" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-6202" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6203" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-6204" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6205" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6206" style="font-family: MathJax_Main; padding-left: 0.278em;">17</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>17</mn></math></span></span><script type="math/tex" id="MathJax-Element-482">Q(10)=17</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-483-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;35&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6207" style="width: 7.036em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.311em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.26em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6208"><span class="mi" id="MathJax-Span-6209" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-6210" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6211" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-6212" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6213" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6214" style="font-family: MathJax_Main; padding-left: 0.278em;">35</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>35</mn></math></span></span><script type="math/tex" id="MathJax-Element-483">Q(100)=35</script>.
# </p>
# <p>Find  <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-484-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6215" style="width: 7.419em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.598em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.588em, 1005.5em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6216"><span class="munderover" id="MathJax-Span-6217"><span style="display: inline-block; position: relative; width: 2.403em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6218" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.78em, 4.178em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-6219"><span class="mrow" id="MathJax-Span-6220"><span class="mn" id="MathJax-Span-6221" style="font-size: 70.7%; font-family: MathJax_Main;">18</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1001.35em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-6222"><span class="mrow" id="MathJax-Span-6223"><span class="mi" id="MathJax-Span-6224" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6225" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-6226" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-6227" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">Q</span><span class="mo" id="MathJax-Span-6228" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6229"><span style="display: inline-block; position: relative; width: 1.443em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6230" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mi" id="MathJax-Span-6231" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6232" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.764em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>18</mn></mrow></munderover><mi>Q</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mi>k</mi></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-484">\\sum_{k=1}^{18}Q(10^k) </script>.
# </p>

# %%
submit_answer(answer; prob_num=588);

# %% [markdown]
# ## Problem 589: Poohsticks Marathon
# <p>
# Christopher Robin and Pooh Bear love the game of Poohsticks so much that
#  they invented a new version which allows them to play for longer before
#  one of them wins and they have to go home for tea. The game starts as
# normal with both dropping a stick simultaneously on the upstream side of
#  a bridge. But rather than the game ending when one of the sticks
# emerges on the downstream side, instead they fish their sticks out of
# the water, and drop them back in again on the upstream side. The game
# only ends when one of the sticks emerges from under the bridge ahead of
# "the other one having also 'lapped' the other stick - that is, having "
# made one additional journey under the bridge compared to the other
# stick.
# </p>
# <p>
# On a particular day when playing this game, the time taken for a stick
# to travel under the bridge varies between a minimum of 30 seconds, and a
#  maximum of 60 seconds. The time taken to fish a stick out of the water
# and drop it back in again on the other side is 5 seconds. The current
# "under the bridge has the unusual property that the sticks' journey time "
# is always an integral number of seconds, and it is equally likely to
# emerge at any of the possible times between 30 and 60 seconds
# (inclusive). It turns out that under these circumstances, the expected
# time for playing a single game is 1036.15 seconds (rounded to 2 decimal
# places). This time is measured from the point of dropping the sticks for
#  the first time, to the point where the winning stick emerges from under
#  the bridge having lapped the other.
# </p>
# <p>
# The stream flows at different rates each day, but maintains the property
#  that the journey time in seconds is equally distributed amongst the
# integers from a minimum, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-485-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6233" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6234"><span class="mi" id="MathJax-Span-6235" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-485">n</script>, to a maximum, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-486-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6236" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.84em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6237"><span class="mi" id="MathJax-Span-6238" style="font-family: MathJax_Math; font-style: italic;">m</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>m</mi></math></span></span><script type="math/tex" id="MathJax-Element-486">m</script>, inclusive. Let the expected time of play in seconds be <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-487-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6239" style="width: 4.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.445em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.35em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6240"><span class="mi" id="MathJax-Span-6241" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-6242" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6243" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-6244" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6245" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">n</span><span class="mo" id="MathJax-Span-6246" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>E</mi><mo stretchy="false">(</mo><mi>m</mi><mo>,</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-487">E(m,n)</script>. Hence <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-488-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;30&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1036.15...&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6247" style="width: 12.203em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.234em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1009.16em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6248"><span class="mi" id="MathJax-Span-6249" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-6250" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6251" style="font-family: MathJax_Main;">60</span><span class="mo" id="MathJax-Span-6252" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6253" style="font-family: MathJax_Main; padding-left: 0.167em;">30</span><span class="mo" id="MathJax-Span-6254" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6255" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6256" style="font-family: MathJax_Main; padding-left: 0.278em;">1036.15...</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>E</mi><mo stretchy="false">(</mo><mn>60</mn><mo>,</mo><mn>30</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1036.15...</mn></math></span></span><script type="math/tex" id="MathJax-Element-488">E(60,30)=1036.15...</script>
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-489-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/munderover&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6257" style="width: 16.318em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.568em, 1012.25em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6258"><span class="mi" id="MathJax-Span-6259" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6260" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6261" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6262" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6263" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-6264" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.656em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6265" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.44em, 4.17em, -1000em); top: -4.496em; left: 1.056em;"><span class="mi" id="MathJax-Span-6266" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.6em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-6267"><span class="mrow" id="MathJax-Span-6268"><span class="mi" id="MathJax-Span-6269" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-6270" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-6271" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="munderover" id="MathJax-Span-6272" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 2.656em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6273" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.6em, 4.221em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-6274"><span class="mrow" id="MathJax-Span-6275"><span class="mi" id="MathJax-Span-6276" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-6277" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-6278" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.4em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-6279"><span class="mrow" id="MathJax-Span-6280"><span class="mi" id="MathJax-Span-6281" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-6282" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-6283" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-6284" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-6285" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6286" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-6287" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6288" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">n</span><span class="mo" id="MathJax-Span-6289" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.791em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>=</mo><mn>2</mn></mrow><mi>k</mi></munderover><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>−</mo><mn>1</mn></mrow></munderover><mi>E</mi><mo stretchy="false">(</mo><mi>m</mi><mo>,</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-489">S(k)=\\sum_{m=2}^k\\sum_{n=1}^{m-1}E(m,n)</script>.
# </p>
# <p>
# For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-490-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7722.82&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6290" style="width: 8.423em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.364em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.31em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6291"><span class="mi" id="MathJax-Span-6292" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6293" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6294" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-6295" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6296" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6297" style="font-family: MathJax_Main; padding-left: 0.278em;">7722.82</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>5</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7722.82</mn></math></span></span><script type="math/tex" id="MathJax-Element-490">S(5)=7722.82</script> rounded to 2 decimal places.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-491-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6298" style="width: 3.83em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.871em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.78em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6299"><span class="mi" id="MathJax-Span-6300" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6301" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6302" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-6303" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-491">S(100)</script> and give your answer rounded to 2 decimal places.
# </p>

# %%
submit_answer(answer; prob_num=589);

# %% [markdown]
# ## Problem 590: Sets with a given Least Common Multiple
# <p>
# Let H(<var>n</var>) denote the number of sets of positive integers such that the least common multiple of the integers in the set equals <var>n</var>.<br>
# E.g.:<br>
# The integers in the following ten sets all have a least common multiple of 6:<br>
# {2,3}, {1,2,3}, {6}, {1,6}, {2,6} ,{1,2,6}, {3,6}, {1,3,6}, {2,3,6} and {1,2,3,6}.<br>
# Thus H(6)=10.
# </p>
# <p>
# Let L(<var>n</var>) denote the least common multiple of the numbers 1 through <var>n</var>.<br>
# E.g. L(6) is the least common multiple of the numbers 1,2,3,4,5,6 and L(6) equals 60.
# </p>
# <p>
# Let HL(<var>n</var>) denote H(L(<var>n</var>)).<br>
# You are given HL(4)=H(12)=44.
# </p>
# <p>
# Find HL(50000). Give your answer modulo 10<sup>9</sup>.
# </p>

# %%
submit_answer(answer; prob_num=590);

# %% [markdown]
# ## Problem 591: Best Approximations by Quadratic Integers
# <p>Given a non-square integer <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-492-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6304" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.53em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6305"><span class="mi" id="MathJax-Span-6306" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.056em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>d</mi></math></span></span><script type="math/tex" id="MathJax-Element-492">d</script>, any real <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-493-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6307" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6308"><span class="mi" id="MathJax-Span-6309" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-493">x</script> can be approximated arbitrarily close by <b>quadratic integers</b> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-494-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;msqrt&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6310" style="width: 4.691em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.541em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.679em, 1003.54em, 2.966em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6311"><span class="mi" id="MathJax-Span-6312" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-6313" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-6314" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">b</span><span class="msqrt" id="MathJax-Span-6315"><span style="display: inline-block; position: relative; width: 1.381em; height: 0px;"><span style="position: absolute; clip: rect(3.182em, 1000.52em, 4.173em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-6316"><span class="mi" id="MathJax-Span-6317" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.55em, 3.935em, -1000em); top: -4.603em; left: 0.833em;"><span style="display: inline-block; position: relative; width: 0.548em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.146em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.076em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.252em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>+</mo><mi>b</mi><msqrt><mi>d</mi></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-494">a+b\\sqrt{d}</script>, where <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-495-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6318" style="width: 1.868em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.388em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1001.38em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6319"><span class="mi" id="MathJax-Span-6320" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-6321" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6322" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.298em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>,</mo><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-495">a,b</script> are integers. For example, the following inequalities approximate <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-496-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6323" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.866em, 1000.57em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6324"><span class="mi" id="MathJax-Span-6325" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.71em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>π</mi></math></span></span><script type="math/tex" id="MathJax-Element-496">\\pi</script> with precision <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-497-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6326" style="width: 3.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.194em, 1002.34em, 2.366em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-6327"><span class="msubsup" id="MathJax-Span-6328"><span style="display: inline-block; position: relative; width: 2.332em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6329" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-6330"><span class="mrow" id="MathJax-Span-6331"><span class="mo" id="MathJax-Span-6332" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-6333" style="font-size: 70.7%; font-family: MathJax_Main;">13</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.296em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mo>−</mo><mn>13</mn></mrow></msup></math></span></span><script type="math/tex" id="MathJax-Element-497">10^{-13}</script>:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span></p><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-498-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML" display="block"&gt;&lt;mn&gt;4375636191520&lt;/mn&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;6188084046055&lt;/mn&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mn&gt;721133315582&lt;/mn&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1019836515172&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6334" style="width: 43.208em; display: inline-block;"><span style="display: inline-block; position: relative; width: 32.727em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.727em, 1032.68em, 3.014em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6335"><span class="mn" id="MathJax-Span-6336" style="font-family: MathJax_Main;">4375636191520</span><span class="msqrt" id="MathJax-Span-6337"><span style="display: inline-block; position: relative; width: 1.333em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-6338"><span class="mn" id="MathJax-Span-6339" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.591em, 1000.5em, 3.915em, -1000em); top: -4.543em; left: 0.833em;"><span style="font-family: MathJax_Main;">–</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.028em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6340" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-6341" style="font-family: MathJax_Main; padding-left: 0.222em;">6188084046055</span><span class="mo" id="MathJax-Span-6342" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-6343" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-6344" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mn" id="MathJax-Span-6345" style="font-family: MathJax_Main; padding-left: 0.278em;">721133315582</span><span class="msqrt" id="MathJax-Span-6346"><span style="display: inline-block; position: relative; width: 1.333em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-6347"><span class="mn" id="MathJax-Span-6348" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.591em, 1000.5em, 3.915em, -1000em); top: -4.543em; left: 0.833em;"><span style="font-family: MathJax_Main;">–</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.028em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6349" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-6350" style="font-family: MathJax_Main; padding-left: 0.222em;">1019836515172</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.315em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><mn>4375636191520</mn><msqrt><mn>2</mn></msqrt><mo>−</mo><mn>6188084046055</mn><mo>&lt;</mo><mi>π</mi><mo>&lt;</mo><mn>721133315582</mn><msqrt><mn>2</mn></msqrt><mo>−</mo><mn>1019836515172</mn></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-498">4375636191520\\sqrt{2}-6188084046055 < \\pi < 721133315582\\sqrt{2}-1019836515172 </script><br>
# We call <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-499-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;msub&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6351" style="width: 6.844em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.167em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.07em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6352"><span class="mi" id="MathJax-Span-6353" style="font-family: MathJax_Math; font-style: italic;">B</span><span class="mi" id="MathJax-Span-6354" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="msubsup" id="MathJax-Span-6355"><span style="display: inline-block; position: relative; width: 1.195em; height: 0px;"><span style="position: absolute; clip: rect(3.16em, 1000.73em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6356" style="font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.75em;"><span class="mi" id="MathJax-Span-6357" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6358" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6359" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-6360" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6361" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">n</span><span class="mo" id="MathJax-Span-6362" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi><mi>Q</mi><msub><mi>A</mi><mi>d</mi></msub><mo stretchy="false">(</mo><mi>x</mi><mo>,</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-499">BQA_d(x,n)</script> the quadratic integer closest to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-500-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6363" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6364"><span class="mi" id="MathJax-Span-6365" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-500">x</script> with the absolute values of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-501-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6366" style="width: 1.868em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.388em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1001.38em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6367"><span class="mi" id="MathJax-Span-6368" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-6369" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6370" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.298em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>,</mo><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-501">a,b</script> not exceeding <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-502-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6371" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6372"><span class="mi" id="MathJax-Span-6373" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-502">n</script>.<br> We also define the integral part of a quadratic integer as <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-503-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;msqrt&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/msqrt&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6374" style="width: 9.285em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.033em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.679em, 1007.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6375"><span class="msubsup" id="MathJax-Span-6376"><span style="display: inline-block; position: relative; width: 0.885em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.5em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6377" style="font-family: MathJax_Math; font-style: italic;">I<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.064em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.44em;"><span class="mi" id="MathJax-Span-6378" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6379" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6380" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-6381" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-6382" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">b</span><span class="msqrt" id="MathJax-Span-6383"><span style="display: inline-block; position: relative; width: 1.381em; height: 0px;"><span style="position: absolute; clip: rect(3.182em, 1000.52em, 4.173em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-6384"><span class="mi" id="MathJax-Span-6385" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1000.55em, 3.935em, -1000em); top: -4.603em; left: 0.833em;"><span style="display: inline-block; position: relative; width: 0.548em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.146em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.076em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6386" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6387" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-6388" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">a</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.588em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>I</mi><mi>d</mi></msub><mo stretchy="false">(</mo><mi>a</mi><mo>+</mo><mi>b</mi><msqrt><mi>d</mi></msqrt><mo stretchy="false">)</mo><mo>=</mo><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-503">I_d(a+b\\sqrt{d}) = a</script>.
#
# <p>You are given that:</p>
# <ul><li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-504-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;msub&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;msqrt&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6389" style="width: 13.639em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.335em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.688em, 1010.33em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6390"><span class="mi" id="MathJax-Span-6391" style="font-family: MathJax_Math; font-style: italic;">B</span><span class="mi" id="MathJax-Span-6392" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="msubsup" id="MathJax-Span-6393"><span style="display: inline-block; position: relative; width: 1.179em; height: 0px;"><span style="position: absolute; clip: rect(3.16em, 1000.73em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6394" style="font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.75em;"><span class="mn" id="MathJax-Span-6395" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6396" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6397" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-6398" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6399" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-6400" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6401" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6402" style="font-family: MathJax_Main; padding-left: 0.278em;">6</span><span class="mo" id="MathJax-Span-6403" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-6404" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="msqrt" id="MathJax-Span-6405"><span style="display: inline-block; position: relative; width: 1.333em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-6406"><span class="mn" id="MathJax-Span-6407" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.591em, 1000.5em, 3.915em, -1000em); top: -4.582em; left: 0.833em;"><span style="font-family: MathJax_Main;">–</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.067em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.576em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi><mi>Q</mi><msub><mi>A</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mi>π</mi><mo>,</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>6</mn><mo>−</mo><mn>2</mn><msqrt><mn>2</mn></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-504">BQA_2(\\pi,10) = 6 - 2\\sqrt{2}</script></li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-505-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;msub&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;26&lt;/mn&gt;&lt;msqrt&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;55&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6408" style="width: 15.553em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.77em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.699em, 1011.72em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6409"><span class="mi" id="MathJax-Span-6410" style="font-family: MathJax_Math; font-style: italic;">B</span><span class="mi" id="MathJax-Span-6411" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="msubsup" id="MathJax-Span-6412"><span style="display: inline-block; position: relative; width: 1.179em; height: 0px;"><span style="position: absolute; clip: rect(3.16em, 1000.73em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6413" style="font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.75em;"><span class="mn" id="MathJax-Span-6414" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6415" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6416" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-6417" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6418" style="font-family: MathJax_Main; padding-left: 0.167em;">100</span><span class="mo" id="MathJax-Span-6419" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6420" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6421" style="font-family: MathJax_Main; padding-left: 0.278em;">26</span><span class="msqrt" id="MathJax-Span-6422"><span style="display: inline-block; position: relative; width: 1.333em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.185em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-6423"><span class="mn" id="MathJax-Span-6424" style="font-family: MathJax_Main;">5</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.591em, 1000.5em, 3.915em, -1000em); top: -4.571em; left: 0.833em;"><span style="font-family: MathJax_Main;">–</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.056em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6425" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-6426" style="font-family: MathJax_Main; padding-left: 0.222em;">55</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.561em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi><mi>Q</mi><msub><mi>A</mi><mn>5</mn></msub><mo stretchy="false">(</mo><mi>π</mi><mo>,</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>26</mn><msqrt><mn>5</mn></msqrt><mo>−</mo><mn>55</mn></math></span></span><script type="math/tex" id="MathJax-Element-505">BQA_5(\\pi,100)=26\\sqrt{5}-55</script></li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-506-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;msub&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;560323&lt;/mn&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;211781&lt;/mn&gt;&lt;msqrt&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6427" style="width: 20.624em; display: inline-block;"><span style="display: inline-block; position: relative; width: 15.598em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1015.6em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6428"><span class="mi" id="MathJax-Span-6429" style="font-family: MathJax_Math; font-style: italic;">B</span><span class="mi" id="MathJax-Span-6430" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="msubsup" id="MathJax-Span-6431"><span style="display: inline-block; position: relative; width: 1.179em; height: 0px;"><span style="position: absolute; clip: rect(3.16em, 1000.73em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6432" style="font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.75em;"><span class="mn" id="MathJax-Span-6433" style="font-size: 70.7%; font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6434" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6435" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-6436" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-6437" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6438" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6439" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6440" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6441" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6442" style="font-family: MathJax_Main; padding-left: 0.278em;">560323</span><span class="mo" id="MathJax-Span-6443" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-6444" style="font-family: MathJax_Main; padding-left: 0.222em;">211781</span><span class="msqrt" id="MathJax-Span-6445"><span style="display: inline-block; position: relative; width: 1.333em; height: 0px;"><span style="position: absolute; clip: rect(3.2em, 1000.48em, 4.185em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-6446"><span class="mn" id="MathJax-Span-6447" style="font-family: MathJax_Main;">7</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.591em, 1000.5em, 3.915em, -1000em); top: -4.576em; left: 0.833em;"><span style="font-family: MathJax_Main;">–</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.061em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi><mi>Q</mi><msub><mi>A</mi><mn>7</mn></msub><mo stretchy="false">(</mo><mi>π</mi><mo>,</mo><msup><mn>10</mn><mn>6</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>560323</mn><mo>−</mo><mn>211781</mn><msqrt><mn>7</mn></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-506">BQA_7(\\pi,10^6)=560323 - 211781\\sqrt{7}</script></li>
# <li><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-507-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;msub&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;6188084046055&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6448" style="width: 21.486em; display: inline-block;"><span style="display: inline-block; position: relative; width: 16.268em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1016.22em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6449"><span class="msubsup" id="MathJax-Span-6450"><span style="display: inline-block; position: relative; width: 0.869em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.5em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6451" style="font-family: MathJax_Math; font-style: italic;">I<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.064em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.44em;"><span class="mn" id="MathJax-Span-6452" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6453" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6454" style="font-family: MathJax_Math; font-style: italic;">B</span><span class="mi" id="MathJax-Span-6455" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="msubsup" id="MathJax-Span-6456"><span style="display: inline-block; position: relative; width: 1.179em; height: 0px;"><span style="position: absolute; clip: rect(3.16em, 1000.73em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6457" style="font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.75em;"><span class="mn" id="MathJax-Span-6458" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6459" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6460" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-6461" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-6462" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6463" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-6464"><span class="mrow" id="MathJax-Span-6465"><span class="mn" id="MathJax-Span-6466" style="font-size: 70.7%; font-family: MathJax_Main;">13</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6467" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6468" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6469" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-6470" style="font-family: MathJax_Main; padding-left: 0.278em;">−</span><span class="mn" id="MathJax-Span-6471" style="font-family: MathJax_Main;">6188084046055</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>I</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mi>B</mi><mi>Q</mi><msub><mi>A</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mi>π</mi><mo>,</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>13</mn></mrow></msup><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo>=</mo><mo>−</mo><mn>6188084046055</mn></math></span></span><script type="math/tex" id="MathJax-Element-507">I_2(BQA_2(\\pi,10^{13}))=-6188084046055</script></li></ul><p>Find the sum of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-508-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;msub&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6472" style="width: 11.342em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.565em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1008.45em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6473"><span class="texatom" id="MathJax-Span-6474"><span class="mrow" id="MathJax-Span-6475"><span class="mo" id="MathJax-Span-6476" style="font-family: MathJax_Main;">|</span></span></span><span class="msubsup" id="MathJax-Span-6477"><span style="display: inline-block; position: relative; width: 0.885em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.5em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6478" style="font-family: MathJax_Math; font-style: italic;">I<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.064em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.44em;"><span class="mi" id="MathJax-Span-6479" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6480" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6481" style="font-family: MathJax_Math; font-style: italic;">B</span><span class="mi" id="MathJax-Span-6482" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="msubsup" id="MathJax-Span-6483"><span style="display: inline-block; position: relative; width: 1.195em; height: 0px;"><span style="position: absolute; clip: rect(3.16em, 1000.73em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6484" style="font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.75em;"><span class="mi" id="MathJax-Span-6485" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6486" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6487" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-6488" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-6489" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6490" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-6491"><span class="mrow" id="MathJax-Span-6492"><span class="mn" id="MathJax-Span-6493" style="font-size: 70.7%; font-family: MathJax_Main;">13</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6494" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6495" style="font-family: MathJax_Main;">)</span><span class="texatom" id="MathJax-Span-6496"><span class="mrow" id="MathJax-Span-6497"><span class="mo" id="MathJax-Span-6498" style="font-family: MathJax_Main;">|</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><msub><mi>I</mi><mi>d</mi></msub><mo stretchy="false">(</mo><mi>B</mi><mi>Q</mi><msub><mi>A</mi><mi>d</mi></msub><mo stretchy="false">(</mo><mi>π</mi><mo>,</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>13</mn></mrow></msup><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow></math></span></span><script type="math/tex" id="MathJax-Element-508">|I_d(BQA_d(\\pi,10^{13}))|</script> for all  non-square positive integers less than 100.</p>

# %%
submit_answer(answer; prob_num=591);

# %% [markdown]
# ## Problem 592: Factorial trailing digits 2
# <p>For any <var>N</var>, let <var>f</var>(<var>N</var>) be the last twelve hexadecimal digits before the trailing zeroes in <var>N</var>!.</p>
#
# <p>For example, the hexadecimal representation of 20! is 21C3677C82B40000,<br>
# so <var>f</var>(20) is the digit sequence 21C3677C82B4.</p>
#
# <p>Find <var>f</var>(20!). Give your answer as twelve hexadecimal digits, using uppercase for the digits A to F.</p>

# %%
submit_answer(answer; prob_num=592);

# %% [markdown]
# ## Problem 593: Fleeting Medians
# <p>We define two sequences <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-509-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6499" style="width: 15.17em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.483em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1011.42em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6500"><span class="mi" id="MathJax-Span-6501" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6502" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-6503" style="font-family: MathJax_Main; padding-left: 0.278em;">{</span><span class="mi" id="MathJax-Span-6504" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6505" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6506" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-6507" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6508" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6509" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6510" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6511" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-6512" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6513" style="font-family: MathJax_Main;">,</span><span class="mo" id="MathJax-Span-6514" style="font-family: MathJax_Main; padding-left: 0.167em;">.</span><span class="mo" id="MathJax-Span-6515" style="font-family: MathJax_Main; padding-left: 0.167em;">.</span><span class="mo" id="MathJax-Span-6516" style="font-family: MathJax_Main; padding-left: 0.167em;">.</span><span class="mo" id="MathJax-Span-6517" style="font-family: MathJax_Main; padding-left: 0.167em;">,</span><span class="mi" id="MathJax-Span-6518" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6519" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6520" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-6521" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6522" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo>=</mo><mo fence="false" stretchy="false">{</mo><mi>S</mi><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>,</mo><mi>S</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>,</mo><mo>.</mo><mo>.</mo><mo>.</mo><mo>,</mo><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-509">S = \\{S(1), S(2), ..., S(n)\\}</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-510-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6523" style="width: 17.275em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.062em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1013em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6524"><span class="msubsup" id="MathJax-Span-6525"><span style="display: inline-block; position: relative; width: 1.042em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1000.65em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6526" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.613em;"><span class="mn" id="MathJax-Span-6527" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6528" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-6529" style="font-family: MathJax_Main; padding-left: 0.278em;">{</span><span class="msubsup" id="MathJax-Span-6530"><span style="display: inline-block; position: relative; width: 1.042em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1000.65em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6531" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.613em;"><span class="mn" id="MathJax-Span-6532" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6533" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6534" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-6535" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6536" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-6537" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.042em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1000.65em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6538" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.613em;"><span class="mn" id="MathJax-Span-6539" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6540" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6541" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-6542" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6543" style="font-family: MathJax_Main;">,</span><span class="mo" id="MathJax-Span-6544" style="font-family: MathJax_Main; padding-left: 0.167em;">.</span><span class="mo" id="MathJax-Span-6545" style="font-family: MathJax_Main; padding-left: 0.167em;">.</span><span class="mo" id="MathJax-Span-6546" style="font-family: MathJax_Main; padding-left: 0.167em;">.</span><span class="mo" id="MathJax-Span-6547" style="font-family: MathJax_Main; padding-left: 0.167em;">,</span><span class="msubsup" id="MathJax-Span-6548" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.042em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1000.65em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6549" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.613em;"><span class="mn" id="MathJax-Span-6550" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6551" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6552" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-6553" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6554" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>S</mi><mn>2</mn></msub><mo>=</mo><mo fence="false" stretchy="false">{</mo><msub><mi>S</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>,</mo><msub><mi>S</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>,</mo><mo>.</mo><mo>.</mo><mo>.</mo><mo>,</mo><msub><mi>S</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-510">S_2 = \\{S_2(1), S_2(2), ..., S_2(n)\\}</script>:</p>
#
# <p><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-511-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msub&gt;&lt;msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6555" style="width: 7.132em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.407em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.682em, 1005.41em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6556"><span class="mi" id="MathJax-Span-6557" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6558" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6559" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6560" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6561" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-6562" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="msubsup" id="MathJax-Span-6563"><span style="display: inline-block; position: relative; width: 0.946em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6564" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.503em;"><span class="mi" id="MathJax-Span-6565" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-6566"><span style="display: inline-block; position: relative; width: 0.832em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1000.29em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6567" style="font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.389em;"><span class="mi" id="MathJax-Span-6568" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.583em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>=</mo><mo stretchy="false">(</mo><msub><mi>p</mi><mi>k</mi></msub><msup><mo stretchy="false">)</mo><mi>k</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-511">S(k) = (p_k)^k</script> mod <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-512-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;10007&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6569" style="width: 3.16em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.392em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.86em, 1002.38em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6570"><span class="mn" id="MathJax-Span-6571" style="font-family: MathJax_Main;">10007</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.048em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>10007</mn></math></span></span><script type="math/tex" id="MathJax-Element-512">10007</script> where <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-513-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6572" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.615em, 1000.96em, 2.538em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-6573"><span class="msubsup" id="MathJax-Span-6574"><span style="display: inline-block; position: relative; width: 0.946em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6575" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.503em;"><span class="mi" id="MathJax-Span-6576" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>p</mi><mi>k</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-513">p_k</script> is the <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-514-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6577" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6578"><span class="mi" id="MathJax-Span-6579" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-514">k</script>th prime number.</p>
#
# <p><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-515-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230A;&lt;/mo&gt;&lt;mfrac&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mn&gt;10000&lt;/mn&gt;&lt;/mfrac&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230B;&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6580" style="width: 17.084em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.638em, 1012.82em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6581"><span class="msubsup" id="MathJax-Span-6582"><span style="display: inline-block; position: relative; width: 1.042em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1000.65em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6583" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.613em;"><span class="mn" id="MathJax-Span-6584" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6585" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6586" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6587" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6588" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-6589" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6590" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6591" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6592" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6593" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-6594" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-6595" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-6596" style="font-family: MathJax_Main;">⌊</span><span class="mfrac" id="MathJax-Span-6597"><span style="display: inline-block; position: relative; width: 1.888em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -4.427em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-6598" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.74em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.884em;"><span class="mn" id="MathJax-Span-6599" style="font-size: 70.7%; font-family: MathJax_Main;">10000</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.89em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.888em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-6600" style="font-family: MathJax_Main;">⌋</span><span class="mo" id="MathJax-Span-6601" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-6602" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-6603" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.822em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>S</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>=</mo><mi>S</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>+</mo><mi>S</mi><mo stretchy="false">(</mo><mo fence="false" stretchy="false">⌊</mo><mfrac><mi>k</mi><mn>10000</mn></mfrac><mo fence="false" stretchy="false">⌋</mo><mo>+</mo><mn>1</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-515">S_2(k) = S(k) + S(\\lfloor\\frac{k}{10000}\\rfloor + 1)</script> where <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-516-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230A;&lt;/mo&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;&amp;#x230B;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6604" style="width: 1.533em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.148em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1000.97em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6605"><span class="mo" id="MathJax-Span-6606" style="font-family: MathJax_Main;">⌊</span><span class="mo" id="MathJax-Span-6607" style="font-family: MathJax_Main;">⋅</span><span class="mo" id="MathJax-Span-6608" style="font-family: MathJax_Main;">⌋</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo fence="false" stretchy="false">⌊</mo><mo>⋅</mo><mo fence="false" stretchy="false">⌋</mo></math></span></span><script type="math/tex" id="MathJax-Element-516">\\lfloor \\cdot \\rfloor</script> denotes the floor function.</p>
#
# <p>Then let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-517-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6609" style="width: 3.974em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.014em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.92em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6610"><span class="mi" id="MathJax-Span-6611" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-6612" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6613" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-6614" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6615" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">j</span><span class="mo" id="MathJax-Span-6616" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo stretchy="false">(</mo><mi>i</mi><mo>,</mo><mi>j</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-517">M(i, j)</script> be the median of elements <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-518-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6617" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6618"><span class="msubsup" id="MathJax-Span-6619"><span style="display: inline-block; position: relative; width: 1.042em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1000.65em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6620" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.613em;"><span class="mn" id="MathJax-Span-6621" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6622" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6623" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-6624" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>S</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mi>i</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-518">S_2(i)</script> through <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-519-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6625" style="width: 2.969em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.249em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.15em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6626"><span class="msubsup" id="MathJax-Span-6627"><span style="display: inline-block; position: relative; width: 1.042em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1000.65em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6628" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.613em;"><span class="mn" id="MathJax-Span-6629" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6630" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6631" style="font-family: MathJax_Math; font-style: italic;">j</span><span class="mo" id="MathJax-Span-6632" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>S</mi><mn>2</mn></msub><mo stretchy="false">(</mo><mi>j</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-519">S_2(j)</script>, inclusive. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-520-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2021.5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6633" style="width: 10.194em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.703em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.65em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6634"><span class="mi" id="MathJax-Span-6635" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-6636" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6637" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-6638" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6639" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-6640" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6641" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6642" style="font-family: MathJax_Main; padding-left: 0.278em;">2021.5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo stretchy="false">(</mo><mn>1</mn><mo>,</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2021.5</mn></math></span></span><script type="math/tex" id="MathJax-Element-520">M(1, 10) = 2021.5</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-521-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;4715.0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6643" style="width: 12.06em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.139em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1009.1em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6644"><span class="mi" id="MathJax-Span-6645" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-6646" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6647"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6648" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6649" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6650" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-6651" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6652" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6653" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6654" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6655" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6656" style="font-family: MathJax_Main; padding-left: 0.278em;">4715.0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>2</mn></msup><mo>,</mo><msup><mn>10</mn><mn>3</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>4715.0</mn></math></span></span><script type="math/tex" id="MathJax-Element-521">M(10^2, 10^3) = 4715.0</script>.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-522-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6657" style="width: 18.902em; display: inline-block;"><span style="display: inline-block; position: relative; width: 14.306em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.568em, 1014.21em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6658"><span class="mi" id="MathJax-Span-6659" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-6660" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6661" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-6662" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6663" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="mo" id="MathJax-Span-6664" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6665" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-6666" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 3.377em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-6667" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1002.32em, 4.221em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-6668"><span class="mrow" id="MathJax-Span-6669"><span class="mi" id="MathJax-Span-6670" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-6671" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mi" id="MathJax-Span-6672" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-6673" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mn" id="MathJax-Span-6674" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.22em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-6675"><span class="mrow" id="MathJax-Span-6676"><span class="mi" id="MathJax-Span-6677" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-6678" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-6679" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-6680" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-6681" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6682" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-6683" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6684" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">i</span><span class="mo" id="MathJax-Span-6685" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-6686" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">k</span><span class="mo" id="MathJax-Span-6687" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-6688" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-6689" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.791em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>k</mi><mo stretchy="false">)</mo><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>−</mo><mi>k</mi><mo>+</mo><mn>1</mn></mrow></munderover><mi>M</mi><mo stretchy="false">(</mo><mi>i</mi><mo>,</mo><mi>i</mi><mo>+</mo><mi>k</mi><mo>−</mo><mn>1</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-522">F(n, k) = \\sum_{i=1}^{n-k+1} M(i, i + k - 1)</script>. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-523-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;463628.5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6690" style="width: 12.251em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.282em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1009.23em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6691"><span class="mi" id="MathJax-Span-6692" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-6693" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-6694" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-6695" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6696" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-6697" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6698" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6699" style="font-family: MathJax_Main; padding-left: 0.278em;">463628.5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mn>100</mn><mo>,</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>463628.5</mn></math></span></span><script type="math/tex" id="MathJax-Element-523">F(100, 10) = 463628.5</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-524-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;675348207.5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6700" style="width: 14.787em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.196em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.664em, 1011.15em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6701"><span class="mi" id="MathJax-Span-6702" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-6703" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6704"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6705" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6706" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6707" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-6708" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6709" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6710" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6711" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6712" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6713" style="font-family: MathJax_Main; padding-left: 0.278em;">675348207.5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.607em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>5</mn></msup><mo>,</mo><msup><mn>10</mn><mn>4</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>675348207.5</mn></math></span></span><script type="math/tex" id="MathJax-Element-524">F(10^5, 10^4) = 675348207.5</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-525-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6714" style="width: 6.318em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.785em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.665em, 1004.69em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6715"><span class="mi" id="MathJax-Span-6716" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-6717" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6718"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6719" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6720" style="font-size: 70.7%; font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6721" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-6722" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-6723" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-6724" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6725" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.606em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>7</mn></msup><mo>,</mo><msup><mn>10</mn><mn>5</mn></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-525">F(10^7, 10^5)</script>. If the sum is not an integer, use <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-526-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;.5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6726" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.72em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6727"><span class="mn" id="MathJax-Span-6728" style="font-family: MathJax_Main;">.5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>.5</mn></math></span></span><script type="math/tex" id="MathJax-Element-526">.5</script> to denote a half. Otherwise, use <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-527-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;.0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6729" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.73em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6730"><span class="mn" id="MathJax-Span-6731" style="font-family: MathJax_Main;">.0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>.0</mn></math></span></span><script type="math/tex" id="MathJax-Element-527">.0</script> instead.</p>

# %%
submit_answer(answer; prob_num=593);

# %% [markdown]
# ## Problem 594: Rhombus Tilings
# <p>
# For a polygon <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-528-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6732" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.72em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6733"><span class="mi" id="MathJax-Span-6734" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi></math></span></span><script type="math/tex" id="MathJax-Element-528">P</script>, let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-529-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6735" style="width: 2.49em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.866em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.77em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6736"><span class="mi" id="MathJax-Span-6737" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mo" id="MathJax-Span-6738" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6739" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-6740" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>t</mi><mo stretchy="false">(</mo><mi>P</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-529">t(P)</script> be the number of ways in which <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-530-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6741" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.72em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6742"><span class="mi" id="MathJax-Span-6743" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi></math></span></span><script type="math/tex" id="MathJax-Element-530">P</script> can be tiled using rhombi and squares with edge length 1. Distinct rotations and reflections are counted as separate tilings.
# </p>
# <p>
# For example, if <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-531-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6744" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.593em, 1000.74em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6745"><span class="mi" id="MathJax-Span-6746" style="font-family: MathJax_Math; font-style: italic;">O</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.085em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>O</mi></math></span></span><script type="math/tex" id="MathJax-Element-531">O</script> is a regular octagon with edge length 1, then <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-532-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6747" style="width: 4.931em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.732em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.69em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6748"><span class="mi" id="MathJax-Span-6749" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mo" id="MathJax-Span-6750" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6751" style="font-family: MathJax_Math; font-style: italic;">O</span><span class="mo" id="MathJax-Span-6752" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6753" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6754" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>t</mi><mo stretchy="false">(</mo><mi>O</mi><mo stretchy="false">)</mo><mo>=</mo><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-532">t(O) = 8</script>. As it happens, all these 8 tilings are rotations of one another:
# </p>
# <div style="text-align:center;">
# <img src="webfiles/p594_octagon_tilings_1.png" alt="p594_octagon_tilings_1.png"></div>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-533-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6755" style="width: 2.299em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.722em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.353em, 1001.72em, 2.632em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-6756"><span class="msubsup" id="MathJax-Span-6757"><span style="display: inline-block; position: relative; width: 1.712em; height: 0px;"><span style="position: absolute; clip: rect(3.172em, 1000.74em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6758" style="font-family: MathJax_Math; font-style: italic;">O</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.763em;"><span class="texatom" id="MathJax-Span-6759"><span class="mrow" id="MathJax-Span-6760"><span class="mi" id="MathJax-Span-6761" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-6762" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6763" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.435em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>O</mi><mrow class="MJX-TeXAtom-ORD"><mi>a</mi><mo>,</mo><mi>b</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-533">O_{a,b}</script> be the equal-angled convex octagon whose edges alternate in length between <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-534-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6764" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1000.5em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6765"><span class="mi" id="MathJax-Span-6766" style="font-family: MathJax_Math; font-style: italic;">a</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.722em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-534">a</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-535-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6767" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.42em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6768"><span class="mi" id="MathJax-Span-6769" style="font-family: MathJax_Math; font-style: italic;">b</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-535">b</script>.
# <br>
# For example, here is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-536-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6770" style="width: 2.299em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.722em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.353em, 1001.72em, 2.632em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-6771"><span class="msubsup" id="MathJax-Span-6772"><span style="display: inline-block; position: relative; width: 1.742em; height: 0px;"><span style="position: absolute; clip: rect(3.172em, 1000.74em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6773" style="font-family: MathJax_Math; font-style: italic;">O</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.763em;"><span class="texatom" id="MathJax-Span-6774"><span class="mrow" id="MathJax-Span-6775"><span class="mn" id="MathJax-Span-6776" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-6777" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6778" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.435em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>O</mi><mrow class="MJX-TeXAtom-ORD"><mn>2</mn><mo>,</mo><mn>1</mn></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-536">O_{2,1}</script>, with one of its tilings:
# </p>
# <div style="text-align:center;">
# <img src="webfiles/p594_octagon_tilings_2.png" alt="p594_octagon_tilings_2.png"></div>
#
# <p>
# You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-537-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6779" style="width: 6.222em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.689em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.65em, 3.11em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6780"><span class="mi" id="MathJax-Span-6781" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mo" id="MathJax-Span-6782" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6783"><span style="display: inline-block; position: relative; width: 1.742em; height: 0px;"><span style="position: absolute; clip: rect(3.172em, 1000.74em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6784" style="font-family: MathJax_Math; font-style: italic;">O</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.763em;"><span class="texatom" id="MathJax-Span-6785"><span class="mrow" id="MathJax-Span-6786"><span class="mn" id="MathJax-Span-6787" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-6788" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6789" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6790" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6791" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6792" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.495em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>t</mi><mo stretchy="false">(</mo><msub><mi>O</mi><mrow class="MJX-TeXAtom-ORD"><mn>1</mn><mo>,</mo><mn>1</mn></mrow></msub><mo stretchy="false">)</mo><mo>=</mo><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-537">t(O_{1,1})=8</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-538-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;76&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6793" style="width: 6.844em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.167em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.12em, 3.11em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6794"><span class="mi" id="MathJax-Span-6795" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mo" id="MathJax-Span-6796" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6797"><span style="display: inline-block; position: relative; width: 1.742em; height: 0px;"><span style="position: absolute; clip: rect(3.172em, 1000.74em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6798" style="font-family: MathJax_Math; font-style: italic;">O</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.763em;"><span class="texatom" id="MathJax-Span-6799"><span class="mrow" id="MathJax-Span-6800"><span class="mn" id="MathJax-Span-6801" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-6802" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6803" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6804" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6805" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6806" style="font-family: MathJax_Main; padding-left: 0.278em;">76</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.495em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>t</mi><mo stretchy="false">(</mo><msub><mi>O</mi><mrow class="MJX-TeXAtom-ORD"><mn>2</mn><mo>,</mo><mn>1</mn></mrow></msub><mo stretchy="false">)</mo><mo>=</mo><mn>76</mn></math></span></span><script type="math/tex" id="MathJax-Element-538">t(O_{2,1})=76</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-539-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;456572&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6807" style="width: 9.38em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.081em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.03em, 3.11em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6808"><span class="mi" id="MathJax-Span-6809" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mo" id="MathJax-Span-6810" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6811"><span style="display: inline-block; position: relative; width: 1.742em; height: 0px;"><span style="position: absolute; clip: rect(3.172em, 1000.74em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6812" style="font-family: MathJax_Math; font-style: italic;">O</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.763em;"><span class="texatom" id="MathJax-Span-6813"><span class="mrow" id="MathJax-Span-6814"><span class="mn" id="MathJax-Span-6815" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-6816" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6817" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6818" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-6819" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6820" style="font-family: MathJax_Main; padding-left: 0.278em;">456572</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.495em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>t</mi><mo stretchy="false">(</mo><msub><mi>O</mi><mrow class="MJX-TeXAtom-ORD"><mn>3</mn><mo>,</mo><mn>2</mn></mrow></msub><mo stretchy="false">)</mo><mo>=</mo><mn>456572</mn></math></span></span><script type="math/tex" id="MathJax-Element-539">t(O_{3,2})=456572</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-540-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;O&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6821" style="width: 3.83em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.871em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.78em, 3.11em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6822"><span class="mi" id="MathJax-Span-6823" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mo" id="MathJax-Span-6824" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-6825"><span style="display: inline-block; position: relative; width: 1.742em; height: 0px;"><span style="position: absolute; clip: rect(3.172em, 1000.74em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6826" style="font-family: MathJax_Math; font-style: italic;">O</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.763em;"><span class="texatom" id="MathJax-Span-6827"><span class="mrow" id="MathJax-Span-6828"><span class="mn" id="MathJax-Span-6829" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-6830" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-6831" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6832" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.495em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>t</mi><mo stretchy="false">(</mo><msub><mi>O</mi><mrow class="MJX-TeXAtom-ORD"><mn>4</mn><mo>,</mo><mn>2</mn></mrow></msub><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-540">t(O_{4,2})</script>.
# </p>

# %%
submit_answer(answer; prob_num=594);

# %% [markdown]
# ## Problem 595: Incremental Random Sort
# <p>
# A deck of cards numbered from 1 to n is shuffled randomly such that each permutation is equally likely.
# </p>
# <p>
# The cards are to be sorted into ascending order using the following technique:
# </p><ol><li> Look at the initial sequence of cards.  If it is already
# sorted, then there is no need for further action.  Otherwise, if any
# subsequences of cards happen to be in the correct place relative to one
# another (ascending with no gaps), then those subsequences are fixed by
# attaching the cards together.  For example, with 7 cards initially in
# the order 4123756, the cards labelled 1, 2 and 3 would be attached
# together, as would 5 and 6.
# </li></ol><ol start="2"><li> The cards are 'shuffled' by being thrown
# into the air, but note that any correctly sequenced cards remain
# attached, so their orders are maintained.  The cards (or bundles of
# attached cards) are then picked up randomly.  You should assume that
# this randomisation is unbiased, despite the fact that some cards are
# single, and others are grouped together.
# </li></ol><ol start="3"><li> Repeat steps 1 and 2 until the cards are sorted.
# </li></ol><p>
#    Let S(n) be the expected number of shuffles needed to sort the cards.
#  Since the order is checked before the first shuffle, S(1) = 0. You are
# given that S(2) = 1, and S(5) = 4213/871.
# </p>
# <p>
# Find S(52), and give your answer rounded to 8 decimal places.
# </p>

# %%
submit_answer(answer; prob_num=595);

# %% [markdown]
# ## Problem 596: Number of lattice points in a hyperball
# <p>Let T(<var>r</var>) be the number of integer quadruplets <var>x</var>, <var>y</var>, <var>z</var>, <var>t</var> such that <var>x</var><sup>2</sup> + <var>y</var><sup>2</sup> + <var>z</var><sup>2</sup> + <var>t</var><sup>2</sup> ≤ <var>r</var><sup>2</sup>. In other words, T(<var>r</var>) is the number of lattice points in the four-dimensional hyperball of radius <var>r</var>.</p>
#
# <p>You are given that T(2) = 89, T(5) = 3121, T(100) = 493490641 and T(10<sup>4</sup>) = 49348022079085897.</p>
#
# <p>Find T(10<sup>8</sup>) mod 1000000007.</p>

# %%
submit_answer(answer; prob_num=596);

# %% [markdown]
# ## Problem 597: Torpids
# The Torpids are rowing races held annually in Oxford, following some curious rules:
#
# <ul><li>
# A division consists of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-541-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6833" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6834"><span class="mi" id="MathJax-Span-6835" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-541">n</script> boats (typically 13), placed in order based on past performance.
# </li><li>
# All boats within a division start at 40 metre intervals along the river,
#  in order with the highest-placed boat starting furthest upstream.
# </li><li>
# The boats all start rowing simultaneously, upstream, trying to catch the
#  boat in front while avoiding being caught by boats behind.
# </li><li>
# Each boat continues rowing until <em>either</em> it reaches the finish line <em>or</em> it catches up with ("bumps") a boat in front.
# </li><li>
# The finish line is a distance <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-542-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6836" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.64em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6837"><span class="mi" id="MathJax-Span-6838" style="font-family: MathJax_Math; font-style: italic;">L</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi></math></span></span><script type="math/tex" id="MathJax-Element-542">L</script>
#  metres (the course length, in reality about 1800 metres) upstream from
# the starting position of the lowest-placed boat. (Because of the
# staggered starting positions, higher-placed boats row a slightly shorter
#  course than lower-placed boats.)
# </li><li>
# When a "bump" occurs, the "bumping" boat takes no further part in the
# race. The "bumped" boat must continue, however, and may even be "bumped"
#  again by boats that started two or more places behind it.
# </li><li>
# After the race, boats are assigned new places within the division, based on the bumps that occurred. Specifically, for any boat <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-543-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6839" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6840"><span class="mi" id="MathJax-Span-6841" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-543">A</script> that started in a lower place than <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-544-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6842" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6843"><span class="mi" id="MathJax-Span-6844" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-544">B</script>, then <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-545-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6845" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6846"><span class="mi" id="MathJax-Span-6847" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-545">A</script> will be placed higher than <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-546-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6848" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6849"><span class="mi" id="MathJax-Span-6850" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-546">B</script> in the new order if and only if one of the following occurred:
#   <ol><li> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-547-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6851" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6852"><span class="mi" id="MathJax-Span-6853" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-547">A</script> bumped <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-548-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6854" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6855"><span class="mi" id="MathJax-Span-6856" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-548">B</script> directly </li>
#   <li> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-549-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6857" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6858"><span class="mi" id="MathJax-Span-6859" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-549">A</script> bumped another boat that went on to bump <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-550-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6860" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6861"><span class="mi" id="MathJax-Span-6862" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-550">B</script> </li>
#   <li> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-551-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6863" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6864"><span class="mi" id="MathJax-Span-6865" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-551">A</script> bumped another boat, that bumped yet another boat, that bumped <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-552-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6866" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6867"><span class="mi" id="MathJax-Span-6868" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-552">B</script> </li>
#   <li> etc </li></ol></li></ul><b>NOTE</b>: For the purposes of this
# "problem you may disregard the boats' lengths, and assume that a bump "
# occurs precisely when the two boats draw level. (In reality, a bump is
# awarded as soon as physical contact is made, which usually occurs when
# "there is much less than a full boat length's overlap.)"
#
# <p>
# Suppose that, in a particular race, each boat <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-553-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6869" style="width: 1.533em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.148em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.374em, 1001.15em, 2.639em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-6870"><span class="msubsup" id="MathJax-Span-6871"><span style="display: inline-block; position: relative; width: 1.125em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.76em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6872" style="font-family: MathJax_Math; font-style: italic;">B</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.759em;"><span class="mi" id="MathJax-Span-6873" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">j</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.452em; border-left: 0px solid; width: 0px; height: 1.416em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>B</mi><mi>j</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-553">B_j</script> rows at a steady speed <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-554-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6874" style="width: 3.878em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.953em, 1002.84em, 3.117em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6875"><span class="msubsup" id="MathJax-Span-6876"><span style="display: inline-block; position: relative; width: 0.851em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6877" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mi" id="MathJax-Span-6878" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">j</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-6879" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-6880" style="font-family: MathJax_Main; padding-left: 0.278em;">−</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.452em; border-left: 0px solid; width: 0px; height: 1.284em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>v</mi><mi>j</mi></msub><mo>=</mo><mo>−</mo></math></span></span><script type="math/tex" id="MathJax-Element-554">v_j = -</script>log<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-555-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;X&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6881" style="width: 1.581em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.196em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.374em, 1001.2em, 2.639em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-6882"><span class="msubsup" id="MathJax-Span-6883"><span style="display: inline-block; position: relative; width: 1.194em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.85em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6884" style="font-family: MathJax_Math; font-style: italic;">X<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.024em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.828em;"><span class="mi" id="MathJax-Span-6885" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">j</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.452em; border-left: 0px solid; width: 0px; height: 1.416em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>X</mi><mi>j</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-555">X_j</script> metres per second, where the <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-556-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;X&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6886" style="width: 1.581em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.196em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.374em, 1001.2em, 2.639em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-6887"><span class="msubsup" id="MathJax-Span-6888"><span style="display: inline-block; position: relative; width: 1.194em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.85em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-6889" style="font-family: MathJax_Math; font-style: italic;">X<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.024em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.828em;"><span class="mi" id="MathJax-Span-6890" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">j</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.452em; border-left: 0px solid; width: 0px; height: 1.416em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>X</mi><mi>j</mi></msub></math></span></span><script type="math/tex" id="MathJax-Element-556">X_j</script>
#  are chosen randomly (with uniform distribution) between 0 and 1,
# independently from one another. These speeds are relative to the
# riverbank: you may disregard the flow of the river.
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-557-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6891" style="width: 3.974em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.014em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.92em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6892"><span class="mi" id="MathJax-Span-6893" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-6894" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-6895" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-6896" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-6897" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">L</span><span class="mo" id="MathJax-Span-6898" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>L</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-557">p(n,L)</script> be the probability that the new order is an <b>even permutation</b> of the starting order, when there are <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-558-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6899" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6900"><span class="mi" id="MathJax-Span-6901" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-558">n</script> boats in the division and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-559-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6902" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.64em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6903"><span class="mi" id="MathJax-Span-6904" style="font-family: MathJax_Math; font-style: italic;">L</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi></math></span></span><script type="math/tex" id="MathJax-Element-559">L</script> is the course length.
# </p>
# <p>
# For example, with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-560-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6905" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1002.4em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6906"><span class="mi" id="MathJax-Span-6907" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-6908" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6909" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.033em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-560">n=3</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-561-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;160&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6910" style="width: 4.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.445em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.853em, 1003.41em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6911"><span class="mi" id="MathJax-Span-6912" style="font-family: MathJax_Math; font-style: italic;">L</span><span class="mo" id="MathJax-Span-6913" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-6914" style="font-family: MathJax_Main; padding-left: 0.278em;">160</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi><mo>=</mo><mn>160</mn></math></span></span><script type="math/tex" id="MathJax-Element-561">L=160</script>, labelling the boats as <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-562-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6915" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6916"><span class="mi" id="MathJax-Span-6917" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-562">A</script>,<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-563-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6918" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6919"><span class="mi" id="MathJax-Span-6920" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-563">B</script>,<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-564-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6921" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6922"><span class="mi" id="MathJax-Span-6923" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-564">C</script> in starting order with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-565-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6924" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6925"><span class="mi" id="MathJax-Span-6926" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-565">C</script> highest, the different possible outcomes of the race are as follows:
# </p>
# <table cellspacing="15" align="center"><tbody><tr><th> Bumps occurring </th>
#   <th> New order </th>
#   <th> Permutation </th>
#   <th> Probability </th>
#  </tr><tr align="center"><td> none </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-566-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6927" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6928"><span class="mi" id="MathJax-Span-6929" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-566">A</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-567-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6930" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6931"><span class="mi" id="MathJax-Span-6932" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-567">B</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-568-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6933" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6934"><span class="mi" id="MathJax-Span-6935" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-568">C</script> </td>
#   <td> even </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-569-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6936" style="width: 2.538em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.86em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6937"><span class="mn" id="MathJax-Span-6938" style="font-family: MathJax_Main;">4</span><span class="texatom" id="MathJax-Span-6939"><span class="mrow" id="MathJax-Span-6940"><span class="mo" id="MathJax-Span-6941" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-6942" style="font-family: MathJax_Main;">15</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>4</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>15</mn></math></span></span><script type="math/tex" id="MathJax-Element-569">4/15</script> </td>
#  </tr><tr align="center"><td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-570-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6943" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6944"><span class="mi" id="MathJax-Span-6945" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-570">B</script> bumps <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-571-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6946" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6947"><span class="mi" id="MathJax-Span-6948" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-571">C</script> </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-572-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6949" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6950"><span class="mi" id="MathJax-Span-6951" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-572">A</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-573-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6952" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6953"><span class="mi" id="MathJax-Span-6954" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-573">C</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-574-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6955" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6956"><span class="mi" id="MathJax-Span-6957" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-574">B</script> </td>
#   <td> odd </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-575-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;45&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6958" style="width: 2.538em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.86em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6959"><span class="mn" id="MathJax-Span-6960" style="font-family: MathJax_Main;">8</span><span class="texatom" id="MathJax-Span-6961"><span class="mrow" id="MathJax-Span-6962"><span class="mo" id="MathJax-Span-6963" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-6964" style="font-family: MathJax_Main;">45</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>8</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>45</mn></math></span></span><script type="math/tex" id="MathJax-Element-575">8/45</script> </td>
#  </tr><tr align="center"><td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-576-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6965" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6966"><span class="mi" id="MathJax-Span-6967" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-576">A</script> bumps <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-577-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6968" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6969"><span class="mi" id="MathJax-Span-6970" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-577">B</script> </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-578-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6971" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6972"><span class="mi" id="MathJax-Span-6973" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-578">B</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-579-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6974" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6975"><span class="mi" id="MathJax-Span-6976" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-579">A</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-580-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6977" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6978"><span class="mi" id="MathJax-Span-6979" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-580">C</script> </td>
#   <td> odd </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-581-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6980" style="width: 1.916em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.435em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.39em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-6981"><span class="mn" id="MathJax-Span-6982" style="font-family: MathJax_Main;">1</span><span class="texatom" id="MathJax-Span-6983"><span class="mrow" id="MathJax-Span-6984"><span class="mo" id="MathJax-Span-6985" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-6986" style="font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-581">1/3</script> </td>
#  </tr><tr align="center"><td> &nbsp; &nbsp; <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-582-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6987" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6988"><span class="mi" id="MathJax-Span-6989" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-582">B</script> bumps <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-583-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6990" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6991"><span class="mi" id="MathJax-Span-6992" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-583">C</script>, then <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-584-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6993" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6994"><span class="mi" id="MathJax-Span-6995" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-584">A</script> bumps <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-585-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6996" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-6997"><span class="mi" id="MathJax-Span-6998" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-585">C</script> &nbsp; &nbsp; </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-586-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-6999" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7000"><span class="mi" id="MathJax-Span-7001" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-586">C</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-587-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7002" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7003"><span class="mi" id="MathJax-Span-7004" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-587">A</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-588-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7005" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7006"><span class="mi" id="MathJax-Span-7007" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-588">B</script> </td>
#   <td> even </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-589-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;27&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7008" style="width: 2.538em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.9em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7009"><span class="mn" id="MathJax-Span-7010" style="font-family: MathJax_Main;">4</span><span class="texatom" id="MathJax-Span-7011"><span class="mrow" id="MathJax-Span-7012"><span class="mo" id="MathJax-Span-7013" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-7014" style="font-family: MathJax_Main;">27</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>4</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>27</mn></math></span></span><script type="math/tex" id="MathJax-Element-589">4/27</script> </td>
#  </tr><tr align="center"><td> &nbsp; &nbsp; <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-590-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7015" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7016"><span class="mi" id="MathJax-Span-7017" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-590">A</script> bumps <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-591-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7018" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7019"><span class="mi" id="MathJax-Span-7020" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-591">B</script>, then <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-592-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7021" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7022"><span class="mi" id="MathJax-Span-7023" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-592">B</script> bumps <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-593-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7024" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7025"><span class="mi" id="MathJax-Span-7026" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-593">C</script> &nbsp; &nbsp; </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-594-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7027" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7028"><span class="mi" id="MathJax-Span-7029" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-594">C</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-595-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7030" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7031"><span class="mi" id="MathJax-Span-7032" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-595">B</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-596-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7033" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7034"><span class="mi" id="MathJax-Span-7035" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-596">A</script> </td>
#   <td> odd </td>
#   <td> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-597-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;27&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7036" style="width: 2.538em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.9em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7037"><span class="mn" id="MathJax-Span-7038" style="font-family: MathJax_Main;">2</span><span class="texatom" id="MathJax-Span-7039"><span class="mrow" id="MathJax-Span-7040"><span class="mo" id="MathJax-Span-7041" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-7042" style="font-family: MathJax_Main;">27</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>27</mn></math></span></span><script type="math/tex" id="MathJax-Element-597">2/27</script> </td>
#  </tr></tbody></table><p>
# Therefore, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-598-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;160&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;27&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;56&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;135&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7043" style="width: 18.758em; display: inline-block;"><span style="display: inline-block; position: relative; width: 14.211em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1014.16em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7044"><span class="mi" id="MathJax-Span-7045" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-7046" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7047" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7048" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7049" style="font-family: MathJax_Main; padding-left: 0.167em;">160</span><span class="mo" id="MathJax-Span-7050" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7051" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7052" style="font-family: MathJax_Main; padding-left: 0.278em;">4</span><span class="texatom" id="MathJax-Span-7053"><span class="mrow" id="MathJax-Span-7054"><span class="mo" id="MathJax-Span-7055" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-7056" style="font-family: MathJax_Main;">15</span><span class="mo" id="MathJax-Span-7057" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7058" style="font-family: MathJax_Main; padding-left: 0.222em;">4</span><span class="texatom" id="MathJax-Span-7059"><span class="mrow" id="MathJax-Span-7060"><span class="mo" id="MathJax-Span-7061" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-7062" style="font-family: MathJax_Main;">27</span><span class="mo" id="MathJax-Span-7063" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7064" style="font-family: MathJax_Main; padding-left: 0.278em;">56</span><span class="texatom" id="MathJax-Span-7065"><span class="mrow" id="MathJax-Span-7066"><span class="mo" id="MathJax-Span-7067" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-7068" style="font-family: MathJax_Main;">135</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mn>160</mn><mo stretchy="false">)</mo><mo>=</mo><mn>4</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>15</mn><mo>+</mo><mn>4</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>27</mn><mo>=</mo><mn>56</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>135</mn></math></span></span><script type="math/tex" id="MathJax-Element-598">p(3,160) = 4/15 + 4/27 = 56/135</script>.
# </p>
# <p>
# You are also given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-599-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;400&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.5107843137&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7069" style="width: 13.926em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1010.51em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7070"><span class="mi" id="MathJax-Span-7071" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-7072" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7073" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-7074" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7075" style="font-family: MathJax_Main; padding-left: 0.167em;">400</span><span class="mo" id="MathJax-Span-7076" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7077" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7078" style="font-family: MathJax_Main; padding-left: 0.278em;">0.5107843137</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo stretchy="false">(</mo><mn>4</mn><mo>,</mo><mn>400</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.5107843137</mn></math></span></span><script type="math/tex" id="MathJax-Element-599">p(4,400)=0.5107843137</script>, rounded to 10 digits after the decimal point.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-600-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1800&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7079" style="width: 6.079em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.593em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.5em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7080"><span class="mi" id="MathJax-Span-7081" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-7082" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7083" style="font-family: MathJax_Main;">13</span><span class="mo" id="MathJax-Span-7084" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7085" style="font-family: MathJax_Main; padding-left: 0.167em;">1800</span><span class="mo" id="MathJax-Span-7086" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo stretchy="false">(</mo><mn>13</mn><mo>,</mo><mn>1800</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-600">p(13,1800)</script> rounded to 10 digits after the decimal point.
# </p>

# %%
submit_answer(answer; prob_num=597);

# %% [markdown]
# ## Problem 598: Split Divisibilities
# <p>
# Consider the number 48.<br>
# There are five pairs of integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-601-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7087" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1000.5em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7088"><span class="mi" id="MathJax-Span-7089" style="font-family: MathJax_Math; font-style: italic;">a</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.722em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-601">a</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-602-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7090" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.42em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7091"><span class="mi" id="MathJax-Span-7092" style="font-family: MathJax_Math; font-style: italic;">b</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-602">b</script> (<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-603-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7093" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.29em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7094"><span class="mi" id="MathJax-Span-7095" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-7096" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-7097" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">b</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.225em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>≤</mo><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-603">a \\leq b</script>) such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-604-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;48&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7098" style="width: 5.888em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.45em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1004.41em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7099"><span class="mi" id="MathJax-Span-7100" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-7101" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mi" id="MathJax-Span-7102" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">b</span><span class="mo" id="MathJax-Span-7103" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7104" style="font-family: MathJax_Main; padding-left: 0.278em;">48</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>×</mo><mi>b</mi><mo>=</mo><mn>48</mn></math></span></span><script type="math/tex" id="MathJax-Element-604">a \\times b=48</script>: (1,48), (2,24), (3,16), (4,12) and (6,8).<br>
# It can be seen that both 6 and 8 have 4 divisors.<br>
# So of those five pairs one consists of two integers with the same number of divisors.</p>
# <p>
# In general:<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-605-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7105" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7106"><span class="mi" id="MathJax-Span-7107" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-7108" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7109" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7110" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-605">C(n)</script> be the number of pairs of positive integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-606-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7111" style="width: 5.457em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.115em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1004.09em, 2.834em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7112"><span class="mi" id="MathJax-Span-7113" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-7114" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mi" id="MathJax-Span-7115" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">b</span><span class="mo" id="MathJax-Span-7116" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-7117" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>×</mo><mi>b</mi><mo>=</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-606">a \\times b=n</script>, (<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-607-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7118" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.29em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7119"><span class="mi" id="MathJax-Span-7120" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-7121" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-7122" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">b</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.225em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>≤</mo><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-607">a \\leq b</script>) such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-608-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7123" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1000.5em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7124"><span class="mi" id="MathJax-Span-7125" style="font-family: MathJax_Math; font-style: italic;">a</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.722em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-608">a</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-609-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7126" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.42em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7127"><span class="mi" id="MathJax-Span-7128" style="font-family: MathJax_Math; font-style: italic;">b</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-609">b</script> have the same number of divisors; <br>so <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-610-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;48&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7129" style="width: 5.696em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.306em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.23em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7130"><span class="mi" id="MathJax-Span-7131" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-7132" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7133" style="font-family: MathJax_Main;">48</span><span class="mo" id="MathJax-Span-7134" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7135" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7136" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>48</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-610">C(48)=1</script>.
# </p>
# <p>
# You are given <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-611-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo&gt;!&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7137" style="width: 6.079em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.593em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.55em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7138"><span class="mi" id="MathJax-Span-7139" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-7140" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7141" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-7142" style="font-family: MathJax_Main;">!</span><span class="mo" id="MathJax-Span-7143" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7144" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7145" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>10</mn><mo>!</mo><mo stretchy="false">)</mo><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-611">C(10!)=3</script>: (1680, 2160), (1800, 2016) and (1890,1920).</p><p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-612-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo&gt;!&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7146" style="width: 4.309em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.254em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.16em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7147"><span class="mi" id="MathJax-Span-7148" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-7149" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7150" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-7151" style="font-family: MathJax_Main;">!</span><span class="mo" id="MathJax-Span-7152" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>100</mn><mo>!</mo><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-612">C(100!)</script></p>

# %%
submit_answer(answer; prob_num=598);

# %% [markdown]
# ## Problem 599: Distinct Colourings of a Rubik's Cube
# <p>
# "The well-known <strong>Rubik's Cube</strong> puzzle has many fascinating"
#  mathematical properties. The 2×2×2 variant has 8 cubelets with a total
# of 24 visible faces, each with a coloured sticker. Successively turning
# faces will rearrange the cubelets, although not all arrangements of
# cubelets are reachable without dismantling the puzzle.
# </p>
# <p>
# Suppose that we wish to apply new stickers to a 2×2×2 Rubik's cube in a non-standard colouring. Specifically, we have <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-613-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7153" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7154"><span class="mi" id="MathJax-Span-7155" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-613">n</script>
#  different colours available (with an unlimited supply of stickers of
# each colour), and we place one sticker on each of the 24 faces in any
# arrangement that we please. We are not required to use all the colours,
# and if desired the same colour may appear in more than one face of a
# single cubelet.
# </p>
# <p>
# We say that two such colourings <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-614-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7156" style="width: 2.921em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.201em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(2.094em, 1002.2em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7157"><span class="msubsup" id="MathJax-Span-7158"><span style="display: inline-block; position: relative; width: 0.862em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7159" style="font-family: MathJax_Math; font-style: italic;">c</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.433em;"><span class="mn" id="MathJax-Span-7160" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7161" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-7162" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.862em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7163" style="font-family: MathJax_Math; font-style: italic;">c</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.433em;"><span class="mn" id="MathJax-Span-7164" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>c</mi><mn>1</mn></msub><mo>,</mo><msub><mi>c</mi><mn>2</mn></msub></math></span></span><script type="math/tex" id="MathJax-Element-614">c_1,c_2</script> are <em>essentially distinct</em> if a cube coloured according to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-615-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7165" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.615em, 1000.86em, 2.494em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-7166"><span class="msubsup" id="MathJax-Span-7167"><span style="display: inline-block; position: relative; width: 0.862em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7168" style="font-family: MathJax_Math; font-style: italic;">c</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.433em;"><span class="mn" id="MathJax-Span-7169" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.261em; border-left: 0px solid; width: 0px; height: 0.908em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>c</mi><mn>1</mn></msub></math></span></span><script type="math/tex" id="MathJax-Element-615">c_1</script> cannot be made to match a cube coloured according to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-616-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7170" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.615em, 1000.86em, 2.494em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-7171"><span class="msubsup" id="MathJax-Span-7172"><span style="display: inline-block; position: relative; width: 0.862em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7173" style="font-family: MathJax_Math; font-style: italic;">c</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.433em;"><span class="mn" id="MathJax-Span-7174" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.261em; border-left: 0px solid; width: 0px; height: 0.908em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>c</mi><mn>2</mn></msub></math></span></span><script type="math/tex" id="MathJax-Element-616">c_2</script> by performing mechanically possible Rubik's Cube moves.
# </p>
# <p>
# For example, with two colours available, there are 183 essentially distinct colourings.
# </p>
# <p>
# How many essentially distinct colourings are there with 10 different colours available?
# </p>

# %%
submit_answer(answer; prob_num=599);

# %% [markdown]
# ## Problem 600: Integer sided equiangular hexagons
# <p>Let <var>H</var>(<var>n</var>) be the number of distinct integer sided <b>equiangular</b> convex hexagons with perimeter not exceeding <var>n</var>.<br>
# Hexagons are distinct if and only if they are not <b>congruent</b>.</p>
#
# <p>You are given <var>H</var>(6)&nbsp;=&nbsp;1, <var>H</var>(12)&nbsp;=&nbsp;10, <var>H</var>(100)&nbsp;=&nbsp;31248.<br>
# Find <var>H</var>(55106).</p>
#
# <div style="text-align:center;">
# <img src="webfiles/p600_equiangular_hexagons.png" alt="p600-equiangular-hexagons.png" border="5"><p><i>Equiangular hexagons with perimeter not exceeding 12</i></p>
# </div>

# %%
submit_answer(answer; prob_num=600);
