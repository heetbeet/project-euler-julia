# %%
include("shared.jl");

# %% [markdown]
# ## Problem 601: Divisibility streaks
# <p>
# For every positive number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-617-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7175" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7176"><span class="mi" id="MathJax-Span-7177" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-617">n</script> we define the function  <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-618-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7178" style="width: 8.041em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.077em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7179"><span class="mi" id="MathJax-Span-7180" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mi" id="MathJax-Span-7181" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mi" id="MathJax-Span-7182" style="font-family: MathJax_Math; font-style: italic;">r</span><span class="mi" id="MathJax-Span-7183" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mi" id="MathJax-Span-7184" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-7185" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7186" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7187" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7188" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7189" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-7190" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">k</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mi>t</mi><mi>r</mi><mi>e</mi><mi>a</mi><mi>k</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-618">streak(n)=k</script>   as the smallest positive integer <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-619-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7191" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7192"><span class="mi" id="MathJax-Span-7193" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-619">k</script> such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-620-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7194" style="width: 3.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.33em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7195"><span class="mi" id="MathJax-Span-7196" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7197" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-7198" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">k</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.151em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>+</mo><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-620">n+k</script> is not divisible by <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-621-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7199" style="width: 2.921em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.201em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1002.13em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7200"><span class="mi" id="MathJax-Span-7201" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7202" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7203" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.151em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi><mo>+</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-621">k+1</script>.<br>
# E.g:<br>
# 13 is divisible by 1 <br>
# 14 is divisible by 2 <br>
# 15 is divisible by 3 <br>
# 16 is divisible by 4 <br>
# 17 is NOT divisible by 5 <br>
# So <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-622-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7204" style="width: 8.423em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.364em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.34em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7205"><span class="mi" id="MathJax-Span-7206" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mi" id="MathJax-Span-7207" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mi" id="MathJax-Span-7208" style="font-family: MathJax_Math; font-style: italic;">r</span><span class="mi" id="MathJax-Span-7209" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mi" id="MathJax-Span-7210" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-7211" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7212" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7213" style="font-family: MathJax_Main;">13</span><span class="mo" id="MathJax-Span-7214" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7215" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7216" style="font-family: MathJax_Main; padding-left: 0.278em;">4</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mi>t</mi><mi>r</mi><mi>e</mi><mi>a</mi><mi>k</mi><mo stretchy="false">(</mo><mn>13</mn><mo stretchy="false">)</mo><mo>=</mo><mn>4</mn></math></span></span><script type="math/tex" id="MathJax-Element-622">streak(13) = 4</script>. <br>
# Similarly:<br>
# 120 is divisible by 1 <br>
# 121 is NOT divisible by 2 <br>
# So <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-623-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;120&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7217" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.77em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7218"><span class="mi" id="MathJax-Span-7219" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mi" id="MathJax-Span-7220" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mi" id="MathJax-Span-7221" style="font-family: MathJax_Math; font-style: italic;">r</span><span class="mi" id="MathJax-Span-7222" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mi" id="MathJax-Span-7223" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-7224" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7225" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7226" style="font-family: MathJax_Main;">120</span><span class="mo" id="MathJax-Span-7227" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7228" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7229" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mi>t</mi><mi>r</mi><mi>e</mi><mi>a</mi><mi>k</mi><mo stretchy="false">(</mo><mn>120</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-623">streak(120) = 1</script>.</p>
# <p>
#
# Define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-624-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7230" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.25em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7231"><span class="mi" id="MathJax-Span-7232" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-7233" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7234" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-7235" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7236" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span><span class="mo" id="MathJax-Span-7237" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>s</mi><mo>,</mo><mi>N</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-624">P(s, N)</script> to be the number of integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-625-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7238" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7239"><span class="mi" id="MathJax-Span-7240" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-625">n</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-626-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7241" style="width: 6.127em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.641em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.853em, 1004.64em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7242"><span class="mn" id="MathJax-Span-7243" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-7244" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-7245" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span><span class="mo" id="MathJax-Span-7246" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-7247" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 1.081em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn><mo>&lt;</mo><mi>n</mi><mo>&lt;</mo><mi>N</mi></math></span></span><script type="math/tex" id="MathJax-Element-626">1 < n < N</script>, for which <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-627-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mi&gt;t&lt;/mi&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7248" style="width: 7.993em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.029em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.98em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7249"><span class="mi" id="MathJax-Span-7250" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mi" id="MathJax-Span-7251" style="font-family: MathJax_Math; font-style: italic;">t</span><span class="mi" id="MathJax-Span-7252" style="font-family: MathJax_Math; font-style: italic;">r</span><span class="mi" id="MathJax-Span-7253" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mi" id="MathJax-Span-7254" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mi" id="MathJax-Span-7255" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7256" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7257" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7258" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7259" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-7260" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">s</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mi>t</mi><mi>r</mi><mi>e</mi><mi>a</mi><mi>k</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mi>s</mi></math></span></span><script type="math/tex" id="MathJax-Element-627">streak(n) = s</script>.<br>
# So <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-628-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;14&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7261" style="width: 6.844em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.167em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.09em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7262"><span class="mi" id="MathJax-Span-7263" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-7264" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7265" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7266" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7267" style="font-family: MathJax_Main; padding-left: 0.167em;">14</span><span class="mo" id="MathJax-Span-7268" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7269" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7270" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mn>14</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-628">P(3, 14) = 1</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-629-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;14286&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7271" style="width: 10.002em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.56em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1007.52em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7272"><span class="mi" id="MathJax-Span-7273" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-7274" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7275" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-7276" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-7277" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7278" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7279" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7280" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7281" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7282" style="font-family: MathJax_Main; padding-left: 0.278em;">14286</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>6</mn><mo>,</mo><msup><mn>10</mn><mn>6</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>14286</mn></math></span></span><script type="math/tex" id="MathJax-Element-629">P(6, 10^6) = 14286</script>.
# </p>
# <p>
# Find the sum, as <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-630-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7283" style="width: 0.481em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.335em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.636em, 1000.29em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7284"><span class="mi" id="MathJax-Span-7285" style="font-family: MathJax_Math; font-style: italic;">i</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.013em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>i</mi></math></span></span><script type="math/tex" id="MathJax-Element-630">i</script> ranges from 1 to 31, of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-631-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7286" style="width: 4.117em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.11em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.665em, 1003.02em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7287"><span class="mi" id="MathJax-Span-7288" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-7289" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7290" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-7291" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-7292" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.819em; height: 0px;"><span style="position: absolute; clip: rect(3.199em, 1000.47em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7293" style="font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.423em; left: 0.5em;"><span class="mi" id="MathJax-Span-7294" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7295" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.607em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>i</mi><mo>,</mo><msup><mn>4</mn><mi>i</mi></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-631">P(i, 4^i)</script>.
# </p>

# %%
submit_answer(answer; prob_num=601);

# %% [markdown]
# ## Problem 602: Product of Head Counts
# <p>
# Alice enlists the help of some friends to generate a random number,
# using a single unfair coin. She and her friends sit around a table and,
# starting with Alice, they take it in turns to toss the coin. Everyone
# keeps a count of how many heads they obtain individually. The process
# ends as soon as Alice obtains a Head. At this point, Alice multiplies
# "all her friends' Head counts together to obtain her random number."
# </p>
# <p>
# As an illustration, suppose Alice is assisted by Bob, Charlie, and Dawn,
#  who are seated round the table in that order, and that they obtain the
# sequence of Head/Tail outcomes <b>THHH—TTTT—THHT—H</b> beginning and
# ending with Alice. Then Bob and Charlie each obtain 2 heads, and Dawn
# obtains 1 head. Alice's random number is therefore <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-632-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7296" style="width: 7.467em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.646em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.859em, 1005.62em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7297"><span class="mn" id="MathJax-Span-7298" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-7299" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-7300" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-7301" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-7302" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-7303" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7304" style="font-family: MathJax_Main; padding-left: 0.278em;">4</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.02em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn><mo>×</mo><mn>2</mn><mo>×</mo><mn>1</mn><mo>=</mo><mn>4</mn></math></span></span><script type="math/tex" id="MathJax-Element-632">2\\times 2\\times 1 = 4</script>.
# </p>
# <p>
# Define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-633-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7305" style="width: 3.734em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.823em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7306"><span class="mi" id="MathJax-Span-7307" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mo" id="MathJax-Span-7308" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7309" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7310" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7311" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-7312" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>e</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-633">e(n, p)</script> to be the expected value of Alice's random number, where <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-634-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7313" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7314"><span class="mi" id="MathJax-Span-7315" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-634">n</script> is the number of friends helping (excluding Alice herself), and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-635-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7316" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7317"><span class="mi" id="MathJax-Span-7318" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-635">p</script> is the probability of the coin coming up Tails.
# </p>
# <p>
# It turns out that, for any fixed <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-636-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7319" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7320"><span class="mi" id="MathJax-Span-7321" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-636">n</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-637-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7322" style="width: 3.734em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.823em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7323"><span class="mi" id="MathJax-Span-7324" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mo" id="MathJax-Span-7325" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7326" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7327" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7328" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-7329" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>e</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-637">e(n, p)</script> is always a polynomial in <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-638-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7330" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7331"><span class="mi" id="MathJax-Span-7332" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-638">p</script>. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-639-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;msup&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7333" style="width: 12.347em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.33em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1009.32em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7334"><span class="mi" id="MathJax-Span-7335" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mo" id="MathJax-Span-7336" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7337" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7338" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7339" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-7340" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7341" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-7342" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.932em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7343" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.503em;"><span class="mn" id="MathJax-Span-7344" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7345" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7346" style="font-family: MathJax_Main; padding-left: 0.222em;">4</span><span class="msubsup" id="MathJax-Span-7347"><span style="display: inline-block; position: relative; width: 0.932em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7348" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.503em;"><span class="mn" id="MathJax-Span-7349" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7350" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-7351" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">p</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.557em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>e</mi><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mi>p</mi><mo stretchy="false">)</mo><mo>=</mo><msup><mi>p</mi><mn>3</mn></msup><mo>+</mo><mn>4</mn><msup><mi>p</mi><mn>2</mn></msup><mo>+</mo><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-639">e(3, p) = p^3 + 4p^2 + p</script>.
# </p>
# <p>
# Define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-640-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7352" style="width: 3.687em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.775em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.68em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7353"><span class="mi" id="MathJax-Span-7354" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-7355" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7356" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7357" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7358" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="mo" id="MathJax-Span-7359" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-640">c(n, k)</script> to be the coefficient of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-641-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7360" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.204em, 1000.96em, 2.538em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-7361"><span class="msubsup" id="MathJax-Span-7362"><span style="display: inline-block; position: relative; width: 0.946em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7363" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.503em;"><span class="mi" id="MathJax-Span-7364" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.509em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mi>p</mi><mi>k</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-641">p^k</script> in the polynomial <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-642-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7365" style="width: 3.734em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.823em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7366"><span class="mi" id="MathJax-Span-7367" style="font-family: MathJax_Math; font-style: italic;">e</span><span class="mo" id="MathJax-Span-7368" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7369" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7370" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7371" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-7372" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>e</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-642">e(n, p)</script>. So <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-643-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7373" style="width: 5.84em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.402em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.33em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7374"><span class="mi" id="MathJax-Span-7375" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-7376" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7377" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7378" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7379" style="font-family: MathJax_Main; padding-left: 0.167em;">1</span><span class="mo" id="MathJax-Span-7380" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7381" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7382" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-643">c(3, 1) = 1</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-644-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7383" style="width: 5.84em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.402em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.37em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7384"><span class="mi" id="MathJax-Span-7385" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-7386" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7387" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7388" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7389" style="font-family: MathJax_Main; padding-left: 0.167em;">2</span><span class="mo" id="MathJax-Span-7390" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7391" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7392" style="font-family: MathJax_Main; padding-left: 0.278em;">4</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mn>2</mn><mo stretchy="false">)</mo><mo>=</mo><mn>4</mn></math></span></span><script type="math/tex" id="MathJax-Element-644">c(3, 2) = 4</script>, and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-645-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7393" style="width: 5.84em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.402em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.33em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7394"><span class="mi" id="MathJax-Span-7395" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-7396" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7397" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7398" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7399" style="font-family: MathJax_Main; padding-left: 0.167em;">3</span><span class="mo" id="MathJax-Span-7400" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7401" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7402" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-645">c(3, 3) = 1</script>.
# </p>
# <p>
# You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-646-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;40&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;&amp;#x2261;&lt;/mo&gt;&lt;mn&gt;986699437&lt;/mn&gt;&lt;mtext&gt;&amp;#xA0;&lt;/mtext&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mtext&gt;mod&amp;#xA0;&lt;/mtext&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7403" style="width: 21.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 15.885em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1015.79em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7404"><span class="mi" id="MathJax-Span-7405" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-7406" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7407" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-7408" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7409" style="font-family: MathJax_Main; padding-left: 0.167em;">40</span><span class="mo" id="MathJax-Span-7410" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7411" style="font-family: MathJax_Main; padding-left: 0.278em;">≡</span><span class="mn" id="MathJax-Span-7412" style="font-family: MathJax_Main; padding-left: 0.278em;">986699437</span><span class="mtext" id="MathJax-Span-7413" style="font-family: MathJax_Main;">&nbsp;</span><span class="mo" id="MathJax-Span-7414" style="font-family: MathJax_Main;">(</span><span class="mtext" id="MathJax-Span-7415" style="font-family: MathJax_Main;">mod&nbsp;</span><span class="msubsup" id="MathJax-Span-7416"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7417" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7418" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7419" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7420" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span><span class="mo" id="MathJax-Span-7421" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mn>100</mn><mo>,</mo><mn>40</mn><mo stretchy="false">)</mo><mo>≡</mo><mn>986699437</mn><mtext>&nbsp;</mtext><mo stretchy="false">(</mo><mtext>mod&nbsp;</mtext><msup><mn>10</mn><mn>9</mn></msup><mo>+</mo><mn>7</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-646">c(100, 40) \\equiv 986699437 \\text{ } (\\text{mod } 10^9+7)</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-647-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10000000&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;4000000&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mspace width="0.667em" /&gt;&lt;mi&gt;mod&lt;/mi&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mspace width="thinmathspace" /&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7422" style="width: 19.955em; display: inline-block;"><span style="display: inline-block; position: relative; width: 15.12em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1015.1em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7423"><span class="mi" id="MathJax-Span-7424" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-7425" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7426" style="font-family: MathJax_Main;">10000000</span><span class="mo" id="MathJax-Span-7427" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7428" style="font-family: MathJax_Main; padding-left: 0.167em;">4000000</span><span class="mo" id="MathJax-Span-7429" style="font-family: MathJax_Main;">)</span><span class="TeXmathchoice" id="MathJax-Span-7430"><span class="mspace" id="MathJax-Span-7431" style="height: 0em; vertical-align: 0em; width: 0.667em; display: inline-block; overflow: hidden;"></span></span><span class="mi" id="MathJax-Span-7432" style="font-family: MathJax_Main; padding-left: 0.167em;">mod</span><span class="mspace" id="MathJax-Span-7433" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mspace" id="MathJax-Span-7434" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="msubsup" id="MathJax-Span-7435" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7436" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7437" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7438" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7439" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mn>10000000</mn><mo>,</mo><mn>4000000</mn><mo stretchy="false">)</mo><mspace width="0.667em"></mspace><mi>mod</mi><mspace width="thinmathspace"></mspace><mspace width="thinmathspace"></mspace><msup><mn>10</mn><mn>9</mn></msup><mo>+</mo><mn>7</mn></math></span></span><script type="math/tex" id="MathJax-Element-647">c(10000000, 4000000) \\mod 10^9+7</script>.
# </p>

# %%
submit_answer(answer; prob_num=602);

# %% [markdown]
# ## Problem 603: Substring sums of prime concatenations
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-648-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7440" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7441"><span class="mi" id="MathJax-Span-7442" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-7443" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7444" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7445" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-648">S(n)</script> be the sum of all contiguous integer-substrings that can be formed from the integer <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-649-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7446" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7447"><span class="mi" id="MathJax-Span-7448" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-649">n</script>. The substrings need not be distinct. </p>
#
# <p>For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-650-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2024&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;20&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;02&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;24&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;202&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;024&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2024&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2304&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7449" style="width: 37.419em; display: inline-block;"><span style="display: inline-block; position: relative; width: 28.325em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1028.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7450"><span class="mi" id="MathJax-Span-7451" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-7452" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7453" style="font-family: MathJax_Main;">2024</span><span class="mo" id="MathJax-Span-7454" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7455" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7456" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span><span class="mo" id="MathJax-Span-7457" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7458" style="font-family: MathJax_Main; padding-left: 0.222em;">0</span><span class="mo" id="MathJax-Span-7459" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7460" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-7461" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7462" style="font-family: MathJax_Main; padding-left: 0.222em;">4</span><span class="mo" id="MathJax-Span-7463" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7464" style="font-family: MathJax_Main; padding-left: 0.222em;">20</span><span class="mo" id="MathJax-Span-7465" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7466" style="font-family: MathJax_Main; padding-left: 0.222em;">02</span><span class="mo" id="MathJax-Span-7467" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7468" style="font-family: MathJax_Main; padding-left: 0.222em;">24</span><span class="mo" id="MathJax-Span-7469" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7470" style="font-family: MathJax_Main; padding-left: 0.222em;">202</span><span class="mo" id="MathJax-Span-7471" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7472" style="font-family: MathJax_Main; padding-left: 0.222em;">024</span><span class="mo" id="MathJax-Span-7473" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7474" style="font-family: MathJax_Main; padding-left: 0.222em;">2024</span><span class="mo" id="MathJax-Span-7475" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7476" style="font-family: MathJax_Main; padding-left: 0.278em;">2304</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>2024</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2</mn><mo>+</mo><mn>0</mn><mo>+</mo><mn>2</mn><mo>+</mo><mn>4</mn><mo>+</mo><mn>20</mn><mo>+</mo><mn>02</mn><mo>+</mo><mn>24</mn><mo>+</mo><mn>202</mn><mo>+</mo><mn>024</mn><mo>+</mo><mn>2024</mn><mo>=</mo><mn>2304</mn></math></span></span><script type="math/tex" id="MathJax-Element-650">S(2024) = 2 + 0 + 2 + 4 + 20 + 02 + 24 + 202 + 024 + 2024 = 2304</script>.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-651-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7477" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7478"><span class="mi" id="MathJax-Span-7479" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-7480" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7481" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7482" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-651">P(n)</script> be the integer formed by concatenating the first <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-652-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7483" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7484"><span class="mi" id="MathJax-Span-7485" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-652">n</script> primes together. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-653-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2357111317&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7486" style="width: 10.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.086em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1008.07em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7487"><span class="mi" id="MathJax-Span-7488" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-7489" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7490" style="font-family: MathJax_Main;">7</span><span class="mo" id="MathJax-Span-7491" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7492" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7493" style="font-family: MathJax_Main; padding-left: 0.278em;">2357111317</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>7</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2357111317</mn></math></span></span><script type="math/tex" id="MathJax-Element-653">P(7) = 2357111317</script>.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-654-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7494" style="width: 4.117em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.11em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.02em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7495"><span class="mi" id="MathJax-Span-7496" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-7497" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7498" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7499" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7500" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="mo" id="MathJax-Span-7501" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-654">C(n, k)</script> be the integer formed by concatenating <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-655-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7502" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7503"><span class="mi" id="MathJax-Span-7504" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-655">k</script> copies of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-656-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7505" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7506"><span class="mi" id="MathJax-Span-7507" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-7508" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7509" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7510" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-656">P(n)</script> together. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-657-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;235711131723571113172357111317&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7511" style="width: 24.596em; display: inline-block;"><span style="display: inline-block; position: relative; width: 18.612em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1018.6em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7512"><span class="mi" id="MathJax-Span-7513" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-7514" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7515" style="font-family: MathJax_Main;">7</span><span class="mo" id="MathJax-Span-7516" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-7517" style="font-family: MathJax_Main; padding-left: 0.167em;">3</span><span class="mo" id="MathJax-Span-7518" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7519" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7520" style="font-family: MathJax_Main; padding-left: 0.278em;">235711131723571113172357111317</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>7</mn><mo>,</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>235711131723571113172357111317</mn></math></span></span><script type="math/tex" id="MathJax-Element-657">C(7, 3) = 235711131723571113172357111317</script>.</p>
#
# <p>Evaluate <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-658-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7521" style="width: 8.711em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.603em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1006.51em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7522"><span class="mi" id="MathJax-Span-7523" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-7524" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7525" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-7526" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-7527"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7528" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7529" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7530" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-7531" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7532" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-7533"><span class="mrow" id="MathJax-Span-7534"><span class="mn" id="MathJax-Span-7535" style="font-size: 70.7%; font-family: MathJax_Main;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7536" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7537" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>C</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>6</mn></msup><mo>,</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>12</mn></mrow></msup><mo stretchy="false">)</mo><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-658">S(C(10^6, 10^{12}))</script> mod <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-659-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7538" style="width: 5.122em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.876em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.78em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7539"><span class="mo" id="MathJax-Span-7540" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-7541"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7542" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7543" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7544" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7545" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span><span class="mo" id="MathJax-Span-7546" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><msup><mn>10</mn><mn>9</mn></msup><mo>+</mo><mn>7</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-659">(10^9 + 7)</script>.</p>

# %%
submit_answer(answer; prob_num=603);

# %% [markdown]
# ## Problem 604: Convex path in square
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-660-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7547" style="width: 3.16em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.392em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7548"><span class="mi" id="MathJax-Span-7549" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7550" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7551" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span><span class="mo" id="MathJax-Span-7552" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mi>N</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-660">F(N)</script> be the maximum number of lattice points in an axis-aligned <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-661-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7553" style="width: 3.974em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.014em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.853em, 1003.01em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7554"><span class="mi" id="MathJax-Span-7555" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span><span class="mo" id="MathJax-Span-7556" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mi" id="MathJax-Span-7557" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>N</mi><mo>×</mo><mi>N</mi></math></span></span><script type="math/tex" id="MathJax-Element-661">N\\times N</script> square that the graph of a single <b>strictly convex</b> increasing function can pass through.
# </p>
# <p>
# You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-662-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7558" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7559"><span class="mi" id="MathJax-Span-7560" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7561" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7562" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-7563" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7564" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7565" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-662">F(1) = 2</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-663-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7566" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.74em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7567"><span class="mi" id="MathJax-Span-7568" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7569" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7570" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7571" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7572" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7573" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-663">F(3) = 3</script>,  <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-664-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7574" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.74em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7575"><span class="mi" id="MathJax-Span-7576" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7577" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7578" style="font-family: MathJax_Main;">9</span><span class="mo" id="MathJax-Span-7579" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7580" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7581" style="font-family: MathJax_Main; padding-left: 0.278em;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mn>9</mn><mo stretchy="false">)</mo><mo>=</mo><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-664">F(9) = 6</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-665-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7582" style="width: 5.648em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.258em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.24em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7583"><span class="mi" id="MathJax-Span-7584" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7585" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7586" style="font-family: MathJax_Main;">11</span><span class="mo" id="MathJax-Span-7587" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7588" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7589" style="font-family: MathJax_Main; padding-left: 0.278em;">7</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mn>11</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7</mn></math></span></span><script type="math/tex" id="MathJax-Element-665">F(11) = 7</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-666-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;30&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7590" style="width: 6.892em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.215em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.17em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7591"><span class="mi" id="MathJax-Span-7592" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7593" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7594" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-7595" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7596" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7597" style="font-family: MathJax_Main; padding-left: 0.278em;">30</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>30</mn></math></span></span><script type="math/tex" id="MathJax-Element-666">F(100) = 30</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-667-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;50000&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1898&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7598" style="width: 9.428em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.129em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.09em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7599"><span class="mi" id="MathJax-Span-7600" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7601" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7602" style="font-family: MathJax_Main;">50000</span><span class="mo" id="MathJax-Span-7603" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7604" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7605" style="font-family: MathJax_Main; padding-left: 0.278em;">1898</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><mn>50000</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1898</mn></math></span></span><script type="math/tex" id="MathJax-Element-667">F(50000) = 1898</script>.<br>
# Below is the graph of a function reaching the maximum 3 for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-668-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7606" style="width: 3.543em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.679em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.853em, 1002.64em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7607"><span class="mi" id="MathJax-Span-7608" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span><span class="mo" id="MathJax-Span-7609" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7610" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>N</mi><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-668">N=3</script>:
# </p>
# <div style="text-align:center;">
# <img src="webfiles/p604_convex3.png" alt="p604_convex3.png"></div>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-669-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7611" style="width: 4.309em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.254em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.16em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7612"><span class="mi" id="MathJax-Span-7613" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-7614" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-7615"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7616" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-7617"><span class="mrow" id="MathJax-Span-7618"><span class="mn" id="MathJax-Span-7619" style="font-size: 70.7%; font-family: MathJax_Main;">18</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7620" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>F</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>18</mn></mrow></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-669">F(10^{18})</script>.
# </p>

# %%
submit_answer(answer; prob_num=604);

# %% [markdown]
# ## Problem 605: Pairwise Coin-Tossing Game
# <p>Consider an <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-670-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7621" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7622"><span class="mi" id="MathJax-Span-7623" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-670">n</script>-player game played in consecutive pairs: Round <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-671-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7624" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7625"><span class="mn" id="MathJax-Span-7626" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-671">1</script> takes place between players <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-672-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7627" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7628"><span class="mn" id="MathJax-Span-7629" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-672">1</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-673-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7630" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7631"><span class="mn" id="MathJax-Span-7632" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-673">2</script>, round <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-674-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7633" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7634"><span class="mn" id="MathJax-Span-7635" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-674">2</script> takes place between players <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-675-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7636" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7637"><span class="mn" id="MathJax-Span-7638" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-675">2</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-676-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7639" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7640"><span class="mn" id="MathJax-Span-7641" style="font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.033em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-676">3</script>, and so on and so forth, all the way up to round <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-677-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7642" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7643"><span class="mi" id="MathJax-Span-7644" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-677">n</script>, which takes place between players <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-678-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7645" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7646"><span class="mi" id="MathJax-Span-7647" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-678">n</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-679-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7648" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7649"><span class="mn" id="MathJax-Span-7650" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-679">1</script>. Then round <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-680-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7651" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.22em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7652"><span class="mi" id="MathJax-Span-7653" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7654" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7655" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.114em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>+</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-680">n+1</script> takes place between players <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-681-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7656" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7657"><span class="mn" id="MathJax-Span-7658" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-681">1</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-682-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7659" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7660"><span class="mn" id="MathJax-Span-7661" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-682">2</script> as the entire cycle starts again.</p>
#
# <p>In other words, during round <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-683-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7662" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.41em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7663"><span class="mi" id="MathJax-Span-7664" style="font-family: MathJax_Math; font-style: italic;">r</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>r</mi></math></span></span><script type="math/tex" id="MathJax-Element-683">r</script>, player <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-684-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo lspace="thickmathspace" rspace="thickmathspace"&gt;mod&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7665" style="width: 11.055em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.373em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1008.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7666"><span class="mo" id="MathJax-Span-7667" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-7668" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7669" style="font-family: MathJax_Math; font-style: italic;">r</span><span class="mo" id="MathJax-Span-7670" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-7671" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-7672" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7673" style="font-family: MathJax_Main; padding-left: 0.278em; padding-right: 0.278em;">mod</span><span class="mi" id="MathJax-Span-7674" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7675" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7676" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7677" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>r</mi><mo>−</mo><mn>1</mn><mo stretchy="false">)</mo><mo lspace="thickmathspace" rspace="thickmathspace">mod</mo><mi>n</mi><mo stretchy="false">)</mo><mo>+</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-684">((r-1) \\bmod n) + 1</script> faces off against player <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-685-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mo lspace="thickmathspace" rspace="thickmathspace"&gt;mod&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7678" style="width: 7.849em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.933em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.86em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7679"><span class="mo" id="MathJax-Span-7680" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7681" style="font-family: MathJax_Math; font-style: italic;">r</span><span class="mo" id="MathJax-Span-7682" style="font-family: MathJax_Main; padding-left: 0.278em; padding-right: 0.278em;">mod</span><span class="mi" id="MathJax-Span-7683" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7684" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7685" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7686" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>r</mi><mo lspace="thickmathspace" rspace="thickmathspace">mod</mo><mi>n</mi><mo stretchy="false">)</mo><mo>+</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-685">(r \\bmod n) + 1</script>.</p>
#
# <p>During each round, a fair coin is tossed to decide which of the two
# players wins that round. If any given player wins both rounds <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-686-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7687" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.41em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7688"><span class="mi" id="MathJax-Span-7689" style="font-family: MathJax_Math; font-style: italic;">r</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>r</mi></math></span></span><script type="math/tex" id="MathJax-Element-686">r</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-687-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;r&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7690" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.03em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7691"><span class="mi" id="MathJax-Span-7692" style="font-family: MathJax_Math; font-style: italic;">r</span><span class="mo" id="MathJax-Span-7693" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7694" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.114em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>r</mi><mo>+</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-687">r+1</script>, then that player wins the entire game.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-688-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7695" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.34em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7696"><span class="msubsup" id="MathJax-Span-7697"><span style="display: inline-block; position: relative; width: 1.141em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7698" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="mi" id="MathJax-Span-7699" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7700" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7701" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7702" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mi>n</mi></msub><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-688">P_n(k)</script> be the probability that player <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-689-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7703" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7704"><span class="mi" id="MathJax-Span-7705" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-689">k</script> wins in an <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-690-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7706" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7707"><span class="mi" id="MathJax-Span-7708" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-690">n</script>-player game, in the form of a reduced fraction. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-691-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;49&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7709" style="width: 7.993em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.029em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.98em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7710"><span class="msubsup" id="MathJax-Span-7711"><span style="display: inline-block; position: relative; width: 1.071em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7712" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="mn" id="MathJax-Span-7713" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7714" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7715" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-7716" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7717" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7718" style="font-family: MathJax_Main; padding-left: 0.278em;">12</span><span class="texatom" id="MathJax-Span-7719"><span class="mrow" id="MathJax-Span-7720"><span class="mo" id="MathJax-Span-7721" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-7722" style="font-family: MathJax_Main;">49</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mn>3</mn></msub><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>12</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>49</mn></math></span></span><script type="math/tex" id="MathJax-Element-691">P_3(1) = 12/49</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-692-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;368&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo&gt;/&lt;/mo&gt;&lt;/mrow&gt;&lt;mn&gt;1323&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7723" style="width: 9.859em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.464em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.42em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7724"><span class="msubsup" id="MathJax-Span-7725"><span style="display: inline-block; position: relative; width: 1.071em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7726" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="mn" id="MathJax-Span-7727" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7728" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7729" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-7730" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7731" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7732" style="font-family: MathJax_Main; padding-left: 0.278em;">368</span><span class="texatom" id="MathJax-Span-7733"><span class="mrow" id="MathJax-Span-7734"><span class="mo" id="MathJax-Span-7735" style="font-family: MathJax_Main;">/</span></span></span><span class="mn" id="MathJax-Span-7736" style="font-family: MathJax_Main;">1323</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mn>6</mn></msub><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>=</mo><mn>368</mn><mrow class="MJX-TeXAtom-ORD"><mo>/</mo></mrow><mn>1323</mn></math></span></span><script type="math/tex" id="MathJax-Element-692">P_6(2) = 368/1323</script>.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-693-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7737" style="width: 3.687em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.775em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.68em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7738"><span class="msubsup" id="MathJax-Span-7739"><span style="display: inline-block; position: relative; width: 1.469em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7740" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="mi" id="MathJax-Span-7741" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7742" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7743" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7744" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>M</mi><mi>n</mi></msub><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-693">M_n(k)</script> be the product of the reduced numerator and denominator of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-694-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7745" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.34em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7746"><span class="msubsup" id="MathJax-Span-7747"><span style="display: inline-block; position: relative; width: 1.141em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7748" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="mi" id="MathJax-Span-7749" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7750" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7751" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7752" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mi>n</mi></msub><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-694">P_n(k)</script>. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-695-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;588&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7753" style="width: 7.132em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.407em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.36em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7754"><span class="msubsup" id="MathJax-Span-7755"><span style="display: inline-block; position: relative; width: 1.399em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7756" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="mn" id="MathJax-Span-7757" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7758" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7759" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-7760" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7761" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7762" style="font-family: MathJax_Main; padding-left: 0.278em;">588</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>M</mi><mn>3</mn></msub><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>588</mn></math></span></span><script type="math/tex" id="MathJax-Element-695">M_3(1) = 588</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-696-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;486864&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7763" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.81em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7764"><span class="msubsup" id="MathJax-Span-7765"><span style="display: inline-block; position: relative; width: 1.399em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7766" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="mn" id="MathJax-Span-7767" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7768" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7769" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-7770" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7771" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7772" style="font-family: MathJax_Main; padding-left: 0.278em;">486864</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>M</mi><mn>6</mn></msub><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>=</mo><mn>486864</mn></math></span></span><script type="math/tex" id="MathJax-Element-696">M_6(2) = 486864</script>.</p>
#
# <p>Find the last <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-697-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7773" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7774"><span class="mn" id="MathJax-Span-7775" style="font-family: MathJax_Main;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-697">8</script> digits of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-698-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7776" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.664em, 1006.75em, 3.147em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7777"><span class="msubsup" id="MathJax-Span-7778"><span style="display: inline-block; position: relative; width: 2.959em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7779" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.753em; left: 0.97em;"><span class="texatom" id="MathJax-Span-7780"><span class="mrow" id="MathJax-Span-7781"><span class="msubsup" id="MathJax-Span-7782"><span style="display: inline-block; position: relative; width: 1.01em; height: 0px;"><span style="position: absolute; clip: rect(3.405em, 1000.68em, 4.178em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7783" style="font-size: 70.7%; font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.297em; left: 0.707em;"><span class="mn" id="MathJax-Span-7784" style="font-size: 50%; font-family: MathJax_Main;">8</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7785" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mn" id="MathJax-Span-7786" style="font-size: 70.7%; font-family: MathJax_Main;">7</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7787" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-7788"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7789" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7790" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7791" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7792" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span><span class="mo" id="MathJax-Span-7793" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.491em; border-left: 0px solid; width: 0px; height: 1.705em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><msup><mn>10</mn><mn>8</mn></msup><mo>+</mo><mn>7</mn></mrow></msub><mo stretchy="false">(</mo><msup><mn>10</mn><mn>4</mn></msup><mo>+</mo><mn>7</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-698">M_{10^8+7}(10^4+7)</script>.</p>

# %%
submit_answer(answer; prob_num=605);

# %% [markdown]
# ## Problem 606: Gozinta Chains II
# <p>
# A <b>gozinta chain</b> for <var>n</var> is a sequence {1,a,b,...,<var>n</var>} where each element properly divides the next. <br>
# For example, there are eight distinct gozinta chains for 12: <br>
# {1,12}, {1,2,12}, {1,2,4,12}, {1,2,6,12}, {1,3,12}, {1,3,6,12}, {1,4,12} and {1,6,12}.
# </p>
# <p>
# Let S(<var>n</var>) be the sum of all numbers, <var>k</var>, not exceeding <var>n</var>, which have 252 distinct gozinta chains. <br>
# You are given S(10<sup>6</sup>)=8462952 and S(10<sup>12</sup>)=623291998881978.
# </p>
# <p>
# Find S(10<sup>36</sup>), giving the last nine digits of your answer.
# </p>

# %%
submit_answer(answer; prob_num=606);

# %% [markdown]
# ## Problem 607: Marsh Crossing
# <p>
# Frodo and Sam need to travel 100 leagues due East from point A to point
# B. On normal terrain, they can cover 10 leagues per day, and so the
# journey would take 10 days. However, their path is crossed by a long
# marsh which runs exactly South-West to North-East, and walking through
# the marsh will slow them down. The marsh is 50 leagues wide at all
# points, and the mid-point of AB is located in the middle of the marsh. A
#  map of the region is shown in the diagram below:
# </p>
#
# <div style="text-align:center;">
# <img src="webfiles/p607_marsh.png" alt="p607_marsh.png"></div>
#
#
# <p>
# The marsh consists of 5 distinct regions, each 10 leagues across, as
# shown by the shading in the map. The strip closest to point A is
# relatively light marsh, and can be crossed at a speed of 9 leagues per
# day. However, each strip becomes progressively harder to navigate, the
# speeds going down to 8, 7, 6 and finally 5 leagues per day for the final
#  region of marsh, before it ends and the terrain becomes easier again,
# with the speed going back to 10 leagues per day.
# </p>
# <p>
# If Frodo and Sam were to head directly East for point B, they would
# travel exactly 100 leagues, and the journey would take approximately
# 13.4738 days. However, this time can be shortened if they deviate from
# the direct path.
# </p>
# <p>
# Find the shortest possible time required to travel from point A to B,
# and give your answer in days, rounded to 10 decimal places.
# </p>

# %%
submit_answer(answer; prob_num=607);

# %% [markdown]
# ## Problem 608: Divisor Sums
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-699-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/munderover&gt;&lt;msub&gt;&lt;mi&gt;&amp;#x03C3;&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/mstyle&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7794" style="width: 14.309em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.813em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.973em, 1010.72em, 4.246em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7795"><span class="mi" id="MathJax-Span-7796" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-7797" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7798" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-7799" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-7800" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">n</span><span class="mo" id="MathJax-Span-7801" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7802" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mstyle" id="MathJax-Span-7803" style="padding-left: 0.278em;"><span class="mrow" id="MathJax-Span-7804"><span class="munderover" id="MathJax-Span-7805"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-7806" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.345em, 1001.17em, 4.439em, -1000em); top: -2.872em; left: 0.128em;"><span class="texatom" id="MathJax-Span-7807"><span class="mrow" id="MathJax-Span-7808"><span class="mi" id="MathJax-Span-7809" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span class="texatom" id="MathJax-Span-7810"><span class="mrow" id="MathJax-Span-7811"><span class="mo" id="MathJax-Span-7812" style="font-size: 70.7%; font-family: MathJax_Main;">|</span></span></span><span class="mi" id="MathJax-Span-7813" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="munderover" id="MathJax-Span-7814" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-7815" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1001.22em, 4.27em, -1000em); top: -2.912em; left: 0.086em;"><span class="texatom" id="MathJax-Span-7816"><span class="mrow" id="MathJax-Span-7817"><span class="mi" id="MathJax-Span-7818" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-7819" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-7820" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.463em, 1000.41em, 4.17em, -1000em); top: -5.169em; left: 0.51em;"><span class="mi" id="MathJax-Span-7821" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-7822" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 0.947em; height: 0px;"><span style="position: absolute; clip: rect(3.445em, 1000.57em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7823" style="font-family: MathJax_Math; font-style: italic;">σ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.001em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.571em;"><span class="texatom" id="MathJax-Span-7824"><span class="mrow" id="MathJax-Span-7825"><span class="mstyle" id="MathJax-Span-7826"><span class="mrow" id="MathJax-Span-7827"><span class="mn" id="MathJax-Span-7828" style="font-size: 60.1%; font-family: MathJax_Main;">0</span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7829" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7830" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mi" id="MathJax-Span-7831" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-7832" style="font-family: MathJax_Main;">)</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.942em; border-left: 0px solid; width: 0px; height: 4.067em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mi>m</mi><mo>,</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mstyle displaystyle="true" scriptlevel="0"><munder><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>d</mi><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><mi>m</mi></mrow></munder><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover><msub><mi>σ</mi><mrow class="MJX-TeXAtom-ORD"><mstyle mathsize="0.85em"><mn>0</mn></mstyle></mrow></msub><mo stretchy="false">(</mo><mi>k</mi><mi>d</mi><mo stretchy="false">)</mo></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-699">D(m,n)=\\displaystyle\\sum_{d|m}\\sum_{k=1}^n\\sigma_{\\small 0}(kd)</script> where <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-700-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7833" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.53em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7834"><span class="mi" id="MathJax-Span-7835" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.056em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>d</mi></math></span></span><script type="math/tex" id="MathJax-Element-700">d</script> runs through all divisors of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-701-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7836" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.84em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7837"><span class="mi" id="MathJax-Span-7838" style="font-family: MathJax_Math; font-style: italic;">m</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>m</mi></math></span></span><script type="math/tex" id="MathJax-Element-701">m</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-702-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;&amp;#x03C3;&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mstyle mathsize="0.85em"&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/mstyle&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7839" style="width: 3.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.25em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7840"><span class="msubsup" id="MathJax-Span-7841"><span style="display: inline-block; position: relative; width: 0.947em; height: 0px;"><span style="position: absolute; clip: rect(3.445em, 1000.57em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7842" style="font-family: MathJax_Math; font-style: italic;">σ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.001em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.571em;"><span class="texatom" id="MathJax-Span-7843"><span class="mrow" id="MathJax-Span-7844"><span class="mstyle" id="MathJax-Span-7845"><span class="mrow" id="MathJax-Span-7846"><span class="mn" id="MathJax-Span-7847" style="font-size: 60.1%; font-family: MathJax_Main;">0</span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7848" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7849" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7850" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>σ</mi><mrow class="MJX-TeXAtom-ORD"><mstyle mathsize="0.85em"><mn>0</mn></mstyle></mrow></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-702">\\sigma_{\\small 0}(n)</script> is the number of divisors of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-703-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7851" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7852"><span class="mi" id="MathJax-Span-7853" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-703">n</script>.<br>
# You are given <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-704-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;!&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3398&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7854" style="width: 9.859em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.464em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1007.42em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7855"><span class="mi" id="MathJax-Span-7856" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-7857" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7858" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-7859" style="font-family: MathJax_Main;">!</span><span class="mo" id="MathJax-Span-7860" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-7861" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7862" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7863" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7864" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7865" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7866" style="font-family: MathJax_Main; padding-left: 0.278em;">3398</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>3</mn><mo>!</mo><mo>,</mo><msup><mn>10</mn><mn>2</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>3398</mn></math></span></span><script type="math/tex" id="MathJax-Element-704">D(3!,10^2)=3398</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-705-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo&gt;!&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;268882292&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7867" style="width: 13.017em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.856em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1009.8em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7868"><span class="mi" id="MathJax-Span-7869" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-7870" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7871" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-7872" style="font-family: MathJax_Main;">!</span><span class="mo" id="MathJax-Span-7873" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-7874" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7875" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7876" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7877" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7878" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7879" style="font-family: MathJax_Main; padding-left: 0.278em;">268882292</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>4</mn><mo>!</mo><mo>,</mo><msup><mn>10</mn><mn>6</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>268882292</mn></math></span></span><script type="math/tex" id="MathJax-Element-705">D(4!,10^6)=268882292</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-706-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;200&lt;/mn&gt;&lt;mo&gt;!&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;mod&amp;#xA0;&lt;/mtext&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7880" style="width: 15.553em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.77em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1011.67em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7881"><span class="mi" id="MathJax-Span-7882" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-7883" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7884" style="font-family: MathJax_Main;">200</span><span class="mo" id="MathJax-Span-7885" style="font-family: MathJax_Main;">!</span><span class="mo" id="MathJax-Span-7886" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-7887" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7888" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-7889"><span class="mrow" id="MathJax-Span-7890"><span class="mn" id="MathJax-Span-7891" style="font-size: 70.7%; font-family: MathJax_Main;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7892" style="font-family: MathJax_Main;">)</span><span class="mtext" id="MathJax-Span-7893" style="font-family: MathJax_Main;">&nbsp;mod&nbsp;</span><span class="mo" id="MathJax-Span-7894" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-7895"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-7896" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-7897" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7898" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-7899" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span><span class="mo" id="MathJax-Span-7900" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>200</mn><mo>!</mo><mo>,</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>12</mn></mrow></msup><mo stretchy="false">)</mo><mtext>&nbsp;mod&nbsp;</mtext><mo stretchy="false">(</mo><msup><mn>10</mn><mn>9</mn></msup><mo>+</mo><mn>7</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-706">D(200!,10^{12}) \\text{ mod } (10^9 + 7)</script>.</p>

# %%
submit_answer(answer; prob_num=608);

# %% [markdown]
# ## Problem 609: π sequences
# <p>
# For every <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-707-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7901" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.37em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7902"><span class="mi" id="MathJax-Span-7903" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7904" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-7905" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.188em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>≥</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-707">n \\ge 1</script> the <b>prime-counting</b> function <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-708-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7906" style="width: 2.586em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.962em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.87em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7907"><span class="mi" id="MathJax-Span-7908" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-7909" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7910" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7911" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>π</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-708">\\pi(n)</script> is equal to the number of primes
# not exceeding <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-709-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7912" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7913"><span class="mi" id="MathJax-Span-7914" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-709">n</script>.<br>
# E.g. <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-710-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7915" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.59em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7916"><span class="mi" id="MathJax-Span-7917" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-7918" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7919" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-7920" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7921" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7922" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>π</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-710">\\pi(6)=3</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-711-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;25&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7923" style="width: 6.701em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.072em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.02em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7924"><span class="mi" id="MathJax-Span-7925" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-7926" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-7927" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-7928" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-7929" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7930" style="font-family: MathJax_Main; padding-left: 0.278em;">25</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>π</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>25</mn></math></span></span><script type="math/tex" id="MathJax-Element-711">\\pi(100)=25</script>.
# </p>
# <p>
# We say that a sequence of integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-712-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo&gt;&amp;#x22EF;&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7931" style="width: 9.572em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.225em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.13em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7932"><span class="mi" id="MathJax-Span-7933" style="font-family: MathJax_Math; font-style: italic;">u</span><span class="mo" id="MathJax-Span-7934" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-7935" style="font-family: MathJax_Main; padding-left: 0.278em;">(</span><span class="msubsup" id="MathJax-Span-7936"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.55em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7937" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.572em;"><span class="mn" id="MathJax-Span-7938" style="font-size: 70.7%; font-family: MathJax_Main;">0</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7939" style="font-family: MathJax_Main;">,</span><span class="mo" id="MathJax-Span-7940" style="font-family: MathJax_Main; padding-left: 0.167em;">⋯</span><span class="mo" id="MathJax-Span-7941" style="font-family: MathJax_Main; padding-left: 0.167em;">,</span><span class="msubsup" id="MathJax-Span-7942" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.268em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.55em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7943" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.572em;"><span class="mi" id="MathJax-Span-7944" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7945" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>u</mi><mo>=</mo><mo stretchy="false">(</mo><msub><mi>u</mi><mn>0</mn></msub><mo>,</mo><mo>⋯</mo><mo>,</mo><msub><mi>u</mi><mi>m</mi></msub><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-712">u  = (u_0,\\cdots,u_m)</script> is a <i><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-713-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7946" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.866em, 1000.57em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7947"><span class="mi" id="MathJax-Span-7948" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.71em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>π</mi></math></span></span><script type="math/tex" id="MathJax-Element-713">\\pi</script> sequence</i> if
# </p><ul><li> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-714-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7949" style="width: 3.83em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.871em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.8em, 2.981em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7950"><span class="msubsup" id="MathJax-Span-7951"><span style="display: inline-block; position: relative; width: 1.071em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.55em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7952" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.572em;"><span class="mi" id="MathJax-Span-7953" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7954" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-7955" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.271em; border-left: 0px solid; width: 0px; height: 1.214em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>u</mi><mi>n</mi></msub><mo>≥</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-714">u_n \\ge 1</script> for every <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-715-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7956" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7957"><span class="mi" id="MathJax-Span-7958" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-715">n</script>
# </li><li> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-716-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7959" style="width: 7.514em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.694em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.6em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7960"><span class="msubsup" id="MathJax-Span-7961"><span style="display: inline-block; position: relative; width: 1.975em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.55em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7962" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.572em;"><span class="texatom" id="MathJax-Span-7963"><span class="mrow" id="MathJax-Span-7964"><span class="mi" id="MathJax-Span-7965" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-7966" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mn" id="MathJax-Span-7967" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7968" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-7969" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-7970" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-7971"><span style="display: inline-block; position: relative; width: 1.071em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.55em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7972" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.572em;"><span class="mi" id="MathJax-Span-7973" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7974" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>u</mi><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>+</mo><mn>1</mn></mrow></msub><mo>=</mo><mi>π</mi><mo stretchy="false">(</mo><msub><mi>u</mi><mi>n</mi></msub><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-716">u_{n+1}= \\pi(u_n)</script>
# </li><li> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-717-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7975" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.55em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7976"><span class="mi" id="MathJax-Span-7977" style="font-family: MathJax_Math; font-style: italic;">u</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>u</mi></math></span></span><script type="math/tex" id="MathJax-Element-717">u</script> has two or more elements
# </li></ul><p>
# For <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-718-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7978" style="width: 4.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.301em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1003.26em, 2.989em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7979"><span class="msubsup" id="MathJax-Span-7980"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.55em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-7981" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.572em;"><span class="mn" id="MathJax-Span-7982" style="font-size: 70.7%; font-family: MathJax_Main;">0</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-7983" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-7984" style="font-family: MathJax_Main; padding-left: 0.278em;">10</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.224em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>u</mi><mn>0</mn></msub><mo>=</mo><mn>10</mn></math></span></span><script type="math/tex" id="MathJax-Element-718">u_0=10</script> there are three distinct <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-719-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7985" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.866em, 1000.57em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7986"><span class="mi" id="MathJax-Span-7987" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.71em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>π</mi></math></span></span><script type="math/tex" id="MathJax-Element-719">\\pi</script> sequences: (10,4),  (10,4,2) and (10,4,2,1).
# </p>
# <p>
# Let  <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-720-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7988" style="width: 2.347em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.77em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.67em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7989"><span class="mi" id="MathJax-Span-7990" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-7991" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-7992" style="font-family: MathJax_Math; font-style: italic;">u</span><span class="mo" id="MathJax-Span-7993" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mi>u</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-720">c(u)</script> be the number of elements of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-721-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7994" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.55em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-7995"><span class="mi" id="MathJax-Span-7996" style="font-family: MathJax_Math; font-style: italic;">u</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>u</mi></math></span></span><script type="math/tex" id="MathJax-Element-721">u</script> that are not prime.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-722-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-7997" style="width: 3.83em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.871em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.78em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-7998"><span class="mi" id="MathJax-Span-7999" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-8000" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8001" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8002" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8003" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="mo" id="MathJax-Span-8004" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-722">p(n,k)</script> be the number of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-723-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C0;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8005" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.866em, 1000.57em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8006"><span class="mi" id="MathJax-Span-8007" style="font-family: MathJax_Math; font-style: italic;">π<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.71em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>π</mi></math></span></span><script type="math/tex" id="MathJax-Element-723">\\pi</script> sequences <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-724-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8008" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.55em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8009"><span class="mi" id="MathJax-Span-8010" style="font-family: MathJax_Math; font-style: italic;">u</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>u</mi></math></span></span><script type="math/tex" id="MathJax-Element-724">u</script>  for which <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-725-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8011" style="width: 3.926em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.967em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.9em, 1002.95em, 2.989em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8012"><span class="msubsup" id="MathJax-Span-8013"><span style="display: inline-block; position: relative; width: 1.001em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.55em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8014" style="font-family: MathJax_Math; font-style: italic;">u</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.572em;"><span class="mn" id="MathJax-Span-8015" style="font-size: 70.7%; font-family: MathJax_Main;">0</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8016" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-8017" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.184em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>u</mi><mn>0</mn></msub><mo>≤</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-725">u_0\\le n</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-726-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;u&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8018" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.62em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8019"><span class="mi" id="MathJax-Span-8020" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-8021" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8022" style="font-family: MathJax_Math; font-style: italic;">u</span><span class="mo" id="MathJax-Span-8023" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8024" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-8025" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">k</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi><mo stretchy="false">(</mo><mi>u</mi><mo stretchy="false">)</mo><mo>=</mo><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-726">c(u)=k</script>.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-727-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8026" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8027"><span class="mi" id="MathJax-Span-8028" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8029" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8030" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8031" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-727">P(n)</script> be the product of all <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-728-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8032" style="width: 3.83em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.871em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.78em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8033"><span class="mi" id="MathJax-Span-8034" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-8035" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8036" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8037" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8038" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="mo" id="MathJax-Span-8039" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-728">p(n,k)</script> that are larger than 0.<br>
# You are given: P(10)=3×8×9×3=648 and P(100)=31038676032.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-729-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8040" style="width: 3.878em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1002.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8041"><span class="mi" id="MathJax-Span-8042" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8043" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8044"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8045" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-8046" style="font-size: 70.7%; font-family: MathJax_Main;">8</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8047" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>8</mn></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-729">P(10^8)</script>. Give your answer modulo 1000000007.
# </p>

# %%
submit_answer(answer; prob_num=609);

# %% [markdown]
# ## Problem 610: Roman Numerals II
# <p>A random generator produces a sequence of symbols drawn from the set {<span style="font-family:'courier new', monospace;">I</span>, <span style="font-family:'courier new', monospace;">V</span>, <span style="font-family:'courier new', monospace;">X</span>, <span style="font-family:'courier new', monospace;">L</span>, <span style="font-family:'courier new', monospace;">C</span>, <span style="font-family:'courier new', monospace;">D</span>, <span style="font-family:'courier new', monospace;">M</span>, <span style="font-family:'courier new', monospace;">#</span>}.
#  Each item in the sequence is determined by selecting one of these
# symbols at random, independently of the other items in the sequence. At
# each step, the seven letters are equally likely to be selected, with
# probability 14% each, but the <span style="font-family:'courier new', monospace;">#</span> symbol only has a 2% chance of selection.</p>
#
# <p>We write down the sequence of letters from left to right as they are generated, and we stop at the first occurrence of the <span style="font-family:'courier new', monospace;">#</span>
#  symbol (without writing it). However, we stipulate that what we have
# written down must always (when non-empty) be a valid Roman numeral
# representation in minimal form. If appending the next letter would
# contravene this then we simply skip it and try again with the next
# symbol generated.</p>
#
# <p>Please take careful note of <a href="https://projecteuler.net/about=roman_numerals">About... Roman Numerals</a>
#  for the definitive rules for this problem on what constitutes a "valid
# Roman numeral representation" and "minimal form". For example, the
# (only) sequence that represents 49 is <span style="font-family:'courier new', monospace;">XLIX</span>. The subtractive combination <span style="font-family:'courier new', monospace;">IL</span> is invalid because of rule (ii), while <span style="font-family:'courier new', monospace;">XXXXIX</span> is valid but not minimal. The rules do not place any restriction on the number of occurrences of <span style="font-family:'courier new', monospace;">M</span>, so all integers have a valid representation. These are the same rules as were used in <a href="https://projecteuler.net/problem=89">Problem 89</a>, and members are invited to solve that problem first.</p>
#
# <p>Find the expected value of the number represented by what we have
# written down when we stop. (If nothing is written down then count that
# as zero.) Give your answer rounded to 8 places after the decimal point.</p>

# %%
submit_answer(answer; prob_num=610);

# %% [markdown]
# ## Problem 611: Hallway of square steps
# <p>Peter moves in a hallway with <var>N</var>+1 doors consecutively numbered from 0 through <var>N</var>. All doors are initially closed. Peter starts in front of door 0, and repeatedly performs the following steps:</p>
# <ul><li>First, he walks a positive square number of doors away from his position.</li>
# <li>Then he walks another, larger square number of doors away from his new position.</li>
# <li>He toggles the door he faces (opens it if closed, closes it if open).</li>
# <li>And finally returns to door 0.</li>
# </ul><p>We call an action any sequence of those steps. Peter never
# performs the exact same action twice, and makes sure to perform all
# "possible actions that don't bring him past the last door.</p>"
# <p>Let <var>F</var>(<var>N</var>) be the number of doors that are open after Peter has performed all possible actions. You are given that <var>F</var>(5)&nbsp;=&nbsp;1, <var>F</var>(100)&nbsp;=&nbsp;27, <var>F</var>(1000)&nbsp;=&nbsp;233 and <var>F</var>(10<sup>6</sup>)&nbsp;=&nbsp;112168.</p>
# <p>Find <var>F</var>(10<sup>12</sup>).</p>

# %%
submit_answer(answer; prob_num=611);

# %% [markdown]
# ## Problem 612: Friend numbers
# <p>
# "Let's call two numbers  <i>friend numbers</i> if their representation in base 10 has at least one common digit.<br> E.g. 1123 and 3981 are friend numbers. "
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-730-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8048" style="width: 2.538em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.914em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8049"><span class="mi" id="MathJax-Span-8050" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-8051" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8052" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8053" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-730">f(n)</script> be the number of pairs <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-731-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8054" style="width: 2.921em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.201em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.11em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8055"><span class="mo" id="MathJax-Span-8056" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8057" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-8058" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8059" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span class="mo" id="MathJax-Span-8060" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>p</mi><mo>,</mo><mi>q</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-731">(p,q)</script> with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-732-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;&amp;#x003C;&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mo&gt;&amp;#x003C;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8061" style="width: 7.993em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.029em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1006.01em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8062"><span class="mn" id="MathJax-Span-8063" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-8064" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-8065" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">p</span><span class="mo" id="MathJax-Span-8066" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-8067" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span class="mo" id="MathJax-Span-8068" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-8069" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.262em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn><mo>≤</mo><mi>p</mi><mo>&lt;</mo><mi>q</mi><mo>&lt;</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-732">1\\le p \\lt q \\lt n</script> such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-733-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8070" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8071"><span class="mi" id="MathJax-Span-8072" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-733">p</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-734-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8073" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8074"><span class="mi" id="MathJax-Span-8075" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-734">q</script> are friend numbers.<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-735-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1539&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8076" style="width: 7.897em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.981em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.94em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8077"><span class="mi" id="MathJax-Span-8078" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-8079" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8080" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-8081" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8082" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8083" style="font-family: MathJax_Main; padding-left: 0.278em;">1539</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1539</mn></math></span></span><script type="math/tex" id="MathJax-Element-735">f(100)=1539</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-736-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8084" style="width: 4.117em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.11em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.02em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8085"><span class="mi" id="MathJax-Span-8086" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-8087" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8088"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8089" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-8090"><span class="mrow" id="MathJax-Span-8091"><span class="mn" id="MathJax-Span-8092" style="font-size: 70.7%; font-family: MathJax_Main;">18</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8093" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>f</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>18</mn></mrow></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-736">f(10^{18})</script> mod <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-737-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1000267129&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8094" style="width: 6.318em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.785em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.86em, 1004.74em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8095"><span class="mn" id="MathJax-Span-8096" style="font-family: MathJax_Main;">1000267129</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.048em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1000267129</mn></math></span></span><script type="math/tex" id="MathJax-Element-737">1000267129</script>.
# </p>

# %%
submit_answer(answer; prob_num=612);

# %% [markdown]
# ## Problem 613: Pythagorean Ant
# <p>Dave
#  is doing his homework on the balcony and, preparing a presentation
# about Pythagorean triangles, has just cut out a triangle with side
# lengths 30cm, 40cm and 50cm from some cardboard, when a gust of wind
# blows the triangle down into the garden.<br>
# Another gust blows a small ant straight onto this triangle. The poor ant
#  is completely disoriented and starts to crawl straight ahead in random
# direction in order to get back into the grass.</p>
#
# <p>Assuming that all possible positions of the ant within the triangle
# and all possible directions of moving on are equiprobable, what is the
# probability that the ant leaves the triangle along its longest side?<br>
# Give your answer rounded to 10 digits after the decimal point.</p>

# %%
submit_answer(answer; prob_num=613);

# %% [markdown]
# ## Problem 614: Special partitions 2
# <p>An <b>integer partition</b> of a number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-738-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8097" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8098"><span class="mi" id="MathJax-Span-8099" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-738">n</script> is a way of writing <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-739-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8100" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8101"><span class="mi" id="MathJax-Span-8102" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-739">n</script> as a sum of positive integers. Partitions that differ only by the order of their summands are considered the same.</p>
#
# <p>We call an integer partition <i>special</i> if 1) all its summands are distinct, and 2) all its even summands are also divisible by 4. <br>For example, the special partitions of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-740-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8103" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.92em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8104"><span class="mn" id="MathJax-Span-8105" style="font-family: MathJax_Main;">10</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>10</mn></math></span></span><script type="math/tex" id="MathJax-Element-740">10</script> are: <span class="MathJax_Preview" style="color: inherit; display: none;"></span></p><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-741-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML" display="block"&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8106" style="width: 17.323em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.11em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.859em, 1013.07em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8107"><span class="mn" id="MathJax-Span-8108" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-8109" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8110" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span><span class="mo" id="MathJax-Span-8111" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8112" style="font-family: MathJax_Main; padding-left: 0.222em;">4</span><span class="mo" id="MathJax-Span-8113" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8114" style="font-family: MathJax_Main; padding-left: 0.222em;">5</span><span class="mo" id="MathJax-Span-8115" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8116" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span><span class="mo" id="MathJax-Span-8117" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8118" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span><span class="mo" id="MathJax-Span-8119" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8120" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span><span class="mo" id="MathJax-Span-8121" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8122" style="font-family: MathJax_Main; padding-left: 0.222em;">9</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.128em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><mn>10</mn><mo>=</mo><mn>1</mn><mo>+</mo><mn>4</mn><mo>+</mo><mn>5</mn><mo>=</mo><mn>3</mn><mo>+</mo><mn>7</mn><mo>=</mo><mn>1</mn><mo>+</mo><mn>9</mn></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-741">10 = 1+4+5=3+7=1+9</script>
# The number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-742-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8123" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.92em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8124"><span class="mn" id="MathJax-Span-8125" style="font-family: MathJax_Main;">10</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>10</mn></math></span></span><script type="math/tex" id="MathJax-Element-742">10</script> admits many more integer partitions (a total of 42), but only those three are special.
#
# <p>Let be <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-743-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8126" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8127"><span class="mi" id="MathJax-Span-8128" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8129" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8130" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8131" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-743">P(n)</script> the number of special integer partitions of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-744-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8132" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8133"><span class="mi" id="MathJax-Span-8134" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-744">n</script>. You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-745-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8135" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.71em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8136"><span class="mi" id="MathJax-Span-8137" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8138" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8139" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-8140" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8141" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8142" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-745">P(1) = 1</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-746-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8143" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.74em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8144"><span class="mi" id="MathJax-Span-8145" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8146" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8147" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-8148" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8149" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8150" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-746">P(2) = 0</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-747-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8151" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.71em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8152"><span class="mi" id="MathJax-Span-8153" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8154" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8155" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-8156" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8157" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8158" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-747">P(3) = 1</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-748-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8159" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.71em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8160"><span class="mi" id="MathJax-Span-8161" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8162" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8163" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-8164" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8165" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8166" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-748">P(6) = 1</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-749-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8167" style="width: 5.648em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.258em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.22em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8168"><span class="mi" id="MathJax-Span-8169" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8170" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8171" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-8172" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8173" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8174" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-749">P(10)=3</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-750-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;37076&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8175" style="width: 8.806em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.651em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.61em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8176"><span class="mi" id="MathJax-Span-8177" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8178" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8179" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-8180" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8181" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8182" style="font-family: MathJax_Main; padding-left: 0.278em;">37076</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>37076</mn></math></span></span><script type="math/tex" id="MathJax-Element-750">P(100) = 37076</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-751-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1000&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3699177285485660336&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8183" style="width: 18.28em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.828em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1013.78em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8184"><span class="mi" id="MathJax-Span-8185" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8186" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8187" style="font-family: MathJax_Main;">1000</span><span class="mo" id="MathJax-Span-8188" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8189" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8190" style="font-family: MathJax_Main; padding-left: 0.278em;">3699177285485660336</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>1000</mn><mo stretchy="false">)</mo><mo>=</mo><mn>3699177285485660336</mn></math></span></span><script type="math/tex" id="MathJax-Element-751">P(1000)=3699177285485660336</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-752-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msup&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8191" style="width: 4.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.445em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.67em, 1003.35em, 4.018em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8192"><span class="mstyle" id="MathJax-Span-8193"><span class="mrow" id="MathJax-Span-8194"><span class="munderover" id="MathJax-Span-8195"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-8196" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.1em, 4.27em, -1000em); top: -2.932em; left: 0.148em;"><span class="texatom" id="MathJax-Span-8197"><span class="mrow" id="MathJax-Span-8198"><span class="mi" id="MathJax-Span-8199" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-8200" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-8201" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.16em, 1001.01em, 4.178em, -1000em); top: -5.169em; left: 0.217em;"><span class="texatom" id="MathJax-Span-8202"><span class="mrow" id="MathJax-Span-8203"><span class="msubsup" id="MathJax-Span-8204"><span style="display: inline-block; position: relative; width: 1.01em; height: 0px;"><span style="position: absolute; clip: rect(3.405em, 1000.68em, 4.178em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8205" style="font-size: 70.7%; font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.297em; left: 0.707em;"><span class="mn" id="MathJax-Span-8206" style="font-size: 50%; font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="texatom" id="MathJax-Span-8207" style="padding-left: 0.167em;"><span class="mrow" id="MathJax-Span-8208"><span class="mi" id="MathJax-Span-8209" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-8210" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8211" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-8212" style="font-family: MathJax_Main;">)</span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.641em; border-left: 0px solid; width: 0px; height: 4.167em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><msup><mn>10</mn><mn>7</mn></msup></mrow></munderover><mrow class="MJX-TeXAtom-ORD"><mi>P</mi><mo stretchy="false">(</mo><mi>i</mi><mo stretchy="false">)</mo></mrow></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-752">\\displaystyle \\sum_{i=1}^{10^7}{P(i)}</script>. Give the result modulo <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-753-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8213" style="width: 4.117em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.11em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.09em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8214"><span class="msubsup" id="MathJax-Span-8215"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8216" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-8217" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8218" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8219" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.375em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>10</mn><mn>9</mn></msup><mo>+</mo><mn>7</mn></math></span></span><script type="math/tex" id="MathJax-Element-753">10^9+7</script>.</p>

# %%
submit_answer(answer; prob_num=614);

# %% [markdown]
# ## Problem 615: The millionth number with at least one million prime factors
# <p>
# "Consider the natural numbers having at least 5 prime factors, which don't have to be distinct.<br> Sorting these numbers by size gives a list which starts with:"
# </p>
# <ul style="list-style:none;"><li>32=2⋅2⋅2⋅2⋅2</li>
# <li>48=2⋅2⋅2⋅2⋅3</li>
# <li>64=2⋅2⋅2⋅2⋅2⋅2</li>
# <li>72=2⋅2⋅2⋅3⋅3</li>
# <li>80=2⋅2⋅2⋅2⋅5</li>
# <li>96=2⋅2⋅2⋅2⋅2⋅3</li>
# <li>&nbsp;  ...</li></ul><p>
# So, for example, the fifth number with at least 5 prime factors is 80.
# </p>
# <p>
# Find the millionth number with at least one million prime factors.<br>  Give your answer modulo 123454321.
# </p>

# %%
submit_answer(answer; prob_num=615);

# %% [markdown]
# ## Problem 616: Creative numbers
# <p>Alice plays the following game, she starts with a list of integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-754-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8220" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.64em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8221"><span class="mi" id="MathJax-Span-8222" style="font-family: MathJax_Math; font-style: italic;">L</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi></math></span></span><script type="math/tex" id="MathJax-Element-754">L</script> and on each step she can either:
# </p><ul><li>remove two elements <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-755-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8223" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1000.5em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8224"><span class="mi" id="MathJax-Span-8225" style="font-family: MathJax_Math; font-style: italic;">a</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.722em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-755">a</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-756-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8226" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.42em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8227"><span class="mi" id="MathJax-Span-8228" style="font-family: MathJax_Math; font-style: italic;">b</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-756">b</script> from <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-757-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8229" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.64em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8230"><span class="mi" id="MathJax-Span-8231" style="font-family: MathJax_Math; font-style: italic;">L</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi></math></span></span><script type="math/tex" id="MathJax-Element-757">L</script> and add <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-758-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8232" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.204em, 1000.91em, 2.354em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-8233"><span class="msubsup" id="MathJax-Span-8234"><span style="display: inline-block; position: relative; width: 0.907em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8235" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.529em;"><span class="mi" id="MathJax-Span-8236" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.266em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mi>a</mi><mi>b</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-758">a^b</script> to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-759-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8237" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.64em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8238"><span class="mi" id="MathJax-Span-8239" style="font-family: MathJax_Math; font-style: italic;">L</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi></math></span></span><script type="math/tex" id="MathJax-Element-759">L</script></li>
# <li>or conversely remove an element <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-760-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8240" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8241"><span class="mi" id="MathJax-Span-8242" style="font-family: MathJax_Math; font-style: italic;">c</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi></math></span></span><script type="math/tex" id="MathJax-Element-760">c</script> from <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-761-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8243" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.64em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8244"><span class="mi" id="MathJax-Span-8245" style="font-family: MathJax_Math; font-style: italic;">L</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi></math></span></span><script type="math/tex" id="MathJax-Element-761">L</script> that can be written as <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-762-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8246" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.204em, 1000.91em, 2.354em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-8247"><span class="msubsup" id="MathJax-Span-8248"><span style="display: inline-block; position: relative; width: 0.907em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8249" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.529em;"><span class="mi" id="MathJax-Span-8250" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.266em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mi>a</mi><mi>b</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-762">a^b</script>, with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-763-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8251" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1000.5em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8252"><span class="mi" id="MathJax-Span-8253" style="font-family: MathJax_Math; font-style: italic;">a</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.722em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-763">a</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-764-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8254" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.42em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8255"><span class="mi" id="MathJax-Span-8256" style="font-family: MathJax_Math; font-style: italic;">b</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-764">b</script> being two integers such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-765-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8257" style="width: 4.261em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.206em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1003.13em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8258"><span class="mi" id="MathJax-Span-8259" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-8260" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8261" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-8262" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-8263" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.298em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>,</mo><mi>b</mi><mo>&gt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-765">a, b > 1</script>, and add both <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-766-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8264" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1000.5em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8265"><span class="mi" id="MathJax-Span-8266" style="font-family: MathJax_Math; font-style: italic;">a</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.722em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-766">a</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-767-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8267" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.42em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8268"><span class="mi" id="MathJax-Span-8269" style="font-family: MathJax_Math; font-style: italic;">b</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-767">b</script> to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-768-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8270" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.64em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8271"><span class="mi" id="MathJax-Span-8272" style="font-family: MathJax_Math; font-style: italic;">L</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi></math></span></span><script type="math/tex" id="MathJax-Element-768">L</script></li></ul><p>For example starting from the list <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-769-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8273" style="width: 4.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.445em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.38em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8274"><span class="mi" id="MathJax-Span-8275" style="font-family: MathJax_Math; font-style: italic;">L</span><span class="mo" id="MathJax-Span-8276" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-8277" style="font-family: MathJax_Main; padding-left: 0.278em;">{</span><span class="mn" id="MathJax-Span-8278" style="font-family: MathJax_Main;">8</span><span class="mo" id="MathJax-Span-8279" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi><mo>=</mo><mo fence="false" stretchy="false">{</mo><mn>8</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-769">L=\\{8\\}</script>, Alice can remove <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-770-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8280" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8281"><span class="mn" id="MathJax-Span-8282" style="font-family: MathJax_Main;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-770">8</script> and add <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-771-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8283" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8284"><span class="mn" id="MathJax-Span-8285" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-771">2</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-772-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8286" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8287"><span class="mn" id="MathJax-Span-8288" style="font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.033em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-772">3</script> resulting in <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-773-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8289" style="width: 5.744em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.354em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.29em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8290"><span class="mi" id="MathJax-Span-8291" style="font-family: MathJax_Math; font-style: italic;">L</span><span class="mo" id="MathJax-Span-8292" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-8293" style="font-family: MathJax_Main; padding-left: 0.278em;">{</span><span class="mn" id="MathJax-Span-8294" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-8295" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8296" style="font-family: MathJax_Main; padding-left: 0.167em;">3</span><span class="mo" id="MathJax-Span-8297" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi><mo>=</mo><mo fence="false" stretchy="false">{</mo><mn>2</mn><mo>,</mo><mn>3</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-773">L=\\{2,3\\}</script> in a first step. Then she can obtain <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-774-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8298" style="width: 4.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.445em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.38em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8299"><span class="mi" id="MathJax-Span-8300" style="font-family: MathJax_Math; font-style: italic;">L</span><span class="mo" id="MathJax-Span-8301" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-8302" style="font-family: MathJax_Main; padding-left: 0.278em;">{</span><span class="mn" id="MathJax-Span-8303" style="font-family: MathJax_Main;">9</span><span class="mo" id="MathJax-Span-8304" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi><mo>=</mo><mo fence="false" stretchy="false">{</mo><mn>9</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-774">L=\\{9\\}</script> in a second step.</p>
#
# <p>Note that the same integer is allowed to appear multiple times in the list.</p>
#
# <p>An integer <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-775-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8305" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.37em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8306"><span class="mi" id="MathJax-Span-8307" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8308" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-8309" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 1.058em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>&gt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-775">n>1</script> is said to be <i>creative</i> if for any integer <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-776-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8310" style="width: 3.543em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.679em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.61em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8311"><span class="mi" id="MathJax-Span-8312" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-8313" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-8314" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 1.058em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>m</mi><mo>&gt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-776">m>1</script> Alice can obtain a list that contains <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-777-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8315" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.84em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8316"><span class="mi" id="MathJax-Span-8317" style="font-family: MathJax_Math; font-style: italic;">m</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>m</mi></math></span></span><script type="math/tex" id="MathJax-Element-777">m</script> starting from <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-778-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;L&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8318" style="width: 4.739em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.589em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.52em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8319"><span class="mi" id="MathJax-Span-8320" style="font-family: MathJax_Math; font-style: italic;">L</span><span class="mo" id="MathJax-Span-8321" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-8322" style="font-family: MathJax_Main; padding-left: 0.278em;">{</span><span class="mi" id="MathJax-Span-8323" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8324" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>L</mi><mo>=</mo><mo fence="false" stretchy="false">{</mo><mi>n</mi><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-778">L=\\{n\\}</script>.
#
# </p><p>Find the sum of all creative integers less than or equal to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-779-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8325" style="width: 2.347em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.77em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.194em, 1001.77em, 2.366em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-8326"><span class="msubsup" id="MathJax-Span-8327"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8328" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-8329"><span class="mrow" id="MathJax-Span-8330"><span class="mn" id="MathJax-Span-8331" style="font-size: 70.7%; font-family: MathJax_Main;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.296em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>12</mn></mrow></msup></math></span></span><script type="math/tex" id="MathJax-Element-779">10^{12}</script>.</p>

# %%
submit_answer(answer; prob_num=616);

# %% [markdown]
# ## Problem 617: Mirror Power Sequence
# <p>For two integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-780-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8332" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1003.28em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8333"><span class="mi" id="MathJax-Span-8334" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8335" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8336" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">e</span><span class="mo" id="MathJax-Span-8337" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-8338" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.262em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>,</mo><mi>e</mi><mo>&gt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-780">n,e > 1</script>, we define a <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-781-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8339" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.2em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8340"><span class="mo" id="MathJax-Span-8341" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8342" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8343" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8344" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">e</span><span class="mo" id="MathJax-Span-8345" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>e</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-781">(n,e)</script>-<i>MPS (Mirror Power Sequence)</i> to be an infinite sequence of integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-782-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8346" style="width: 3.734em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.823em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8347"><span class="mo" id="MathJax-Span-8348" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8349"><span style="display: inline-block; position: relative; width: 0.848em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8350" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.529em;"><span class="mi" id="MathJax-Span-8351" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-8352"><span style="display: inline-block; position: relative; width: 1.612em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1000.29em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-8353" style="font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.389em;"><span class="texatom" id="MathJax-Span-8354"><span class="mrow" id="MathJax-Span-8355"><span class="mi" id="MathJax-Span-8356" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-8357" style="font-size: 70.7%; font-family: MathJax_Main;">≥</span><span class="mn" id="MathJax-Span-8358" style="font-size: 70.7%; font-family: MathJax_Main;">0</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><msub><mi>a</mi><mi>i</mi></msub><msub><mo stretchy="false">)</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>≥</mo><mn>0</mn></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-782">(a_i)_{i\\ge 0}</script> such that for all <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-783-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8359" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.11em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8360"><span class="mi" id="MathJax-Span-8361" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-8362" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-8363" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.188em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>i</mi><mo>≥</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-783">i\\ge 0</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-784-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msubsup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;/msubsup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msubsup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;/msubsup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8364" style="width: 12.969em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.809em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1009.71em, 3.134em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8365"><span class="msubsup" id="MathJax-Span-8366"><span style="display: inline-block; position: relative; width: 1.752em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8367" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.529em;"><span class="texatom" id="MathJax-Span-8368"><span class="mrow" id="MathJax-Span-8369"><span class="mi" id="MathJax-Span-8370" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-8371" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mn" id="MathJax-Span-8372" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8373" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-8374" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">m</span><span class="mi" id="MathJax-Span-8375" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mi" id="MathJax-Span-8376" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8377" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8378"><span style="display: inline-block; position: relative; width: 0.934em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8379" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.41em, 4.17em, -1000em); top: -4.371em; left: 0.529em;"><span class="mi" id="MathJax-Span-8380" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">e</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.408em, 1000.32em, 4.17em, -1000em); top: -3.716em; left: 0.529em;"><span class="mi" id="MathJax-Span-8381" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8382" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8383" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">n</span><span class="mo" id="MathJax-Span-8384" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="msubsup" id="MathJax-Span-8385" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.934em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8386" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.41em, 4.17em, -1000em); top: -4.371em; left: 0.529em;"><span class="mi" id="MathJax-Span-8387" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">e</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.408em, 1000.32em, 4.17em, -1000em); top: -3.716em; left: 0.529em;"><span class="mi" id="MathJax-Span-8388" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8389" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.473em; border-left: 0px solid; width: 0px; height: 1.526em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>a</mi><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>+</mo><mn>1</mn></mrow></msub><mo>=</mo><mi>m</mi><mi>i</mi><mi>n</mi><mo stretchy="false">(</mo><msubsup><mi>a</mi><mi>i</mi><mi>e</mi></msubsup><mo>,</mo><mi>n</mi><mo>−</mo><msubsup><mi>a</mi><mi>i</mi><mi>e</mi></msubsup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-784">a_{i+1} = min(a_i^e,n-a_i^e)</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-785-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8390" style="width: 3.495em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.632em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.56em, 2.981em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8391"><span class="msubsup" id="MathJax-Span-8392"><span style="display: inline-block; position: relative; width: 0.848em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8393" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.529em;"><span class="mi" id="MathJax-Span-8394" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8395" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-8396" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.271em; border-left: 0px solid; width: 0px; height: 1.214em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>a</mi><mi>i</mi></msub><mo>&gt;</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-785">a_i > 1</script>.<br> Examples of such sequences are the two <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-786-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8397" style="width: 3.495em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.632em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.54em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8398"><span class="mo" id="MathJax-Span-8399" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8400" style="font-family: MathJax_Main;">18</span><span class="mo" id="MathJax-Span-8401" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8402" style="font-family: MathJax_Main; padding-left: 0.167em;">2</span><span class="mo" id="MathJax-Span-8403" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mn>18</mn><mo>,</mo><mn>2</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-786">(18,2)</script>-MPS sequences made of alternating <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-787-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8404" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8405"><span class="mn" id="MathJax-Span-8406" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-787">2</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-788-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8407" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.859em, 1000.45em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8408"><span class="mn" id="MathJax-Span-8409" style="font-family: MathJax_Main;">4</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.02em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>4</mn></math></span></span><script type="math/tex" id="MathJax-Element-788">4</script>.</p>
#
# <p>Note that even though such a sequence is uniquely determined by <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-789-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8410" style="width: 2.06em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.531em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(2.094em, 1001.49em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8411"><span class="mi" id="MathJax-Span-8412" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8413" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8414" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">e</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>,</mo><mi>e</mi></math></span></span><script type="math/tex" id="MathJax-Element-789">n,e</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-790-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8415" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.616em, 1000.96em, 2.51em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-8416"><span class="msubsup" id="MathJax-Span-8417"><span style="display: inline-block; position: relative; width: 0.958em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8418" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.529em;"><span class="mn" id="MathJax-Span-8419" style="font-size: 70.7%; font-family: MathJax_Main;">0</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 0.927em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>a</mi><mn>0</mn></msub></math></span></span><script type="math/tex" id="MathJax-Element-790">a_0</script>, for most values such a sequence does not exist. For example, no <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-791-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8420" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.2em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8421"><span class="mo" id="MathJax-Span-8422" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8423" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8424" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8425" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">e</span><span class="mo" id="MathJax-Span-8426" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>e</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-791">(n,e)</script>-MPS exists for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-792-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8427" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.4em, 2.863em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8428"><span class="mi" id="MathJax-Span-8429" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8430" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mn" id="MathJax-Span-8431" style="font-family: MathJax_Main; padding-left: 0.278em;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.116em; border-left: 0px solid; width: 0px; height: 1.058em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>&lt;</mo><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-792">n < 6</script>.</p>
#
# <p>Define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-793-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8432" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8433"><span class="mi" id="MathJax-Span-8434" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-8435" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8436" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8437" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-793">C(n)</script> to be the number of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-794-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8438" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.2em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8439"><span class="mo" id="MathJax-Span-8440" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8441" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8442" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8443" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">e</span><span class="mo" id="MathJax-Span-8444" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>e</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-794">(n,e)</script>-MPS for some <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-795-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8445" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.44em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8446"><span class="mi" id="MathJax-Span-8447" style="font-family: MathJax_Math; font-style: italic;">e</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>e</mi></math></span></span><script type="math/tex" id="MathJax-Element-795">e</script>, and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-796-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/munderover&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8448" style="width: 10.002em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.56em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.803em, 1007.47em, 4.018em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8449"><span class="mstyle" id="MathJax-Span-8450"><span class="mrow" id="MathJax-Span-8451"><span class="mi" id="MathJax-Span-8452" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-8453" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8454" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span><span class="mo" id="MathJax-Span-8455" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8456" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-8457" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-8458" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.29em, 4.27em, -1000em); top: -2.932em; left: 0.058em;"><span class="texatom" id="MathJax-Span-8459"><span class="mrow" id="MathJax-Span-8460"><span class="mi" id="MathJax-Span-8461" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8462" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-8463" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.293em, 1000.63em, 4.163em, -1000em); top: -5.169em; left: 0.408em;"><span class="mi" id="MathJax-Span-8464" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="texatom" id="MathJax-Span-8465" style="padding-left: 0.167em;"><span class="mrow" id="MathJax-Span-8466"><span class="mi" id="MathJax-Span-8467" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-8468" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8469" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8470" style="font-family: MathJax_Main;">)</span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.641em; border-left: 0px solid; width: 0px; height: 3.992em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><mi>D</mi><mo stretchy="false">(</mo><mi>N</mi><mo stretchy="false">)</mo><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>2</mn></mrow><mi>N</mi></munderover><mrow class="MJX-TeXAtom-ORD"><mi>C</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></mrow></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-796">\\displaystyle D(N) = \\sum_{n=2}^N {C(n)}</script>.
# <br>You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-797-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8471" style="width: 5.744em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.354em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8472"><span class="mi" id="MathJax-Span-8473" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-8474" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8475" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-8476" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8477" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8478" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-797">D(10) = 2</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-798-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;21&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8479" style="width: 7.036em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.311em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.24em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8480"><span class="mi" id="MathJax-Span-8481" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-8482" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8483" style="font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-8484" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8485" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8486" style="font-family: MathJax_Main; padding-left: 0.278em;">21</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>100</mn><mo stretchy="false">)</mo><mo>=</mo><mn>21</mn></math></span></span><script type="math/tex" id="MathJax-Element-798">D(100) = 21</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-799-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1000&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;69&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8487" style="width: 7.658em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.789em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.74em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8488"><span class="mi" id="MathJax-Span-8489" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-8490" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8491" style="font-family: MathJax_Main;">1000</span><span class="mo" id="MathJax-Span-8492" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8493" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8494" style="font-family: MathJax_Main; padding-left: 0.278em;">69</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>1000</mn><mo stretchy="false">)</mo><mo>=</mo><mn>69</mn></math></span></span><script type="math/tex" id="MathJax-Element-799">D(1000) = 69</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-800-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1303&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8495" style="width: 8.28em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.268em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1006.22em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8496"><span class="mi" id="MathJax-Span-8497" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-8498" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8499"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8500" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-8501" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8502" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8503" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8504" style="font-family: MathJax_Main; padding-left: 0.278em;">1303</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>6</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>1303</mn></math></span></span><script type="math/tex" id="MathJax-Element-800">D(10^6) = 1303</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-801-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1014800&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8505" style="width: 10.624em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.038em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1008em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8506"><span class="mi" id="MathJax-Span-8507" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-8508" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8509"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8510" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-8511"><span class="mrow" id="MathJax-Span-8512"><span class="mn" id="MathJax-Span-8513" style="font-size: 70.7%; font-family: MathJax_Main;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8514" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8515" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8516" style="font-family: MathJax_Main; padding-left: 0.278em;">1014800</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>12</mn></mrow></msup><mo stretchy="false">)</mo><mo>=</mo><mn>1014800</mn></math></span></span><script type="math/tex" id="MathJax-Element-801">D(10^{12}) = 1014800</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-802-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8517" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.25em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8518"><span class="mi" id="MathJax-Span-8519" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-8520" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8521"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-8522" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-8523"><span class="mrow" id="MathJax-Span-8524"><span class="mn" id="MathJax-Span-8525" style="font-size: 70.7%; font-family: MathJax_Main;">18</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8526" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>18</mn></mrow></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-802">D(10^{18})</script>.</p>

# %%
submit_answer(answer; prob_num=617);

# %% [markdown]
# ## Problem 618: Numbers with a given prime factor sum
# <p>Consider the numbers 15, 16 and 18:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-803-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8527" style="width: 5.888em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.45em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1004.4em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8528"><span class="mn" id="MathJax-Span-8529" style="font-family: MathJax_Main;">15</span><span class="mo" id="MathJax-Span-8530" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8531" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span><span class="mo" id="MathJax-Span-8532" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-8533" style="font-family: MathJax_Main; padding-left: 0.222em;">5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>15</mn><mo>=</mo><mn>3</mn><mo>×</mo><mn>5</mn></math></span></span><script type="math/tex" id="MathJax-Element-803">15=3\\times 5</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-804-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8534" style="width: 5.266em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.971em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1003.93em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8535"><span class="mn" id="MathJax-Span-8536" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-8537" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8538" style="font-family: MathJax_Main; padding-left: 0.222em;">5</span><span class="mo" id="MathJax-Span-8539" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8540" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.114em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>3</mn><mo>+</mo><mn>5</mn><mo>=</mo><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-804">3+5=8</script>.<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-805-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;16&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8541" style="width: 10.289em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.799em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1007.75em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8542"><span class="mn" id="MathJax-Span-8543" style="font-family: MathJax_Main;">16</span><span class="mo" id="MathJax-Span-8544" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8545" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span><span class="mo" id="MathJax-Span-8546" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-8547" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-8548" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-8549" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-8550" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-8551" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>16</mn><mo>=</mo><mn>2</mn><mo>×</mo><mn>2</mn><mo>×</mo><mn>2</mn><mo>×</mo><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-805">16 = 2\\times 2\\times 2\\times 2</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-806-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8552" style="width: 9.667em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.321em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1007.28em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8553"><span class="mn" id="MathJax-Span-8554" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-8555" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8556" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-8557" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8558" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-8559" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8560" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-8561" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8562" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.114em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn><mo>+</mo><mn>2</mn><mo>+</mo><mn>2</mn><mo>+</mo><mn>2</mn><mo>=</mo><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-806">2+2+2+2=8</script>.<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-807-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8563" style="width: 8.089em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.124em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1006.08em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8564"><span class="mn" id="MathJax-Span-8565" style="font-family: MathJax_Main;">18</span><span class="mo" id="MathJax-Span-8566" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8567" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span><span class="mo" id="MathJax-Span-8568" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-8569" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mo" id="MathJax-Span-8570" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="mn" id="MathJax-Span-8571" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>18</mn><mo>=</mo><mn>2</mn><mo>×</mo><mn>3</mn><mo>×</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-807">18 = 2\\times 3\\times 3</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-808-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8572" style="width: 7.467em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.646em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1005.6em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8573"><span class="mn" id="MathJax-Span-8574" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-8575" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8576" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mo" id="MathJax-Span-8577" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8578" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mo" id="MathJax-Span-8579" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8580" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.114em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn><mo>+</mo><mn>3</mn><mo>+</mo><mn>3</mn><mo>=</mo><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-808">2+3+3=8</script>.<br>
#
# 15, 16 and 18 are the only numbers that have 8 as sum of the prime factors (counted with multiplicity).</p>
# <p>
# We define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-809-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8581" style="width: 2.586em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.962em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.87em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8582"><span class="mi" id="MathJax-Span-8583" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-8584" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8585" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-8586" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-809">S(k)</script> to be the sum of all numbers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-810-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8587" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8588"><span class="mi" id="MathJax-Span-8589" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-810">n</script> where the sum of the prime factors (with multiplicity)  of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-811-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8590" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8591"><span class="mi" id="MathJax-Span-8592" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-811">n</script> is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-812-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8593" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8594"><span class="mi" id="MathJax-Span-8595" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-812">k</script>.<br>
# Hence <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-813-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;16&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;49&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8596" style="width: 14.213em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1010.72em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8597"><span class="mi" id="MathJax-Span-8598" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-8599" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8600" style="font-family: MathJax_Main;">8</span><span class="mo" id="MathJax-Span-8601" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8602" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8603" style="font-family: MathJax_Main; padding-left: 0.278em;">15</span><span class="mo" id="MathJax-Span-8604" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8605" style="font-family: MathJax_Main; padding-left: 0.222em;">16</span><span class="mo" id="MathJax-Span-8606" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8607" style="font-family: MathJax_Main; padding-left: 0.222em;">18</span><span class="mo" id="MathJax-Span-8608" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8609" style="font-family: MathJax_Main; padding-left: 0.278em;">49</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>8</mn><mo stretchy="false">)</mo><mo>=</mo><mn>15</mn><mo>+</mo><mn>16</mn><mo>+</mo><mn>18</mn><mo>=</mo><mn>49</mn></math></span></span><script type="math/tex" id="MathJax-Element-813">S(8) = 15+16+18 = 49</script>.<br>
# Other examples: <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-814-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8610" style="width: 4.883em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.684em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.64em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8611"><span class="mi" id="MathJax-Span-8612" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-8613" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8614" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-8615" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8616" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8617" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-814">S(1) = 0</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-815-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8618" style="width: 4.883em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.684em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.63em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8619"><span class="mi" id="MathJax-Span-8620" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-8621" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8622" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-8623" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8624" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8625" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-815">S(2) = 2</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-816-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8626" style="width: 4.883em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.684em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.64em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8627"><span class="mi" id="MathJax-Span-8628" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-8629" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8630" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-8631" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8632" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8633" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-816">S(3) = 3</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-817-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8634" style="width: 10.146em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.656em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.58em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8635"><span class="mi" id="MathJax-Span-8636" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-8637" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8638" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-8639" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8640" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8641" style="font-family: MathJax_Main; padding-left: 0.278em;">5</span><span class="mo" id="MathJax-Span-8642" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8643" style="font-family: MathJax_Main; padding-left: 0.222em;">6</span><span class="mo" id="MathJax-Span-8644" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8645" style="font-family: MathJax_Main; padding-left: 0.278em;">11</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>5</mn><mo stretchy="false">)</mo><mo>=</mo><mn>5</mn><mo>+</mo><mn>6</mn><mo>=</mo><mn>11</mn></math></span></span><script type="math/tex" id="MathJax-Element-817">S(5) = 5 + 6 = 11</script>.</p>
# <p>
# The Fibonacci sequence is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-818-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8646" style="width: 21.342em; display: inline-block;"><span style="display: inline-block; position: relative; width: 16.172em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1016.12em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8647"><span class="msubsup" id="MathJax-Span-8648"><span style="display: inline-block; position: relative; width: 1.072em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8649" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="mn" id="MathJax-Span-8650" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8651" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8652" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span><span class="mo" id="MathJax-Span-8653" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-8654" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.072em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8655" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="mn" id="MathJax-Span-8656" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8657" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8658" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span><span class="mo" id="MathJax-Span-8659" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-8660" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.072em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8661" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="mn" id="MathJax-Span-8662" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8663" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8664" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span><span class="mo" id="MathJax-Span-8665" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-8666" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.072em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8667" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="mn" id="MathJax-Span-8668" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8669" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8670" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span><span class="mo" id="MathJax-Span-8671" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-8672" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.072em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8673" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="mn" id="MathJax-Span-8674" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8675" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8676" style="font-family: MathJax_Main; padding-left: 0.278em;">5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.28em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>F</mi><mn>1</mn></msub><mo>=</mo><mn>1</mn><mo>,</mo><msub><mi>F</mi><mn>2</mn></msub><mo>=</mo><mn>1</mn><mo>,</mo><msub><mi>F</mi><mn>3</mn></msub><mo>=</mo><mn>2</mn><mo>,</mo><msub><mi>F</mi><mn>4</mn></msub><mo>=</mo><mn>3</mn><mo>,</mo><msub><mi>F</mi><mn>5</mn></msub><mo>=</mo><mn>5</mn></math></span></span><script type="math/tex" id="MathJax-Element-818">F_1 = 1, F_2 = 1, F_3 = 2, F_4 = 3, F_5 = 5</script>, ....<br>
# Find the last nine digits of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-819-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;24&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8677" style="width: 5.457em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.115em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.807em, 1004.02em, 4.038em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8678"><span class="mstyle" id="MathJax-Span-8679"><span class="mrow" id="MathJax-Span-8680"><span class="munderover" id="MathJax-Span-8681"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-8682" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1001.24em, 4.27em, -1000em); top: -2.912em; left: 0.086em;"><span class="texatom" id="MathJax-Span-8683"><span class="mrow" id="MathJax-Span-8684"><span class="mi" id="MathJax-Span-8685" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-8686" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-8687" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.297em, 1000.69em, 4.163em, -1000em); top: -5.169em; left: 0.368em;"><span class="texatom" id="MathJax-Span-8688"><span class="mrow" id="MathJax-Span-8689"><span class="mn" id="MathJax-Span-8690" style="font-size: 70.7%; font-family: MathJax_Main;">24</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="texatom" id="MathJax-Span-8691" style="padding-left: 0.167em;"><span class="mrow" id="MathJax-Span-8692"><span class="mi" id="MathJax-Span-8693" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-8694" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-8695"><span style="display: inline-block; position: relative; width: 1.086em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-8696" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="mi" id="MathJax-Span-8697" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-8698" style="font-family: MathJax_Main;">)</span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.667em; border-left: 0px solid; width: 0px; height: 4.012em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mn>2</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>24</mn></mrow></munderover><mrow class="MJX-TeXAtom-ORD"><mi>S</mi><mo stretchy="false">(</mo><msub><mi>F</mi><mi>k</mi></msub><mo stretchy="false">)</mo></mrow></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-819">\\displaystyle\\sum_{k=2}^{24}{S(F_k)}</script>.</p>

# %%
submit_answer(answer; prob_num=618);

# %% [markdown]
# ## Problem 619: Square subsets
# <p>For a set of positive integers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-820-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8699" style="width: 12.586em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.522em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1009.46em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8700"><span class="mo" id="MathJax-Span-8701" style="font-family: MathJax_Main;">{</span><span class="mi" id="MathJax-Span-8702" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-8703" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8704" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">a</span><span class="mo" id="MathJax-Span-8705" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8706" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-8707" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8708" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">a</span><span class="mo" id="MathJax-Span-8709" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-8710" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-8711" style="font-family: MathJax_Main;">,</span><span class="mo" id="MathJax-Span-8712" style="font-family: MathJax_Main; padding-left: 0.167em;">…</span><span class="mo" id="MathJax-Span-8713" style="font-family: MathJax_Main; padding-left: 0.167em;">,</span><span class="mi" id="MathJax-Span-8714" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-8715" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo fence="false" stretchy="false">{</mo><mi>a</mi><mo>,</mo><mi>a</mi><mo>+</mo><mn>1</mn><mo>,</mo><mi>a</mi><mo>+</mo><mn>2</mn><mo>,</mo><mo>…</mo><mo>,</mo><mi>b</mi><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-820">\\{a, a+1, a+2, \\dots , b\\}</script>, let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-821-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8716" style="width: 3.878em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8717"><span class="mi" id="MathJax-Span-8718" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-8719" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8720" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-8721" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8722" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-8723" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mi>a</mi><mo>,</mo><mi>b</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-821">C(a,b)</script> be the number of non-empty subsets in which the product of all elements is a perfect square.</p>
# <p>For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-822-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8724" style="width: 6.892em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.215em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.17em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8725"><span class="mi" id="MathJax-Span-8726" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-8727" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8728" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-8729" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8730" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-8731" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8732" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8733" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>5</mn><mo>,</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-822">C(5,10)=3</script>, since the products of all elements of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-823-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8734" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.71em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8735"><span class="mo" id="MathJax-Span-8736" style="font-family: MathJax_Main;">{</span><span class="mn" id="MathJax-Span-8737" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-8738" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8739" style="font-family: MathJax_Main; padding-left: 0.167em;">8</span><span class="mo" id="MathJax-Span-8740" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8741" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-8742" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo fence="false" stretchy="false">{</mo><mn>5</mn><mo>,</mo><mn>8</mn><mo>,</mo><mn>10</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-823">\\{5, 8, 10\\}</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-824-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8743" style="width: 6.222em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.689em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.62em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8744"><span class="mo" id="MathJax-Span-8745" style="font-family: MathJax_Main;">{</span><span class="mn" id="MathJax-Span-8746" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-8747" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8748" style="font-family: MathJax_Main; padding-left: 0.167em;">8</span><span class="mo" id="MathJax-Span-8749" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8750" style="font-family: MathJax_Main; padding-left: 0.167em;">9</span><span class="mo" id="MathJax-Span-8751" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8752" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-8753" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo fence="false" stretchy="false">{</mo><mn>5</mn><mo>,</mo><mn>8</mn><mo>,</mo><mn>9</mn><mo>,</mo><mn>10</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-824">\\{5, 8, 9, 10\\}</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-825-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8754" style="width: 1.916em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.435em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.37em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8755"><span class="mo" id="MathJax-Span-8756" style="font-family: MathJax_Main;">{</span><span class="mn" id="MathJax-Span-8757" style="font-family: MathJax_Main;">9</span><span class="mo" id="MathJax-Span-8758" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo fence="false" stretchy="false">{</mo><mn>9</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-825">\\{9\\}</script> are perfect squares, and no other subsets of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-826-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8759" style="width: 8.663em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.555em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.49em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8760"><span class="mo" id="MathJax-Span-8761" style="font-family: MathJax_Main;">{</span><span class="mn" id="MathJax-Span-8762" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-8763" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8764" style="font-family: MathJax_Main; padding-left: 0.167em;">6</span><span class="mo" id="MathJax-Span-8765" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8766" style="font-family: MathJax_Main; padding-left: 0.167em;">7</span><span class="mo" id="MathJax-Span-8767" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8768" style="font-family: MathJax_Main; padding-left: 0.167em;">8</span><span class="mo" id="MathJax-Span-8769" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8770" style="font-family: MathJax_Main; padding-left: 0.167em;">9</span><span class="mo" id="MathJax-Span-8771" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8772" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-8773" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo fence="false" stretchy="false">{</mo><mn>5</mn><mo>,</mo><mn>6</mn><mo>,</mo><mn>7</mn><mo>,</mo><mn>8</mn><mo>,</mo><mn>9</mn><mo>,</mo><mn>10</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-826">\\{5, 6, 7, 8, 9, 10\\}</script> have this property.</p>
# <p>You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-827-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;40&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;55&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8774" style="width: 8.184em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.172em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.12em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8775"><span class="mi" id="MathJax-Span-8776" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-8777" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8778" style="font-family: MathJax_Main;">40</span><span class="mo" id="MathJax-Span-8779" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8780" style="font-family: MathJax_Main; padding-left: 0.167em;">55</span><span class="mo" id="MathJax-Span-8781" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8782" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8783" style="font-family: MathJax_Main; padding-left: 0.278em;">15</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>40</mn><mo>,</mo><mn>55</mn><mo stretchy="false">)</mo><mo>=</mo><mn>15</mn></math></span></span><script type="math/tex" id="MathJax-Element-827">C(40,55) =15</script>, and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-828-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1000&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1234&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;mod&amp;#xA0;&lt;/mtext&gt;&lt;mn&gt;1000000007&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;975523611&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8784" style="width: 24.5em; display: inline-block;"><span style="display: inline-block; position: relative; width: 18.565em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1018.49em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8785"><span class="mi" id="MathJax-Span-8786" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-8787" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8788" style="font-family: MathJax_Main;">1000</span><span class="mo" id="MathJax-Span-8789" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8790" style="font-family: MathJax_Main; padding-left: 0.167em;">1234</span><span class="mo" id="MathJax-Span-8791" style="font-family: MathJax_Main;">)</span><span class="mtext" id="MathJax-Span-8792" style="font-family: MathJax_Main;">&nbsp;mod&nbsp;</span><span class="mn" id="MathJax-Span-8793" style="font-family: MathJax_Main;">1000000007</span><span class="mo" id="MathJax-Span-8794" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8795" style="font-family: MathJax_Main; padding-left: 0.278em;">975523611</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>1000</mn><mo>,</mo><mn>1234</mn><mo stretchy="false">)</mo><mtext>&nbsp;mod&nbsp;</mtext><mn>1000000007</mn><mo>=</mo><mn>975523611</mn></math></span></span><script type="math/tex" id="MathJax-Element-828">C(1000,1234) \\text{ mod } 1000000007=975523611</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-829-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1000000&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1234567&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mtext&gt;&amp;#xA0;mod&amp;#xA0;&lt;/mtext&gt;&lt;mn&gt;1000000007&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8796" style="width: 20.864em; display: inline-block;"><span style="display: inline-block; position: relative; width: 15.789em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1015.77em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8797"><span class="mi" id="MathJax-Span-8798" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-8799" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8800" style="font-family: MathJax_Main;">1000000</span><span class="mo" id="MathJax-Span-8801" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8802" style="font-family: MathJax_Main; padding-left: 0.167em;">1234567</span><span class="mo" id="MathJax-Span-8803" style="font-family: MathJax_Main;">)</span><span class="mtext" id="MathJax-Span-8804" style="font-family: MathJax_Main;">&nbsp;mod&nbsp;</span><span class="mn" id="MathJax-Span-8805" style="font-family: MathJax_Main;">1000000007</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi><mo stretchy="false">(</mo><mn>1000000</mn><mo>,</mo><mn>1234567</mn><mo stretchy="false">)</mo><mtext>&nbsp;mod&nbsp;</mtext><mn>1000000007</mn></math></span></span><script type="math/tex" id="MathJax-Element-829">C(1000000,1234567) \\text{ mod } 1000000007</script>.</p>

# %%
submit_answer(answer; prob_num=619);

# %% [markdown]
# ## Problem 620: Planetary Gears
# <p>A circle <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-830-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8806" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8807"><span class="mi" id="MathJax-Span-8808" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-830">C</script> of circumference <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-831-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8809" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8810"><span class="mi" id="MathJax-Span-8811" style="font-family: MathJax_Math; font-style: italic;">c</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi></math></span></span><script type="math/tex" id="MathJax-Element-831">c</script> centimetres has a smaller circle <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-832-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8812" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.67em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8813"><span class="mi" id="MathJax-Span-8814" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi></math></span></span><script type="math/tex" id="MathJax-Element-832">S</script> of circumference <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-833-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8815" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8816"><span class="mi" id="MathJax-Span-8817" style="font-family: MathJax_Math; font-style: italic;">s</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.723em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi></math></span></span><script type="math/tex" id="MathJax-Element-833">s</script> centimetres lying off-centre within it. Four other distinct circles, which we call "planets", with circumferences <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-834-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8818" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8819"><span class="mi" id="MathJax-Span-8820" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-834">p</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-835-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8821" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8822"><span class="mi" id="MathJax-Span-8823" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-835">p</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-836-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8824" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8825"><span class="mi" id="MathJax-Span-8826" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-836">q</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-837-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8827" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8828"><span class="mi" id="MathJax-Span-8829" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-837">q</script> centimetres respectively (<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-838-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8830" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.996em, 1002.3em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8831"><span class="mi" id="MathJax-Span-8832" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-8833" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-8834" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.095em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>&lt;</mo><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-838">p<q</script>), are inscribed within <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-839-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8835" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8836"><span class="mi" id="MathJax-Span-8837" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-839">C</script> but outside <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-840-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8838" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.67em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8839"><span class="mi" id="MathJax-Span-8840" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi></math></span></span><script type="math/tex" id="MathJax-Element-840">S</script>, with each planet touching both <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-841-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8841" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8842"><span class="mi" id="MathJax-Span-8843" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-841">C</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-842-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8844" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.67em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8845"><span class="mi" id="MathJax-Span-8846" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi></math></span></span><script type="math/tex" id="MathJax-Element-842">S</script> tangentially. The planets are permitted to overlap one another, but the boundaries of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-843-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8847" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.67em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8848"><span class="mi" id="MathJax-Span-8849" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi></math></span></span><script type="math/tex" id="MathJax-Element-843">S</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-844-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8850" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8851"><span class="mi" id="MathJax-Span-8852" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-844">C</script> must be at least 1cm apart at their closest point.</p>
#
# <p>Now suppose that these circles are actually gears with perfectly meshing teeth at a pitch of 1cm. <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-845-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8853" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8854"><span class="mi" id="MathJax-Span-8855" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-845">C</script> is an internal gear with teeth on the inside. We require that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-846-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8856" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8857"><span class="mi" id="MathJax-Span-8858" style="font-family: MathJax_Math; font-style: italic;">c</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi></math></span></span><script type="math/tex" id="MathJax-Element-846">c</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-847-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8859" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8860"><span class="mi" id="MathJax-Span-8861" style="font-family: MathJax_Math; font-style: italic;">s</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.723em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi></math></span></span><script type="math/tex" id="MathJax-Element-847">s</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-848-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8862" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8863"><span class="mi" id="MathJax-Span-8864" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-848">p</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-849-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8865" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8866"><span class="mi" id="MathJax-Span-8867" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-849">q</script> are all integers (as they are the numbers of teeth), and we further stipulate that any gear must have at least 5 teeth.</p>
#
# <p>Note that "perfectly meshing" means that as the gears rotate, the
# ratio between their angular velocities remains constant, and the teeth
# of one gear perfectly align with the groves of the other gear and vice
# versa. Only for certain gear sizes and positions will it be possible for
#  <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-850-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8868" style="width: 0.911em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.67em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.67em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8869"><span class="mi" id="MathJax-Span-8870" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi></math></span></span><script type="math/tex" id="MathJax-Element-850">S</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-851-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8871" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.592em, 1000.77em, 2.606em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8872"><span class="mi" id="MathJax-Span-8873" style="font-family: MathJax_Math; font-style: italic;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.086em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>C</mi></math></span></span><script type="math/tex" id="MathJax-Element-851">C</script> each to mesh perfectly with all the planets. Arrangements where not all gears mesh perfectly are not valid.</p>
#
# <p>Define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-852-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8874" style="width: 5.935em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.498em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.4em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8875"><span class="mi" id="MathJax-Span-8876" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-8877" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8878" style="font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-8879" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8880" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">s</span><span class="mo" id="MathJax-Span-8881" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8882" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-8883" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8884" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span class="mo" id="MathJax-Span-8885" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo stretchy="false">(</mo><mi>c</mi><mo>,</mo><mi>s</mi><mo>,</mo><mi>p</mi><mo>,</mo><mi>q</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-852">g(c,s,p,q)</script> to be the number of such gear arrangements for given values of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-853-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8886" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8887"><span class="mi" id="MathJax-Span-8888" style="font-family: MathJax_Math; font-style: italic;">c</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>c</mi></math></span></span><script type="math/tex" id="MathJax-Element-853">c</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-854-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8889" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8890"><span class="mi" id="MathJax-Span-8891" style="font-family: MathJax_Math; font-style: italic;">s</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.723em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi></math></span></span><script type="math/tex" id="MathJax-Element-854">s</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-855-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8892" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8893"><span class="mi" id="MathJax-Span-8894" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-855">p</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-856-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8895" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8896"><span class="mi" id="MathJax-Span-8897" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-856">q</script>:
#  it turns out that this is finite as only certain discrete arrangements
# are possible satisfying the above conditions. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-857-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;16&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8898" style="width: 8.998em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.794em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.75em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8899"><span class="mi" id="MathJax-Span-8900" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-8901" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8902" style="font-family: MathJax_Main;">16</span><span class="mo" id="MathJax-Span-8903" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8904" style="font-family: MathJax_Main; padding-left: 0.167em;">5</span><span class="mo" id="MathJax-Span-8905" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8906" style="font-family: MathJax_Main; padding-left: 0.167em;">5</span><span class="mo" id="MathJax-Span-8907" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-8908" style="font-family: MathJax_Main; padding-left: 0.167em;">6</span><span class="mo" id="MathJax-Span-8909" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8910" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8911" style="font-family: MathJax_Main; padding-left: 0.278em;">9</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>g</mi><mo stretchy="false">(</mo><mn>16</mn><mo>,</mo><mn>5</mn><mo>,</mo><mn>5</mn><mo>,</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>9</mn></math></span></span><script type="math/tex" id="MathJax-Element-857">g(16,5,5,6)=9</script>.</p>
#
# <p>Here is one such arrangement:</p>
# <div align="center"><img src="webfiles/p620_planetary_gears.png" alt="Example arrangement"></div>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-858-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8912" style="width: 20.864em; display: inline-block;"><span style="display: inline-block; position: relative; width: 15.789em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1015.69em, 3.246em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8913"><span class="mi" id="MathJax-Span-8914" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-8915" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8916" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8917" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8918" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-8919" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 4.218em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-8920" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-8921"><span class="mrow" id="MathJax-Span-8922"><span class="mi" id="MathJax-Span-8923" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-8924" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mi" id="MathJax-Span-8925" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-8926" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mi" id="MathJax-Span-8927" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.01em;"></span></span><span class="mo" id="MathJax-Span-8928" style="font-size: 70.7%; font-family: MathJax_Main;">≤</span><span class="mi" id="MathJax-Span-8929" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-8930" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-8931" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8932" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-8933" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-8934" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">p</span><span class="mo" id="MathJax-Span-8935" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-8936" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span class="mo" id="MathJax-Span-8937" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8938" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">s</span><span class="mo" id="MathJax-Span-8939" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8940" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-8941" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-8942" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span class="mo" id="MathJax-Span-8943" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.621em; border-left: 0px solid; width: 0px; height: 1.674em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><munder><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>s</mi><mo>+</mo><mi>p</mi><mo>+</mo><mi>q</mi><mo>≤</mo><mi>n</mi></mrow></munder><mi>g</mi><mo stretchy="false">(</mo><mi>s</mi><mo>+</mo><mi>p</mi><mo>+</mo><mi>q</mi><mo>,</mo><mi>s</mi><mo>,</mo><mi>p</mi><mo>,</mo><mi>q</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-858">G(n) = \\sum_{s+p+q\\le n} g(s+p+q,s,p,q)</script> where the sum only includes cases with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-859-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8944" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.996em, 1002.3em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8945"><span class="mi" id="MathJax-Span-8946" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-8947" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-8948" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.095em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>&lt;</mo><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-859">p<q</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-860-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8949" style="width: 3.112em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.344em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.29em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8950"><span class="mi" id="MathJax-Span-8951" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-8952" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-8953" style="font-family: MathJax_Main; padding-left: 0.278em;">5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.262em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>≥</mo><mn>5</mn></math></span></span><script type="math/tex" id="MathJax-Element-860">p\\ge 5</script>, and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-861-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8954" style="width: 3.065em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.297em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.25em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8955"><span class="mi" id="MathJax-Span-8956" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-8957" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-8958" style="font-family: MathJax_Main; padding-left: 0.278em;">5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.188em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mo>≥</mo><mn>5</mn></math></span></span><script type="math/tex" id="MathJax-Element-861">s\\ge 5</script>, all integers. You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-862-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;16&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8959" style="width: 5.696em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.306em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.26em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8960"><span class="mi" id="MathJax-Span-8961" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-8962" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8963" style="font-family: MathJax_Main;">16</span><span class="mo" id="MathJax-Span-8964" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8965" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8966" style="font-family: MathJax_Main; padding-left: 0.278em;">9</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>16</mn><mo stretchy="false">)</mo><mo>=</mo><mn>9</mn></math></span></span><script type="math/tex" id="MathJax-Element-862">G(16)=9</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-863-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;20&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;205&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8967" style="width: 6.988em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.263em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.21em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8968"><span class="mi" id="MathJax-Span-8969" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-8970" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8971" style="font-family: MathJax_Main;">20</span><span class="mo" id="MathJax-Span-8972" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8973" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8974" style="font-family: MathJax_Main; padding-left: 0.278em;">205</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>20</mn><mo stretchy="false">)</mo><mo>=</mo><mn>205</mn></math></span></span><script type="math/tex" id="MathJax-Element-863">G(20)=205</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-864-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;500&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8975" style="width: 3.926em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.967em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.87em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8976"><span class="mi" id="MathJax-Span-8977" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-8978" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8979" style="font-family: MathJax_Main;">500</span><span class="mo" id="MathJax-Span-8980" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>500</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-864">G(500)</script>.</p>

# %%
submit_answer(answer; prob_num=620);

# %% [markdown]
# ## Problem 621: Expressing an integer as the sum of triangular numbers
# <p>Gauss famously proved that every positive integer can be expressed as the sum of three <b>triangular numbers</b>
#  (including 0 as the lowest triangular number).  In fact most numbers
# can be expressed as a sum of three triangular numbers in several ways.</p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-865-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8981" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8982"><span class="mi" id="MathJax-Span-8983" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-8984" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-8985" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-8986" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-865">G(n)</script> be the number of ways of expressing <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-866-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8987" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-8988"><span class="mi" id="MathJax-Span-8989" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-866">n</script> as the sum of three triangular numbers, regarding different arrangements of the terms of the sum as distinct.</p>
# <p>
# For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-867-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8990" style="width: 5.074em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.828em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.81em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8991"><span class="mi" id="MathJax-Span-8992" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-8993" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-8994" style="font-family: MathJax_Main;">9</span><span class="mo" id="MathJax-Span-8995" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-8996" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-8997" style="font-family: MathJax_Main; padding-left: 0.278em;">7</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>9</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7</mn></math></span></span><script type="math/tex" id="MathJax-Element-867">G(9) = 7</script>, as 9 can be expressed as:  3+3+3, 0+3+6, 0+6+3, 3+0+6, 3+6+0, 6+0+3, 6+3+0.<br>
# You are given <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-868-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1000&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;78&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-8998" style="width: 7.61em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.742em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.7em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-8999"><span class="mi" id="MathJax-Span-9000" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-9001" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9002" style="font-family: MathJax_Main;">1000</span><span class="mo" id="MathJax-Span-9003" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9004" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9005" style="font-family: MathJax_Main; padding-left: 0.278em;">78</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>1000</mn><mo stretchy="false">)</mo><mo>=</mo><mn>78</mn></math></span></span><script type="math/tex" id="MathJax-Element-868">G(1000) = 78</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-869-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2106&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9006" style="width: 8.232em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.22em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1006.18em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9007"><span class="mi" id="MathJax-Span-9008" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-9009" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-9010"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-9011" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-9012" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-9013" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9014" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9015" style="font-family: MathJax_Main; padding-left: 0.278em;">2106</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>6</mn></msup><mo stretchy="false">)</mo><mo>=</mo><mn>2106</mn></math></span></span><script type="math/tex" id="MathJax-Element-869">G(10^6) = 2106</script>.</p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-870-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;17&lt;/mn&gt;&lt;mn&gt;526&lt;/mn&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9016" style="width: 8.663em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.555em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1006.46em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9017"><span class="mi" id="MathJax-Span-9018" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-9019" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9020" style="font-family: MathJax_Main;">17</span><span class="mn" id="MathJax-Span-9021" style="font-family: MathJax_Main;">526</span><span class="mo" id="MathJax-Span-9022" style="font-family: MathJax_Main; padding-left: 0.222em;">×</span><span class="msubsup" id="MathJax-Span-9023" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-9024" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-9025" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-9026" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>17</mn><mn>526</mn><mo>×</mo><msup><mn>10</mn><mn>9</mn></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-870">G(17 526 \\times 10^9)</script>.</p>

# %%
submit_answer(answer; prob_num=621);

# %% [markdown]
# ## Problem 622: Riffle Shuffles
# <p>
# A riffle shuffle is executed as follows: a deck of cards is split into
# two equal halves, with the top half taken in the left hand and the
# bottom half taken in the right hand. Next, the cards are interleaved
# exactly, with the top card in the right half inserted just after the top
#  card in the left half, the 2nd card in the right half just after the
# 2nd card in the left half, etc. (Note that this process preserves the
# location of the top and bottom card of the deck)
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-871-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9027" style="width: 2.49em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.866em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.77em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9028"><span class="mi" id="MathJax-Span-9029" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-9030" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9031" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-9032" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-871">s(n)</script> be the minimum number of consecutive riffle shuffles needed to restore a deck of size <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-872-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9033" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9034"><span class="mi" id="MathJax-Span-9035" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-872">n</script> to its original configuration, where <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-873-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9036" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9037"><span class="mi" id="MathJax-Span-9038" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-873">n</script> is a positive even number.</p>
# <p>
# Amazingly, a standard deck of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-874-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;52&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9039" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.91em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9040"><span class="mn" id="MathJax-Span-9041" style="font-family: MathJax_Main;">52</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>52</mn></math></span></span><script type="math/tex" id="MathJax-Element-874">52</script> cards will first return to its original configuration after only <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-875-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9042" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9043"><span class="mn" id="MathJax-Span-9044" style="font-family: MathJax_Main;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-875">8</script> perfect shuffles, so <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-876-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;52&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9045" style="width: 5.313em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.019em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.98em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9046"><span class="mi" id="MathJax-Span-9047" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-9048" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9049" style="font-family: MathJax_Main;">52</span><span class="mo" id="MathJax-Span-9050" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9051" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9052" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mo stretchy="false">(</mo><mn>52</mn><mo stretchy="false">)</mo><mo>=</mo><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-876">s(52) = 8</script>. It can be verified that a deck of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-877-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;86&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9053" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.91em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9054"><span class="mn" id="MathJax-Span-9055" style="font-family: MathJax_Main;">86</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>86</mn></math></span></span><script type="math/tex" id="MathJax-Element-877">86</script> cards will also return to its original configuration after exactly <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-878-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9056" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9057"><span class="mn" id="MathJax-Span-9058" style="font-family: MathJax_Main;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-878">8</script> shuffles, and the sum of all values of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-879-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9059" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9060"><span class="mi" id="MathJax-Span-9061" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-879">n</script> that satisfy <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-880-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9062" style="width: 4.883em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.684em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.64em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9063"><span class="mi" id="MathJax-Span-9064" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-9065" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9066" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-9067" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9068" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9069" style="font-family: MathJax_Main; padding-left: 0.278em;">8</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mn>8</mn></math></span></span><script type="math/tex" id="MathJax-Element-880">s(n) = 8</script> is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-881-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;412&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9070" style="width: 1.916em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.435em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.859em, 1001.38em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9071"><span class="mn" id="MathJax-Span-9072" style="font-family: MathJax_Main;">412</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.02em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>412</mn></math></span></span><script type="math/tex" id="MathJax-Element-881">412</script>.
# </p>
# <p>
# Find the sum of all values of n that satisfy <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-882-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;60&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9073" style="width: 5.505em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.163em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.12em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9074"><span class="mi" id="MathJax-Span-9075" style="font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-9076" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9077" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-9078" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9079" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9080" style="font-family: MathJax_Main; padding-left: 0.278em;">60</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>s</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mn>60</mn></math></span></span><script type="math/tex" id="MathJax-Element-882">s(n) = 60</script>.
# </p>

# %%
submit_answer(answer; prob_num=622);

# %% [markdown]
# ## Problem 623: Lambda Count
# <p>The <i>lambda-calculus</i> is a universal model of computation at the core of functional programming languages. It is based on <i>lambda-terms</i>,
#  a minimal programming language featuring only function definitions,
# function calls and variables. Lambda-terms are built according to the
# following rules:</p>
# <ul><li>Any <i>variable</i> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-883-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9081" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9082"><span class="mi" id="MathJax-Span-9083" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-883">x</script> (single letter, from some infinite alphabet) is a lambda-term.</li>
# <li>If <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-884-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9084" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9085"><span class="mi" id="MathJax-Span-9086" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-884">M</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-885-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9087" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.91em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9088"><span class="mi" id="MathJax-Span-9089" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>N</mi></math></span></span><script type="math/tex" id="MathJax-Element-885">N</script> are lambda-terms, then <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-886-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9090" style="width: 3.543em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.679em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.58em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9091"><span class="mo" id="MathJax-Span-9092" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9093" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mi" id="MathJax-Span-9094" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span><span class="mo" id="MathJax-Span-9095" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>M</mi><mi>N</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-886">(M N)</script> is a lambda-term, called the <i>application</i> of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-887-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9096" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9097"><span class="mi" id="MathJax-Span-9098" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-887">M</script> to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-888-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9099" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.91em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9100"><span class="mi" id="MathJax-Span-9101" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>N</mi></math></span></span><script type="math/tex" id="MathJax-Element-888">N</script>.</li>
# <li>If <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-889-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9102" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9103"><span class="mi" id="MathJax-Span-9104" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-889">x</script> is a variable and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-890-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9105" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9106"><span class="mi" id="MathJax-Span-9107" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-890">M</script> is a term, then <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-891-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9108" style="width: 4.5em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.397em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9109"><span class="mo" id="MathJax-Span-9110" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9111" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9112" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9113" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9114" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-9115" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mi>M</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-891">(\\lambda x. M)</script> is a lambda-term, called an <i>abstraction</i>. An abstraction defines an anonymous function, taking <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-892-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9116" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9117"><span class="mi" id="MathJax-Span-9118" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-892">x</script> as parameter and sending back <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-893-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9119" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9120"><span class="mi" id="MathJax-Span-9121" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-893">M</script>.</li>
# </ul><p>A lambda-term <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-894-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;T&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9122" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.62em, 1000.72em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9123"><span class="mi" id="MathJax-Span-9124" style="font-family: MathJax_Math; font-style: italic;">T<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.12em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.02em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>T</mi></math></span></span><script type="math/tex" id="MathJax-Element-894">T</script> is said to be <i>closed</i> if for all variables <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-895-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9125" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9126"><span class="mi" id="MathJax-Span-9127" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-895">x</script>, all occurrences of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-896-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9128" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9129"><span class="mi" id="MathJax-Span-9130" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-896">x</script> within <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-897-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;T&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9131" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.62em, 1000.72em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9132"><span class="mi" id="MathJax-Span-9133" style="font-family: MathJax_Math; font-style: italic;">T<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.12em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.02em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>T</mi></math></span></span><script type="math/tex" id="MathJax-Element-897">T</script> are contained within some abstraction <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-898-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9134" style="width: 4.5em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.397em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9135"><span class="mo" id="MathJax-Span-9136" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9137" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9138" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9139" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9140" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-9141" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mi>M</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-898">(\\lambda x. M)</script> in <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-899-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;T&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9142" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.62em, 1000.72em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9143"><span class="mi" id="MathJax-Span-9144" style="font-family: MathJax_Math; font-style: italic;">T<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.12em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.02em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>T</mi></math></span></span><script type="math/tex" id="MathJax-Element-899">T</script>. The smallest such abstraction is said to <i>bind</i> the occurrence of the variable <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-900-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9145" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9146"><span class="mi" id="MathJax-Span-9147" style="font-family: MathJax_Math; font-style: italic;">x</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi></math></span></span><script type="math/tex" id="MathJax-Element-900">x</script>.
#  In other words, a lambda-term is closed if all its variables are bound
# to parameters of enclosing functions definitions. For example, the term <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-901-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9148" style="width: 3.878em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9149"><span class="mo" id="MathJax-Span-9150" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9151" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9152" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9153" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9154" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9155" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-901">(\\lambda x. x)</script> is closed, while the term <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-902-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9156" style="width: 5.553em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.211em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.12em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9157"><span class="mo" id="MathJax-Span-9158" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9159" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9160" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9161" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9162" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9163" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9164" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9165" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9166" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mi>y</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-902">(\\lambda x. (x y))</script> is not because <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-903-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9167" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.48em, 2.789em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9168"><span class="mi" id="MathJax-Span-9169" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 0.98em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi></math></span></span><script type="math/tex" id="MathJax-Element-903">y</script> is not bound.</p>
#
# <p>Also, we can rename variables as long as no binding abstraction changes. This means that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-904-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9170" style="width: 3.878em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9171"><span class="mo" id="MathJax-Span-9172" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9173" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9174" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9175" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9176" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9177" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-904">(\\lambda x. x)</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-905-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9178" style="width: 3.687em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.775em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.68em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9179"><span class="mo" id="MathJax-Span-9180" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9181" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9182" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9183" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9184" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9185" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mi>y</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-905">(\\lambda y. y)</script> should be considered equivalent since we merely renamed a parameter. Two terms equivalent modulo such renaming are called <i><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-906-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03B1;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9186" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.59em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9187"><span class="mi" id="MathJax-Span-9188" style="font-family: MathJax_Math; font-style: italic;">α</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>α</mi></math></span></span><script type="math/tex" id="MathJax-Element-906">\\alpha</script>-equivalent</i>. Note that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-907-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9189" style="width: 8.567em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.459em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.36em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9190"><span class="mo" id="MathJax-Span-9191" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9192" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9193" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9194" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9195" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9196" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9197" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9198" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9199" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9200" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9201" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9202" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9203" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9204" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mi>y</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-907">(\\lambda x. (\\lambda y. (x y)))</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-908-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9205" style="width: 8.806em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.651em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.56em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9206"><span class="mo" id="MathJax-Span-9207" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9208" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9209" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9210" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9211" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9212" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9213" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9214" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9215" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9216" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9217" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9218" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9219" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9220" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-908">(\\lambda x. (\\lambda x. (x x)))</script> are not <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-909-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03B1;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9221" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.59em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9222"><span class="mi" id="MathJax-Span-9223" style="font-family: MathJax_Math; font-style: italic;">α</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>α</mi></math></span></span><script type="math/tex" id="MathJax-Element-909">\\alpha</script>-equivalent, since the abstraction binding the first variable was the outer one and becomes the inner one. However, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-910-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9224" style="width: 8.567em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.459em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.36em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9225"><span class="mo" id="MathJax-Span-9226" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9227" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9228" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9229" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9230" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9231" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9232" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9233" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9234" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9235" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9236" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9237" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9238" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9239" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mi>y</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-910">(\\lambda x. (\\lambda y. (x y)))</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-911-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9240" style="width: 8.567em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.459em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.36em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9241"><span class="mo" id="MathJax-Span-9242" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9243" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9244" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9245" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9246" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9247" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9248" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9249" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9250" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9251" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mi" id="MathJax-Span-9252" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9253" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9254" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9255" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>y</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-911">(\\lambda y. (\\lambda x. (y x)))</script> are <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-912-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03B1;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9256" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.59em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9257"><span class="mi" id="MathJax-Span-9258" style="font-family: MathJax_Math; font-style: italic;">α</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>α</mi></math></span></span><script type="math/tex" id="MathJax-Element-912">\\alpha</script>-equivalent.</p>
#
# <p>The following table regroups the lambda-terms that can be written with at most <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-913-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9259" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.91em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9260"><span class="mn" id="MathJax-Span-9261" style="font-family: MathJax_Main;">15</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>15</mn></math></span></span><script type="math/tex" id="MathJax-Element-913">15</script> symbols, symbols being parenthesis, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-914-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9262" style="width: 0.768em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.55em, 2.596em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9263"><span class="mi" id="MathJax-Span-9264" style="font-family: MathJax_Math; font-style: italic;">λ</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.079em; border-left: 0px solid; width: 0px; height: 1.058em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>λ</mi></math></span></span><script type="math/tex" id="MathJax-Element-914">\\lambda</script>, dot and variables.</p>
#
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-915-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML" display="block"&gt;&lt;mtable columnalign="center center center center" rowspacing="4pt" columnspacing="1em" rowlines="solid solid solid solid" columnlines="solid solid solid" frame="solid"&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;.&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;/mtable&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9265" style="width: 42.443em; display: inline-block;"><span style="display: inline-block; position: relative; width: 32.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(-1.833em, 1031.99em, 5.735em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-9266"><span class="mtable" id="MathJax-Span-9267" style="padding-right: 0.167em; padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 31.8em; height: 0px;"><span style="position: absolute; clip: rect(4.031em, 1006.91em, 11.118em, -1000em); top: -7.799em; left: 0.4em;"><span style="display: inline-block; position: relative; width: 7em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1002.85em, 4.413em, -1000em); top: -6.894em; left: 50%; margin-left: -1.475em;"><span class="mtd" id="MathJax-Span-9268"><span class="mrow" id="MathJax-Span-9269"><span class="mo" id="MathJax-Span-9270" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9271" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9272" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9273" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9274" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9275" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1005.55em, 4.413em, -1000em); top: -5.444em; left: 50%; margin-left: -2.825em;"><span class="mtd" id="MathJax-Span-9313"><span class="mrow" id="MathJax-Span-9314"><span class="mo" id="MathJax-Span-9315" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9316" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9317" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9318" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9319" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9320" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9321" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9322" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9323" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9324" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9325" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9326" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.43em, 4.413em, -1000em); top: -3.994em; left: 50%; margin-left: -3.263em;"><span class="mtd" id="MathJax-Span-9373"><span class="mrow" id="MathJax-Span-9374"><span class="mo" id="MathJax-Span-9375" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9376" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9377" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9378" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9379" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9380" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9381" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9382" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9383" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9384" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mi" id="MathJax-Span-9385" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9386" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9387" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9388" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.51em, 4.413em, -1000em); top: -2.544em; left: 50%; margin-left: -3.301em;"><span class="mtd" id="MathJax-Span-9437"><span class="mrow" id="MathJax-Span-9438"><span class="mo" id="MathJax-Span-9439" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9440" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9441" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9442" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9443" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mo" id="MathJax-Span-9444" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9445" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9446" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9447" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9448" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9449" style="font-family: MathJax_Main;">)</span><span class="mi" id="MathJax-Span-9450" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9451" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9452" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.91em, 4.413em, -1000em); top: -1.094em; left: 50%; margin-left: -3.5em;"><span class="mtd" id="MathJax-Span-9502"><span class="mrow" id="MathJax-Span-9503"><span class="mo" id="MathJax-Span-9504" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9505" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9506" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9507" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9508" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9509" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9510" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-9511" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9512" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9513" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9514" style="font-family: MathJax_Main;">)</span><span class="mi" id="MathJax-Span-9515" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9516" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9517" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9518" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 7.799em;"></span></span><span style="position: absolute; clip: rect(4.031em, 1006.91em, 11.118em, -1000em); top: -7.799em; left: 8.4em;"><span style="display: inline-block; position: relative; width: 7em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1004.21em, 4.413em, -1000em); top: -6.894em; left: 50%; margin-left: -2.15em;"><span class="mtd" id="MathJax-Span-9276"><span class="mrow" id="MathJax-Span-9277"><span class="mo" id="MathJax-Span-9278" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9279" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9280" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9281" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9282" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9283" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9284" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9285" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9286" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1005.55em, 4.413em, -1000em); top: -5.444em; left: 50%; margin-left: -2.825em;"><span class="mtd" id="MathJax-Span-9327"><span class="mrow" id="MathJax-Span-9328"><span class="mo" id="MathJax-Span-9329" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9330" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9331" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9332" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9333" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mo" id="MathJax-Span-9334" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9335" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9336" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9337" style="font-family: MathJax_Main;">)</span><span class="mi" id="MathJax-Span-9338" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9339" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9340" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.35em, 4.413em, -1000em); top: -3.994em; left: 50%; margin-left: -3.225em;"><span class="mtd" id="MathJax-Span-9389"><span class="mrow" id="MathJax-Span-9390"><span class="mo" id="MathJax-Span-9391" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9392" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9393" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9394" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9395" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9396" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9397" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9398" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9399" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9400" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mi" id="MathJax-Span-9401" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9402" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9403" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9404" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.43em, 4.413em, -1000em); top: -2.544em; left: 50%; margin-left: -3.263em;"><span class="mtd" id="MathJax-Span-9453"><span class="mrow" id="MathJax-Span-9454"><span class="mo" id="MathJax-Span-9455" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9456" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9457" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9458" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9459" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mo" id="MathJax-Span-9460" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9461" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9462" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9463" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9464" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9465" style="font-family: MathJax_Main;">)</span><span class="mi" id="MathJax-Span-9466" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9467" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9468" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.91em, 4.413em, -1000em); top: -1.094em; left: 50%; margin-left: -3.5em;"><span class="mtd" id="MathJax-Span-9519"><span class="mrow" id="MathJax-Span-9520"><span class="mo" id="MathJax-Span-9521" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9522" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9523" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9524" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9525" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mo" id="MathJax-Span-9526" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9527" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9528" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9529" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9530" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9531" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9532" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9533" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9534" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9535" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 7.799em;"></span></span><span style="position: absolute; clip: rect(4.031em, 1006.91em, 11.118em, -1000em); top: -7.799em; left: 16.4em;"><span style="display: inline-block; position: relative; width: 7em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1005.16em, 4.413em, -1000em); top: -6.894em; left: 50%; margin-left: -2.626em;"><span class="mtd" id="MathJax-Span-9287"><span class="mrow" id="MathJax-Span-9288"><span class="mo" id="MathJax-Span-9289" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9290" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9291" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9292" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9293" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9294" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9295" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9296" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9297" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9298" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9299" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.51em, 4.413em, -1000em); top: -5.444em; left: 50%; margin-left: -3.301em;"><span class="mtd" id="MathJax-Span-9341"><span class="mrow" id="MathJax-Span-9342"><span class="mo" id="MathJax-Span-9343" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9344" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9345" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9346" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9347" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9348" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9349" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9350" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9351" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9352" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9353" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9354" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9355" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9356" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.51em, 4.413em, -1000em); top: -3.994em; left: 50%; margin-left: -3.301em;"><span class="mtd" id="MathJax-Span-9405"><span class="mrow" id="MathJax-Span-9406"><span class="mo" id="MathJax-Span-9407" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9408" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9409" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9410" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9411" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9412" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9413" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9414" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9415" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9416" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9417" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9418" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9419" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9420" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.58em, 4.413em, -1000em); top: -2.544em; left: 50%; margin-left: -3.339em;"><span class="mtd" id="MathJax-Span-9469"><span class="mrow" id="MathJax-Span-9470"><span class="mo" id="MathJax-Span-9471" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-9472" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9473" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9474" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9475" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9476" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9477" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9478" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9479" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9480" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9481" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9482" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">x</span><span class="mo" id="MathJax-Span-9483" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9484" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.91em, 4.413em, -1000em); top: -1.094em; left: 50%; margin-left: -3.5em;"><span class="mtd" id="MathJax-Span-9536"><span class="mrow" id="MathJax-Span-9537"><span class="mo" id="MathJax-Span-9538" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9539" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9540" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9541" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9542" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mo" id="MathJax-Span-9543" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9544" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9545" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9546" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9547" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9548" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9549" style="font-family: MathJax_Main;">)</span><span class="mi" id="MathJax-Span-9550" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9551" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9552" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 7.799em;"></span></span><span style="position: absolute; clip: rect(4.031em, 1006.91em, 11.118em, -1000em); top: -7.799em; left: 24.4em;"><span style="display: inline-block; position: relative; width: 7em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1005.08em, 4.413em, -1000em); top: -6.894em; left: 50%; margin-left: -2.588em;"><span class="mtd" id="MathJax-Span-9300"><span class="mrow" id="MathJax-Span-9301"><span class="mo" id="MathJax-Span-9302" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9303" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9304" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9305" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9306" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9307" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9308" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9309" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9310" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9311" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9312" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.43em, 4.413em, -1000em); top: -5.444em; left: 50%; margin-left: -3.263em;"><span class="mtd" id="MathJax-Span-9357"><span class="mrow" id="MathJax-Span-9358"><span class="mo" id="MathJax-Span-9359" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9360" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9361" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9362" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9363" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9364" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9365" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9366" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9367" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9368" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9369" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9370" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9371" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9372" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.43em, 4.413em, -1000em); top: -3.994em; left: 50%; margin-left: -3.263em;"><span class="mtd" id="MathJax-Span-9421"><span class="mrow" id="MathJax-Span-9422"><span class="mo" id="MathJax-Span-9423" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9424" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9425" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9426" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9427" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9428" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9429" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9430" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9431" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9432" style="font-family: MathJax_Main;">.</span><span class="mi" id="MathJax-Span-9433" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-9434" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9435" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9436" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.91em, 4.413em, -1000em); top: -2.544em; left: 50%; margin-left: -3.5em;"><span class="mtd" id="MathJax-Span-9485"><span class="mrow" id="MathJax-Span-9486"><span class="mo" id="MathJax-Span-9487" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9488" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9489" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9490" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9491" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mi" id="MathJax-Span-9492" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9493" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9494" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9495" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9496" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9497" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9498" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9499" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9500" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9501" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1006.91em, 4.413em, -1000em); top: -1.094em; left: 50%; margin-left: -3.5em;"><span class="mtd" id="MathJax-Span-9553"><span class="mrow" id="MathJax-Span-9554"><span class="mo" id="MathJax-Span-9555" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9556" style="font-family: MathJax_Math; font-style: italic;">λ</span><span class="mi" id="MathJax-Span-9557" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9558" style="font-family: MathJax_Main;">.</span><span class="mo" id="MathJax-Span-9559" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mo" id="MathJax-Span-9560" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-9561" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9562" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mi" id="MathJax-Span-9563" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9564" style="font-family: MathJax_Main;">)</span><span class="mi" id="MathJax-Span-9565" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9566" style="font-family: MathJax_Main;">)</span><span class="mi" id="MathJax-Span-9567" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-9568" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9569" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 7.799em;"></span></span><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-left: 1.3px solid; width: 0px; height: 7.281em; position: absolute; top: -3.89em; left: 7.9em; border-style: solid;"></span><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-left: 1.3px solid; width: 0px; height: 7.281em; position: absolute; top: -3.89em; left: 15.9em; border-style: solid;"></span><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-left: 1.3px solid; width: 0px; height: 7.281em; position: absolute; top: -3.89em; left: 23.9em; border-style: solid;"></span><span style="border: 1.3px solid; display: inline-block; overflow: hidden; width: 31.68em; height: 7.161em; vertical-align: -0.06em; position: absolute; top: -3.89em; left: 0em;"></span><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 31.8em; height: 0px; position: absolute; top: -2.485em; left: 0em;"></span><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 31.8em; height: 0px; position: absolute; top: -1.035em; left: 0em;"></span><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 31.8em; height: 0px; position: absolute; top: 0.415em; left: 0em;"></span><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 31.8em; height: 0px; position: absolute; top: 1.865em; left: 0em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -4.538em; border-left: 0px solid; width: 0px; height: 9.737em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><mtable columnalign="center center center center" rowspacing="4pt" columnspacing="1em" rowlines="solid solid solid solid" columnlines="solid solid solid" frame="solid"><mtr><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mi>y</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd></mtr><mtr><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mi>y</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd></mtr><mtr><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mo stretchy="false">(</mo><mi>y</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mo stretchy="false">(</mo><mi>y</mi><mi>y</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mi>y</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd></mtr><mtr><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>y</mi><mo>.</mo><mi>y</mi><mo stretchy="false">)</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd></mtr><mtr><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>x</mi><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mo stretchy="false">(</mo><mi>λ</mi><mi>x</mi><mo>.</mo><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mo stretchy="false">(</mo><mi>x</mi><mi>x</mi><mo stretchy="false">)</mo><mi>x</mi><mo stretchy="false">)</mo><mi>x</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd></mtr></mtable></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-915">\\begin{array}{|c|c|c|c|}
# \\hline
# (\\lambda x.x) & (\\lambda x.(x x)) & (\\lambda x.(\\lambda y.x)) & (\\lambda x.(\\lambda y.y)) \\\
# \\hline
# (\\lambda x.(x (x x))) & (\\lambda x.((x x) x)) & (\\lambda x.(\\lambda y.(x x))) & (\\lambda x.(\\lambda y.(x y))) \\\
# \\hline
# (\\lambda x.(\\lambda y.(y x))) & (\\lambda x.(\\lambda y.(y y))) & (\\lambda x.(x (\\lambda y.x))) & (\\lambda x.(x (\\lambda y.y))) \\\
# \\hline
# (\\lambda x.((\\lambda y.x) x)) & (\\lambda x.((\\lambda y.y) x)) & ((\\lambda x.x) (\\lambda x.x)) & (\\lambda x.(x (x (x x)))) \\\
# \\hline
# (\\lambda x.(x ((x x) x))) & (\\lambda x.((x x) (x x))) & (\\lambda x.((x (x x)) x)) & (\\lambda x.(((x x) x) x)) \\\
# \\hline
# \\end{array}</script>
#
# <p>Let be <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-916-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x039B;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9570" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9571"><span class="mi" id="MathJax-Span-9572" style="font-family: MathJax_Main;">Λ</span><span class="mo" id="MathJax-Span-9573" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9574" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-9575" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi mathvariant="normal">Λ</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-916">\\Lambda(n)</script> the number of distinct closed lambda-terms that can be written using at most <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-917-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9576" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9577"><span class="mi" id="MathJax-Span-9578" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-917">n</script> symbols, where terms that are <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-918-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03B1;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9579" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.59em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9580"><span class="mi" id="MathJax-Span-9581" style="font-family: MathJax_Math; font-style: italic;">α</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>α</mi></math></span></span><script type="math/tex" id="MathJax-Element-918">\\alpha</script>-equivalent to one another should be counted only once. You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-919-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x039B;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9582" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.71em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9583"><span class="mi" id="MathJax-Span-9584" style="font-family: MathJax_Main;">Λ</span><span class="mo" id="MathJax-Span-9585" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9586" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-9587" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9588" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9589" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi mathvariant="normal">Λ</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-919">\\Lambda(6) = 1</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-920-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x039B;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9590" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9591"><span class="mi" id="MathJax-Span-9592" style="font-family: MathJax_Main;">Λ</span><span class="mo" id="MathJax-Span-9593" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9594" style="font-family: MathJax_Main;">9</span><span class="mo" id="MathJax-Span-9595" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9596" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9597" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi mathvariant="normal">Λ</mi><mo stretchy="false">(</mo><mn>9</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-920">\\Lambda(9) = 2</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-921-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x039B;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;20&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9598" style="width: 6.27em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.737em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.7em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9599"><span class="mi" id="MathJax-Span-9600" style="font-family: MathJax_Main;">Λ</span><span class="mo" id="MathJax-Span-9601" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9602" style="font-family: MathJax_Main;">15</span><span class="mo" id="MathJax-Span-9603" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9604" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9605" style="font-family: MathJax_Main; padding-left: 0.278em;">20</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi mathvariant="normal">Λ</mi><mo stretchy="false">(</mo><mn>15</mn><mo stretchy="false">)</mo><mo>=</mo><mn>20</mn></math></span></span><script type="math/tex" id="MathJax-Element-921">\\Lambda(15) = 20</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-922-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x039B;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;35&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3166438&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9606" style="width: 9.428em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.129em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.09em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9607"><span class="mi" id="MathJax-Span-9608" style="font-family: MathJax_Main;">Λ</span><span class="mo" id="MathJax-Span-9609" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9610" style="font-family: MathJax_Main;">35</span><span class="mo" id="MathJax-Span-9611" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9612" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9613" style="font-family: MathJax_Main; padding-left: 0.278em;">3166438</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi mathvariant="normal">Λ</mi><mo stretchy="false">(</mo><mn>35</mn><mo stretchy="false">)</mo><mo>=</mo><mn>3166438</mn></math></span></span><script type="math/tex" id="MathJax-Element-922">\\Lambda(35) = 3166438</script>.</p>
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-923-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x039B;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2000&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9614" style="width: 4.5em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.397em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9615"><span class="mi" id="MathJax-Span-9616" style="font-family: MathJax_Main;">Λ</span><span class="mo" id="MathJax-Span-9617" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9618" style="font-family: MathJax_Main;">2000</span><span class="mo" id="MathJax-Span-9619" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi mathvariant="normal">Λ</mi><mo stretchy="false">(</mo><mn>2000</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-923">\\Lambda(2000)</script>. Give the answer modulo <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-924-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mn&gt;000&lt;/mn&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mn&gt;000&lt;/mn&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mn&gt;007&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9620" style="width: 6.988em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.263em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.86em, 1005.25em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9621"><span class="mn" id="MathJax-Span-9622" style="font-family: MathJax_Main;">1</span><span class="mspace" id="MathJax-Span-9623" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-9624" style="font-family: MathJax_Main;">000</span><span class="mspace" id="MathJax-Span-9625" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-9626" style="font-family: MathJax_Main;">000</span><span class="mspace" id="MathJax-Span-9627" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-9628" style="font-family: MathJax_Main;">007</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.048em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn><mspace width="thinmathspace"></mspace><mn>000</mn><mspace width="thinmathspace"></mspace><mn>000</mn><mspace width="thinmathspace"></mspace><mn>007</mn></math></span></span><script type="math/tex" id="MathJax-Element-924">1\\,000\\,000\\,007</script>.</p>

# %%
submit_answer(answer; prob_num=623);

# %% [markdown]
# ## Problem 624: Two heads are better than one
# <p>
# An unbiased coin is tossed repeatedly until two consecutive heads are obtained. Suppose these occur on the <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-925-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9629" style="width: 4.644em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.493em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.4em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9630"><span class="mo" id="MathJax-Span-9631" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9632" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-9633" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-9634" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-9635" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>M</mi><mo>−</mo><mn>1</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-925">(M-1)</script>th and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-926-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9636" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9637"><span class="mi" id="MathJax-Span-9638" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-926">M</script>th toss.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-927-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9639" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9640"><span class="mi" id="MathJax-Span-9641" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9642" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9643" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-9644" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-927">P(n)</script> be the probability that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-928-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9645" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9646"><span class="mi" id="MathJax-Span-9647" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-928">M</script> is divisible by <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-929-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9648" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9649"><span class="mi" id="MathJax-Span-9650" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-929">n</script>. For example, the outcomes HH, HTHH, and THTTHH all count towards <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-930-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9651" style="width: 2.586em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.962em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.87em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9652"><span class="mi" id="MathJax-Span-9653" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9654" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9655" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-9656" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-930">P(2)</script>, but THH and HTTHH do not.</p>
# <p>
# You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-931-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9657" style="width: 5.313em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.019em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1004.02em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9658"><span class="mi" id="MathJax-Span-9659" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9660" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9661" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-9662" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9663" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-9664" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-9665" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-9666" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.805em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>=</mo><mfrac><mn>3</mn><mn>5</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-931">P(2) =\\frac 3 5</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-932-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mn&gt;31&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9667" style="width: 5.744em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.354em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1004.35em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9668"><span class="mi" id="MathJax-Span-9669" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9670" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9671" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-9672" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9673" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-9674" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.827em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-9675" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.66em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.354em;"><span class="mn" id="MathJax-Span-9676" style="font-size: 70.7%; font-family: MathJax_Main;">31</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.83em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.827em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.806em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mfrac><mn>9</mn><mn>31</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-932">P(3)=\\frac 9  {31}</script>. Indeed, it can be shown that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-933-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9677" style="width: 2.778em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.01em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9678"><span class="mi" id="MathJax-Span-9679" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9680" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9681" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-9682" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>P</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-933">P(n)</script> is always a rational number.</p>
# <p>
# For a prime <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-934-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9683" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9684"><span class="mi" id="MathJax-Span-9685" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-934">p</script> and a fully reduced fraction <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-935-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9686" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.339em, 1000.72em, 2.743em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-9687"><span class="mfrac" id="MathJax-Span-9688"><span style="display: inline-block; position: relative; width: 0.494em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.426em; left: 50%; margin-left: -0.187em;"><span class="mi" id="MathJax-Span-9689" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.152em;"><span class="mi" id="MathJax-Span-9690" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.494em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.601em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mi>a</mi><mi>b</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-935">\\frac a b</script>, define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-936-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mfrac&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/mfrac&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9691" style="width: 4.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.301em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.21em, 3.221em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9692"><span class="mi" id="MathJax-Span-9693" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-9694" style="font-family: MathJax_Main;">(</span><span class="mfrac" id="MathJax-Span-9695"><span style="display: inline-block; position: relative; width: 0.494em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.426em; left: 50%; margin-left: -0.187em;"><span class="mi" id="MathJax-Span-9696" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.152em;"><span class="mi" id="MathJax-Span-9697" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.494em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-9698" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-9699" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-9700" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.642em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mfrac><mi>a</mi><mi>b</mi></mfrac><mo>,</mo><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-936">Q(\\frac a b,p)</script> to be the smallest positive <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-937-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9701" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-9702"><span class="mi" id="MathJax-Span-9703" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-937">q</script> for which <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-938-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;#x2261;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mspace width="0.444em" /&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;mod&lt;/mi&gt;&lt;mspace width="0.333em" /&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9704" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.75em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9705"><span class="mi" id="MathJax-Span-9706" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-9707" style="font-family: MathJax_Main; padding-left: 0.278em;">≡</span><span class="mi" id="MathJax-Span-9708" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">b</span><span class="mi" id="MathJax-Span-9709" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span class="TeXmathchoice" id="MathJax-Span-9710"><span class="mspace" id="MathJax-Span-9711" style="height: 0em; vertical-align: 0em; width: 0.444em; display: inline-block; overflow: hidden;"></span></span><span class="mo" id="MathJax-Span-9712" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9713" style="font-family: MathJax_Main;">mod</span><span class="mspace" id="MathJax-Span-9714" style="height: 0em; vertical-align: 0em; width: 0.333em; display: inline-block; overflow: hidden;"></span><span class="mi" id="MathJax-Span-9715" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">p</span><span class="mo" id="MathJax-Span-9716" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi><mo>≡</mo><mi>b</mi><mi>q</mi><mspace width="0.444em"></mspace><mo stretchy="false">(</mo><mi>mod</mi><mspace width="0.333em"></mspace><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-938">a \\equiv b q \\pmod{p}</script>.<br>
# For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-939-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;109&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/mfrac&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;109&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;66&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9717" style="width: 17.467em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.206em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1013.16em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9718"><span class="mi" id="MathJax-Span-9719" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-9720" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9721" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9722" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9723" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-9724" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9725" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-9726" style="font-family: MathJax_Main; padding-left: 0.167em;">109</span><span class="mo" id="MathJax-Span-9727" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9728" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-9729" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">Q</span><span class="mo" id="MathJax-Span-9730" style="font-family: MathJax_Main;">(</span><span class="mfrac" id="MathJax-Span-9731"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-9732" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-9733" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-9734" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-9735" style="font-family: MathJax_Main; padding-left: 0.167em;">109</span><span class="mo" id="MathJax-Span-9736" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9737" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9738" style="font-family: MathJax_Main; padding-left: 0.278em;">66</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.805em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mi>P</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>,</mo><mn>109</mn><mo stretchy="false">)</mo><mo>=</mo><mi>Q</mi><mo stretchy="false">(</mo><mfrac><mn>3</mn><mn>5</mn></mfrac><mo>,</mo><mn>109</mn><mo stretchy="false">)</mo><mo>=</mo><mn>66</mn></math></span></span><script type="math/tex" id="MathJax-Element-939">Q(P(2), 109) = Q(\\frac 3 5, 109) = 66</script>, because <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-940-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;66&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;330&lt;/mn&gt;&lt;mo&gt;&amp;#x2261;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mspace width="0.444em" /&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;mod&lt;/mi&gt;&lt;mspace width="0.333em" /&gt;&lt;mn&gt;109&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9739" style="width: 15.505em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.722em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1011.63em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9740"><span class="mn" id="MathJax-Span-9741" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-9742" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-9743" style="font-family: MathJax_Main; padding-left: 0.222em;">66</span><span class="mo" id="MathJax-Span-9744" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9745" style="font-family: MathJax_Main; padding-left: 0.278em;">330</span><span class="mo" id="MathJax-Span-9746" style="font-family: MathJax_Main; padding-left: 0.278em;">≡</span><span class="mn" id="MathJax-Span-9747" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span><span class="TeXmathchoice" id="MathJax-Span-9748"><span class="mspace" id="MathJax-Span-9749" style="height: 0em; vertical-align: 0em; width: 0.444em; display: inline-block; overflow: hidden;"></span></span><span class="mo" id="MathJax-Span-9750" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9751" style="font-family: MathJax_Main;">mod</span><span class="mspace" id="MathJax-Span-9752" style="height: 0em; vertical-align: 0em; width: 0.333em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-9753" style="font-family: MathJax_Main; padding-left: 0.167em;">109</span><span class="mo" id="MathJax-Span-9754" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>5</mn><mo>⋅</mo><mn>66</mn><mo>=</mo><mn>330</mn><mo>≡</mo><mn>3</mn><mspace width="0.444em"></mspace><mo stretchy="false">(</mo><mi>mod</mi><mspace width="0.333em"></mspace><mn>109</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-940">5 \\cdot 66 = 330 \\equiv 3 \\pmod{109}</script> and 66 is the smallest positive such number.<br>
# Similarly <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-941-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;109&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;46&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9755" style="width: 10.194em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.703em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.66em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9756"><span class="mi" id="MathJax-Span-9757" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-9758" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9759" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9760" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9761" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-9762" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9763" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-9764" style="font-family: MathJax_Main; padding-left: 0.167em;">109</span><span class="mo" id="MathJax-Span-9765" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9766" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9767" style="font-family: MathJax_Main; padding-left: 0.278em;">46</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mi>P</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>,</mo><mn>109</mn><mo stretchy="false">)</mo><mo>=</mo><mn>46</mn></math></span></span><script type="math/tex" id="MathJax-Element-941">Q(P(3),109) = 46</script>.</p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-942-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;18&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mn&gt;000&lt;/mn&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mn&gt;000&lt;/mn&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mn&gt;009&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9768" style="width: 13.974em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.574em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1010.48em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9769"><span class="mi" id="MathJax-Span-9770" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-9771" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9772" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-9773" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-9774"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-9775" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-9776"><span class="mrow" id="MathJax-Span-9777"><span class="mn" id="MathJax-Span-9778" style="font-size: 70.7%; font-family: MathJax_Main;">18</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-9779" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9780" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-9781" style="font-family: MathJax_Main; padding-left: 0.167em;">1</span><span class="mspace" id="MathJax-Span-9782" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-9783" style="font-family: MathJax_Main;">000</span><span class="mspace" id="MathJax-Span-9784" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-9785" style="font-family: MathJax_Main;">000</span><span class="mspace" id="MathJax-Span-9786" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mn" id="MathJax-Span-9787" style="font-family: MathJax_Main;">009</span><span class="mo" id="MathJax-Span-9788" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mi>P</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>18</mn></mrow></msup><mo stretchy="false">)</mo><mo>,</mo><mn>1</mn><mspace width="thinmathspace"></mspace><mn>000</mn><mspace width="thinmathspace"></mspace><mn>000</mn><mspace width="thinmathspace"></mspace><mn>009</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-942">Q(P(10^{18}),1\\,000\\,000\\,009)</script>.</p>

# %%
submit_answer(answer; prob_num=624);

# %% [markdown]
# ## Problem 625: Gcd sum
# <p>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-943-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/munderover&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/munderover&gt;&lt;mtext&gt;gcd&lt;/mtext&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9789" style="width: 16.079em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.576em, 1012.06em, 3.253em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9790"><span class="mi" id="MathJax-Span-9791" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-9792" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9793" style="font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.085em;"></span></span><span class="mo" id="MathJax-Span-9794" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9795" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-9796" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.326em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-9797" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.393em, 1000.7em, 4.163em, -1000em); top: -4.496em; left: 1.056em;"><span class="mi" id="MathJax-Span-9798" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">N<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.27em, 4.307em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-9799"><span class="mrow" id="MathJax-Span-9800"><span class="mi" id="MathJax-Span-9801" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">j</span><span class="mo" id="MathJax-Span-9802" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-9803" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="munderover" id="MathJax-Span-9804" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 2.279em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-9805" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.408em, 1000.37em, 4.307em, -1000em); top: -4.508em; left: 1.056em;"><span class="mi" id="MathJax-Span-9806" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">j</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.22em, 4.17em, -1000em); top: -3.713em; left: 1.056em;"><span class="texatom" id="MathJax-Span-9807"><span class="mrow" id="MathJax-Span-9808"><span class="mi" id="MathJax-Span-9809" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-9810" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-9811" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mtext" id="MathJax-Span-9812" style="font-family: MathJax_Main; padding-left: 0.167em;">gcd</span><span class="mo" id="MathJax-Span-9813" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-9814" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-9815" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-9816" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">j</span><span class="mo" id="MathJax-Span-9817" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.63em; border-left: 0px solid; width: 0px; height: 1.961em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mi>N</mi><mo stretchy="false">)</mo><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>j</mi><mo>=</mo><mn>1</mn></mrow><mi>N</mi></munderover><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mi>j</mi></munderover><mtext>gcd</mtext><mo stretchy="false">(</mo><mi>i</mi><mo>,</mo><mi>j</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-943">G(N)=\\sum_{j=1}^N\\sum_{i=1}^j \\text{gcd}(i,j)</script>. <br>
# You are given: <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-944-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;122&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9818" style="width: 6.988em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.263em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.21em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9819"><span class="mi" id="MathJax-Span-9820" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-9821" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-9822" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-9823" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-9824" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-9825" style="font-family: MathJax_Main; padding-left: 0.278em;">122</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>122</mn></math></span></span><script type="math/tex" id="MathJax-Element-944">G(10)=122</script>.</p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-945-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-9826" style="width: 4.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.301em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.21em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-9827"><span class="mi" id="MathJax-Span-9828" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-9829" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-9830"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-9831" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-9832"><span class="mrow" id="MathJax-Span-9833"><span class="mn" id="MathJax-Span-9834" style="font-size: 70.7%; font-family: MathJax_Main;">11</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-9835" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>11</mn></mrow></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-945">G(10^{11})</script>. Give your answer modulo 998244353
# </p>

# %%
submit_answer(answer; prob_num=625);
