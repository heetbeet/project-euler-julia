# %%
include("shared.jl");

# %% [markdown]
# ## Problem 551: Sum of digits sequence
# <p>Let <var>a</var><sub>0</sub>, <var>a</var><sub>1</sub>, <var>a</var><sub>2</sub>, ... be an integer sequence defined by:</p>
# <ul><li><var>a</var><sub>0</sub> = 1;</li>
# <li>for <var>n</var> ≥ 1, <var>a<sub>n</sub></var> is the sum of the digits of all preceding terms.</li>
# </ul><p>The sequence starts with 1, 1, 2, 4, 8, 16, 23, 28, 38, 49, ...<br>
# You are given <var>a</var><sub>10<sup>6</sup></sub>&nbsp;=&nbsp;31054319.</p>
# <p>Find <var>a</var><sub>10<sup>15</sup></sub>.</p>

# %%
submit_answer(answer; prob_num=551);

# %% [markdown]
# ## Problem 552: Chinese leftovers II
# <p>
# Let <var>A<sub>n</sub></var> be the smallest positive integer satisfying  <var>A<sub>n</sub></var> mod <var>p<sub>i</sub></var> = <var>i</var>  for all 1 ≤ <var>i</var> ≤ <var>n</var>, where <var>p<sub>i</sub></var> is the
# <var>i</var>-th prime.
# <br>For example <var>A</var><sub>2</sub> = 5, since this is the smallest positive solution of the system of equations </p>
# <ul style="list-style-type:none;margin-left:2cm;"><li> <var>A</var><sub>2</sub> mod 2 = 1 </li>
# <li> <var>A</var><sub>2</sub> mod 3 = 2</li></ul><p>
# The system of equations for <var>A</var><sub>3</sub> adds another constraint. That is, <var>A</var><sub>3</sub> is the smallest positive solution of</p>
# <ul style="list-style-type:none;margin-left:2cm;"><li> <var>A</var><sub>3</sub> mod 2 = 1 </li>
# <li> <var>A</var><sub>3</sub> mod 3 = 2</li>
# <li> <var>A</var><sub>3</sub> mod 5 = 3</li></ul><p>
# and hence <var>A</var><sub>3</sub> = 23. Similarly, one gets <var>A</var><sub>4</sub> = 53 and <var>A</var><sub>5</sub> = 1523.
# </p>
# <p>
# Let S(<var>n</var>) be the sum of all primes up to <var>n</var> that divide at least one element in the sequence <var>A</var>.
# <br>For example, S(50) = 69 = 5 + 23 + 41, since 5 divides <var>A</var><sub>2</sub>, 23 divides <var>A</var><sub>3</sub> and 41 divides <var>A</var><sub>10</sub> = 5765999453. No other prime number up to 50 divides an element in <var>A</var>.
# </p>
# <p>
# Find S(300000).</p>

# %%
submit_answer(answer; prob_num=552);

# %% [markdown]
# ## Problem 553: Power sets of power sets
# <p>Let <var>P</var>(<var>n</var>) be the set of the first <var>n</var> positive integers {1, 2, ..., <var>n</var>}.<br>
# Let Q(<var>n</var>) be the set of all the non-empty subsets of <var>P</var>(<var>n</var>).<br>
# Let R(<var>n</var>) be the set of all the non-empty subsets of <var>Q</var>(<var>n</var>).</p>
#
# <p>An element <var>X</var>&nbsp;∈&nbsp;<var>R</var>(<var>n</var>) is a non-empty subset of <var>Q</var>(<var>n</var>), so it is itself a set.<br>
# From <var>X</var> we can construct a graph as follows:</p>
#
# <ul><li>Each element <var>Y</var>&nbsp;∈&nbsp;<var>X</var> corresponds to a vertex and labeled with <var>Y</var>;</li>
# <li>Two vertices <var>Y</var><sub>1</sub> and <var>Y</var><sub>2</sub> are connected if <var>Y</var><sub>1</sub>&nbsp;∩&nbsp;<var>Y</var><sub>2</sub>&nbsp;≠&nbsp;∅.</li>
# </ul><p>For example, <var>X</var>&nbsp;=&nbsp;{{1},&nbsp;{1,2,3},&nbsp;{3},&nbsp;{5,6},&nbsp;{6,7}} results in the following graph:</p>
#
# <div align="center"><img src="webfiles/p553-power-sets.gif" alt="p553-power-sets.gif"></div>
#
# <p>This graph has two <b>connected components</b>.</p>
#
# <p>Let <var>C</var>(<var>n</var>,<var>k</var>) be the number of elements of <var>R</var>(<var>n</var>) that have exactly <var>k</var> connected components in their graph.<br>
# You are given <var>C</var>(2,1)&nbsp;=&nbsp;6, <var>C</var>(3,1)&nbsp;=&nbsp;111, <var>C</var>(4,2)&nbsp;=&nbsp;486, <var>C</var>(100,10)&nbsp;mod&nbsp;1&nbsp;000&nbsp;000&nbsp;007&nbsp;=&nbsp;728209718.</p>
#
# <p>Find <var>C</var>(10<sup>4</sup>,10)&nbsp;mod&nbsp;1&nbsp;000&nbsp;000&nbsp;007.</p>

# %%
submit_answer(answer; prob_num=553);

# %% [markdown]
# ## Problem 554: Centaurs on a chess board
# <p>On
#  a chess board, a centaur moves like a king or a knight. The diagram
# below shows the valid moves of a centaur (represented by an inverted
# king) on an 8x8 board.</p>
#
# <div align="center"><img src="webfiles/p554-centaurs.png" alt="p554-centaurs.png"></div>
#
# <p>It can be shown that at most <var>n</var><sup>2</sup> non-attacking centaurs can be placed on a board of size 2<var>n</var>×2<var>n</var>.<br>
# Let <var>C</var>(<var>n</var>) be the number of ways to place <var>n</var><sup>2</sup> centaurs on a 2<var>n</var>×2<var>n</var> board so that no centaur attacks another directly.<br>
# For example <var>C</var>(1)&nbsp;=&nbsp;4, <var>C</var>(2)&nbsp;=&nbsp;25, <var>C</var>(10)&nbsp;=&nbsp;1477721.</p>
#
# <p>Let <var>F<sub>i</sub></var> be the <var>i</var><sup>th</sup> Fibonacci number defined as <var>F</var><sub>1</sub>&nbsp;=&nbsp;<var>F</var><sub>2</sub>&nbsp;=&nbsp;1 and <var>F</var><sub>i</sub>&nbsp;=&nbsp;<var>F</var><sub><var>i</var>-1</sub>&nbsp;+&nbsp;<var>F</var><sub><var>i</var>-2</sub> for <var>i</var>&nbsp;&gt;&nbsp;2.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-179-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;mrow&gt;&lt;mo&gt;(&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;90&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;C&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;mtext&gt;mod&amp;#xA0;&lt;/mtext&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3301" style="width: 15.696em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.866em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(2.652em, 1011.77em, 5.938em, -1000em); top: -4.545em; left: 0em;"><span class="mrow" id="MathJax-Span-3302"><span class="mstyle" id="MathJax-Span-3303"><span class="mrow" id="MathJax-Span-3304"><span class="mrow" id="MathJax-Span-3305"><span class="mo" id="MathJax-Span-3306" style="vertical-align: 0em;"><span style="font-family: MathJax_Size4;">(</span></span><span class="munderover" id="MathJax-Span-3307"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-3308" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.11em, 4.27em, -1000em); top: -2.932em; left: 0.148em;"><span class="texatom" id="MathJax-Span-3309"><span class="mrow" id="MathJax-Span-3310"><span class="mi" id="MathJax-Span-3311" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-3312" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-3313" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.305em, 1000.68em, 4.178em, -1000em); top: -5.169em; left: 0.368em;"><span class="texatom" id="MathJax-Span-3314"><span class="mrow" id="MathJax-Span-3315"><span class="mn" id="MathJax-Span-3316" style="font-size: 70.7%; font-family: MathJax_Main;">90</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3317" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">C<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.045em;"></span></span><span class="mo" id="MathJax-Span-3318" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3319"><span style="display: inline-block; position: relative; width: 0.962em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3320" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="mi" id="MathJax-Span-3321" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3322" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3323" style="vertical-align: 0em;"><span style="font-family: MathJax_Size4;">)</span></span></span><span class="mtext" id="MathJax-Span-3324" style="font-family: MathJax_Main; padding-left: 0.167em;">mod&nbsp;</span><span class="mo" id="MathJax-Span-3325" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3326"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-3327" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.432em; left: 1em;"><span class="mn" id="MathJax-Span-3328" style="font-size: 70.7%; font-family: MathJax_Main;">8</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3329" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-3330" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span><span class="mo" id="MathJax-Span-3331" style="font-family: MathJax_Main;">)</span></span></span></span><span style="display: inline-block; width: 0px; height: 4.545em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.712em; border-left: 0px solid; width: 0px; height: 4.085em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><mrow><mo>(</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>2</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>90</mn></mrow></munderover><mi>C</mi><mo stretchy="false">(</mo><msub><mi>F</mi><mi>i</mi></msub><mo stretchy="false">)</mo><mo>)</mo></mrow><mtext>mod&nbsp;</mtext><mo stretchy="false">(</mo><msup><mn>10</mn><mn>8</mn></msup><mo>+</mo><mn>7</mn><mo stretchy="false">)</mo></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-179">\\displaystyle \\left( \\sum_{i=2}^{90} C(F_i) \\right) \\text{mod } (10^8+7)</script>.</p>

# %%
submit_answer(answer; prob_num=554);

# %% [markdown]
# ## Problem 555: McCarthy 91 function
# <p>
# The McCarthy 91 function is defined as follows:
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span></p><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-180-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML" display="block"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;91&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mrow&gt;&lt;mo&gt;{&lt;/mo&gt;&lt;mtable columnalign="left left" rowspacing=".2em" columnspacing="1em" displaystyle="false"&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mtext&gt;if&amp;#xA0;&lt;/mtext&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;91&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;91&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mtext&gt;if&amp;#xA0;&lt;/mtext&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;/mtable&gt;&lt;mo fence="true" stretchy="true" symmetric="true"&gt;&lt;/mo&gt;&lt;/mrow&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3332" style="width: 27.132em; display: inline-block;"><span style="display: inline-block; position: relative; width: 20.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(2.33em, 1020.53em, 5.016em, -1000em); top: -3.923em; left: 0em;"><span class="mrow" id="MathJax-Span-3333"><span class="msubsup" id="MathJax-Span-3334"><span style="display: inline-block; position: relative; width: 1.752em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3335" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3336"><span class="mrow" id="MathJax-Span-3337"><span class="mn" id="MathJax-Span-3338" style="font-size: 70.7%; font-family: MathJax_Main;">91</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3339" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3340" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3341" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3342" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mrow" id="MathJax-Span-3343" style="padding-left: 0.278em;"><span class="mo" id="MathJax-Span-3344" style="vertical-align: 0em;"><span style="font-family: MathJax_Size3;">{</span></span><span class="mtable" id="MathJax-Span-3345" style="padding-right: 0.167em; padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 14.984em; height: 0px;"><span style="position: absolute; clip: rect(2.635em, 1007.79em, 5.038em, -1000em); top: -4.019em; left: 0em;"><span style="display: inline-block; position: relative; width: 7.882em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1002.78em, 4.245em, -1000em); top: -4.594em; left: 0em;"><span class="mtd" id="MathJax-Span-3346"><span class="mrow" id="MathJax-Span-3347"><span class="mi" id="MathJax-Span-3348" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3349" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-3350" style="font-family: MathJax_Main; padding-left: 0.222em;">10</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1007.79em, 4.413em, -1000em); top: -3.394em; left: 0em;"><span class="mtd" id="MathJax-Span-3357"><span class="mrow" id="MathJax-Span-3358"><span class="msubsup" id="MathJax-Span-3359"><span style="display: inline-block; position: relative; width: 1.752em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3360" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3361"><span class="mrow" id="MathJax-Span-3362"><span class="mn" id="MathJax-Span-3363" style="font-size: 70.7%; font-family: MathJax_Main;">91</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3364" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3365"><span style="display: inline-block; position: relative; width: 1.752em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3366" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3367"><span class="mrow" id="MathJax-Span-3368"><span class="mn" id="MathJax-Span-3369" style="font-size: 70.7%; font-family: MathJax_Main;">91</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3370" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3371" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3372" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-3373" style="font-family: MathJax_Main; padding-left: 0.222em;">11</span><span class="mo" id="MathJax-Span-3374" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3375" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.596em, 1006.06em, 4.926em, -1000em); top: -4.019em; left: 8.882em;"><span style="display: inline-block; position: relative; width: 6.102em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1004.23em, 4.203em, -1000em); top: -4.594em; left: 0em;"><span class="mtd" id="MathJax-Span-3351"><span class="mrow" id="MathJax-Span-3352"><span class="mtext" id="MathJax-Span-3353" style="font-family: MathJax_Main;">if&nbsp;</span><span class="mi" id="MathJax-Span-3354" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3355" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-3356" style="font-family: MathJax_Main; padding-left: 0.278em;">100</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.171em, 1006.06em, 4.301em, -1000em); top: -3.394em; left: 0em;"><span class="mtd" id="MathJax-Span-3376"><span class="mrow" id="MathJax-Span-3377"><span class="mtext" id="MathJax-Span-3378" style="font-family: MathJax_Main;">if&nbsp;</span><span class="mn" id="MathJax-Span-3379" style="font-family: MathJax_Main;">0</span><span class="mo" id="MathJax-Span-3380" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-3381" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span><span class="mo" id="MathJax-Span-3382" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mn" id="MathJax-Span-3383" style="font-family: MathJax_Main; padding-left: 0.278em;">100</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3384"></span></span></span><span style="display: inline-block; width: 0px; height: 3.923em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.316em; border-left: 0px solid; width: 0px; height: 3.293em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mn>91</mn></mrow></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mrow><mo>{</mo><mtable columnalign="left left" rowspacing=".2em" columnspacing="1em" displaystyle="false"><mtr><mtd><mi>n</mi><mo>−</mo><mn>10</mn></mtd><mtd><mtext>if&nbsp;</mtext><mi>n</mi><mo>&gt;</mo><mn>100</mn></mtd></mtr><mtr><mtd><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mn>91</mn></mrow></msub><mo stretchy="false">(</mo><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mn>91</mn></mrow></msub><mo stretchy="false">(</mo><mi>n</mi><mo>+</mo><mn>11</mn><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mtext>if&nbsp;</mtext><mn>0</mn><mo>≤</mo><mi>n</mi><mo>≤</mo><mn>100</mn></mtd></mtr></mtable><mo fence="true" stretchy="true" symmetric="true"></mo></mrow></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-180">
# M_{91}(n) =
#     \\begin{cases}
#         n - 10 & \\text{if } n > 100 \\\
#         M_{91}(M_{91}(n+11)) & \\text{if } 0 \\leq n \\leq 100
#     \\end{cases}
# </script>
#
# <p>
# We can generalize this definition by abstracting away the constants into new variables:
#
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span></p><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-181-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML" display="block"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mrow&gt;&lt;mo&gt;{&lt;/mo&gt;&lt;mtable columnalign="left left" rowspacing=".2em" columnspacing="1em" displaystyle="false"&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mtext&gt;if&amp;#xA0;&lt;/mtext&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mtext&gt;if&amp;#xA0;&lt;/mtext&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;/mtable&gt;&lt;mo fence="true" stretchy="true" symmetric="true"&gt;&lt;/mo&gt;&lt;/mrow&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3385" style="width: 29.715em; display: inline-block;"><span style="display: inline-block; position: relative; width: 22.488em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(2.33em, 1022.49em, 5.016em, -1000em); top: -3.923em; left: 0em;"><span class="mrow" id="MathJax-Span-3386"><span class="msubsup" id="MathJax-Span-3387"><span style="display: inline-block; position: relative; width: 2.759em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3388" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3389"><span class="mrow" id="MathJax-Span-3390"><span class="mi" id="MathJax-Span-3391" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3392" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3393" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3394" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3395" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3396" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3397" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3398" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3399" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mrow" id="MathJax-Span-3400" style="padding-left: 0.278em;"><span class="mo" id="MathJax-Span-3401" style="vertical-align: 0em;"><span style="font-family: MathJax_Size3;">{</span></span><span class="mtable" id="MathJax-Span-3402" style="padding-right: 0.167em; padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 15.897em; height: 0px;"><span style="position: absolute; clip: rect(2.699em, 1009.32em, 5.056em, -1000em); top: -4.019em; left: 0em;"><span style="display: inline-block; position: relative; width: 9.417em; height: 0px;"><span style="position: absolute; clip: rect(3.293em, 1002.24em, 4.245em, -1000em); top: -4.613em; left: 0em;"><span class="mtd" id="MathJax-Span-3403"><span class="mrow" id="MathJax-Span-3404"><span class="mi" id="MathJax-Span-3405" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3406" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mi" id="MathJax-Span-3407" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.126em, 1009.32em, 4.45em, -1000em); top: -3.413em; left: 0em;"><span class="mtd" id="MathJax-Span-3414"><span class="mrow" id="MathJax-Span-3415"><span class="msubsup" id="MathJax-Span-3416"><span style="display: inline-block; position: relative; width: 2.759em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3417" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3418"><span class="mrow" id="MathJax-Span-3419"><span class="mi" id="MathJax-Span-3420" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3421" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3422" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3423" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3424" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3425" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3426"><span style="display: inline-block; position: relative; width: 2.759em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3427" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3428"><span class="mrow" id="MathJax-Span-3429"><span class="mi" id="MathJax-Span-3430" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3431" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3432" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3433" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3434" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3435" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3436" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3437" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-3438" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">k</span><span class="mo" id="MathJax-Span-3439" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3440" style="font-family: MathJax_Main;">)</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.577em, 1005.46em, 4.907em, -1000em); top: -4.019em; left: 10.417em;"><span style="display: inline-block; position: relative; width: 5.48em; height: 0px;"><span style="position: absolute; clip: rect(3.171em, 1003.63em, 4.203em, -1000em); top: -4.613em; left: 0em;"><span class="mtd" id="MathJax-Span-3408"><span class="mrow" id="MathJax-Span-3409"><span class="mtext" id="MathJax-Span-3410" style="font-family: MathJax_Main;">if&nbsp;</span><span class="mi" id="MathJax-Span-3411" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3412" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mi" id="MathJax-Span-3413" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">m</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.171em, 1005.46em, 4.301em, -1000em); top: -3.413em; left: 0em;"><span class="mtd" id="MathJax-Span-3441"><span class="mrow" id="MathJax-Span-3442"><span class="mtext" id="MathJax-Span-3443" style="font-family: MathJax_Main;">if&nbsp;</span><span class="mn" id="MathJax-Span-3444" style="font-family: MathJax_Main;">0</span><span class="mo" id="MathJax-Span-3445" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-3446" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span><span class="mo" id="MathJax-Span-3447" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-3448" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">m</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3449"></span></span></span><span style="display: inline-block; width: 0px; height: 3.923em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.316em; border-left: 0px solid; width: 0px; height: 3.293em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mrow><mo>{</mo><mtable columnalign="left left" rowspacing=".2em" columnspacing="1em" displaystyle="false"><mtr><mtd><mi>n</mi><mo>−</mo><mi>s</mi></mtd><mtd><mtext>if&nbsp;</mtext><mi>n</mi><mo>&gt;</mo><mi>m</mi></mtd></mtr><mtr><mtd><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub><mo stretchy="false">(</mo><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub><mo stretchy="false">(</mo><mi>n</mi><mo>+</mo><mi>k</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mtd><mtd><mtext>if&nbsp;</mtext><mn>0</mn><mo>≤</mo><mi>n</mi><mo>≤</mo><mi>m</mi></mtd></mtr></mtable><mo fence="true" stretchy="true" symmetric="true"></mo></mrow></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-181">
# M_{m,k,s}(n) =
#     \\begin{cases}
#         n - s & \\text{if } n > m \\\
#         M_{m,k,s}(M_{m,k,s}(n+k)) & \\text{if } 0 \\leq n \\leq m
#     \\end{cases}
# </script>
#
# <p>
# This way, we have <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-182-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;91&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3450" style="width: 9.237em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.986em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.853em, 1006.99em, 3.11em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3451"><span class="msubsup" id="MathJax-Span-3452"><span style="display: inline-block; position: relative; width: 1.752em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3453" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3454"><span class="mrow" id="MathJax-Span-3455"><span class="mn" id="MathJax-Span-3456" style="font-size: 70.7%; font-family: MathJax_Main;">91</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3457" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-3458" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 3.913em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3459" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3460"><span class="mrow" id="MathJax-Span-3461"><span class="mn" id="MathJax-Span-3462" style="font-size: 70.7%; font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-3463" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3464" style="font-size: 70.7%; font-family: MathJax_Main;">11</span><span class="mo" id="MathJax-Span-3465" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3466" style="font-size: 70.7%; font-family: MathJax_Main;">10</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.407em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mn>91</mn></mrow></msub><mo>=</mo><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mn>100</mn><mo>,</mo><mn>11</mn><mo>,</mo><mn>10</mn></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-182">M_{91} = M_{100,11,10}</script>.
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-183-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3467" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.377em, 1002.44em, 2.632em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3468"><span class="msubsup" id="MathJax-Span-3469"><span style="display: inline-block; position: relative; width: 2.432em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3470" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="texatom" id="MathJax-Span-3471"><span class="mrow" id="MathJax-Span-3472"><span class="mi" id="MathJax-Span-3473" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3474" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3475" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3476" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3477" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.403em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>F</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-183">F_{m,k,s}</script> be the set of fixed points of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-184-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3478" style="width: 3.687em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.775em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.374em, 1002.78em, 2.632em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3479"><span class="msubsup" id="MathJax-Span-3480"><span style="display: inline-block; position: relative; width: 2.759em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3481" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3482"><span class="mrow" id="MathJax-Span-3483"><span class="mi" id="MathJax-Span-3484" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3485" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3486" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3487" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3488" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.407em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-184">M_{m,k,s}</script>. That is,
#
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span></p><div class="MathJax_Display" style="text-align: center;"><span class="MathJax" id="MathJax-Element-185-Frame" tabindex="0" style="text-align: center; position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML" display="block"&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mrow&gt;&lt;mo&gt;{&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi mathvariant="double-struck"&gt;N&lt;/mi&gt;&lt;/mrow&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mo stretchy="false"&gt;|&lt;/mo&gt;&lt;/mrow&gt;&lt;mspace width="thinmathspace" /&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;}&lt;/mo&gt;&lt;/mrow&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3489" style="width: 18.471em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.971em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(2.073em, 1013.91em, 3.397em, -1000em); top: -2.967em; left: 0em;"><span class="mrow" id="MathJax-Span-3490"><span class="msubsup" id="MathJax-Span-3491"><span style="display: inline-block; position: relative; width: 2.432em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3492" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="texatom" id="MathJax-Span-3493"><span class="mrow" id="MathJax-Span-3494"><span class="mi" id="MathJax-Span-3495" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3496" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3497" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3498" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3499" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3500" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mrow" id="MathJax-Span-3501" style="padding-left: 0.278em;"><span class="mo" id="MathJax-Span-3502" style=""><span style="font-family: MathJax_Main;">{</span></span><span class="mi" id="MathJax-Span-3503" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3504" style="font-family: MathJax_Main; padding-left: 0.278em;">∈</span><span class="texatom" id="MathJax-Span-3505" style="padding-left: 0.278em;"><span class="mrow" id="MathJax-Span-3506"><span class="mi" id="MathJax-Span-3507" style="font-family: MathJax_AMS;">N</span></span></span><span class="mspace" id="MathJax-Span-3508" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="texatom" id="MathJax-Span-3509"><span class="mrow" id="MathJax-Span-3510"><span class="mo" id="MathJax-Span-3511" style="font-family: MathJax_Main;">|</span></span></span><span class="mspace" id="MathJax-Span-3512" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="msubsup" id="MathJax-Span-3513"><span style="display: inline-block; position: relative; width: 2.759em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3514" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3515"><span class="mrow" id="MathJax-Span-3516"><span class="mi" id="MathJax-Span-3517" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3518" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3519" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3520" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3521" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3522" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3523" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3524" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3525" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-3526" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span><span class="mo" id="MathJax-Span-3527" style=""><span style="font-family: MathJax_Main;">}</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.967em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.495em;"></span></span></nobr><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML" display="block"><msub><mi>F</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub><mo>=</mo><mrow><mo>{</mo><mi>n</mi><mo>∈</mo><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="double-struck">N</mi></mrow><mspace width="thinmathspace"></mspace><mrow class="MJX-TeXAtom-ORD"><mo stretchy="false">|</mo></mrow><mspace width="thinmathspace"></mspace><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mi>n</mi><mo>}</mo></mrow></math></span></span></div><script type="math/tex; mode=display" id="MathJax-Element-185">F_{m,k,s}= \\left\\{ n \\in \\mathbb{N} \\, | \\, M_{m,k,s}(n) = n \\right\\}</script>
#
# <p>
# For example, the only fixed point of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-186-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;91&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3528" style="width: 2.347em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.77em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.374em, 1001.77em, 2.51em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3529"><span class="msubsup" id="MathJax-Span-3530"><span style="display: inline-block; position: relative; width: 1.752em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3531" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.97em;"><span class="texatom" id="MathJax-Span-3532"><span class="mrow" id="MathJax-Span-3533"><span class="mn" id="MathJax-Span-3534" style="font-size: 70.7%; font-family: MathJax_Main;">91</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.246em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>M</mi><mrow class="MJX-TeXAtom-ORD"><mn>91</mn></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-186">M_{91}</script> is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-187-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;91&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3535" style="width: 3.878em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.919em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.85em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3536"><span class="mi" id="MathJax-Span-3537" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3538" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-3539" style="font-family: MathJax_Main; padding-left: 0.278em;">91</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>=</mo><mn>91</mn></math></span></span><script type="math/tex" id="MathJax-Element-187">n = 91</script>. In other words, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-188-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo fence="false" stretchy="false"&gt;{&lt;/mo&gt;&lt;mn&gt;91&lt;/mn&gt;&lt;mo fence="false" stretchy="false"&gt;}&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3540" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.78em, 3.11em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3541"><span class="msubsup" id="MathJax-Span-3542"><span style="display: inline-block; position: relative; width: 3.586em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3543" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="texatom" id="MathJax-Span-3544"><span class="mrow" id="MathJax-Span-3545"><span class="mn" id="MathJax-Span-3546" style="font-size: 70.7%; font-family: MathJax_Main;">100</span><span class="mo" id="MathJax-Span-3547" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3548" style="font-size: 70.7%; font-family: MathJax_Main;">11</span><span class="mo" id="MathJax-Span-3549" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3550" style="font-size: 70.7%; font-family: MathJax_Main;">10</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3551" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mo" id="MathJax-Span-3552" style="font-family: MathJax_Main; padding-left: 0.278em;">{</span><span class="mn" id="MathJax-Span-3553" style="font-family: MathJax_Main;">91</span><span class="mo" id="MathJax-Span-3554" style="font-family: MathJax_Main;">}</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.495em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>F</mi><mrow class="MJX-TeXAtom-ORD"><mn>100</mn><mo>,</mo><mn>11</mn><mo>,</mo><mn>10</mn></mrow></msub><mo>=</mo><mo fence="false" stretchy="false">{</mo><mn>91</mn><mo fence="false" stretchy="false">}</mo></math></span></span><script type="math/tex" id="MathJax-Element-188">F_{100,11,10}= \\{91\\}</script>.
# </p>
# <p>
# Now, define <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-189-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3555" style="width: 6.51em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.928em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.83em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3556"><span class="mi" id="MathJax-Span-3557" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mi" id="MathJax-Span-3558" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-3559" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3560" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3561" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3562" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="mo" id="MathJax-Span-3563" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3564" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">s</span><span class="mo" id="MathJax-Span-3565" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mi>F</mi><mo stretchy="false">(</mo><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-189">SF(m,k,s)</script> as the sum of the elements in <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-190-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3566" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.377em, 1002.44em, 2.632em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3567"><span class="msubsup" id="MathJax-Span-3568"><span style="display: inline-block; position: relative; width: 2.432em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3569" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.643em;"><span class="texatom" id="MathJax-Span-3570"><span class="mrow" id="MathJax-Span-3571"><span class="mi" id="MathJax-Span-3572" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3573" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3574" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3575" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3576" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.403em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>F</mi><mrow class="MJX-TeXAtom-ORD"><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-190">F_{m,k,s}</script> and let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-191-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;s&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3577" style="width: 16.797em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.727em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.586em, 1012.63em, 4.168em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3578"><span class="mi" id="MathJax-Span-3579" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-3580" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3581" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-3582" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3583" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">m</span><span class="mo" id="MathJax-Span-3584" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3585" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mstyle" id="MathJax-Span-3586" style="padding-left: 0.278em;"><span class="mrow" id="MathJax-Span-3587"><span class="munderover" id="MathJax-Span-3588"><span style="display: inline-block; position: relative; width: 3.06em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0.808em;"><span class="mo" id="MathJax-Span-3589" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1003.05em, 4.4em, -1000em); top: -2.912em; left: 0em;"><span class="texatom" id="MathJax-Span-3590"><span class="mrow" id="MathJax-Span-3591"><span class="mn" id="MathJax-Span-3592" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-3593" style="font-size: 70.7%; font-family: MathJax_Main;">≤</span><span class="mi" id="MathJax-Span-3594" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">s</span><span class="mo" id="MathJax-Span-3595" style="font-size: 70.7%; font-family: MathJax_Main;">&lt;</span><span class="mi" id="MathJax-Span-3596" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3597" style="font-size: 70.7%; font-family: MathJax_Main;">≤</span><span class="mi" id="MathJax-Span-3598" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">p</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="texatom" id="MathJax-Span-3599" style="padding-left: 0.167em;"><span class="mrow" id="MathJax-Span-3600"><span class="mi" id="MathJax-Span-3601" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mi" id="MathJax-Span-3602" style="font-family: MathJax_Math; font-style: italic;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-3603" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3604" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3605" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3606" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="mo" id="MathJax-Span-3607" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3608" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">s</span><span class="mo" id="MathJax-Span-3609" style="font-family: MathJax_Main;">)</span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.838em; border-left: 0px solid; width: 0px; height: 3.155em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>p</mi><mo>,</mo><mi>m</mi><mo stretchy="false">)</mo><mo>=</mo><mstyle displaystyle="true" scriptlevel="0"><munder><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mn>1</mn><mo>≤</mo><mi>s</mi><mo>&lt;</mo><mi>k</mi><mo>≤</mo><mi>p</mi></mrow></munder><mrow class="MJX-TeXAtom-ORD"><mi>S</mi><mi>F</mi><mo stretchy="false">(</mo><mi>m</mi><mo>,</mo><mi>k</mi><mo>,</mo><mi>s</mi><mo stretchy="false">)</mo></mrow></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-191">S(p,m) = \\displaystyle \\sum_{1 \\leq s < k \\leq p}{SF(m,k,s)}</script>.
# </p>
# <p>
# For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-192-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;225&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3610" style="width: 8.663em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.555em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.5em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3611"><span class="mi" id="MathJax-Span-3612" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-3613" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-3614" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-3615" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3616" style="font-family: MathJax_Main; padding-left: 0.167em;">10</span><span class="mo" id="MathJax-Span-3617" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3618" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-3619" style="font-family: MathJax_Main; padding-left: 0.278em;">225</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>10</mn><mo>,</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>225</mn></math></span></span><script type="math/tex" id="MathJax-Element-192">S(10, 10) = 225</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-193-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1000&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1000&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;208724467&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3620" style="width: 14.978em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.34em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1011.33em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3621"><span class="mi" id="MathJax-Span-3622" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-3623" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-3624" style="font-family: MathJax_Main;">1000</span><span class="mo" id="MathJax-Span-3625" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3626" style="font-family: MathJax_Main; padding-left: 0.167em;">1000</span><span class="mo" id="MathJax-Span-3627" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3628" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-3629" style="font-family: MathJax_Main; padding-left: 0.278em;">208724467</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>1000</mn><mo>,</mo><mn>1000</mn><mo stretchy="false">)</mo><mo>=</mo><mn>208724467</mn></math></span></span><script type="math/tex" id="MathJax-Element-193">S(1000, 1000)=208724467</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-194-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3630" style="width: 6.27em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.737em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1004.64em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3631"><span class="mi" id="MathJax-Span-3632" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-3633" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3634"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-3635" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-3636" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3637" style="font-family: MathJax_Main;">,</span><span class="msubsup" id="MathJax-Span-3638" style="padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-3639" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-3640" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3641" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>6</mn></msup><mo>,</mo><msup><mn>10</mn><mn>6</mn></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-194">S(10^6, 10^6)</script>.
# </p>

# %%
submit_answer(answer; prob_num=555);

# %% [markdown]
# ## Problem 556: Squarefree Gaussian Integers
# <p>A <b>Gaussian integer</b> is a number <var>z</var>&nbsp;=&nbsp;<var>a</var>&nbsp;+&nbsp;<var>b</var>i where <var>a</var>, <var>b</var> are integers and i<sup>2</sup>&nbsp;=&nbsp;-1.<br>
# Gaussian integers are a subset of the complex numbers, and the integers are the subset of Gaussian integers for which <var>b</var>&nbsp;=&nbsp;0.</p>
#
# <p>A Gaussian integer <b>unit</b> is one for which <var>a</var><sup>2</sup>&nbsp;+&nbsp;<var>b</var><sup>2</sup>&nbsp;=&nbsp;1, i.e. one of 1, i, -1, -i.<br>
# "Let's define a <i>proper</i> Gaussian integer as one for which <var>a</var>&nbsp;&gt;&nbsp;0 and <var>b</var>&nbsp;≥&nbsp;0.</p>"
#
# <p>A Gaussian integer z<sub>1</sub>&nbsp;=&nbsp;a<sub>1</sub>&nbsp;+&nbsp;<var>b</var><sub>1</sub>i is said to be divisible by <var>z</var><sub>2</sub>&nbsp;=&nbsp;a<sub>2</sub>&nbsp;+&nbsp;<var>b</var><sub>2</sub>i if <var>z</var><sub>3</sub>&nbsp;=&nbsp;<var>a</var><sub>3</sub>&nbsp;+&nbsp;<var>b</var><sub>3</sub>i&nbsp;=&nbsp;<var>z</var><sub>1</sub>/<var>z</var><sub>2</sub> is a Gaussian integer.<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-195-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/mfrac&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;msubsup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msubsup&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;msubsup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msubsup&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3642" style="width: 34.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 26.172em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.429em, 1026.13em, 3.57em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3643"><span class="mfrac" id="MathJax-Span-3644"><span style="display: inline-block; position: relative; width: 0.752em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.563em, 1000.63em, 4.269em, -1000em); top: -4.525em; left: 50%; margin-left: -0.316em;"><span class="msubsup" id="MathJax-Span-3645"><span style="display: inline-block; position: relative; width: 0.632em; height: 0px;"><span style="position: absolute; clip: rect(3.563em, 1000.33em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3646" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.329em;"><span class="mn" id="MathJax-Span-3647" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.63em, 4.269em, -1000em); top: -3.674em; left: 50%; margin-left: -0.316em;"><span class="msubsup" id="MathJax-Span-3648"><span style="display: inline-block; position: relative; width: 0.632em; height: 0px;"><span style="position: absolute; clip: rect(3.563em, 1000.33em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3649" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.002em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.329em;"><span class="mn" id="MathJax-Span-3650" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.75em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.752em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-3651" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-3652" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.198em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1002.05em, 4.269em, -1000em); top: -4.525em; left: 50%; margin-left: -1.039em;"><span class="mrow" id="MathJax-Span-3653"><span class="msubsup" id="MathJax-Span-3654"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3655" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3656" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3657" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3658"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3659" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3660" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3661" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1002.05em, 4.269em, -1000em); top: -3.629em; left: 50%; margin-left: -1.039em;"><span class="mrow" id="MathJax-Span-3662"><span class="msubsup" id="MathJax-Span-3663"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3664" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3665" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3666" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3667"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3668" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3669" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3670" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1002.2em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 2.198em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-3671" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-3672" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 5.375em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.345em, 1005.19em, 4.339em, -1000em); top: -4.596em; left: 50%; margin-left: -2.628em;"><span class="mrow" id="MathJax-Span-3673"><span class="mo" id="MathJax-Span-3674" style="font-size: 70.7%; font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3675"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3676" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3677" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3678" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3679"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3680" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3681" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3682" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-3683" style="font-size: 70.7%; font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3684" style="font-size: 70.7%; font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3685"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3686" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3687" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3688" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="msubsup" id="MathJax-Span-3689"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3690" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3691" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3692" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-3693" style="font-size: 70.7%; font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.345em, 1005.19em, 4.339em, -1000em); top: -3.589em; left: 50%; margin-left: -2.628em;"><span class="mrow" id="MathJax-Span-3694"><span class="mo" id="MathJax-Span-3695" style="font-size: 70.7%; font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3696"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3697" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3698" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3699" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3700"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3701" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3702" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3703" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-3704" style="font-size: 70.7%; font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3705" style="font-size: 70.7%; font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3706"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3707" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3708" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3709" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="msubsup" id="MathJax-Span-3710"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3711" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3712" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3713" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-3714" style="font-size: 70.7%; font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1005.38em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 5.375em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-3715" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-3716" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 3.237em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1003.12em, 4.269em, -1000em); top: -4.525em; left: 50%; margin-left: -1.559em;"><span class="mrow" id="MathJax-Span-3717"><span class="msubsup" id="MathJax-Span-3718"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3719" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3720" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3721"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3722" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3723" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3724" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3725"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3726" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3727" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3728"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3729" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3730" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.245em, 1001.83em, 4.379em, -1000em); top: -3.489em; left: 50%; margin-left: -0.917em;"><span class="mrow" id="MathJax-Span-3731"><span class="msubsup" id="MathJax-Span-3732"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3733" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.263em; left: 0.374em;"><span class="mn" id="MathJax-Span-3734" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.802em; left: 0.374em;"><span class="mn" id="MathJax-Span-3735" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3736" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3737"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3738" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.317em; left: 0.303em;"><span class="mn" id="MathJax-Span-3739" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.844em; left: 0.303em;"><span class="mn" id="MathJax-Span-3740" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1003.24em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 3.237em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mo" id="MathJax-Span-3741" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mfrac" id="MathJax-Span-3742" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 3.237em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1003.12em, 4.269em, -1000em); top: -4.525em; left: 50%; margin-left: -1.559em;"><span class="mrow" id="MathJax-Span-3743"><span class="msubsup" id="MathJax-Span-3744"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3745" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3746" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3747"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3748" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3749" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3750" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="msubsup" id="MathJax-Span-3751"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3752" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3753" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3754"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3755" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3756" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.245em, 1001.83em, 4.379em, -1000em); top: -3.489em; left: 50%; margin-left: -0.917em;"><span class="mrow" id="MathJax-Span-3757"><span class="msubsup" id="MathJax-Span-3758"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3759" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.263em; left: 0.374em;"><span class="mn" id="MathJax-Span-3760" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.802em; left: 0.374em;"><span class="mn" id="MathJax-Span-3761" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3762" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3763"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3764" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.317em; left: 0.303em;"><span class="mn" id="MathJax-Span-3765" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.844em; left: 0.303em;"><span class="mn" id="MathJax-Span-3766" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1003.24em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 3.237em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="mi" id="MathJax-Span-3767" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-3768" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-3769" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.958em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3770" style="font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.529em;"><span class="mn" id="MathJax-Span-3771" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3772" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-3773" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 0.858em; height: 0px;"><span style="position: absolute; clip: rect(3.182em, 1000.42em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3774" style="font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.429em;"><span class="mn" id="MathJax-Span-3775" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3776" style="font-family: MathJax_Math; font-style: italic;">i</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.049em; border-left: 0px solid; width: 0px; height: 2.574em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><msub><mi>z</mi><mn>1</mn></msub><msub><mi>z</mi><mn>2</mn></msub></mfrac><mo>=</mo><mfrac><mrow><msub><mi>a</mi><mn>1</mn></msub><mo>+</mo><msub><mi>b</mi><mn>1</mn></msub><mi>i</mi></mrow><mrow><msub><mi>a</mi><mn>2</mn></msub><mo>+</mo><msub><mi>b</mi><mn>2</mn></msub><mi>i</mi></mrow></mfrac><mo>=</mo><mfrac><mrow><mo stretchy="false">(</mo><msub><mi>a</mi><mn>1</mn></msub><mo>+</mo><msub><mi>b</mi><mn>1</mn></msub><mi>i</mi><mo stretchy="false">)</mo><mo stretchy="false">(</mo><msub><mi>a</mi><mn>2</mn></msub><mo>−</mo><msub><mi>b</mi><mn>2</mn></msub><mi>i</mi><mo stretchy="false">)</mo></mrow><mrow><mo stretchy="false">(</mo><msub><mi>a</mi><mn>2</mn></msub><mo>+</mo><msub><mi>b</mi><mn>2</mn></msub><mi>i</mi><mo stretchy="false">)</mo><mo stretchy="false">(</mo><msub><mi>a</mi><mn>2</mn></msub><mo>−</mo><msub><mi>b</mi><mn>2</mn></msub><mi>i</mi><mo stretchy="false">)</mo></mrow></mfrac><mo>=</mo><mfrac><mrow><msub><mi>a</mi><mn>1</mn></msub><msub><mi>a</mi><mn>2</mn></msub><mo>+</mo><msub><mi>b</mi><mn>1</mn></msub><msub><mi>b</mi><mn>2</mn></msub></mrow><mrow><msubsup><mi>a</mi><mn>2</mn><mn>2</mn></msubsup><mo>+</mo><msubsup><mi>b</mi><mn>2</mn><mn>2</mn></msubsup></mrow></mfrac><mo>+</mo><mfrac><mrow><msub><mi>a</mi><mn>2</mn></msub><msub><mi>b</mi><mn>1</mn></msub><mo>−</mo><msub><mi>a</mi><mn>1</mn></msub><msub><mi>b</mi><mn>2</mn></msub></mrow><mrow><msubsup><mi>a</mi><mn>2</mn><mn>2</mn></msubsup><mo>+</mo><msubsup><mi>b</mi><mn>2</mn><mn>2</mn></msubsup></mrow></mfrac><mi>i</mi><mo>=</mo><msub><mi>a</mi><mn>3</mn></msub><mo>+</mo><msub><mi>b</mi><mn>3</mn></msub><mi>i</mi></math></span></span><script type="math/tex" id="MathJax-Element-195">\\frac {z_1} {z_2} = \\frac {a_1 + b_1 i} {a_2 + b_2 i} = \\frac {(a_1 + b_1 i)(a_2 - b_2 i)} {(a_2 + b_2 i)(a_2 - b_2 i)} = \\frac {a_1 a_2 + b_1 b_2} {a_2^2 + b_2^2} + \\frac  {a_2 b_1 - a_1 b_2}  {a_2^2 + b_2^2}i = a_3 + b_3 i</script><br>
# So, <var>z</var><sub>1</sub> is divisible by <var>z</var><sub>2</sub> if <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-196-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;msubsup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msubsup&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3777" style="width: 4.644em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.493em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.061em, 1003.49em, 3.092em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3778"><span class="mfrac" id="MathJax-Span-3779"><span style="display: inline-block; position: relative; width: 3.237em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1003.12em, 4.269em, -1000em); top: -4.525em; left: 50%; margin-left: -1.559em;"><span class="mrow" id="MathJax-Span-3780"><span class="msubsup" id="MathJax-Span-3781"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3782" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3783" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3784"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3785" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3786" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3787" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3788"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3789" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3790" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3791"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3792" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3793" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.245em, 1001.83em, 4.379em, -1000em); top: -3.489em; left: 50%; margin-left: -0.917em;"><span class="mrow" id="MathJax-Span-3794"><span class="msubsup" id="MathJax-Span-3795"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3796" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.263em; left: 0.374em;"><span class="mn" id="MathJax-Span-3797" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.802em; left: 0.374em;"><span class="mn" id="MathJax-Span-3798" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3799" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3800"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3801" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.317em; left: 0.303em;"><span class="mn" id="MathJax-Span-3802" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.844em; left: 0.303em;"><span class="mn" id="MathJax-Span-3803" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1003.24em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 3.237em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.049em; border-left: 0px solid; width: 0px; height: 2.428em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mrow><msub><mi>a</mi><mn>1</mn></msub><msub><mi>a</mi><mn>2</mn></msub><mo>+</mo><msub><mi>b</mi><mn>1</mn></msub><msub><mi>b</mi><mn>2</mn></msub></mrow><mrow><msubsup><mi>a</mi><mn>2</mn><mn>2</mn></msubsup><mo>+</mo><msubsup><mi>b</mi><mn>2</mn><mn>2</mn></msubsup></mrow></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-196">\\frac {a_1 a_2 + b_1 b_2} {a_2^2 + b_2^2}</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-197-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;msub&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;msubsup&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msubsup&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msubsup&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3804" style="width: 4.644em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.493em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.061em, 1003.49em, 3.092em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3805"><span class="mfrac" id="MathJax-Span-3806"><span style="display: inline-block; position: relative; width: 3.237em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1003.12em, 4.269em, -1000em); top: -4.525em; left: 50%; margin-left: -1.559em;"><span class="mrow" id="MathJax-Span-3807"><span class="msubsup" id="MathJax-Span-3808"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3809" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3810" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3811"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3812" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3813" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3814" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="msubsup" id="MathJax-Span-3815"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3816" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.374em;"><span class="mn" id="MathJax-Span-3817" style="font-size: 50%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="msubsup" id="MathJax-Span-3818"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3819" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.913em; left: 0.303em;"><span class="mn" id="MathJax-Span-3820" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.245em, 1001.83em, 4.379em, -1000em); top: -3.489em; left: 50%; margin-left: -0.917em;"><span class="mrow" id="MathJax-Span-3821"><span class="msubsup" id="MathJax-Span-3822"><span style="display: inline-block; position: relative; width: 0.677em; height: 0px;"><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3823" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.263em; left: 0.374em;"><span class="mn" id="MathJax-Span-3824" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.802em; left: 0.374em;"><span class="mn" id="MathJax-Span-3825" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-3826" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="msubsup" id="MathJax-Span-3827"><span style="display: inline-block; position: relative; width: 0.606em; height: 0px;"><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3828" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -4.317em; left: 0.303em;"><span class="mn" id="MathJax-Span-3829" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.543em, 1000.3em, 4.163em, -1000em); top: -3.844em; left: 0.303em;"><span class="mn" id="MathJax-Span-3830" style="font-size: 50%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1003.24em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 3.237em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.049em; border-left: 0px solid; width: 0px; height: 2.428em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mrow><msub><mi>a</mi><mn>2</mn></msub><msub><mi>b</mi><mn>1</mn></msub><mo>−</mo><msub><mi>a</mi><mn>1</mn></msub><msub><mi>b</mi><mn>2</mn></msub></mrow><mrow><msubsup><mi>a</mi><mn>2</mn><mn>2</mn></msubsup><mo>+</mo><msubsup><mi>b</mi><mn>2</mn><mn>2</mn></msubsup></mrow></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-197">\\frac  {a_2 b_1 - a_1 b_2}  {a_2^2 + b_2^2}</script> are integers.<br>
# For example, 2 is divisible by 1&nbsp;+&nbsp;i because 2/(1&nbsp;+&nbsp;i)&nbsp;=&nbsp;1&nbsp;-&nbsp;i is a Gaussian integer.</p>
#
# <p>A <b>Gaussian prime</b> is a Gaussian integer that is divisible only by a unit, itself or itself times a unit.<br>
# For example, 1&nbsp;+&nbsp;2i is a Gaussian prime, because it is only
# divisible by 1, i, -1, -i, 1&nbsp;+&nbsp;2i,
# i(1&nbsp;+&nbsp;2i)&nbsp;=&nbsp;i&nbsp;-&nbsp;2,
# -(1&nbsp;+&nbsp;2i)&nbsp;=&nbsp;-1&nbsp;-&nbsp;2i and
# -i(1&nbsp;+&nbsp;2i)&nbsp;=&nbsp;2&nbsp;-&nbsp;i.<br>
# 2 is not a Gaussian prime as it is divisible by 1&nbsp;+&nbsp;i.</p>
#
# <p>A Gaussian integer can be uniquely factored as the product of a unit and proper Gaussian primes.<br>
# For example 2&nbsp;=&nbsp;-i(1&nbsp;+&nbsp;i)<sup>2</sup> and 1&nbsp;+&nbsp;3i&nbsp;=&nbsp;(1&nbsp;+&nbsp;i)(2&nbsp;+&nbsp;i).<br>
# A Gaussian integer is said to be squarefree if its prime factorization does not contain repeated proper Gaussian primes.<br>
# So 2 is not squarefree over the Gaussian integers, but 1&nbsp;+&nbsp;3i is.<br>
# Units and Gaussian primes are squarefree by definition.</p>
#
# <p>Let <var>f</var>(<var>n</var>) be the count of proper squarefree Gaussian integers with <var>a</var><sup>2</sup>&nbsp;+&nbsp;<var>b</var><sup>2</sup>&nbsp;≤&nbsp;n.<br>
# For example <var>f</var>(10)&nbsp;=&nbsp;7 because 1, 1&nbsp;+&nbsp;i,
# 1&nbsp;+&nbsp;2i,
# 1&nbsp;+&nbsp;3i&nbsp;=&nbsp;(1&nbsp;+&nbsp;i)(2&nbsp;+&nbsp;i),
# 2&nbsp;+&nbsp;i, 3 and
# 3&nbsp;+&nbsp;i&nbsp;=&nbsp;-i(1&nbsp;+&nbsp;i)(1&nbsp;+&nbsp;2i) are
# squarefree, while 2&nbsp;=&nbsp;-i(1&nbsp;+&nbsp;i)<sup>2</sup> and 2&nbsp;+&nbsp;2i&nbsp;=&nbsp;-i(1&nbsp;+&nbsp;i)<sup>3</sup> are not.<br>
# You are given <var>f</var>(10<sup>2</sup>)&nbsp;=&nbsp;54, <var>f</var>(10<sup>4</sup>)&nbsp;=&nbsp;5218 and <var>f</var>(10<sup>8</sup>)&nbsp;=&nbsp;52126906.</p>
#
# <p>Find <var>f</var>(10<sup>14</sup>).</p>

# %%
submit_answer(answer; prob_num=556);

# %% [markdown]
# ## Problem 557: Cutting triangles
# <p>
# A triangle is cut into four pieces by two straight lines, each starting
# at one vertex and ending on the opposite edge. This results in forming
# three smaller triangular pieces, and one quadrilateral.  If the original
#  triangle has an integral area, it is often possible to choose cuts such
#  that all of the four pieces also have integral area.  For example, the
# diagram below shows a triangle of area 55 that has been cut in this way.
# </p>
# <div align="center"><img src="webfiles/p557-triangle.gif" alt="p557-triangle.gif"></div>
# <p>
# Representing the areas as <var>a, b, c</var> and <var>d</var>, in the example above, the individual areas are <var>a</var> = 22, <var>b</var> = 8, <var>c</var> = 11 and <var>d</var> = 14.  It is also possible to cut a triangle of area 55 such that <var>a</var> = 20, <var>b</var> = 2, <var>c</var> = 24, <var>d</var> = 9.</p>
# <p>
# Define a triangle cutting quadruple (<var>a, b, c, d</var>) as a valid integral division of a triangle, where <var>a</var> is the area of the triangle between the two cut vertices, <var>d</var> is the area of the quadrilateral and <var>b</var> and <var>c</var> are the areas of the two other triangles, with the restriction that <var>b ≤ c</var>.
#   The two solutions described above are (22,8,11,14) and (20,2,24,9).
# These are the only two possible quadruples that have a total area of 55.
# </p>
# <p>
# Define S(<var>n</var>) as the sum of the area of the uncut triangles represented by all valid quadruples with <var>a+b+c+d</var> ≤ <var>n</var>.<br> For example, S(20) = 259.
# </p>
# <p>
# Find S(10000).
# </p>

# %%
submit_answer(answer; prob_num=557);

# %% [markdown]
# ## Problem 558: Irrational base
# <p>Let <var>r</var> be the real root of the equation <var>x</var><sup>3</sup>&nbsp;=&nbsp;<var>x</var><sup>2</sup>&nbsp;+&nbsp;1.<br>
# Every positive integer can be written as the sum of distinct increasing powers of <var>r</var>.<br>
# If we require the number of terms to be finite and the difference
# between any two exponents to be three or more, then the representation
# is unique.<br>
# For example, 3&nbsp;=&nbsp;<var>r</var><sup>&nbsp;-10</sup>&nbsp;+&nbsp;<var>r</var><sup>&nbsp;-5</sup>&nbsp;+&nbsp;<var>r</var><sup>&nbsp;-1</sup>&nbsp;+&nbsp;<var>r</var><sup>&nbsp;2</sup> and 10&nbsp;=&nbsp;<var>r</var><sup>&nbsp;-10</sup>&nbsp;+&nbsp;<var>r</var><sup>&nbsp;-7</sup>&nbsp;+&nbsp;<var>r</var><sup>&nbsp;6</sup>.<br>
# Interestingly, the relation holds for the complex roots of the equation.</p>
#
# <p>Let <var>w</var>(<var>n</var>) be the number of terms in this unique representation of <var>n</var>. Thus <var>w</var>(3)&nbsp;=&nbsp;4 and <var>w</var>(10)&nbsp;=&nbsp;3.</p>
#
# <p>More formally, for all positive integers <var>n</var>, we have:<br><var>n</var> = <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-198-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi mathvariant="normal"&gt;&amp;#x221E;&lt;/mi&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x221E;&lt;/mi&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3831" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.495em, 1002.11em, 3.61em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3832"><span class="mstyle" id="MathJax-Span-3833"><span class="mrow" id="MathJax-Span-3834"><span class="munderover" id="MathJax-Span-3835"><span style="display: inline-block; position: relative; width: 2.176em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0.366em;"><span class="mo" id="MathJax-Span-3836" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1002.14em, 4.321em, -1000em); top: -2.912em; left: 0em;"><span class="texatom" id="MathJax-Span-3837"><span class="mrow" id="MathJax-Span-3838"><span class="mi" id="MathJax-Span-3839" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3840" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mo" id="MathJax-Span-3841" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mi" id="MathJax-Span-3842" style="font-size: 70.7%; font-family: MathJax_Main;">∞</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.463em, 1000.67em, 4.17em, -1000em); top: -5.169em; left: 0.734em;"><span class="texatom" id="MathJax-Span-3843"><span class="mrow" id="MathJax-Span-3844"><span class="mi" id="MathJax-Span-3845" style="font-size: 70.7%; font-family: MathJax_Main;">∞</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.733em; border-left: 0px solid; width: 0px; height: 3.859em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mo>−</mo><mi mathvariant="normal">∞</mi></mrow><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">∞</mi></mrow></munderover></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-198">\\displaystyle \\sum_{k=-\\infty}^{\\infty}</script> <var>b<sub>k</sub>&nbsp;r<sup>k</sup></var><br>
# under the conditions that:<br><var>b<sub>k</sub></var> is 0 or 1 for all <var>k</var>;<br><var>b<sub>k</sub></var>&nbsp;+&nbsp;<var>b</var><sub><var>k</var>+1</sub>&nbsp;+&nbsp;<var>b</var><sub><var>k</var>+2</sub>&nbsp;≤&nbsp;1 for all <var>k</var>;<br><var>w</var>(<var>n</var>) = <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-199-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi mathvariant="normal"&gt;&amp;#x221E;&lt;/mi&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi mathvariant="normal"&gt;&amp;#x221E;&lt;/mi&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3846" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.495em, 1002.11em, 3.61em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3847"><span class="mstyle" id="MathJax-Span-3848"><span class="mrow" id="MathJax-Span-3849"><span class="munderover" id="MathJax-Span-3850"><span style="display: inline-block; position: relative; width: 2.176em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0.366em;"><span class="mo" id="MathJax-Span-3851" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1002.14em, 4.321em, -1000em); top: -2.912em; left: 0em;"><span class="texatom" id="MathJax-Span-3852"><span class="mrow" id="MathJax-Span-3853"><span class="mi" id="MathJax-Span-3854" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3855" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mo" id="MathJax-Span-3856" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mi" id="MathJax-Span-3857" style="font-size: 70.7%; font-family: MathJax_Main;">∞</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.463em, 1000.67em, 4.17em, -1000em); top: -5.169em; left: 0.734em;"><span class="texatom" id="MathJax-Span-3858"><span class="mrow" id="MathJax-Span-3859"><span class="mi" id="MathJax-Span-3860" style="font-size: 70.7%; font-family: MathJax_Main;">∞</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.733em; border-left: 0px solid; width: 0px; height: 3.859em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mo>−</mo><mi mathvariant="normal">∞</mi></mrow><mrow class="MJX-TeXAtom-ORD"><mi mathvariant="normal">∞</mi></mrow></munderover></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-199">\\displaystyle \\sum_{k=-\\infty}^{\\infty}</script> <var>b<sub>k</sub></var> is finite.</p>
#
# <p>Let S(<var>m</var>)&nbsp;= <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-200-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3861" style="width: 1.916em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.435em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.495em, 1001.38em, 3.676em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3862"><span class="mstyle" id="MathJax-Span-3863"><span class="mrow" id="MathJax-Span-3864"><span class="munderover" id="MathJax-Span-3865"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-3866" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.14em, 4.407em, -1000em); top: -2.932em; left: 0.124em;"><span class="texatom" id="MathJax-Span-3867"><span class="mrow" id="MathJax-Span-3868"><span class="mi" id="MathJax-Span-3869" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">j</span><span class="mo" id="MathJax-Span-3870" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-3871" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.463em, 1000.61em, 4.17em, -1000em); top: -5.169em; left: 0.412em;"><span class="texatom" id="MathJax-Span-3872"><span class="mrow" id="MathJax-Span-3873"><span class="mi" id="MathJax-Span-3874" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.821em; border-left: 0px solid; width: 0px; height: 3.947em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>j</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mi>m</mi></mrow></munderover></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-200">\\displaystyle \\sum_{j=1}^{m}</script> <var>w</var>(<var>j</var><sup>2</sup>).<br>
# You are given S(10) = 61 and S(1000) = 19403.</p>
#
# <p>Find S(5 000 000).</p>

# %%
submit_answer(answer; prob_num=558);

# %% [markdown]
# ## Problem 559: Permuted Matrices
# <p>An <b>ascent</b> of a column <var>j</var> in a matrix occurs if the value of column <var>j</var> is smaller than the value of column <var>j</var>+1 in all rows.
# </p><p>
# Let P(<var>k</var>, <var>r</var>, <var>n</var>) be the number of <var>r</var> x <var>n</var> matrices with the following properties:</p>
#
# <ul><li>The rows are permutations of {1, 2, 3, ... , <var>n</var>}.</li>
# <li> Numbering the first column as 1, a column ascent occurs at column <var>j</var>&lt;<var>n</var> <b>if and only if</b> <var>j</var> is not a multiple of <var>k</var>.</li>
#
# </ul><p>For example, P(1, 2, 3) = 19, P(2, 4, 6) = 65508751 and  P(7, 5, 30) mod 1000000123 = 161858102.</p>
#
# Let Q(<var>n</var>) =<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-201-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mspace width="thinmathspace" /&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/munderover&gt;&lt;mspace width="thinmathspace" /&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3875" style="width: 2.347em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.77em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.495em, 1001.77em, 3.56em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3876"><span class="mspace" id="MathJax-Span-3877" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span><span class="mstyle" id="MathJax-Span-3878"><span class="mrow" id="MathJax-Span-3879"><span class="munderover" id="MathJax-Span-3880"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-3881" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1001.22em, 4.27em, -1000em); top: -2.912em; left: 0.086em;"><span class="texatom" id="MathJax-Span-3882"><span class="mrow" id="MathJax-Span-3883"><span class="mi" id="MathJax-Span-3884" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-3885" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-3886" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.463em, 1000.41em, 4.17em, -1000em); top: -5.169em; left: 0.51em;"><span class="mi" id="MathJax-Span-3887" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mspace" id="MathJax-Span-3888" style="height: 0em; vertical-align: 0em; width: 0.167em; display: inline-block; overflow: hidden;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.667em; border-left: 0px solid; width: 0px; height: 3.793em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mspace width="thinmathspace"></mspace><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover><mspace width="thinmathspace"></mspace></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-201">\\,  \\displaystyle \\sum_{k=1}^n\\,</script> P(<var>k</var>, <var>n</var>, <var>n</var>).<br>
# For example, Q(5) = 21879393751 and Q(50) mod 1000000123 = 819573537.
#
# <p>Find Q(50000) mod 1000000123.</p>

# %%
submit_answer(answer; prob_num=559);

# %% [markdown]
# ## Problem 560: Coprime Nim
# <p>Coprime Nim is just like ordinary normal play Nim, but the players may only remove a number of stones from a pile  that is <b>coprime</b> with the current size of the pile. Two players remove stones in turn. The player who removes the last stone wins.</p>
#
# <p>Let L(<var>n</var>,&nbsp;<var>k</var>) be the number of <b>losing</b> starting positions for the first player, assuming perfect play, when the game is played with <var>k</var> piles, each having between 1 and <var>n</var>&nbsp;-&nbsp;1 stones inclusively.</p>
#
# <p>For example, L(5,&nbsp;2)&nbsp;=&nbsp;6 since the losing initial
# positions are (1,&nbsp;1), (2,&nbsp;2), (2,&nbsp;4), (3,&nbsp;3),
# (4,&nbsp;2) and (4,&nbsp;4).<br>
# You are also given L(10,&nbsp;5)&nbsp;=&nbsp;9964, L(10,&nbsp;10)&nbsp;=&nbsp;472400303, L(10<sup>3</sup>,&nbsp;10<sup>3</sup>)&nbsp;mod&nbsp;1&nbsp;000&nbsp;000&nbsp;007&nbsp;=&nbsp;954021836.</p>
#
# <p>Find L(10<sup>7</sup>,&nbsp;10<sup>7</sup>)&nbsp;mod&nbsp;1&nbsp;000&nbsp;000&nbsp;007</p>

# %%
submit_answer(answer; prob_num=560);

# %% [markdown]
# ## Problem 561: Divisor Pairs
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-202-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3889" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3890"><span class="mi" id="MathJax-Span-3891" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-3892" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3893" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3894" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-202">S(n)</script> be the number of pairs <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-203-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3895" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3896"><span class="mo" id="MathJax-Span-3897" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3898" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-3899" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3900" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-3901" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mi>a</mi><mo>,</mo><mi>b</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-203">(a,b)</script> of distinct divisors of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-204-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3902" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-3903"><span class="mi" id="MathJax-Span-3904" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-204">n</script> such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-205-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3905" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1000.5em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-3906"><span class="mi" id="MathJax-Span-3907" style="font-family: MathJax_Math; font-style: italic;">a</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 0.722em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>a</mi></math></span></span><script type="math/tex" id="MathJax-Element-205">a</script> divides <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-206-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3908" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.42em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-3909"><span class="mi" id="MathJax-Span-3910" style="font-family: MathJax_Math; font-style: italic;">b</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>b</mi></math></span></span><script type="math/tex" id="MathJax-Element-206">b</script>.<br>
# For <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-207-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3911" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.4em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3912"><span class="mi" id="MathJax-Span-3913" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-3914" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-3915" style="font-family: MathJax_Main; padding-left: 0.278em;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>=</mo><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-207">n=6</script> we get the following pairs: <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-208-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3916" style="width: 13.304em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.048em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1009.95em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3917"><span class="mo" id="MathJax-Span-3918" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-3919" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-3920" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3921" style="font-family: MathJax_Main; padding-left: 0.167em;">2</span><span class="mo" id="MathJax-Span-3922" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3923" style="font-family: MathJax_Main;">,</span><span class="mo" id="MathJax-Span-3924" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mn" id="MathJax-Span-3925" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-3926" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3927" style="font-family: MathJax_Main; padding-left: 0.167em;">3</span><span class="mo" id="MathJax-Span-3928" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3929" style="font-family: MathJax_Main;">,</span><span class="mo" id="MathJax-Span-3930" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mn" id="MathJax-Span-3931" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-3932" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3933" style="font-family: MathJax_Main; padding-left: 0.167em;">6</span><span class="mo" id="MathJax-Span-3934" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3935" style="font-family: MathJax_Main;">,</span><span class="mo" id="MathJax-Span-3936" style="font-family: MathJax_Main; padding-left: 0.167em;">(</span><span class="mn" id="MathJax-Span-3937" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-3938" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3939" style="font-family: MathJax_Main; padding-left: 0.167em;">6</span><span class="mo" id="MathJax-Span-3940" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mn>1</mn><mo>,</mo><mn>2</mn><mo stretchy="false">)</mo><mo>,</mo><mo stretchy="false">(</mo><mn>1</mn><mo>,</mo><mn>3</mn><mo stretchy="false">)</mo><mo>,</mo><mo stretchy="false">(</mo><mn>1</mn><mo>,</mo><mn>6</mn><mo stretchy="false">)</mo><mo>,</mo><mo stretchy="false">(</mo><mn>2</mn><mo>,</mo><mn>6</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-208">(1,2), (1,3), (1,6),( 2,6)</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-209-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3941" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3942"><span class="mo" id="MathJax-Span-3943" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-3944" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-3945" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-3946" style="font-family: MathJax_Main; padding-left: 0.167em;">6</span><span class="mo" id="MathJax-Span-3947" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mn>3</mn><mo>,</mo><mn>6</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-209">(3,6)</script>. So <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-210-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3948" style="width: 4.883em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.684em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.63em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3949"><span class="mi" id="MathJax-Span-3950" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-3951" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-3952" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-3953" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-3954" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-3955" style="font-family: MathJax_Main; padding-left: 0.278em;">5</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>5</mn></math></span></span><script type="math/tex" id="MathJax-Element-210">S(6)=5</script>.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-211-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/msub&gt;&lt;mi mathvariant="normal"&gt;&amp;#x0023;&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3956" style="width: 2.682em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.01em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1001.95em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3957"><span class="msubsup" id="MathJax-Span-3958"><span style="display: inline-block; position: relative; width: 1.199em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3959" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.503em;"><span class="mi" id="MathJax-Span-3960" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3961" style="font-family: MathJax_Main;">#</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.298em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>p</mi><mi>m</mi></msub><mi mathvariant="normal">#</mi></math></span></span><script type="math/tex" id="MathJax-Element-211">p_m\\#</script> be the product of the first <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-212-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3962" style="width: 1.151em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.84em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-3963"><span class="mi" id="MathJax-Span-3964" style="font-family: MathJax_Math; font-style: italic;">m</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>m</mi></math></span></span><script type="math/tex" id="MathJax-Element-212">m</script> prime numbers,  so <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-213-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;mi mathvariant="normal"&gt;&amp;#x0023;&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x2217;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3965" style="width: 8.902em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.746em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.842em, 1006.7em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3966"><span class="msubsup" id="MathJax-Span-3967"><span style="display: inline-block; position: relative; width: 0.932em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3968" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.503em;"><span class="mn" id="MathJax-Span-3969" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-3970" style="font-family: MathJax_Main;">#</span><span class="mo" id="MathJax-Span-3971" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-3972" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span><span class="mo" id="MathJax-Span-3973" style="font-family: MathJax_Main; padding-left: 0.222em;">∗</span><span class="mn" id="MathJax-Span-3974" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mo" id="MathJax-Span-3975" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-3976" style="font-family: MathJax_Main; padding-left: 0.278em;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.298em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>p</mi><mn>2</mn></msub><mi mathvariant="normal">#</mi><mo>=</mo><mn>2</mn><mo>∗</mo><mn>3</mn><mo>=</mo><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-213">p_2\\# = 2*3 = 6</script>.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-214-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3977" style="width: 4.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.445em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.35em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3978"><span class="mi" id="MathJax-Span-3979" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-3980" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-3981" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-3982" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-3983" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">n</span><span class="mo" id="MathJax-Span-3984" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>E</mi><mo stretchy="false">(</mo><mi>m</mi><mo>,</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-214">E(m, n)</script> be the highest integer <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-215-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3985" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-3986"><span class="mi" id="MathJax-Span-3987" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-215">k</script> such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-216-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3988" style="width: 1.294em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.957em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.174em, 1000.96em, 2.344em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-3989"><span class="msubsup" id="MathJax-Span-3990"><span style="display: inline-block; position: relative; width: 0.943em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-3991" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mi" id="MathJax-Span-3992" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.293em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>2</mn><mi>k</mi></msup></math></span></span><script type="math/tex" id="MathJax-Element-216">2^k</script> divides <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-217-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/msub&gt;&lt;mi mathvariant="normal"&gt;&amp;#x0023;&lt;/mi&gt;&lt;msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-3993" style="width: 6.222em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.689em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.59em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-3994"><span class="mi" id="MathJax-Span-3995" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-3996" style="font-family: MathJax_Main;">(</span><span class="mo" id="MathJax-Span-3997" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-3998"><span style="display: inline-block; position: relative; width: 1.199em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.5em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-3999" style="font-family: MathJax_Math; font-style: italic;">p</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.503em;"><span class="mi" id="MathJax-Span-4000" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4001" style="font-family: MathJax_Main;">#</span><span class="msubsup" id="MathJax-Span-4002"><span style="display: inline-block; position: relative; width: 0.888em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1000.29em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4003" style="font-family: MathJax_Main;">)</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.389em;"><span class="mi" id="MathJax-Span-4004" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4005" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mo stretchy="false">(</mo><msub><mi>p</mi><mi>m</mi></msub><mi mathvariant="normal">#</mi><msup><mo stretchy="false">)</mo><mi>n</mi></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-217">S((p_m\\#)^n)</script>.<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-218-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4006" style="width: 6.27em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.737em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.7em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4007"><span class="mi" id="MathJax-Span-4008" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-4009" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4010" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-4011" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-4012" style="font-family: MathJax_Main; padding-left: 0.167em;">1</span><span class="mo" id="MathJax-Span-4013" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4014" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4015" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>E</mi><mo stretchy="false">(</mo><mn>2</mn><mo>,</mo><mn>1</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-218">E(2,1) = 0</script> since <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-219-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4016" style="width: 1.199em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.909em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.194em, 1000.91em, 2.344em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4017"><span class="msubsup" id="MathJax-Span-4018"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-4019" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mn" id="MathJax-Span-4020" style="font-size: 70.7%; font-family: MathJax_Main;">0</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.267em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mn>2</mn><mn>0</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-219">2^0</script> is the highest power of 2 that divides S(6)=5.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-220-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;904961&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4021" style="width: 14.739em; display: inline-block;"><span style="display: inline-block; position: relative; width: 11.148em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.746em, 1011.05em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4022"><span class="mi" id="MathJax-Span-4023" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-4024" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4025" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4026" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4027" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-4028" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.279em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4029" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.5em, 4.17em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4030"><span class="mrow" id="MathJax-Span-4031"><span class="mi" id="MathJax-Span-4032" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.22em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4033"><span class="mrow" id="MathJax-Span-4034"><span class="mi" id="MathJax-Span-4035" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-4036" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4037" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4038" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-4039" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4040" style="font-family: MathJax_Main;">904961</span><span class="mo" id="MathJax-Span-4041" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4042" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">i</span><span class="mo" id="MathJax-Span-4043" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.555em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>i</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mi>n</mi></mrow></munderover><mi>E</mi><mo stretchy="false">(</mo><mn>904961</mn><mo>,</mo><mi>i</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-220">Q(n)=\\sum_{i=1}^{n} E(904961, i)</script><br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-221-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;8&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2714886&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4044" style="width: 8.902em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.746em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.7em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4045"><span class="mi" id="MathJax-Span-4046" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-4047" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4048" style="font-family: MathJax_Main;">8</span><span class="mo" id="MathJax-Span-4049" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4050" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4051" style="font-family: MathJax_Main; padding-left: 0.278em;">2714886</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><mn>8</mn><mo stretchy="false">)</mo><mo>=</mo><mn>2714886</mn></math></span></span><script type="math/tex" id="MathJax-Element-221">Q(8)=2714886</script>.
# </p>
# <p>
# Evaluate <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-222-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;Q&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;12&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4052" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1003.25em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4053"><span class="mi" id="MathJax-Span-4054" style="font-family: MathJax_Math; font-style: italic;">Q</span><span class="mo" id="MathJax-Span-4055" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-4056"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-4057" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-4058"><span class="mrow" id="MathJax-Span-4059"><span class="mn" id="MathJax-Span-4060" style="font-size: 70.7%; font-family: MathJax_Main;">12</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4061" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>Q</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>12</mn></mrow></msup><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-222">Q(10^{12})</script>.
# </p>

# %%
submit_answer(answer; prob_num=561);

# %% [markdown]
# ## Problem 562: Maximal perimeter
# <p>Construct triangle ABC such that:</p>
# <ul><li>Vertices A, B and C are lattice points inside or on the circle of radius <var>r</var> centered at the origin;</li>
# <li>the triangle contains no other lattice point inside or on its edges;</li>
# <li>the perimeter is maximum.</li></ul><p>Let <var>R</var> be the circumradius of triangle ABC and T(<var>r</var>) = <var>R</var>/<var>r</var>.<br>
# For <var>r</var> = 5, one possible triangle has vertices (-4,-3), (4,2)  and (1,0) with perimeter <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-223-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msqrt&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;34&lt;/mn&gt;&lt;/msqrt&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msqrt&gt;&lt;mn&gt;89&lt;/mn&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4062" style="width: 10.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.99em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.693em, 1007.99em, 2.986em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4063"><span class="msqrt" id="MathJax-Span-4064"><span style="display: inline-block; position: relative; width: 1.858em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-4065"><span class="mn" id="MathJax-Span-4066" style="font-family: MathJax_Main;">13</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1001.03em, 3.935em, -1000em); top: -4.583em; left: 0.833em;"><span style="display: inline-block; position: relative; width: 1.025em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.331em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.056em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4067" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-4068" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.858em; height: 0px;"><span style="position: absolute; clip: rect(3.199em, 1000.97em, 4.185em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-4069"><span class="mn" id="MathJax-Span-4070" style="font-family: MathJax_Main;">34</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1001.03em, 3.935em, -1000em); top: -4.589em; left: 0.833em;"><span style="display: inline-block; position: relative; width: 1.025em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.331em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.062em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4071" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msqrt" id="MathJax-Span-4072" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.858em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-4073"><span class="mn" id="MathJax-Span-4074" style="font-family: MathJax_Main;">89</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1001.03em, 3.935em, -1000em); top: -4.583em; left: 0.833em;"><span style="display: inline-block; position: relative; width: 1.025em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 0.331em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.056em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.278em; border-left: 0px solid; width: 0px; height: 1.454em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msqrt><mn>13</mn></msqrt><mo>+</mo><msqrt><mn>34</mn></msqrt><mo>+</mo><msqrt><mn>89</mn></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-223">\\sqrt{13}+\\sqrt{34}+\\sqrt{89}</script> and circumradius <var>R</var> = <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-224-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;19669&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4075" style="width: 4.117em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.11em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.884em, 1003.11em, 2.972em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4076"><span class="msqrt" id="MathJax-Span-4077"><span style="display: inline-block; position: relative; width: 3.128em; height: 0px;"><span style="position: absolute; clip: rect(2.989em, 1002.13em, 4.533em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-4078"><span class="mfrac" id="MathJax-Span-4079"><span style="display: inline-block; position: relative; width: 1.888em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.74em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.884em;"><span class="mn" id="MathJax-Span-4080" style="font-size: 70.7%; font-family: MathJax_Main;">19669</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4081" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.89em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.888em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1002.07em, 3.935em, -1000em); top: -4.919em; left: 1em;"><span style="display: inline-block; position: relative; width: 2.069em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 1.375em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="font-family: MathJax_Main; position: absolute; top: -4.019em; left: 0.414em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="font-family: MathJax_Main; position: absolute; top: -4.019em; left: 0.936em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -4.042em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.891em; border-left: 0px solid; width: 0px; height: 2.502em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msqrt><mfrac><mn>19669</mn><mn>2</mn></mfrac></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-224">\\sqrt {\\frac {19669} 2 }</script>, so T(5) =<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-225-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msqrt&gt;&lt;mfrac&gt;&lt;mn&gt;19669&lt;/mn&gt;&lt;mn&gt;50&lt;/mn&gt;&lt;/mfrac&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4082" style="width: 4.117em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.11em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.892em, 1003.11em, 2.979em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4083"><span class="msqrt" id="MathJax-Span-4084"><span style="display: inline-block; position: relative; width: 3.128em; height: 0px;"><span style="position: absolute; clip: rect(2.989em, 1002.13em, 4.549em, -1000em); top: -4.019em; left: 1em;"><span class="mrow" id="MathJax-Span-4085"><span class="mfrac" id="MathJax-Span-4086"><span style="display: inline-block; position: relative; width: 1.888em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.74em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.884em;"><span class="mn" id="MathJax-Span-4087" style="font-size: 70.7%; font-family: MathJax_Main;">19669</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.68em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.354em;"><span class="mn" id="MathJax-Span-4088" style="font-size: 70.7%; font-family: MathJax_Main;">50</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.89em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.888em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.603em, 1002.07em, 3.935em, -1000em); top: -4.911em; left: 1em;"><span style="display: inline-block; position: relative; width: 2.069em; height: 0px;"><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: -0.084em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Main; top: -4.019em; left: 1.375em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="font-family: MathJax_Main; position: absolute; top: -4.019em; left: 0.414em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="font-family: MathJax_Main; position: absolute; top: -4.019em; left: 0.936em;">−<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(2.726em, 1001.02em, 4.813em, -1000em); top: -4.034em; left: 0em;"><span style="font-family: MathJax_Size2;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.901em; border-left: 0px solid; width: 0px; height: 2.502em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msqrt><mfrac><mn>19669</mn><mn>50</mn></mfrac></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-225">\\sqrt {\\frac {19669} {50} }</script>.<br>
# You are given T(10) ~ 97.26729 and T(100) ~ 9157.64707.</p>
#
# <p>Find T(10<sup>7</sup>). Give your answer rounded to the nearest integer.</p>

# %%
submit_answer(answer; prob_num=562);

# %% [markdown]
# ## Problem 563: Robot Welders
# <p>A
#  company specialises in producing large rectangular metal sheets,
# starting from unit square metal plates.  The welding is performed by a
# range of robots of increasing size.  Unfortunately, the programming
# options of these robots are rather limited.  Each one can only process
# up to 25 identical rectangles of metal, which they can weld along either
#  edge to produce a larger rectangle.  The only programmable variables
# are the number of rectangles to be processed (up to and including 25),
# and whether to weld the long or short edge.</p>
#
# <p>For example, the first robot could be programmed to weld together 11
# raw unit square plates to make a 11×1 strip.  The next could take 10 of
# these 11×1 strips, and weld them either to make a longer 110×1 strip, or
#  a 11×10 rectangle.  Many, but not all, possible dimensions of  metal
# sheets can be constructed in this way.</p>
#
# <p>One regular customer has a particularly unusual order.  He always
# demands that the finished product should have an exact area, and that
# the long side must not be more than 10% larger than the short side.  If
# these requirements can be met in more than one way, in terms of the
# exact dimensions of the two sides, then he demands that all variants are
#  produced.  For example, if he were to ask for metal sheet of area
# 889200, then there are three final dimensions that can be produced:
# 900×988, 912×975 and 936×950.  The target area of 889200 is the smallest
#  area which can be manufactured in three different variants, within the
# limitations of the robot welders.</p>
#
# <p>Let M(n) be the minimal area that can be manufactured in <u>exactly</u> n variants with the longer edge not greater than 10% bigger than the shorter edge.  Hence M(3) = 889200.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-226-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4089" style="width: 6.701em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.072em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.588em, 1004.98em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4090"><span class="munderover" id="MathJax-Span-4091"><span style="display: inline-block; position: relative; width: 2.459em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4092" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.14em, 4.178em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4093"><span class="mrow" id="MathJax-Span-4094"><span class="mn" id="MathJax-Span-4095" style="font-size: 70.7%; font-family: MathJax_Main;">100</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.4em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4096"><span class="mrow" id="MathJax-Span-4097"><span class="mi" id="MathJax-Span-4098" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4099" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4100" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4101" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-4102" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4103" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4104" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.764em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>2</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>100</mn></mrow></munderover><mi>M</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-226"> \\sum_{n=2}^{100} M(n)</script>.</p>

# %%
submit_answer(answer; prob_num=563);

# %% [markdown]
# ## Problem 564: Maximal polygons
# <p>A line segment of length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-227-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4105" style="width: 3.687em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.775em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1002.73em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4106"><span class="mn" id="MathJax-Span-4107" style="font-family: MathJax_Main;">2</span><span class="mi" id="MathJax-Span-4108" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4109" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-4110" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.114em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn><mi>n</mi><mo>−</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-227">2n-3</script> is randomly split into <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-228-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4111" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4112"><span class="mi" id="MathJax-Span-4113" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-228">n</script> segments of integer length (<span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-229-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4114" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1002.4em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4115"><span class="mi" id="MathJax-Span-4116" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4117" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mn" id="MathJax-Span-4118" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.186em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>≥</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-229">n \\ge 3</script>). In the sequence given by this split, the segments are then used as consecutive sides of a convex <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-230-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4119" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4120"><span class="mi" id="MathJax-Span-4121" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-230">n</script>-polygon, formed in such a way that its area is maximal.  All of the <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-231-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mrow&gt;&lt;mrow class="MJX-TeXAtom-OPEN"&gt;&lt;mo maxsize="1.2em" minsize="1.2em"&gt;(&lt;/mo&gt;&lt;/mrow&gt;&lt;mfrac linethickness="0"&gt;&lt;mrow&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;mrow class="MJX-TeXAtom-CLOSE"&gt;&lt;mo maxsize="1.2em" minsize="1.2em"&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;/mrow&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4122" style="width: 3.495em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.632em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.661em, 1002.48em, 3.274em, -1000em); top: -2.727em; left: 0em;"><span class="mrow" id="MathJax-Span-4123"><span class="mrow" id="MathJax-Span-4124"><span class="TeXmathchoice" id="MathJax-Span-4125"><span class="texatom" id="MathJax-Span-4126"><span class="mrow" id="MathJax-Span-4127"><span class="mo" id="MathJax-Span-4128" style="vertical-align: 0em;"><span style="font-family: MathJax_Size1;">(</span></span></span></span></span><span class="mfrac" id="MathJax-Span-4129"><span style="display: inline-block; position: relative; width: 1.681em; height: 0px;"><span style="position: absolute; clip: rect(3.397em, 1001.66em, 4.221em, -1000em); top: -4.463em; left: 50%; margin-left: -0.841em;"><span class="mrow" id="MathJax-Span-4130"><span class="mn" id="MathJax-Span-4131" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span class="mi" id="MathJax-Span-4132" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4133" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-4134" style="font-size: 70.7%; font-family: MathJax_Main;">4</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.28em, 4.221em, -1000em); top: -3.674em; left: 50%; margin-left: -0.664em;"><span class="mrow" id="MathJax-Span-4135"><span class="mi" id="MathJax-Span-4136" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4137" style="font-size: 70.7%; font-family: MathJax_Main;">−</span><span class="mn" id="MathJax-Span-4138" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="TeXmathchoice" id="MathJax-Span-4139"><span class="texatom" id="MathJax-Span-4140"><span class="mrow" id="MathJax-Span-4141"><span class="mo" id="MathJax-Span-4142" style="vertical-align: 0em;"><span style="font-family: MathJax_Size1;">)</span></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.727em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.595em; border-left: 0px solid; width: 0px; height: 1.876em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow><mrow class="MJX-TeXAtom-OPEN"><mo maxsize="1.2em" minsize="1.2em">(</mo></mrow><mfrac linethickness="0"><mrow><mn>2</mn><mi>n</mi><mo>−</mo><mn>4</mn></mrow><mrow><mi>n</mi><mo>−</mo><mn>1</mn></mrow></mfrac><mrow class="MJX-TeXAtom-CLOSE"><mo maxsize="1.2em" minsize="1.2em">)</mo></mrow></mrow></math></span></span><script type="math/tex" id="MathJax-Element-231">\\binom{2n-4} {n-1}</script> possibilities for splitting up the initial line segment occur with the same probability. </p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-232-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4143" style="width: 2.873em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.153em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4144"><span class="mi" id="MathJax-Span-4145" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-4146" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4147" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4148" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>E</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-232">E(n)</script> be the expected value of the area that is obtained by this procedure.<br>
# For example, for <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-233-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4149" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1002.4em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4150"><span class="mi" id="MathJax-Span-4151" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4152" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4153" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.033em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>=</mo><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-233">n=3</script> the only possible split of the line segment of length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-234-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4154" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4155"><span class="mn" id="MathJax-Span-4156" style="font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.033em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-234">3</script> results in three line segments with length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-235-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4157" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4158"><span class="mn" id="MathJax-Span-4159" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-235">1</script>, that form an equilateral triangle with an area of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-236-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/mfrac&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4160" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1002.06em, 2.723em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4161"><span class="mfrac" id="MathJax-Span-4162"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4163" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.397em, 1000.33em, 4.163em, -1000em); top: -3.641em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4164" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="msqrt" id="MathJax-Span-4165"><span style="display: inline-block; position: relative; width: 1.333em; height: 0px;"><span style="position: absolute; clip: rect(3.211em, 1000.46em, 4.185em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-4166"><span class="mn" id="MathJax-Span-4167" style="font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.591em, 1000.5em, 3.915em, -1000em); top: -4.571em; left: 0.833em;"><span style="font-family: MathJax_Main;">–</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.056em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.563em; border-left: 0px solid; width: 0px; height: 1.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mn>4</mn></mfrac><msqrt><mn>3</mn></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-236">\\frac 1 4 \\sqrt{3}</script>. Therefore <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-237-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.433013&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4168" style="width: 9.189em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.938em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.9em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4169"><span class="mi" id="MathJax-Span-4170" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-4171" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4172" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-4173" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4174" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4175" style="font-family: MathJax_Main; padding-left: 0.278em;">0.433013</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>E</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.433013</mn></math></span></span><script type="math/tex" id="MathJax-Element-237">E(3)=0.433013</script>, rounded to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-238-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4176" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4177"><span class="mn" id="MathJax-Span-4178" style="font-family: MathJax_Main;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-238">6</script> decimal places.<br>
# For <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-239-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4179" style="width: 3.256em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.44em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.859em, 1002.41em, 2.834em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4180"><span class="mi" id="MathJax-Span-4181" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4182" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4183" style="font-family: MathJax_Main; padding-left: 0.278em;">4</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi><mo>=</mo><mn>4</mn></math></span></span><script type="math/tex" id="MathJax-Element-239">n=4</script> you can find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-240-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4184" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.859em, 1000.45em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4185"><span class="mn" id="MathJax-Span-4186" style="font-family: MathJax_Main;">4</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.02em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>4</mn></math></span></span><script type="math/tex" id="MathJax-Element-240">4</script> different possible splits, each of which is composed of three line segments with length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-241-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4187" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4188"><span class="mn" id="MathJax-Span-4189" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-241">1</script> and one line segment with length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-242-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4190" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4191"><span class="mn" id="MathJax-Span-4192" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-242">2</script>. All of these splits lead to the same maximal quadrilateral with an area of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-243-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/mfrac&gt;&lt;msqrt&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msqrt&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4193" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.172em, 1002.06em, 2.723em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4194"><span class="mfrac" id="MathJax-Span-4195"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4196" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.397em, 1000.33em, 4.163em, -1000em); top: -3.641em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4197" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span><span class="msqrt" id="MathJax-Span-4198"><span style="display: inline-block; position: relative; width: 1.333em; height: 0px;"><span style="position: absolute; clip: rect(3.211em, 1000.46em, 4.185em, -1000em); top: -4.019em; left: 0.833em;"><span class="mrow" id="MathJax-Span-4199"><span class="mn" id="MathJax-Span-4200" style="font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.591em, 1000.5em, 3.915em, -1000em); top: -4.571em; left: 0.833em;"><span style="font-family: MathJax_Main;">–</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.076em, 1000.85em, 4.363em, -1000em); top: -4.056em; left: 0em;"><span style="font-family: MathJax_Main;">√</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.563em; border-left: 0px solid; width: 0px; height: 1.795em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>3</mn><mn>4</mn></mfrac><msqrt><mn>3</mn></msqrt></math></span></span><script type="math/tex" id="MathJax-Element-243">\\frac 3 4 \\sqrt{3}</script>, thus <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-244-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1.299038&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4201" style="width: 9.189em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.938em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.9em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4202"><span class="mi" id="MathJax-Span-4203" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-4204" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4205" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-4206" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4207" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4208" style="font-family: MathJax_Main; padding-left: 0.278em;">1.299038</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>E</mi><mo stretchy="false">(</mo><mn>4</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1.299038</mn></math></span></span><script type="math/tex" id="MathJax-Element-244">E(4)=1.299038</script>, rounded to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-245-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4209" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4210"><span class="mn" id="MathJax-Span-4211" style="font-family: MathJax_Main;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-245">6</script> decimal places.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-246-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/munderover&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4212" style="width: 9.285em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.033em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.795em, 1006.94em, 4.025em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4213"><span class="mi" id="MathJax-Span-4214" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4215" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4216" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-4217" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4218" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mstyle" id="MathJax-Span-4219" style="padding-left: 0.278em;"><span class="mrow" id="MathJax-Span-4220"><span class="munderover" id="MathJax-Span-4221"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4222" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.3em, 4.278em, -1000em); top: -2.932em; left: 0.058em;"><span class="texatom" id="MathJax-Span-4223"><span class="mrow" id="MathJax-Span-4224"><span class="mi" id="MathJax-Span-4225" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4226" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4227" style="font-size: 70.7%; font-family: MathJax_Main;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.285em, 1000.36em, 4.17em, -1000em); top: -5.169em; left: 0.538em;"><span class="mi" id="MathJax-Span-4228" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4229" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span class="mo" id="MathJax-Span-4230" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4231" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4232" style="font-family: MathJax_Main;">)</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.65em; border-left: 0px solid; width: 0px; height: 4.011em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>=</mo><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>3</mn></mrow><mi>k</mi></munderover><mi>E</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-246">S(k)=\\displaystyle \\sum_{n=3}^k E(n)</script>.<br>
# For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-247-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.433013&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4233" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.8em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4234"><span class="mi" id="MathJax-Span-4235" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4236" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4237" style="font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-4238" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4239" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4240" style="font-family: MathJax_Main; padding-left: 0.278em;">0.433013</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>3</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.433013</mn></math></span></span><script type="math/tex" id="MathJax-Element-247">S(3)=0.433013</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-248-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1.732051&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4241" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.77em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4242"><span class="mi" id="MathJax-Span-4243" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4244" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4245" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-4246" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4247" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4248" style="font-family: MathJax_Main; padding-left: 0.278em;">1.732051</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>4</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1.732051</mn></math></span></span><script type="math/tex" id="MathJax-Element-248">S(4)=1.732051</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-249-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;4.604767&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4249" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.83em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4250"><span class="mi" id="MathJax-Span-4251" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4252" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4253" style="font-family: MathJax_Main;">5</span><span class="mo" id="MathJax-Span-4254" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4255" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4256" style="font-family: MathJax_Main; padding-left: 0.278em;">4.604767</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>5</mn><mo stretchy="false">)</mo><mo>=</mo><mn>4.604767</mn></math></span></span><script type="math/tex" id="MathJax-Element-249">S(5)=4.604767</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-250-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;66.955511&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4257" style="width: 10.289em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.799em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4258"><span class="mi" id="MathJax-Span-4259" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4260" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4261" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-4262" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4263" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4264" style="font-family: MathJax_Main; padding-left: 0.278em;">66.955511</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>66.955511</mn></math></span></span><script type="math/tex" id="MathJax-Element-250">S(10)=66.955511</script>, rounded to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-251-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4265" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4266"><span class="mn" id="MathJax-Span-4267" style="font-family: MathJax_Main;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-251">6</script> decimal places each.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-252-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;50&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4268" style="width: 3.16em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.392em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.3em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4269"><span class="mi" id="MathJax-Span-4270" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4271" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4272" style="font-family: MathJax_Main;">50</span><span class="mo" id="MathJax-Span-4273" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>50</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-252">S(50)</script>, rounded to <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-253-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4274" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4275"><span class="mn" id="MathJax-Span-4276" style="font-family: MathJax_Main;">6</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.034em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>6</mn></math></span></span><script type="math/tex" id="MathJax-Element-253">6</script> decimal places.</p>

# %%
submit_answer(answer; prob_num=564);

# %% [markdown]
# ## Problem 565: Divisibility of sum of divisors
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-254-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C3;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4277" style="width: 2.586em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.962em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.87em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4278"><span class="mi" id="MathJax-Span-4279" style="font-family: MathJax_Math; font-style: italic;">σ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.001em;"></span></span><span class="mo" id="MathJax-Span-4280" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4281" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4282" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>σ</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-254">\\sigma(n)</script> be the sum of the divisors of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-255-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4283" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4284"><span class="mi" id="MathJax-Span-4285" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-255">n</script>.<br>
# E.g. the divisors of 4 are 1, 2 and 4, so <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-256-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C3;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4286" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.62em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4287"><span class="mi" id="MathJax-Span-4288" style="font-family: MathJax_Math; font-style: italic;">σ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.001em;"></span></span><span class="mo" id="MathJax-Span-4289" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4290" style="font-family: MathJax_Main;">4</span><span class="mo" id="MathJax-Span-4291" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4292" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4293" style="font-family: MathJax_Main; padding-left: 0.278em;">7</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>σ</mi><mo stretchy="false">(</mo><mn>4</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7</mn></math></span></span><script type="math/tex" id="MathJax-Element-256">\\sigma(4)=7</script>.
# </p>
# <p>
# The numbers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-257-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4294" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4295"><span class="mi" id="MathJax-Span-4296" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-257">n</script> not exceeding 20 such that 7 divides  <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-258-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C3;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4297" style="width: 2.586em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.962em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.87em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4298"><span class="mi" id="MathJax-Span-4299" style="font-family: MathJax_Math; font-style: italic;">σ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.001em;"></span></span><span class="mo" id="MathJax-Span-4300" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4301" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4302" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>σ</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-258">\\sigma(n)</script> are:  4,12,13 and 20, the sum of these numbers being 49.
# </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-259-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4303" style="width: 3.974em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.014em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.92em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4304"><span class="mi" id="MathJax-Span-4305" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4306" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4307" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4308" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4309" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-4310" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo>,</mo><mi>d</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-259">S(n , d)</script> be the sum of the numbers <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-260-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4311" style="width: 0.481em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.335em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.636em, 1000.29em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4312"><span class="mi" id="MathJax-Span-4313" style="font-family: MathJax_Math; font-style: italic;">i</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.013em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>i</mi></math></span></span><script type="math/tex" id="MathJax-Element-260">i</script> not exceeding <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-261-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4314" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4315"><span class="mi" id="MathJax-Span-4316" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-261">n</script> such that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-262-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4317" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.53em, 2.594em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4318"><span class="mi" id="MathJax-Span-4319" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.076em; border-left: 0px solid; width: 0px; height: 1.056em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>d</mi></math></span></span><script type="math/tex" id="MathJax-Element-262">d</script> divides <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-263-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;&amp;#x03C3;&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4320" style="width: 2.251em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.675em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.58em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4321"><span class="mi" id="MathJax-Span-4322" style="font-family: MathJax_Math; font-style: italic;">σ<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.001em;"></span></span><span class="mo" id="MathJax-Span-4323" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4324" style="font-family: MathJax_Math; font-style: italic;">i</span><span class="mo" id="MathJax-Span-4325" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>σ</mi><mo stretchy="false">(</mo><mi>i</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-263">\\sigma(i)</script>.<br>
# So <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-264-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;20&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;49&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4326" style="width: 7.419em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.598em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.55em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4327"><span class="mi" id="MathJax-Span-4328" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4329" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4330" style="font-family: MathJax_Main;">20</span><span class="mo" id="MathJax-Span-4331" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-4332" style="font-family: MathJax_Main; padding-left: 0.167em;">7</span><span class="mo" id="MathJax-Span-4333" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4334" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4335" style="font-family: MathJax_Main; padding-left: 0.278em;">49</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>20</mn><mo>,</mo><mn>7</mn><mo stretchy="false">)</mo><mo>=</mo><mn>49</mn></math></span></span><script type="math/tex" id="MathJax-Element-264">S(20 , 7)=49</script>.
#
# </p>
# <p>
# You are given: <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-265-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2017&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;150850429&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4336" style="width: 14.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 10.861em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1010.82em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4337"><span class="mi" id="MathJax-Span-4338" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4339" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-4340"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-4341" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-4342" style="font-size: 70.7%; font-family: MathJax_Main;">6</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4343" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-4344" style="font-family: MathJax_Main; padding-left: 0.167em;">2017</span><span class="mo" id="MathJax-Span-4345" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4346" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4347" style="font-family: MathJax_Main; padding-left: 0.278em;">150850429</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>6</mn></msup><mo>,</mo><mn>2017</mn><mo stretchy="false">)</mo><mo>=</mo><mn>150850429</mn></math></span></span><script type="math/tex" id="MathJax-Element-265">S(10^6,2017)=150850429</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-266-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2017&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;249652238344557&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4348" style="width: 18.136em; display: inline-block;"><span style="display: inline-block; position: relative; width: 13.732em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1013.72em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4349"><span class="mi" id="MathJax-Span-4350" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4351" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-4352"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-4353" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-4354" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4355" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-4356" style="font-family: MathJax_Main; padding-left: 0.167em;">2017</span><span class="mo" id="MathJax-Span-4357" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4358" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4359" style="font-family: MathJax_Main; padding-left: 0.278em;">249652238344557</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mn>9</mn></msup><mo>,</mo><mn>2017</mn><mo stretchy="false">)</mo><mo>=</mo><mn>249652238344557</mn></math></span></span><script type="math/tex" id="MathJax-Element-266">S(10^9 , 2017)=249652238344557</script>.
# </p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-267-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2017&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4360" style="width: 7.323em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.55em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1005.46em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4361"><span class="mi" id="MathJax-Span-4362" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4363" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-4364"><span style="display: inline-block; position: relative; width: 1.782em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-4365" style="font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="texatom" id="MathJax-Span-4366"><span class="mrow" id="MathJax-Span-4367"><span class="mn" id="MathJax-Span-4368" style="font-size: 70.7%; font-family: MathJax_Main;">11</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4369" style="font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-4370" style="font-family: MathJax_Main; padding-left: 0.167em;">2017</span><span class="mo" id="MathJax-Span-4371" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.597em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><msup><mn>10</mn><mrow class="MJX-TeXAtom-ORD"><mn>11</mn></mrow></msup><mo>,</mo><mn>2017</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-267">S(10^{11} , 2017)</script>
# </p>

# %%
submit_answer(answer; prob_num=565);

# %% [markdown]
# ## Problem 566: Cake Icing Puzzle
# <p>Adam plays the following game with his birthday cake.</p>
#
# <p>He cuts a piece forming a circular sector of 60 degrees and flips the piece upside down, with the icing on the bottom.<br>
# He then rotates the cake by 60 degrees counterclockwise, cuts an adjacent 60 degree piece and flips it upside down.<br>
# He keeps repeating this, until after a total of twelve steps, all the icing is back on top.</p>
#
# <p>Amazingly, this works for any piece size, even if the cutting angle
# is an irrational number: all the icing will be back on top after a
# finite number of steps.</p>
#
# <p>Now, Adam tries something different: he alternates cutting pieces of size <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-268-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;360&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4372" style="width: 4.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.301em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1003.3em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4373"><span class="mi" id="MathJax-Span-4374" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-4375" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4376" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.181em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.03em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.53em;"><span class="mn" id="MathJax-Span-4377" style="font-size: 70.7%; font-family: MathJax_Main;">360</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4378" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.18em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.181em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.806em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi><mo>=</mo><mfrac><mn>360</mn><mn>9</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-268">x=\\frac{360}{9}</script> degrees, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-269-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;360&lt;/mn&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4379" style="width: 4.261em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.206em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1003.21em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4380"><span class="mi" id="MathJax-Span-4381" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-4382" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4383" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.181em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.03em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.53em;"><span class="mn" id="MathJax-Span-4384" style="font-size: 70.7%; font-family: MathJax_Main;">360</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.68em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.354em;"><span class="mn" id="MathJax-Span-4385" style="font-size: 70.7%; font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.18em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.181em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.806em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi><mo>=</mo><mfrac><mn>360</mn><mn>10</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-269">y=\\frac{360}{10}</script> degrees and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-270-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;360&lt;/mn&gt;&lt;msqrt&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;/msqrt&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4386" style="width: 4.548em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.445em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1003.45em, 3.43em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4387"><span class="mi" id="MathJax-Span-4388" style="font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-4389" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4390" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.416em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.03em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.53em;"><span class="mn" id="MathJax-Span-4391" style="font-size: 70.7%; font-family: MathJax_Main;">360</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.289em, 1001.3em, 4.283em, -1000em); top: -3.533em; left: 50%; margin-left: -0.648em;"><span class="msqrt" id="MathJax-Span-4392"><span style="display: inline-block; position: relative; width: 1.296em; height: 0px;"><span style="position: absolute; clip: rect(3.405em, 1000.66em, 4.163em, -1000em); top: -4.019em; left: 0.589em;"><span class="mrow" id="MathJax-Span-4393"><span class="mn" id="MathJax-Span-4394" style="font-size: 70.7%; font-family: MathJax_Main;">11</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.952em, 1000.71em, 1.256em, -1000em); top: -1.682em; left: 0.589em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.707em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.31em, 1000.6em, 4.304em, -1000em); top: -4.04em; left: 0em;"><span><span style="font-size: 70.7%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.42em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.416em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.864em; border-left: 0px solid; width: 0px; height: 2.097em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>z</mi><mo>=</mo><mfrac><mn>360</mn><msqrt><mn>11</mn></msqrt></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-270">z=\\frac{360 }{\\sqrt{11}}</script> degrees. The first piece he cuts has size <var>x</var> and he flips it. The second has size <var>y</var> and he flips it. The third has size <var>z</var> and he flips it. He repeats this with pieces of size <var>x</var>, <var>y</var> and <var>z</var> in that order until all the icing is back on top, and discovers he needs 60 flips altogether.</p>
#
# <div align="center"><img src="webfiles/p566-cakeicingpuzzle.gif" alt="p566-cakeicingpuzzle.gif"></div>
#
# <p>Let <var>F</var>(<var>a</var>, <var>b</var>, <var>c</var>) be the minimum number of piece flips needed to get all the icing back on top for pieces of size <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-271-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;360&lt;/mn&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4395" style="width: 4.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.301em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1003.3em, 3.175em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4396"><span class="mi" id="MathJax-Span-4397" style="font-family: MathJax_Math; font-style: italic;">x</span><span class="mo" id="MathJax-Span-4398" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4399" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.181em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.03em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.53em;"><span class="mn" id="MathJax-Span-4400" style="font-size: 70.7%; font-family: MathJax_Main;">360</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.564em, 1000.36em, 4.17em, -1000em); top: -3.674em; left: 50%; margin-left: -0.187em;"><span class="mi" id="MathJax-Span-4401" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.18em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.181em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.528em; border-left: 0px solid; width: 0px; height: 1.761em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>x</mi><mo>=</mo><mfrac><mn>360</mn><mi>a</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-271">x=\\frac{360}{a}</script> degrees, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-272-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;360&lt;/mn&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4402" style="width: 4.261em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.206em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1003.21em, 3.221em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4403"><span class="mi" id="MathJax-Span-4404" style="font-family: MathJax_Math; font-style: italic;">y<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.006em;"></span></span><span class="mo" id="MathJax-Span-4405" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4406" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.181em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.03em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.53em;"><span class="mn" id="MathJax-Span-4407" style="font-size: 70.7%; font-family: MathJax_Main;">360</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.3em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.152em;"><span class="mi" id="MathJax-Span-4408" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.18em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.181em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.822em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>y</mi><mo>=</mo><mfrac><mn>360</mn><mi>b</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-272">y=\\frac{360}{b}</script> degrees and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-273-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;360&lt;/mn&gt;&lt;msqrt&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;/msqrt&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4409" style="width: 4.261em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.206em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.65em, 1003.21em, 3.43em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4410"><span class="mi" id="MathJax-Span-4411" style="font-family: MathJax_Math; font-style: italic;">z<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-4412" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4413" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.181em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1001.03em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.53em;"><span class="mn" id="MathJax-Span-4414" style="font-size: 70.7%; font-family: MathJax_Main;">360</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.372em, 1000.9em, 4.366em, -1000em); top: -3.616em; left: 50%; margin-left: -0.448em;"><span class="msqrt" id="MathJax-Span-4415"><span style="display: inline-block; position: relative; width: 0.895em; height: 0px;"><span style="position: absolute; clip: rect(3.563em, 1000.3em, 4.17em, -1000em); top: -4.019em; left: 0.589em;"><span class="mrow" id="MathJax-Span-4416"><span class="mi" id="MathJax-Span-4417" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">c</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.952em, 1000.31em, 1.256em, -1000em); top: -1.599em; left: 0.589em;"><span style="display: inline-block; overflow: hidden; vertical-align: -0.06em; border-top: 1.2px solid; width: 0.306em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span><span style="position: absolute; clip: rect(3.31em, 1000.6em, 4.304em, -1000em); top: -3.957em; left: 0em;"><span><span style="font-size: 70.7%; font-family: MathJax_Main;">√</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.18em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.181em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.864em; border-left: 0px solid; width: 0px; height: 2.097em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>z</mi><mo>=</mo><mfrac><mn>360</mn><msqrt><mi>c</mi></msqrt></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-273">z=\\frac{360}{\\sqrt{c}}</script> degrees.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-274-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mi&gt;F&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4418" style="width: 16.557em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.536em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1012.44em, 3.206em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4419"><span class="mi" id="MathJax-Span-4420" style="font-family: MathJax_Math; font-style: italic;">G</span><span class="mo" id="MathJax-Span-4421" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4422" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4423" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4424" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-4425" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 5.093em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4426" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4427"><span class="mrow" id="MathJax-Span-4428"><span class="mn" id="MathJax-Span-4429" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span class="mo" id="MathJax-Span-4430" style="font-size: 70.7%; font-family: MathJax_Main;">≤</span><span class="mi" id="MathJax-Span-4431" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-4432" style="font-size: 70.7%; font-family: MathJax_Main;">&lt;</span><span class="mi" id="MathJax-Span-4433" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">b</span><span class="mo" id="MathJax-Span-4434" style="font-size: 70.7%; font-family: MathJax_Main;">&lt;</span><span class="mi" id="MathJax-Span-4435" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">c</span><span class="mo" id="MathJax-Span-4436" style="font-size: 70.7%; font-family: MathJax_Main;">≤</span><span class="mi" id="MathJax-Span-4437" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4438" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">F<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.106em;"></span></span><span class="mo" id="MathJax-Span-4439" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4440" style="font-family: MathJax_Math; font-style: italic;">a</span><span class="mo" id="MathJax-Span-4441" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4442" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-4443" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4444" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">c</span><span class="mo" id="MathJax-Span-4445" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.569em; border-left: 0px solid; width: 0px; height: 1.622em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>G</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><munder><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mn>9</mn><mo>≤</mo><mi>a</mi><mo>&lt;</mo><mi>b</mi><mo>&lt;</mo><mi>c</mi><mo>≤</mo><mi>n</mi></mrow></munder><mi>F</mi><mo stretchy="false">(</mo><mi>a</mi><mo>,</mo><mi>b</mi><mo>,</mo><mi>c</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-274">G(n) = \\sum_{9 \\le a < b < c \\le n} F(a,b,c)</script>, for integers <var>a</var>, <var>b</var> and <var>c</var>.</p>
#
# <p>You are given that <var>F</var>(9,&nbsp;10,&nbsp;11)&nbsp;=&nbsp;60, <var>F</var>(10,&nbsp;14,&nbsp;16)&nbsp;=&nbsp;506, <var>F</var>(15,&nbsp;16,&nbsp;17)&nbsp;=&nbsp;785232.<br>
# You are also given <var>G</var>(11)&nbsp;=&nbsp;60, <var>G</var>(14)&nbsp;=&nbsp;58020 and <var>G</var>(17)&nbsp;=&nbsp;1269260.</p>
#
# <p>Find <var>G</var>(53).</p>

# %%
submit_answer(answer; prob_num=566);

# %% [markdown]
# ## Problem 567: Reciprocal games I
# <p>Tom has built a random generator that is connected to a row of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-275-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4446" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4447"><span class="mi" id="MathJax-Span-4448" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-275">n</script> light bulbs. Whenever the random generator is activated each of the <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-276-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4449" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4450"><span class="mi" id="MathJax-Span-4451" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-276">n</script> lights is turned on with the probability of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-277-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4452" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.715em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4453"><span class="mfrac" id="MathJax-Span-4454"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4455" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4456" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.552em; border-left: 0px solid; width: 0px; height: 1.765em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mn>2</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-277">\\frac 1 2</script>, independently of its former state or the state of the other light bulbs.</p>
#
# <p>While discussing with his friend Jerry how to use his generator, they invent two different games, they call the <i>reciprocal games</i>:<br>
# Both games consist of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-278-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4457" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4458"><span class="mi" id="MathJax-Span-4459" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-278">n</script> turns. Each turn is started by choosing a number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-279-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4460" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4461"><span class="mi" id="MathJax-Span-4462" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-279">k</script> randomly between (and including) <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-280-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4463" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4464"><span class="mn" id="MathJax-Span-4465" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-280">1</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-281-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4466" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4467"><span class="mi" id="MathJax-Span-4468" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-281">n</script>, with equal probability of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-282-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4469" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.77em, 2.697em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4470"><span class="mfrac" id="MathJax-Span-4471"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4472" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.41em, 4.17em, -1000em); top: -3.674em; left: 50%; margin-left: -0.212em;"><span class="mi" id="MathJax-Span-4473" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.54em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.544em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.529em; border-left: 0px solid; width: 0px; height: 1.741em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>n</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-282">\\frac 1 n</script> for each number, while the possible win for that turn is the reciprocal of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-283-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4474" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4475"><span class="mi" id="MathJax-Span-4476" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-283">k</script>, that is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-284-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4477" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.743em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4478"><span class="mfrac" id="MathJax-Span-4479"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4480" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-4481" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.801em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>k</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-284">\\frac 1 k</script>.</p>
#
# <p>In game A, Tom activates his random generator once in each turn. If
# the number of lights turned on is the same as the previously chosen
# number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-285-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4482" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4483"><span class="mi" id="MathJax-Span-4484" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-285">k</script>, Jerry wins and gets <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-286-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4485" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.743em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4486"><span class="mfrac" id="MathJax-Span-4487"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4488" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-4489" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.801em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>k</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-286">\\frac 1 k</script>, otherwise he will receive nothing for that turn. Jerry's expected win after playing the total game A consisting of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-287-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4490" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4491"><span class="mi" id="MathJax-Span-4492" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-287">n</script> turns is called <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-288-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4493" style="width: 3.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.536em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.44em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4494"><span class="msubsup" id="MathJax-Span-4495"><span style="display: inline-block; position: relative; width: 1.16em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4496" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.857em; left: 0.555em;"><span class="mi" id="MathJax-Span-4497" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4498" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4499" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4500" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>A</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-288">J_A(n)</script>. For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-289-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.39505208&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4501" style="width: 11.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.325em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1008.28em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4502"><span class="msubsup" id="MathJax-Span-4503"><span style="display: inline-block; position: relative; width: 1.16em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4504" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.857em; left: 0.555em;"><span class="mi" id="MathJax-Span-4505" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4506" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4507" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-4508" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4509" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4510" style="font-family: MathJax_Main; padding-left: 0.278em;">0.39505208</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>A</mi></msub><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.39505208</mn></math></span></span><script type="math/tex" id="MathJax-Element-289">J_A(6)=0.39505208</script>, rounded to 8 decimal places.</p>
#
# <p>For each turn in game B, after <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-290-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4511" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4512"><span class="mi" id="MathJax-Span-4513" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-290">k</script> has been randomly selected, Tom keeps reactivating his random generator until exactly <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-291-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4514" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4515"><span class="mi" id="MathJax-Span-4516" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-291">k</script>
#  lights are turned on. After that Jerry takes over and reactivates the
# random generator until he, too, has generated a pattern with exactly <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-292-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4517" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4518"><span class="mi" id="MathJax-Span-4519" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-292">k</script> lights turned on. If this pattern is identical to Tom's last pattern, Jerry wins and gets <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-293-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4520" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.743em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4521"><span class="mfrac" id="MathJax-Span-4522"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4523" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-4524" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.801em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>k</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-293">\\frac 1 k</script>, otherwise he will receive nothing. Jerry's expected win after the total game B consisting of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-294-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4525" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4526"><span class="mi" id="MathJax-Span-4527" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-294">n</script> turns is called <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-295-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4528" style="width: 3.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.536em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.44em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4529"><span class="msubsup" id="MathJax-Span-4530"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4531" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.555em;"><span class="mi" id="MathJax-Span-4532" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">B</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4533" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4534" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4535" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>B</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-295">J_B(n)</script>. For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-296-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.43333333&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4536" style="width: 11.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.325em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1008.28em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4537"><span class="msubsup" id="MathJax-Span-4538"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4539" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.555em;"><span class="mi" id="MathJax-Span-4540" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">B</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4541" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4542" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-4543" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4544" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4545" style="font-family: MathJax_Main; padding-left: 0.278em;">0.43333333</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>B</mi></msub><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.43333333</mn></math></span></span><script type="math/tex" id="MathJax-Element-296">J_B(6)=0.43333333</script>, rounded to 8 decimal places.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-297-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/munderover&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4546" style="width: 15.983em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.105em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.973em, 1012.01em, 4.018em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4547"><span class="mstyle" id="MathJax-Span-4548"><span class="mrow" id="MathJax-Span-4549"><span class="mi" id="MathJax-Span-4550" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4551" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4552" style="font-family: MathJax_Math; font-style: italic;">m</span><span class="mo" id="MathJax-Span-4553" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4554" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-4555" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4556" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.28em, 4.27em, -1000em); top: -2.932em; left: 0.058em;"><span class="texatom" id="MathJax-Span-4557"><span class="mrow" id="MathJax-Span-4558"><span class="mi" id="MathJax-Span-4559" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4560" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4561" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.463em, 1000.61em, 4.17em, -1000em); top: -5.169em; left: 0.412em;"><span class="mi" id="MathJax-Span-4562" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">m</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4563" style="font-family: MathJax_Main;">(</span><span class="msubsup" id="MathJax-Span-4564"><span style="display: inline-block; position: relative; width: 1.16em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4565" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.857em; left: 0.555em;"><span class="mi" id="MathJax-Span-4566" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4567" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4568" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4569" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4570" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="msubsup" id="MathJax-Span-4571" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4572" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.555em;"><span class="mi" id="MathJax-Span-4573" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">B</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4574" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4575" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4576" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4577" style="font-family: MathJax_Main;">)</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.641em; border-left: 0px solid; width: 0px; height: 3.767em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><mi>S</mi><mo stretchy="false">(</mo><mi>m</mi><mo stretchy="false">)</mo><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>1</mn></mrow><mi>m</mi></munderover><mo stretchy="false">(</mo><msub><mi>J</mi><mi>A</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>+</mo><msub><mi>J</mi><mi>B</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo stretchy="false">)</mo></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-297">\\displaystyle S(m)=\\sum_{n=1}^m (J_A(n)+J_B(n))</script>. For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-298-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7.58932292&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4578" style="width: 10.289em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.799em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.75em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4579"><span class="mi" id="MathJax-Span-4580" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-4581" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4582" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-4583" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4584" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4585" style="font-family: MathJax_Main; padding-left: 0.278em;">7.58932292</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7.58932292</mn></math></span></span><script type="math/tex" id="MathJax-Element-298">S(6)=7.58932292</script>, rounded to 8 decimal places.</p>
#
# <p>Find S(123456789), rounded to 8 decimal places.</p>

# %%
submit_answer(answer; prob_num=567);

# %% [markdown]
# ## Problem 568: Reciprocal games II
# <p>Tom has built a random generator that is connected to a row of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-299-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4586" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4587"><span class="mi" id="MathJax-Span-4588" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-299">n</script> light bulbs. Whenever the random generator is activated each of the <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-300-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4589" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4590"><span class="mi" id="MathJax-Span-4591" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-300">n</script> lights is turned on with the probability of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-301-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4592" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.715em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4593"><span class="mfrac" id="MathJax-Span-4594"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4595" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4596" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.552em; border-left: 0px solid; width: 0px; height: 1.765em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mn>2</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-301">\\frac 1 2</script>, independently of its former state or the state of the other light bulbs.</p>
#
# <p>While discussing with his friend Jerry how to use his generator, they invent two different games, they call the <i>reciprocal games</i>:<br>
# Both games consist of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-302-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4597" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4598"><span class="mi" id="MathJax-Span-4599" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-302">n</script> turns. Each turn is started by choosing a number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-303-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4600" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4601"><span class="mi" id="MathJax-Span-4602" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-303">k</script> randomly between (and including) <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-304-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4603" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4604"><span class="mn" id="MathJax-Span-4605" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-304">1</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-305-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4606" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4607"><span class="mi" id="MathJax-Span-4608" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-305">n</script>, with equal probability of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-306-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4609" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.77em, 2.697em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4610"><span class="mfrac" id="MathJax-Span-4611"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4612" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.41em, 4.17em, -1000em); top: -3.674em; left: 50%; margin-left: -0.212em;"><span class="mi" id="MathJax-Span-4613" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.54em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.544em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.529em; border-left: 0px solid; width: 0px; height: 1.741em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>n</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-306">\\frac 1 n</script> for each number, while the possible win for that turn is the reciprocal of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-307-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4614" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4615"><span class="mi" id="MathJax-Span-4616" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-307">k</script>, that is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-308-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4617" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.743em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4618"><span class="mfrac" id="MathJax-Span-4619"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4620" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-4621" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.801em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>k</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-308">\\frac 1 k</script>.</p>
#
# <p>In game A, Tom activates his random generator once in each turn. If
# the number of lights turned on is the same as the previously chosen
# number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-309-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4622" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4623"><span class="mi" id="MathJax-Span-4624" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-309">k</script>, Jerry wins and gets <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-310-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4625" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.743em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4626"><span class="mfrac" id="MathJax-Span-4627"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4628" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-4629" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.801em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>k</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-310">\\frac 1 k</script>, otherwise he will receive nothing for that turn. Jerry's expected win after playing the total game A consisting of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-311-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4630" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4631"><span class="mi" id="MathJax-Span-4632" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-311">n</script> turns is called <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-312-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4633" style="width: 3.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.536em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.44em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4634"><span class="msubsup" id="MathJax-Span-4635"><span style="display: inline-block; position: relative; width: 1.16em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4636" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.857em; left: 0.555em;"><span class="mi" id="MathJax-Span-4637" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4638" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4639" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4640" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>A</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-312">J_A(n)</script>. For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-313-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.39505208&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4641" style="width: 11.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.325em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1008.28em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4642"><span class="msubsup" id="MathJax-Span-4643"><span style="display: inline-block; position: relative; width: 1.16em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4644" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.857em; left: 0.555em;"><span class="mi" id="MathJax-Span-4645" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4646" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4647" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-4648" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4649" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4650" style="font-family: MathJax_Main; padding-left: 0.278em;">0.39505208</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>A</mi></msub><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.39505208</mn></math></span></span><script type="math/tex" id="MathJax-Element-313">J_A(6)=0.39505208</script>, rounded to 8 decimal places.</p>
#
# <p>For each turn in game B, after <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-314-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4651" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4652"><span class="mi" id="MathJax-Span-4653" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-314">k</script> has been randomly selected, Tom keeps reactivating his random generator until exactly <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-315-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4654" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4655"><span class="mi" id="MathJax-Span-4656" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-315">k</script>
#  lights are turned on. After that Jerry takes over and reactivates the
# random generator until he, too, has generated a pattern with exactly <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-316-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4657" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4658"><span class="mi" id="MathJax-Span-4659" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-316">k</script> lights turned on. If this pattern is identical to Tom's last pattern, Jerry wins and gets <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-317-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4660" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.743em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4661"><span class="mfrac" id="MathJax-Span-4662"><span style="display: inline-block; position: relative; width: 0.488em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4663" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -3.629em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-4664" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.49em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.488em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.589em; border-left: 0px solid; width: 0px; height: 1.801em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mi>k</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-317">\\frac 1 k</script>, otherwise he will receive nothing. Jerry's expected win after the total game B consisting of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-318-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4665" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4666"><span class="mi" id="MathJax-Span-4667" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-318">n</script> turns is called <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-319-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4668" style="width: 3.352em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.536em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1002.44em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4669"><span class="msubsup" id="MathJax-Span-4670"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4671" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.555em;"><span class="mi" id="MathJax-Span-4672" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">B</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4673" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4674" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4675" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>B</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-319">J_B(n)</script>. For example <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-320-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.43333333&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4676" style="width: 11.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.325em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1008.28em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4677"><span class="msubsup" id="MathJax-Span-4678"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4679" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.555em;"><span class="mi" id="MathJax-Span-4680" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">B</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4681" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4682" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-4683" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4684" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4685" style="font-family: MathJax_Main; padding-left: 0.278em;">0.43333333</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>J</mi><mi>B</mi></msub><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.43333333</mn></math></span></span><script type="math/tex" id="MathJax-Element-320">J_B(6)=0.43333333</script>, rounded to 8 decimal places.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-321-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;J&lt;/mi&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4686" style="width: 13.017em; display: inline-block;"><span style="display: inline-block; position: relative; width: 9.856em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1009.76em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4687"><span class="mi" id="MathJax-Span-4688" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-4689" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4690" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4691" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4692" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="msubsup" id="MathJax-Span-4693" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4694" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.555em;"><span class="mi" id="MathJax-Span-4695" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">B</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4696" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4697" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4698" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4699" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="msubsup" id="MathJax-Span-4700" style="padding-left: 0.222em;"><span style="display: inline-block; position: relative; width: 1.16em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.63em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4701" style="font-family: MathJax_Math; font-style: italic;">J<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.078em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.857em; left: 0.555em;"><span class="mi" id="MathJax-Span-4702" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">A</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4703" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4704" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4705" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><msub><mi>J</mi><mi>B</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>−</mo><msub><mi>J</mi><mi>A</mi></msub><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-321">D(n)=J_B(n)−J_A(n)</script>. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-322-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0.03828125&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4706" style="width: 10.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.99em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1007.94em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4707"><span class="mi" id="MathJax-Span-4708" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-4709" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4710" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-4711" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4712" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4713" style="font-family: MathJax_Main; padding-left: 0.278em;">0.03828125</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo><mo>=</mo><mn>0.03828125</mn></math></span></span><script type="math/tex" id="MathJax-Element-322">D(6) = 0.03828125</script>.</p>
#
# <p>Find the 7 most significant digits of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-323-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;123456789&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4714" style="width: 7.801em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.885em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.79em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4715"><span class="mi" id="MathJax-Span-4716" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-4717" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4718" style="font-family: MathJax_Main;">123456789</span><span class="mo" id="MathJax-Span-4719" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>123456789</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-323">D(123456789)</script> after removing all leading zeros.<br>
# (If, for example, we had asked for the 7 most significant digits of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-324-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;D&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;6&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4720" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4721"><span class="mi" id="MathJax-Span-4722" style="font-family: MathJax_Math; font-style: italic;">D</span><span class="mo" id="MathJax-Span-4723" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4724" style="font-family: MathJax_Main;">6</span><span class="mo" id="MathJax-Span-4725" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>D</mi><mo stretchy="false">(</mo><mn>6</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-324">D(6)</script>, the answer would have been 3828125.)</p>

# %%
submit_answer(answer; prob_num=568);

# %% [markdown]
# ## Problem 569: Prime Mountain Range
# <p>A <i>mountain range</i> consists of a line of mountains with slopes of exactly 45°, and heights governed by the prime numbers, <var>p<sub>n</sub></var>. The up-slope of the <var>k</var><sup>th</sup> mountain is of height <var>p</var><sub>2<var>k</var>−1</sub>, and the downslope is <var>p</var><sub>2<var>k</var></sub>. The first few foot-hills of this range are illustrated below.</p>
#
# <div style="text-align:center;">
# <img src="webfiles/p569-prime-mountain-range.gif" alt="p569-prime-mountain-range.gif"></div>
#
# <p>Tenzing sets out to climb each one in turn, starting from the lowest.
#  At the top of each peak, he looks back and counts how many of the
# previous peaks he can see. In the example above, the eye-line from the
# third mountain is drawn in red, showing that he can only see the peak of
#  the second mountain from this viewpoint. Similarly, from the 9<sup>th</sup> mountain, he can see three peaks, those of the 5<sup>th</sup>, 7<sup>th</sup> and 8<sup>th</sup> mountain.</p>
#
# <p>Let P(<var>k</var>) be the number of peaks that are visible looking back from the <var>k</var><sup>th</sup> mountain.  Hence P(3)=1 and P(9)=3.<br>
# Also <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-325-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;100&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;227&lt;/mn&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4726" style="width: 8.471em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.411em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.815em, 1006.4em, 4.038em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4727"><span class="mstyle" id="MathJax-Span-4728"><span class="mrow" id="MathJax-Span-4729"><span class="munderover" id="MathJax-Span-4730"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4731" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1001.22em, 4.27em, -1000em); top: -2.912em; left: 0.086em;"><span class="texatom" id="MathJax-Span-4732"><span class="mrow" id="MathJax-Span-4733"><span class="mi" id="MathJax-Span-4734" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-4735" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4736" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.305em, 1001.03em, 4.178em, -1000em); top: -5.169em; left: 0.192em;"><span class="texatom" id="MathJax-Span-4737"><span class="mrow" id="MathJax-Span-4738"><span class="mn" id="MathJax-Span-4739" style="font-size: 70.7%; font-family: MathJax_Main;">100</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4740" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-4741" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4742" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-4743" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4744" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4745" style="font-family: MathJax_Main; padding-left: 0.278em;">227</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.667em; border-left: 0px solid; width: 0px; height: 4.002em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>100</mn></mrow></munderover><mi>P</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo><mo>=</mo><mn>227</mn></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-325">\\displaystyle \\sum_{k=1}^{100} P(k) = 227</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-326-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;2500000&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4746" style="width: 6.222em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.689em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.815em, 1004.59em, 4.038em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4747"><span class="mstyle" id="MathJax-Span-4748"><span class="mrow" id="MathJax-Span-4749"><span class="munderover" id="MathJax-Span-4750"><span style="display: inline-block; position: relative; width: 2.475em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0.515em;"><span class="mo" id="MathJax-Span-4751" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1001.22em, 4.27em, -1000em); top: -2.912em; left: 0.601em;"><span class="texatom" id="MathJax-Span-4752"><span class="mrow" id="MathJax-Span-4753"><span class="mi" id="MathJax-Span-4754" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-4755" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4756" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.305em, 1002.45em, 4.178em, -1000em); top: -5.169em; left: 0em;"><span class="texatom" id="MathJax-Span-4757"><span class="mrow" id="MathJax-Span-4758"><span class="mn" id="MathJax-Span-4759" style="font-size: 70.7%; font-family: MathJax_Main;">2500000</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4760" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span class="mo" id="MathJax-Span-4761" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4762" style="font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-4763" style="font-family: MathJax_Main;">)</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.667em; border-left: 0px solid; width: 0px; height: 4.002em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mn>1</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>2500000</mn></mrow></munderover><mi>P</mi><mo stretchy="false">(</mo><mi>k</mi><mo stretchy="false">)</mo></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-326">\\displaystyle \\sum_{k=1}^{2500000} P(k)</script>.</p>

# %%
submit_answer(answer; prob_num=569);

# %% [markdown]
# ## Problem 570: Snowflakes
# <p>A
#  snowflake of order n is formed by overlaying an equilateral triangle
# (rotated by 180 degrees) onto each equilateral triangle of the same size
#  in a snowflake of order n-1. A snowflake of order 1 is a single
# equilateral triangle.</p>
#
#
#
# <div> <img src="webfiles/p570-slowflakes.png" alt="p570-slowflakes.png"></div>
#
#
# <p>Some areas of the snowflake are overlaid repeatedly. In the above
# picture, blue represents the areas that are one layer thick, red two
# layers thick, yellow three layers thick, and so on. </p>
#
# <p>For an order n snowflake, let A(n) be the number of triangles that
# are one layer thick, and let B(n) be the number of triangles that are
# three layers thick. Define G(n) = gcd(A(n), B(n)).</p>
#
# <p>E.g. A(3) = 30, B(3) = 6, G(3)=6<br>
# A(11) = 3027630, B(11) = 19862070, G(11) = 30</p>
#
# <p>Further, G(500) = 186 and  <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-327-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;500&lt;/mn&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;5124&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4764" style="width: 10.624em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.038em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.588em, 1008.01em, 3.124em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4765"><span class="munderover" id="MathJax-Span-4766"><span style="display: inline-block; position: relative; width: 2.459em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4767" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.14em, 4.178em, -1000em); top: -4.496em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4768"><span class="mrow" id="MathJax-Span-4769"><span class="mn" id="MathJax-Span-4770" style="font-size: 70.7%; font-family: MathJax_Main;">500</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.4em, 4.178em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4771"><span class="mrow" id="MathJax-Span-4772"><span class="mi" id="MathJax-Span-4773" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4774" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4775" style="font-size: 70.7%; font-family: MathJax_Main;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4776" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">G</span><span class="mo" id="MathJax-Span-4777" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4778" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4779" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-4780" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-4781" style="font-family: MathJax_Main; padding-left: 0.278em;">5124</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.46em; border-left: 0px solid; width: 0px; height: 1.775em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>3</mn></mrow><mrow class="MJX-TeXAtom-ORD"><mn>500</mn></mrow></munderover><mi>G</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo><mo>=</mo><mn>5124</mn></math></span></span><script type="math/tex" id="MathJax-Element-327">\\sum_{n=3}^{500}G(n)=5124</script></p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-328-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mstyle displaystyle="true" scriptlevel="0"&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mrow&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;msup&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;/msup&gt;&lt;/mrow&gt;&lt;/munderover&gt;&lt;mi&gt;G&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/mstyle&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4782" style="width: 5.026em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.78em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(0.67em, 1003.68em, 4.025em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4783"><span class="mstyle" id="MathJax-Span-4784"><span class="mrow" id="MathJax-Span-4785"><span class="munderover" id="MathJax-Span-4786"><span style="display: inline-block; position: relative; width: 1.444em; height: 0px;"><span style="position: absolute; clip: rect(2.926em, 1001.39em, 4.613em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4787" style="font-family: MathJax_Size2; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.3em, 4.278em, -1000em); top: -2.932em; left: 0.058em;"><span class="texatom" id="MathJax-Span-4788"><span class="mrow" id="MathJax-Span-4789"><span class="mi" id="MathJax-Span-4790" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4791" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4792" style="font-size: 70.7%; font-family: MathJax_Main;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.16em, 1001.01em, 4.178em, -1000em); top: -5.169em; left: 0.217em;"><span class="texatom" id="MathJax-Span-4793"><span class="mrow" id="MathJax-Span-4794"><span class="msubsup" id="MathJax-Span-4795"><span style="display: inline-block; position: relative; width: 1.01em; height: 0px;"><span style="position: absolute; clip: rect(3.405em, 1000.68em, 4.178em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-4796" style="font-size: 70.7%; font-family: MathJax_Main;">10</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.297em; left: 0.707em;"><span class="mn" id="MathJax-Span-4797" style="font-size: 50%; font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4798" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">G</span><span class="mo" id="MathJax-Span-4799" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-4800" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4801" style="font-family: MathJax_Main;">)</span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -1.65em; border-left: 0px solid; width: 0px; height: 4.177em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mstyle displaystyle="true" scriptlevel="0"><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>=</mo><mn>3</mn></mrow><mrow class="MJX-TeXAtom-ORD"><msup><mn>10</mn><mn>7</mn></msup></mrow></munderover><mi>G</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></mstyle></math></span></span><script type="math/tex" id="MathJax-Element-328">\\displaystyle \\sum_{n=3}^{10^7}G(n)</script>.</p>

# %%
submit_answer(answer; prob_num=570);

# %% [markdown]
# ## Problem 571: Super Pandigital Numbers
# <p>A positive number is <b>pandigital</b> in base <var>b</var> if it contains all digits from 0 to <var>b</var>&nbsp;-&nbsp;1 at least once when written in base <var>b</var>.</p>
#
# <p>A <i>n-super-pandigital</i> number is a number that is simultaneously pandigital in all bases from 2 to <var>n</var> inclusively.<br>
# For example 978&nbsp;=&nbsp;1111010010<sub>2</sub>&nbsp;=&nbsp;1100020<sub>3</sub>&nbsp;=&nbsp;33102<sub>4</sub>&nbsp;=&nbsp;12403<sub>5</sub> is the smallest 5-super-pandigital number.<br>
# Similarly, 1093265784 is the smallest 10-super-pandigital number.<br>
# The sum of the 10 smallest 10-super-pandigital numbers is 20319792309.</p>
#
# <p>What is the sum of the 10 smallest 12-super-pandigital numbers?</p>

# %%
submit_answer(answer; prob_num=571);

# %% [markdown]
# ## Problem 572: Idempotent matrices
# <p>
# A matrix <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-329-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4802" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4803"><span class="mi" id="MathJax-Span-4804" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-329">M</script> is called idempotent if <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-330-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msup&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4805" style="width: 5.218em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.923em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1003.92em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4806"><span class="msubsup" id="MathJax-Span-4807"><span style="display: inline-block; position: relative; width: 1.554em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1001.05em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4808" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 1.125em;"><span class="mn" id="MathJax-Span-4809" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4810" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-4811" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.227em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msup><mi>M</mi><mn>2</mn></msup><mo>=</mo><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-330">M^2 = M</script>.<br>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-331-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4812" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4813"><span class="mi" id="MathJax-Span-4814" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-331">M</script> be a three by three matrix :
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-332-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mrow&gt;&lt;mo&gt;(&lt;/mo&gt;&lt;mtable rowspacing="4pt" columnspacing="1em"&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;mtr&gt;&lt;mtd&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mi&gt;h&lt;/mi&gt;&lt;/mtd&gt;&lt;mtd&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/mtd&gt;&lt;/mtr&gt;&lt;/mtable&gt;&lt;mo&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4815" style="width: 10.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 8.086em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(2.295em, 1007.79em, 6.392em, -1000em); top: -4.593em; left: 0em;"><span class="mrow" id="MathJax-Span-4816"><span class="mi" id="MathJax-Span-4817" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span><span class="mo" id="MathJax-Span-4818" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mrow" id="MathJax-Span-4819" style="padding-left: 0.278em;"><span class="mo" id="MathJax-Span-4820" style="vertical-align: 2.155em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; font-family: MathJax_Size4; top: -2.865em; left: 0em;">⎛<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Size4; top: -0.853em; left: 0em;">⎝<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="font-family: MathJax_Size4; position: absolute; top: -1.814em; left: 0em;">⎜<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mtable" id="MathJax-Span-4821" style="padding-right: 0.167em; padding-left: 0.167em;"><span style="display: inline-block; position: relative; width: 3.655em; height: 0px;"><span style="position: absolute; clip: rect(2.51em, 1000.52em, 6.248em, -1000em); top: -4.45em; left: 0em;"><span style="display: inline-block; position: relative; width: 0.529em; height: 0px;"><span style="position: absolute; clip: rect(3.435em, 1000.51em, 4.173em, -1000em); top: -5.374em; left: 50%; margin-left: -0.265em;"><span class="mtd" id="MathJax-Span-4822"><span class="mrow" id="MathJax-Span-4823"><span class="mi" id="MathJax-Span-4824" style="font-family: MathJax_Math; font-style: italic;">a</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.182em, 1000.52em, 4.173em, -1000em); top: -3.974em; left: 50%; margin-left: -0.262em;"><span class="mtd" id="MathJax-Span-4831"><span class="mrow" id="MathJax-Span-4832"><span class="mi" id="MathJax-Span-4833" style="font-family: MathJax_Math; font-style: italic;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.434em, 1000.48em, 4.368em, -1000em); top: -2.569em; left: 50%; margin-left: -0.24em;"><span class="mtd" id="MathJax-Span-4840"><span class="mrow" id="MathJax-Span-4841"><span class="mi" id="MathJax-Span-4842" style="font-family: MathJax_Math; font-style: italic;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.45em;"></span></span><span style="position: absolute; clip: rect(2.305em, 1000.55em, 6.102em, -1000em); top: -4.498em; left: 1.529em;"><span style="display: inline-block; position: relative; width: 0.576em; height: 0px;"><span style="position: absolute; clip: rect(3.182em, 1000.42em, 4.174em, -1000em); top: -5.374em; left: 50%; margin-left: -0.214em;"><span class="mtd" id="MathJax-Span-4825"><span class="mrow" id="MathJax-Span-4826"><span class="mi" id="MathJax-Span-4827" style="font-family: MathJax_Math; font-style: italic;">b</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -3.974em; left: 50%; margin-left: -0.233em;"><span class="mtd" id="MathJax-Span-4834"><span class="mrow" id="MathJax-Span-4835"><span class="mi" id="MathJax-Span-4836" style="font-family: MathJax_Math; font-style: italic;">e</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.182em, 1000.55em, 4.174em, -1000em); top: -2.569em; left: 50%; margin-left: -0.288em;"><span class="mtd" id="MathJax-Span-4843"><span class="mrow" id="MathJax-Span-4844"><span class="mi" id="MathJax-Span-4845" style="font-family: MathJax_Math; font-style: italic;">h</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.498em;"></span></span><span style="position: absolute; clip: rect(2.318em, 1000.55em, 5.863em, -1000em); top: -4.258em; left: 3.105em;"><span style="display: inline-block; position: relative; width: 0.55em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.43em, 4.174em, -1000em); top: -5.374em; left: 50%; margin-left: -0.216em;"><span class="mtd" id="MathJax-Span-4828"><span class="mrow" id="MathJax-Span-4829"><span class="mi" id="MathJax-Span-4830" style="font-family: MathJax_Math; font-style: italic;">c</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.171em, 1000.55em, 4.368em, -1000em); top: -3.974em; left: 50%; margin-left: -0.275em;"><span class="mtd" id="MathJax-Span-4837"><span class="mrow" id="MathJax-Span-4838"><span class="mi" id="MathJax-Span-4839" style="font-family: MathJax_Math; font-style: italic;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.215em, 1000.3em, 4.174em, -1000em); top: -2.569em; left: 50%; margin-left: -0.172em;"><span class="mtd" id="MathJax-Span-4846"><span class="mrow" id="MathJax-Span-4847"><span class="mi" id="MathJax-Span-4848" style="font-family: MathJax_Math; font-style: italic;">i</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span><span style="display: inline-block; width: 0px; height: 4.258em;"></span></span></span></span><span class="mo" id="MathJax-Span-4849" style="vertical-align: 2.155em;"><span style="display: inline-block; position: relative; width: 0.875em; height: 0px;"><span style="position: absolute; font-family: MathJax_Size4; top: -2.865em; left: 0em;">⎞<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; font-family: MathJax_Size4; top: -0.853em; left: 0em;">⎠<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="font-family: MathJax_Size4; position: absolute; top: -1.814em; left: 0em;">⎟<span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 4.593em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -2.248em; border-left: 0px solid; width: 0px; height: 5.156em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi><mo>=</mo><mrow><mo>(</mo><mtable rowspacing="4pt" columnspacing="1em"><mtr><mtd><mi>a</mi></mtd><mtd><mi>b</mi></mtd><mtd><mi>c</mi></mtd></mtr><mtr><mtd><mi>d</mi></mtd><mtd><mi>e</mi></mtd><mtd><mi>f</mi></mtd></mtr><mtr><mtd><mi>g</mi></mtd><mtd><mi>h</mi></mtd><mtd><mi>i</mi></mtd></mtr></mtable><mo>)</mo></mrow></math></span></span><script type="math/tex" id="MathJax-Element-332">M=\\begin{pmatrix}
#   a & b & c\\\\
#   d & e & f\\\
#   g &h &i\\\
# \\end{pmatrix}</script>.<br>
# Let C(<var>n</var>) be the number of  idempotent three by three matrices <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-333-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4850" style="width: 1.39em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.053em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1001.05em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4851"><span class="mi" id="MathJax-Span-4852" style="font-family: MathJax_Math; font-style: italic;">M<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.081em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>M</mi></math></span></span><script type="math/tex" id="MathJax-Element-333">M</script> with integer elements such that<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-334-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;a&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;b&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;c&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;e&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;f&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;g&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;h&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4853" style="width: 16.701em; display: inline-block;"><span style="display: inline-block; position: relative; width: 12.632em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.831em, 1012.61em, 3.028em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4854"><span class="mo" id="MathJax-Span-4855" style="font-family: MathJax_Main;">−</span><span class="mi" id="MathJax-Span-4856" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4857" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-4858" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">a</span><span class="mo" id="MathJax-Span-4859" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4860" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">b</span><span class="mo" id="MathJax-Span-4861" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4862" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">c</span><span class="mo" id="MathJax-Span-4863" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4864" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">d<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-4865" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4866" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">e</span><span class="mo" id="MathJax-Span-4867" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4868" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">f<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.06em;"></span></span><span class="mo" id="MathJax-Span-4869" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4870" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">g<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.003em;"></span></span><span class="mo" id="MathJax-Span-4871" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4872" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">h</span><span class="mo" id="MathJax-Span-4873" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4874" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">i</span><span class="mo" id="MathJax-Span-4875" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-4876" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.334em; border-left: 0px solid; width: 0px; height: 1.328em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo>−</mo><mi>n</mi><mo>≤</mo><mi>a</mi><mo>,</mo><mi>b</mi><mo>,</mo><mi>c</mi><mo>,</mo><mi>d</mi><mo>,</mo><mi>e</mi><mo>,</mo><mi>f</mi><mo>,</mo><mi>g</mi><mo>,</mo><mi>h</mi><mo>,</mo><mi>i</mi><mo>≤</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-334"> -n \\le a,b,c,d,e,f,g,h,i \\le n</script>.</p>
# <p>
# C(1)=164 and C(2)=848.
# </p>
# <p>
# Find C(200).
# </p>

# %%
submit_answer(answer; prob_num=572);

# %% [markdown]
# ## Problem 573: Unfair race
# <p><span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-335-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4877" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4878"><span class="mi" id="MathJax-Span-4879" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-335">n</script> runners in very different training states want to compete in a race. Each one of them is given a different starting number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-336-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4880" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4881"><span class="mi" id="MathJax-Span-4882" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-336">k</script> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-337-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4883" style="width: 6.653em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.024em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.93em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4884"><span class="mo" id="MathJax-Span-4885" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-4886" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-4887" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-4888" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">k</span><span class="mo" id="MathJax-Span-4889" style="font-family: MathJax_Main; padding-left: 0.278em;">≤</span><span class="mi" id="MathJax-Span-4890" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span><span class="mo" id="MathJax-Span-4891" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mo stretchy="false">(</mo><mn>1</mn><mo>≤</mo><mi>k</mi><mo>≤</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-337">(1\\leq k \\leq n)</script> according to his (constant) individual racing speed being <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-338-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;v&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4892" style="width: 3.974em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.014em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.638em, 1003.01em, 3.176em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4893"><span class="msubsup" id="MathJax-Span-4894"><span style="display: inline-block; position: relative; width: 0.928em; height: 0px;"><span style="position: absolute; clip: rect(3.433em, 1000.47em, 4.174em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4895" style="font-family: MathJax_Math; font-style: italic;">v</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.485em;"><span class="mi" id="MathJax-Span-4896" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4897" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4898" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.544em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.385em, 1000.36em, 4.17em, -1000em); top: -4.427em; left: 50%; margin-left: -0.184em;"><span class="mi" id="MathJax-Span-4899" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.41em, 4.17em, -1000em); top: -3.674em; left: 50%; margin-left: -0.212em;"><span class="mi" id="MathJax-Span-4900" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.54em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.544em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.529em; border-left: 0px solid; width: 0px; height: 1.777em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>v</mi><mi>k</mi></msub><mo>=</mo><mfrac><mi>k</mi><mi>n</mi></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-338">v_k=\\frac{k}{n}</script>.<br>
# In order to give the slower runners a chance to win the race, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-339-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4901" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4902"><span class="mi" id="MathJax-Span-4903" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-339">n</script>
#  different starting positions are chosen randomly (with uniform
# distribution) and independently from each other within the racing track
# of length <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-340-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4904" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4905"><span class="mn" id="MathJax-Span-4906" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-340">1</script>. After this, the starting position nearest to the goal is assigned to runner <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-341-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4907" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.41em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4908"><span class="mn" id="MathJax-Span-4909" style="font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-341">1</script>, the next nearest starting position to runner <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-342-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4910" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.87em, 1000.43em, 2.823em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4911"><span class="mn" id="MathJax-Span-4912" style="font-family: MathJax_Main;">2</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.005em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn></math></span></span><script type="math/tex" id="MathJax-Element-342">2</script> and so on, until finally the starting position furthest away from the goal is assigned to runner <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-343-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4913" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4914"><span class="mi" id="MathJax-Span-4915" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-343">n</script>. The winner of the race is the runner who reaches the goal first.</p>
#
# <p>Interestingly, the expected running time for the winner is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-344-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4916" style="width: 0.959em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.718em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.187em, 1000.72em, 2.715em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4917"><span class="mfrac" id="MathJax-Span-4918"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4919" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4920" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.552em; border-left: 0px solid; width: 0px; height: 1.765em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mn>1</mn><mn>2</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-344">\\frac{1}{2}</script>,
#  independently of the number of runners. Moreover, while it can be shown
#  that all runners will have the same expected running time of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-345-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mfrac&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mrow&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4921" style="width: 2.251em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.675em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.337em, 1001.67em, 2.773em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4922"><span class="mfrac" id="MathJax-Span-4923"><span style="display: inline-block; position: relative; width: 1.448em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.563em, 1000.41em, 4.17em, -1000em); top: -4.427em; left: 50%; margin-left: -0.212em;"><span class="mi" id="MathJax-Span-4924" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1001.28em, 4.221em, -1000em); top: -3.648em; left: 50%; margin-left: -0.664em;"><span class="mrow" id="MathJax-Span-4925"><span class="mi" id="MathJax-Span-4926" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4927" style="font-size: 70.7%; font-family: MathJax_Main;">+</span><span class="mn" id="MathJax-Span-4928" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1001.45em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 1.448em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.629em; border-left: 0px solid; width: 0px; height: 1.643em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mfrac><mi>n</mi><mrow><mi>n</mi><mo>+</mo><mn>1</mn></mrow></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-345">\\frac{n}{n+1}</script>, the race is still unfair, since the winning chances may differ significantly for different starting numbers:</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-346-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4929" style="width: 2.299em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.722em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.374em, 1001.72em, 2.632em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-4930"><span class="msubsup" id="MathJax-Span-4931"><span style="display: inline-block; position: relative; width: 1.706em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4932" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="texatom" id="MathJax-Span-4933"><span class="mrow" id="MathJax-Span-4934"><span class="mi" id="MathJax-Span-4935" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4936" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4937" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.442em; border-left: 0px solid; width: 0px; height: 1.407em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>,</mo><mi>k</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-346">P_{n,k}</script> be the probability for runner <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-347-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4938" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.603em, 1000.51em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4939"><span class="mi" id="MathJax-Span-4940" style="font-family: MathJax_Math; font-style: italic;">k</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 1.057em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>k</mi></math></span></span><script type="math/tex" id="MathJax-Element-347">k</script> to win a race with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-348-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4941" style="width: 0.816em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.622em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.6em, 2.595em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-4942"><span class="mi" id="MathJax-Span-4943" style="font-family: MathJax_Math; font-style: italic;">n</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.078em; border-left: 0px solid; width: 0px; height: 0.724em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-348">n</script> runners and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-349-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munderover&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/munderover&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4944" style="width: 9.763em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.368em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.746em, 1007.37em, 3.116em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4945"><span class="msubsup" id="MathJax-Span-4946"><span style="display: inline-block; position: relative; width: 1.237em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.76em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4947" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.738em;"><span class="mi" id="MathJax-Span-4948" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4949" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="munderover" id="MathJax-Span-4950" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 2.403em; height: 0px;"><span style="position: absolute; clip: rect(3.126em, 1001em, 4.413em, -1000em); top: -4.019em; left: 0em;"><span class="mo" id="MathJax-Span-4951" style="font-family: MathJax_Size1; vertical-align: 0em;">∑</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.563em, 1000.5em, 4.17em, -1000em); top: -4.496em; left: 1.056em;"><span class="mi" id="MathJax-Span-4952" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.385em, 1001.35em, 4.17em, -1000em); top: -3.734em; left: 1.056em;"><span class="texatom" id="MathJax-Span-4953"><span class="mrow" id="MathJax-Span-4954"><span class="mi" id="MathJax-Span-4955" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span><span class="mo" id="MathJax-Span-4956" style="font-size: 70.7%; font-family: MathJax_Main;">=</span><span class="mn" id="MathJax-Span-4957" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mi" id="MathJax-Span-4958" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">k</span><span class="msubsup" id="MathJax-Span-4959"><span style="display: inline-block; position: relative; width: 1.706em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4960" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="texatom" id="MathJax-Span-4961"><span class="mrow" id="MathJax-Span-4962"><span class="mi" id="MathJax-Span-4963" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-4964" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-4965" style="font-size: 70.7%; font-family: MathJax_Math; font-style: italic;">k</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.45em; border-left: 0px solid; width: 0px; height: 1.555em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>E</mi><mi>n</mi></msub><mo>=</mo><munderover><mo>∑</mo><mrow class="MJX-TeXAtom-ORD"><mi>k</mi><mo>=</mo><mn>1</mn></mrow><mi>n</mi></munderover><mi>k</mi><msub><mi>P</mi><mrow class="MJX-TeXAtom-ORD"><mi>n</mi><mo>,</mo><mi>k</mi></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-349">E_n = \\sum_{k=1}^n k P_{n,k}</script> be the expected starting number of the winner in that race. It can be shown that, for example,
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-350-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4966" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.657em, 1003.64em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4967"><span class="msubsup" id="MathJax-Span-4968"><span style="display: inline-block; position: relative; width: 1.621em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4969" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="texatom" id="MathJax-Span-4970"><span class="mrow" id="MathJax-Span-4971"><span class="mn" id="MathJax-Span-4972" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-4973" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-4974" style="font-size: 70.7%; font-family: MathJax_Main;">1</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4975" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4976" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.397em, 1000.33em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4977" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4978" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.796em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mrow class="MJX-TeXAtom-ORD"><mn>3</mn><mo>,</mo><mn>1</mn></mrow></msub><mo>=</mo><mfrac><mn>4</mn><mn>9</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-350">P_{3,1}=\\frac{4}{9}</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-351-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4979" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.665em, 1003.64em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4980"><span class="msubsup" id="MathJax-Span-4981"><span style="display: inline-block; position: relative; width: 1.621em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4982" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="texatom" id="MathJax-Span-4983"><span class="mrow" id="MathJax-Span-4984"><span class="mn" id="MathJax-Span-4985" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-4986" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-4987" style="font-size: 70.7%; font-family: MathJax_Main;">2</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-4988" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-4989" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4990" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-4991" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.785em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mrow class="MJX-TeXAtom-ORD"><mn>3</mn><mo>,</mo><mn>2</mn></mrow></msub><mo>=</mo><mfrac><mn>2</mn><mn>9</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-351">P_{3,2}=\\frac{2}{9}</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-352-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;P&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-4992" style="width: 4.835em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.636em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.665em, 1003.64em, 3.208em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-4993"><span class="msubsup" id="MathJax-Span-4994"><span style="display: inline-block; position: relative; width: 1.621em; height: 0px;"><span style="position: absolute; clip: rect(3.193em, 1000.75em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-4995" style="font-family: MathJax_Math; font-style: italic;">P<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.109em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.642em;"><span class="texatom" id="MathJax-Span-4996"><span class="mrow" id="MathJax-Span-4997"><span class="mn" id="MathJax-Span-4998" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span class="mo" id="MathJax-Span-4999" style="font-size: 70.7%; font-family: MathJax_Main;">,</span><span class="mn" id="MathJax-Span-5000" style="font-size: 70.7%; font-family: MathJax_Main;">3</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5001" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-5002" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.474em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.405em, 1000.3em, 4.163em, -1000em); top: -4.419em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5003" style="font-size: 70.7%; font-family: MathJax_Main;">1</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.649em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5004" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.47em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.474em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.572em; border-left: 0px solid; width: 0px; height: 1.784em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>P</mi><mrow class="MJX-TeXAtom-ORD"><mn>3</mn><mo>,</mo><mn>3</mn></mrow></msub><mo>=</mo><mfrac><mn>1</mn><mn>3</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-352">P_{3,3}=\\frac{1}{3}</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-353-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mn&gt;17&lt;/mn&gt;&lt;mn&gt;9&lt;/mn&gt;&lt;/mfrac&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5005" style="width: 4.691em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.541em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.643em, 1003.54em, 3.209em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5006"><span class="msubsup" id="MathJax-Span-5007"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.76em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5008" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.738em;"><span class="mn" id="MathJax-Span-5009" style="font-size: 70.7%; font-family: MathJax_Main;">3</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5010" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mfrac" id="MathJax-Span-5011" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.827em; height: 0px; margin-right: 0.12em; margin-left: 0.12em;"><span style="position: absolute; clip: rect(3.398em, 1000.7em, 4.178em, -1000em); top: -4.434em; left: 50%; margin-left: -0.354em;"><span class="mn" id="MathJax-Span-5012" style="font-size: 70.7%; font-family: MathJax_Main;">17</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(3.405em, 1000.32em, 4.178em, -1000em); top: -3.648em; left: 50%; margin-left: -0.177em;"><span class="mn" id="MathJax-Span-5013" style="font-size: 70.7%; font-family: MathJax_Main;">9</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; clip: rect(0.849em, 1000.83em, 1.196em, -1000em); top: -1.273em; left: 0em;"><span style="display: inline-block; overflow: hidden; vertical-align: 0em; border-top: 1.3px solid; width: 0.827em; height: 0px;"></span><span style="display: inline-block; width: 0px; height: 1.053em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.573em; border-left: 0px solid; width: 0px; height: 1.815em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>E</mi><mn>3</mn></msub><mo>=</mo><mfrac><mn>17</mn><mn>9</mn></mfrac></math></span></span><script type="math/tex" id="MathJax-Element-353">E_3=\\frac{17}{9}</script> for a race with <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-354-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5014" style="width: 0.672em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.478em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.871em, 1000.43em, 2.845em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5015"><span class="mn" id="MathJax-Span-5016" style="font-family: MathJax_Main;">3</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.092em; border-left: 0px solid; width: 0px; height: 1.033em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>3</mn></math></span></span><script type="math/tex" id="MathJax-Element-354">3</script> runners. <br>
# You are given that <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-355-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mn&gt;4&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2.21875&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5017" style="width: 7.467em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.646em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1005.59em, 2.973em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5018"><span class="msubsup" id="MathJax-Span-5019"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.76em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5020" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.738em;"><span class="mn" id="MathJax-Span-5021" style="font-size: 70.7%; font-family: MathJax_Main;">4</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5022" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5023" style="font-family: MathJax_Main; padding-left: 0.278em;">2.21875</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.261em; border-left: 0px solid; width: 0px; height: 1.222em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>E</mi><mn>4</mn></msub><mo>=</mo><mn>2.21875</mn></math></span></span><script type="math/tex" id="MathJax-Element-355">E_4=2.21875</script>, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-356-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2.5104&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5024" style="width: 6.844em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.167em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1005.14em, 2.989em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5025"><span class="msubsup" id="MathJax-Span-5026"><span style="display: inline-block; position: relative; width: 1.167em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.76em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5027" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.738em;"><span class="mn" id="MathJax-Span-5028" style="font-size: 70.7%; font-family: MathJax_Main;">5</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5029" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5030" style="font-family: MathJax_Main; padding-left: 0.278em;">2.5104</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.242em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>E</mi><mn>5</mn></msub><mo>=</mo><mn>2.5104</mn></math></span></span><script type="math/tex" id="MathJax-Element-356">E_5=2.5104</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-357-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3.66021568&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5031" style="width: 9.811em; display: inline-block;"><span style="display: inline-block; position: relative; width: 7.416em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.856em, 1007.37em, 2.989em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5032"><span class="msubsup" id="MathJax-Span-5033"><span style="display: inline-block; position: relative; width: 1.52em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.76em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5034" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.738em;"><span class="texatom" id="MathJax-Span-5035"><span class="mrow" id="MathJax-Span-5036"><span class="mn" id="MathJax-Span-5037" style="font-size: 70.7%; font-family: MathJax_Main;">10</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span><span class="mo" id="MathJax-Span-5038" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5039" style="font-family: MathJax_Main; padding-left: 0.278em;">3.66021568</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.242em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>E</mi><mrow class="MJX-TeXAtom-ORD"><mn>10</mn></mrow></msub><mo>=</mo><mn>3.66021568</mn></math></span></span><script type="math/tex" id="MathJax-Element-357">E_{10}=3.66021568</script>.</p>
#
# <p>Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-358-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;msub&gt;&lt;mi&gt;E&lt;/mi&gt;&lt;mrow class="MJX-TeXAtom-ORD"&gt;&lt;mn&gt;1000000&lt;/mn&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5040" style="width: 4.356em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.301em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.377em, 1003.3em, 2.51em, -1000em); top: -2.201em; left: 0em;"><span class="mrow" id="MathJax-Span-5041"><span class="msubsup" id="MathJax-Span-5042"><span style="display: inline-block; position: relative; width: 3.288em; height: 0px;"><span style="position: absolute; clip: rect(3.196em, 1000.76em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5043" style="font-family: MathJax_Math; font-style: italic;">E<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.026em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -3.869em; left: 0.738em;"><span class="texatom" id="MathJax-Span-5044"><span class="mrow" id="MathJax-Span-5045"><span class="mn" id="MathJax-Span-5046" style="font-size: 70.7%; font-family: MathJax_Main;">1000000</span></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.201em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.282em; border-left: 0px solid; width: 0px; height: 1.242em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><msub><mi>E</mi><mrow class="MJX-TeXAtom-ORD"><mn>1000000</mn></mrow></msub></math></span></span><script type="math/tex" id="MathJax-Element-358">E_{1000000}</script> rounded to 4 digits after the decimal point.</p>

# %%
submit_answer(answer; prob_num=573);

# %% [markdown]
# ## Problem 574: Verifying Primes
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-359-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5047" style="width: 0.577em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.431em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.43em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5048"><span class="mi" id="MathJax-Span-5049" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-359">q</script> be a prime and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-360-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mo&gt;&amp;gt;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5050" style="width: 6.127em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.641em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.82em, 1004.6em, 2.961em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5051"><span class="mi" id="MathJax-Span-5052" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-5053" style="font-family: MathJax_Main; padding-left: 0.278em;">≥</span><span class="mi" id="MathJax-Span-5054" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">B</span><span class="mo" id="MathJax-Span-5055" style="font-family: MathJax_Main; padding-left: 0.278em;">&gt;</span><span class="mn" id="MathJax-Span-5056" style="font-family: MathJax_Main; padding-left: 0.278em;">0</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.245em; border-left: 0px solid; width: 0px; height: 1.254em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi><mo>≥</mo><mi>B</mi><mo>&gt;</mo><mn>0</mn></math></span></span><script type="math/tex" id="MathJax-Element-360">A \\ge B >0</script> be two integers with the following properties:
# </p><ul><li> <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-361-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5057" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5058"><span class="mi" id="MathJax-Span-5059" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-361">A</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-362-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5060" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.614em, 1000.76em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5061"><span class="mi" id="MathJax-Span-5062" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.028em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-362">B</script> have no prime factor in common, that is <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-363-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mtext&gt;gcd&lt;/mtext&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5063" style="width: 7.993em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.029em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5064"><span class="mtext" id="MathJax-Span-5065" style="font-family: MathJax_Main;">gcd</span><span class="mo" id="MathJax-Span-5066" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5067" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-5068" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5069" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">B</span><span class="mo" id="MathJax-Span-5070" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5071" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5072" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mtext>gcd</mtext><mo stretchy="false">(</mo><mi>A</mi><mo>,</mo><mi>B</mi><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-363">\\text{gcd}(A,B)=1</script>.</li>
# <li> The product <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-364-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5073" style="width: 2.06em; display: inline-block;"><span style="display: inline-block; position: relative; width: 1.531em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1001.53em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5074"><span class="mi" id="MathJax-Span-5075" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mi" id="MathJax-Span-5076" style="font-family: MathJax_Math; font-style: italic;">B</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-364">AB</script> is divisible by every prime less than q.</li>
#
# </ul><p>It can be shown that, given these conditions, any sum <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-365-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5077" style="width: 6.653em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.024em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1005.02em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5078"><span class="mi" id="MathJax-Span-5079" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-5080" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-5081" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">B</span><span class="mo" id="MathJax-Span-5082" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="msubsup" id="MathJax-Span-5083" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.943em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.46em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5084" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.514em;"><span class="mn" id="MathJax-Span-5085" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.483em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi><mo>+</mo><mi>B</mi><mo>&lt;</mo><msup><mi>q</mi><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-365">A+B<q^2</script> and any difference <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-366-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5086" style="width: 8.998em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.794em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1006.79em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5087"><span class="mn" id="MathJax-Span-5088" style="font-family: MathJax_Main;">1</span><span class="mo" id="MathJax-Span-5089" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-5090" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">A</span><span class="mo" id="MathJax-Span-5091" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mi" id="MathJax-Span-5092" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">B</span><span class="mo" id="MathJax-Span-5093" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="msubsup" id="MathJax-Span-5094" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.943em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.46em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5095" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.514em;"><span class="mn" id="MathJax-Span-5096" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.483em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>1</mn><mo>&lt;</mo><mi>A</mi><mo>−</mo><mi>B</mi><mo>&lt;</mo><msup><mi>q</mi><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-366">1<A-B<q^2</script> has to be a prime number. Thus you can verify that a number <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-367-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5097" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5098"><span class="mi" id="MathJax-Span-5099" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-367">p</script> is prime by showing that either <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-368-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5100" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1006.84em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5101"><span class="mi" id="MathJax-Span-5102" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5103" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-5104" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">A</span><span class="mo" id="MathJax-Span-5105" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-5106" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">B</span><span class="mo" id="MathJax-Span-5107" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="msubsup" id="MathJax-Span-5108" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.943em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.46em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5109" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.514em;"><span class="mn" id="MathJax-Span-5110" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.483em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>=</mo><mi>A</mi><mo>+</mo><mi>B</mi><mo>&lt;</mo><msup><mi>q</mi><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-368">p=A+B<q^2</script> or <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-369-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5111" style="width: 9.045em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.842em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.702em, 1006.84em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5112"><span class="mi" id="MathJax-Span-5113" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5114" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-5115" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">A</span><span class="mo" id="MathJax-Span-5116" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mi" id="MathJax-Span-5117" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">B</span><span class="mo" id="MathJax-Span-5118" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="msubsup" id="MathJax-Span-5119" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.943em; height: 0px;"><span style="position: absolute; clip: rect(3.434em, 1000.46em, 4.357em, -1000em); top: -4.019em; left: 0em;"><span class="mi" id="MathJax-Span-5120" style="font-family: MathJax_Math; font-style: italic;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.382em; left: 0.514em;"><span class="mn" id="MathJax-Span-5121" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.483em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>=</mo><mi>A</mi><mo>−</mo><mi>B</mi><mo>&lt;</mo><msup><mi>q</mi><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-369">p=A-B<q^2</script> for some <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-370-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;q&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5122" style="width: 3.83em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.871em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.82em, 1002.87em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5123"><span class="mi" id="MathJax-Span-5124" style="font-family: MathJax_Math; font-style: italic;">A</span><span class="mo" id="MathJax-Span-5125" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5126" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">B</span><span class="mo" id="MathJax-Span-5127" style="font-family: MathJax_Main;">,</span><span class="mi" id="MathJax-Span-5128" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.167em;">q<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.014em;"></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.328em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi><mo>,</mo><mi>B</mi><mo>,</mo><mi>q</mi></math></span></span><script type="math/tex" id="MathJax-Element-370">A,B,q</script> fulfilling the conditions listed above.</p>
#
# <p>Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-371-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5129" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5130"><span class="mi" id="MathJax-Span-5131" style="font-family: MathJax_Math; font-style: italic; text-rendering: optimizelegibility;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.186em;"></span></span><span class="mo" id="MathJax-Span-5132" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5133" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5134" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>V</mi><mo stretchy="false">(</mo><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-371">V(p)</script> be the smallest possible value of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-372-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5135" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5136"><span class="mi" id="MathJax-Span-5137" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-372">A</script> in any sum <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-373-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5138" style="width: 6.079em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.593em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.82em, 1004.59em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5139"><span class="mi" id="MathJax-Span-5140" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5141" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-5142" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">A</span><span class="mo" id="MathJax-Span-5143" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mi" id="MathJax-Span-5144" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">B</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.328em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>=</mo><mi>A</mi><mo>+</mo><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-373">p=A+B</script> and any difference <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-374-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;B&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5145" style="width: 6.079em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.593em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.82em, 1004.59em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5146"><span class="mi" id="MathJax-Span-5147" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5148" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mi" id="MathJax-Span-5149" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">A</span><span class="mo" id="MathJax-Span-5150" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mi" id="MathJax-Span-5151" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.222em;">B</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.328em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>=</mo><mi>A</mi><mo>−</mo><mi>B</mi></math></span></span><script type="math/tex" id="MathJax-Element-374">p=A-B</script>, that verifies <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-375-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5152" style="width: 0.72em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.526em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.855em, 1000.52em, 2.778em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5153"><span class="mi" id="MathJax-Span-5154" style="font-family: MathJax_Math; font-style: italic;">p</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 0.966em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi></math></span></span><script type="math/tex" id="MathJax-Element-375">p</script> being prime. Examples:<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-376-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5155" style="width: 5.074em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.828em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.76em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5156"><span class="mi" id="MathJax-Span-5157" style="font-family: MathJax_Math; font-style: italic; text-rendering: optimizelegibility;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.186em;"></span></span><span class="mo" id="MathJax-Span-5158" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5159" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-5160" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5161" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5162" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>V</mi><mo stretchy="false">(</mo><mn>2</mn><mo stretchy="false">)</mo><mo>=</mo><mn>1</mn></math></span></span><script type="math/tex" id="MathJax-Element-376">V(2)=1</script>, since <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-377-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5163" style="width: 8.232em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.22em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1006.22em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5164"><span class="mn" id="MathJax-Span-5165" style="font-family: MathJax_Main;">2</span><span class="mo" id="MathJax-Span-5166" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5167" style="font-family: MathJax_Main; padding-left: 0.278em;">1</span><span class="mo" id="MathJax-Span-5168" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5169" style="font-family: MathJax_Main; padding-left: 0.222em;">1</span><span class="mo" id="MathJax-Span-5170" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="msubsup" id="MathJax-Span-5171" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.45em, 4.163em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5172" style="font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 0.5em;"><span class="mn" id="MathJax-Span-5173" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.375em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>2</mn><mo>=</mo><mn>1</mn><mo>+</mo><mn>1</mn><mo>&lt;</mo><msup><mn>2</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-377">2=1+1< 2^2</script>. <br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-378-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;37&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;22&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5174" style="width: 6.318em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.785em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.73em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5175"><span class="mi" id="MathJax-Span-5176" style="font-family: MathJax_Math; font-style: italic; text-rendering: optimizelegibility;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.186em;"></span></span><span class="mo" id="MathJax-Span-5177" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5178" style="font-family: MathJax_Main;">37</span><span class="mo" id="MathJax-Span-5179" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5180" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5181" style="font-family: MathJax_Main; padding-left: 0.278em;">22</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>V</mi><mo stretchy="false">(</mo><mn>37</mn><mo stretchy="false">)</mo><mo>=</mo><mn>22</mn></math></span></span><script type="math/tex" id="MathJax-Element-378">V(37)=22</script>, since <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-379-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;37&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;22&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;15&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5182" style="width: 18.519em; display: inline-block;"><span style="display: inline-block; position: relative; width: 14.019em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.662em, 1014.02em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5183"><span class="mn" id="MathJax-Span-5184" style="font-family: MathJax_Main;">37</span><span class="mo" id="MathJax-Span-5185" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5186" style="font-family: MathJax_Main; padding-left: 0.278em;">22</span><span class="mo" id="MathJax-Span-5187" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5188" style="font-family: MathJax_Main; padding-left: 0.222em;">15</span><span class="mo" id="MathJax-Span-5189" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5190" style="font-family: MathJax_Main; padding-left: 0.278em;">2</span><span class="mo" id="MathJax-Span-5191" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5192" style="font-family: MathJax_Main; padding-left: 0.222em;">11</span><span class="mo" id="MathJax-Span-5193" style="font-family: MathJax_Main; padding-left: 0.222em;">+</span><span class="mn" id="MathJax-Span-5194" style="font-family: MathJax_Main; padding-left: 0.222em;">3</span><span class="mo" id="MathJax-Span-5195" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5196" style="font-family: MathJax_Main; padding-left: 0.222em;">5</span><span class="mo" id="MathJax-Span-5197" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="msubsup" id="MathJax-Span-5198" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 0.929em; height: 0px;"><span style="position: absolute; clip: rect(3.2em, 1000.48em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5199" style="font-family: MathJax_Main;">7</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.422em; left: 0.5em;"><span class="mn" id="MathJax-Span-5200" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.388em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>37</mn><mo>=</mo><mn>22</mn><mo>+</mo><mn>15</mn><mo>=</mo><mn>2</mn><mo>⋅</mo><mn>11</mn><mo>+</mo><mn>3</mn><mo>⋅</mo><mn>5</mn><mo>&lt;</mo><msup><mn>7</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-379">37=22+15=2 \\cdot 11+3 \\cdot 5< 7^2</script> is the associated sum with the smallest possible <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-380-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5201" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5202"><span class="mi" id="MathJax-Span-5203" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-380">A</script>.<br>
# <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-381-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;151&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;165&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5204" style="width: 7.61em; display: inline-block;"><span style="display: inline-block; position: relative; width: 5.742em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1005.69em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5205"><span class="mi" id="MathJax-Span-5206" style="font-family: MathJax_Math; font-style: italic; text-rendering: optimizelegibility;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.186em;"></span></span><span class="mo" id="MathJax-Span-5207" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5208" style="font-family: MathJax_Main;">151</span><span class="mo" id="MathJax-Span-5209" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5210" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5211" style="font-family: MathJax_Main; padding-left: 0.278em;">165</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>V</mi><mo stretchy="false">(</mo><mn>151</mn><mo stretchy="false">)</mo><mo>=</mo><mn>165</mn></math></span></span><script type="math/tex" id="MathJax-Element-381">V(151)=165</script> since <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-382-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mn&gt;151&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;165&lt;/mn&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;14&lt;/mn&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;5&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;11&lt;/mn&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mn&gt;7&lt;/mn&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;msup&gt;&lt;mn&gt;13&lt;/mn&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5212" style="width: 22.06em; display: inline-block;"><span style="display: inline-block; position: relative; width: 16.699em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.672em, 1016.7em, 2.905em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5213"><span class="mn" id="MathJax-Span-5214" style="font-family: MathJax_Main;">151</span><span class="mo" id="MathJax-Span-5215" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5216" style="font-family: MathJax_Main; padding-left: 0.278em;">165</span><span class="mo" id="MathJax-Span-5217" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-5218" style="font-family: MathJax_Main; padding-left: 0.222em;">14</span><span class="mo" id="MathJax-Span-5219" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5220" style="font-family: MathJax_Main; padding-left: 0.278em;">3</span><span class="mo" id="MathJax-Span-5221" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5222" style="font-family: MathJax_Main; padding-left: 0.222em;">5</span><span class="mo" id="MathJax-Span-5223" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5224" style="font-family: MathJax_Main; padding-left: 0.222em;">11</span><span class="mo" id="MathJax-Span-5225" style="font-family: MathJax_Main; padding-left: 0.222em;">−</span><span class="mn" id="MathJax-Span-5226" style="font-family: MathJax_Main; padding-left: 0.222em;">2</span><span class="mo" id="MathJax-Span-5227" style="font-family: MathJax_Main; padding-left: 0.222em;">⋅</span><span class="mn" id="MathJax-Span-5228" style="font-family: MathJax_Main; padding-left: 0.222em;">7</span><span class="mo" id="MathJax-Span-5229" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="msubsup" id="MathJax-Span-5230" style="padding-left: 0.278em;"><span style="display: inline-block; position: relative; width: 1.429em; height: 0px;"><span style="position: absolute; clip: rect(3.21em, 1000.96em, 4.185em, -1000em); top: -4.019em; left: 0em;"><span class="mn" id="MathJax-Span-5231" style="font-family: MathJax_Main;">13</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span><span style="position: absolute; top: -4.412em; left: 1em;"><span class="mn" id="MathJax-Span-5232" style="font-size: 70.7%; font-family: MathJax_Main;">2</span><span style="display: inline-block; width: 0px; height: 4.019em;"></span></span></span></span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.171em; border-left: 0px solid; width: 0px; height: 1.375em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mn>151</mn><mo>=</mo><mn>165</mn><mo>−</mo><mn>14</mn><mo>=</mo><mn>3</mn><mo>⋅</mo><mn>5</mn><mo>⋅</mo><mn>11</mn><mo>−</mo><mn>2</mn><mo>⋅</mo><mn>7</mn><mo>&lt;</mo><msup><mn>13</mn><mn>2</mn></msup></math></span></span><script type="math/tex" id="MathJax-Element-382">151=165-14=3 \\cdot 5 \\cdot 11 - 2 \\cdot 7<13^2</script> is the associated difference with the smallest possible <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-383-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5233" style="width: 1.007em; display: inline-block;"><span style="display: inline-block; position: relative; width: 0.766em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.581em, 1000.74em, 2.584em, -1000em); top: -2.44em; left: 0em;"><span class="mrow" id="MathJax-Span-5234"><span class="mi" id="MathJax-Span-5235" style="font-family: MathJax_Math; font-style: italic;">A</span></span><span style="display: inline-block; width: 0px; height: 2.44em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.063em; border-left: 0px solid; width: 0px; height: 1.071em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>A</mi></math></span></span><script type="math/tex" id="MathJax-Element-383">A</script>. </p>
# <p>
# Let <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-384-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5236" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5237"><span class="mi" id="MathJax-Span-5238" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5239" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5240" style="font-family: MathJax_Math; font-style: italic;">n</span><span class="mo" id="MathJax-Span-5241" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mi>n</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-384">S(n)</script> be the sum of <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-385-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5242" style="width: 2.73em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.057em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1001.96em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5243"><span class="mi" id="MathJax-Span-5244" style="font-family: MathJax_Math; font-style: italic; text-rendering: optimizelegibility;">V<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.186em;"></span></span><span class="mo" id="MathJax-Span-5245" style="font-family: MathJax_Main;">(</span><span class="mi" id="MathJax-Span-5246" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5247" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>V</mi><mo stretchy="false">(</mo><mi>p</mi><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-385">V(p)</script> for all primes <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-386-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;p&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5248" style="width: 3.304em; display: inline-block;"><span style="display: inline-block; position: relative; width: 2.488em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.996em, 1002.47em, 3.017em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5249"><span class="mi" id="MathJax-Span-5250" style="font-family: MathJax_Math; font-style: italic;">p</span><span class="mo" id="MathJax-Span-5251" style="font-family: MathJax_Main; padding-left: 0.278em;">&lt;</span><span class="mi" id="MathJax-Span-5252" style="font-family: MathJax_Math; font-style: italic; padding-left: 0.278em;">n</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.319em; border-left: 0px solid; width: 0px; height: 1.095em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>p</mi><mo>&lt;</mo><mi>n</mi></math></span></span><script type="math/tex" id="MathJax-Element-386">p<n</script>. For example, <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-387-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;10&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5253" style="width: 6.127em; display: inline-block;"><span style="display: inline-block; position: relative; width: 4.641em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1004.6em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5254"><span class="mi" id="MathJax-Span-5255" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5256" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5257" style="font-family: MathJax_Main;">10</span><span class="mo" id="MathJax-Span-5258" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5259" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5260" style="font-family: MathJax_Main; padding-left: 0.278em;">10</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>10</mn><mo stretchy="false">)</mo><mo>=</mo><mn>10</mn></math></span></span><script type="math/tex" id="MathJax-Element-387">S(10)=10</script> and <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-388-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;200&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;7177&lt;/mn&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5261" style="width: 8.041em; display: inline-block;"><span style="display: inline-block; position: relative; width: 6.077em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1006.06em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5262"><span class="mi" id="MathJax-Span-5263" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5264" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5265" style="font-family: MathJax_Main;">200</span><span class="mo" id="MathJax-Span-5266" style="font-family: MathJax_Main;">)</span><span class="mo" id="MathJax-Span-5267" style="font-family: MathJax_Main; padding-left: 0.278em;">=</span><span class="mn" id="MathJax-Span-5268" style="font-family: MathJax_Main; padding-left: 0.278em;">7177</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>200</mn><mo stretchy="false">)</mo><mo>=</mo><mn>7177</mn></math></span></span><script type="math/tex" id="MathJax-Element-388">S(200)=7177</script>.</p>
# <p>
# Find <span class="MathJax_Preview" style="color: inherit; display: none;"></span><span class="MathJax" id="MathJax-Element-389-Frame" tabindex="0" style="position: relative;" data-mathml='&lt;math xmlns="http://www.w3.org/1998/Math/MathML"&gt;&lt;mi&gt;S&lt;/mi&gt;&lt;mo stretchy="false"&gt;(&lt;/mo&gt;&lt;mn&gt;3800&lt;/mn&gt;&lt;mo stretchy="false"&gt;)&lt;/mo&gt;&lt;/math&gt;' role="presentation"><nobr aria-hidden="true"><span class="math" id="MathJax-Span-5269" style="width: 4.452em; display: inline-block;"><span style="display: inline-block; position: relative; width: 3.349em; height: 0px; font-size: 132%;"><span style="position: absolute; clip: rect(1.786em, 1003.25em, 3.073em, -1000em); top: -2.679em; left: 0em;"><span class="mrow" id="MathJax-Span-5270"><span class="mi" id="MathJax-Span-5271" style="font-family: MathJax_Math; font-style: italic;">S<span style="display: inline-block; overflow: hidden; height: 1px; width: 0.032em;"></span></span><span class="mo" id="MathJax-Span-5272" style="font-family: MathJax_Main;">(</span><span class="mn" id="MathJax-Span-5273" style="font-family: MathJax_Main;">3800</span><span class="mo" id="MathJax-Span-5274" style="font-family: MathJax_Main;">)</span></span><span style="display: inline-block; width: 0px; height: 2.679em;"></span></span></span><span style="display: inline-block; overflow: hidden; vertical-align: -0.393em; border-left: 0px solid; width: 0px; height: 1.446em;"></span></span></nobr><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mi>S</mi><mo stretchy="false">(</mo><mn>3800</mn><mo stretchy="false">)</mo></math></span></span><script type="math/tex" id="MathJax-Element-389">S(3800)</script>.
# </p>

# %%
submit_answer(answer; prob_num=574);

# %% [markdown]
# ## Problem 575: Wandering Robots
# <p>It
#  was quite an ordinary day when a mysterious alien vessel appeared as if
#  from nowhere. After waiting several hours and receiving no response it
# is decided to send a team to investigate, of which you are included.
# Upon entering the vessel you are met by a friendly holographic figure,
# Katharina, who explains the purpose of the vessel, Eulertopia.</p>
#
# <p>She claims that Eulertopia is almost older than time itself. Its
# mission was to take advantage of a combination of incredible
# computational power and vast periods of time to discover the answer to
# life, the universe, and everything. Hence the resident cleaning robot,
# Leonhard, along with his housekeeping responsibilities, was built with a
#  powerful computational matrix to ponder the meaning of life as he
# wanders through a massive 1000 by 1000 square grid of rooms. She goes on
#  to explain that the rooms are numbered sequentially from left to right,
#  row by row. So, for example, if Leonhard was wandering around a 5 by 5
# grid then the rooms would be numbered in the following way.</p>
#
# <div style="text-align:center;">
# <img src="webfiles/p575_wandering_robot_1_5x5.png" alt="p575_wandering_robot_1_5x5.png"></div>
#
# <p>Many millenia ago Leonhard reported to Katharina to have found the
# answer and he is willing to share it with any life form who proves to be
#  worthy of such knowledge.</p>
#
# <p>Katharina further explains that the designers of Leonhard were given
# instructions to program him with equal probability of remaining in the
# same room or travelling to an adjacent room. However, it was not clear
# to them if this meant (i) an equal probability being split equally
# between remaining in the room and the number of available routes, or,
# (ii) an equal probability (50%) of remaining in the same room and then
# the other 50% was to be split equally between the number of available
# routes.</p>
#
# <div style="text-align:center;">
# <table style="width:100%;"><tbody><tr><td><img src="webfiles/p575_wandering_robot_2_fixed.png" alt="p575_wandering_robot_2_fixed.png"></td>
# <td><img src="webfiles/p575_wandering_robot_3_dynamic.png" alt="p575_wandering_robot_3_dynamic.png"></td>
# </tr><tr style="font-style:italic;"><td>(i) Probability of remaining related to number of exits</td>
# <td>(ii) Fixed 50% probability of remaining</td>
# </tr></tbody></table></div>
#
# <p>The records indicate that they decided to flip a coin. Heads would
# mean that the probability of remaining was dynamically related to the
# number of exits whereas tails would mean that they program Leonhard with
#  a fixed 50% probability of remaining in a particular room.
# Unfortunately there is no record of the outcome of the coin, so without
# further information we would need to assume that there is equal
# probability of either of the choices being implemented.</p>
#
# <p>Katharina suggests it should not be too challenging to determine that
#  the probability of finding him in a square numbered room in a 5 by 5
# grid after unfathomable periods of time would be approximately
# 0.177976190476 [12 d.p.].</p>
#
# <p>In order to prove yourself worthy of visiting the great oracle you
# must calculate the probability of finding him in a square numbered room
# in the 1000 by 1000 lair in which he has been wandering.<br>
# (Give your answer rounded to 12 decimal places)</p>

# %%
submit_answer(answer; prob_num=575);
